# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder ,OrdinalEncoder
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
bikecl  = pd.read_csv("./data/bikecl_with_bikelane_updated_Oct3.csv", sep= ",")
#strt2 = pd.read_csv('./data/street_withlane_Oct5.csv', sep= ",")

# %%
strt2 = pd.read_csv('./data/street_bike_sidewalk_oct6.csv', sep= ",")
len(strt2)
# Out:
# 23495

# %%
strt2['street_index'] = strt2.index

# %%
## accident with positive examples 

positive_example = bikecl.merge(strt2, left_on = ['near_str_index'], right_on = ['street_index'] , how = 'left',
                               indicator = True)

#positive_example.loc[:,['near_str_index','bike_facility','index','EXISTING_FACILITY_TYPE']]

# %%
positive_example.groupby('bike_facility').size()
# Out:
# bike_facility
# In Street, Major Separation     157
# In Street, Minor Separation     820
# Multi-use Trail                  49
# Neighborhood Greenway            24
# NoFacility                     4114
# Sharrow                         543
# dtype: int64

# %%
positive_example.loc[positive_example['accident_year'] < positive_example['bikelane_yr_complete'],'bike_facility'] 
## was already changed to nofacility
# Out:
# 8       NoFacility
# 26      NoFacility
# 32      NoFacility
# 41      NoFacility
# 57      NoFacility
#            ...
# 4669    NoFacility
# 4721    NoFacility
# 4762    NoFacility
# 4846    NoFacility
# 4948    NoFacility
# Name: bike_facility, Length: 616, dtype: object

# %%
str_update = pd.read_csv('./data/str_neigh_zone_speed_oct6.csv')

# %%
str_update.head()
# Out:
#    COMPKEY     CLASS_DESC            CATEGORY_D                 GEN_ALIAS  AREA_ACRES  TOTAL_POPU  HOUSEHOLDS  AWDT_18  AWDT_18_log
# 0     1006       Downtown              Downtown  Downtown Commercial Core       206.5        4260        2530  21000.0     9.952278
# 1     1009       Downtown              Downtown  Downtown Commercial Core       206.5        4260        2530  17800.0     9.786954
# 2     1032   Multi-Family  Lowrise Multi-Family                Queen Anne      1888.4       37283       19354      NaN          NaN
# 3     1051  Single Family         Single Family                Queen Anne      1888.4       37283       19354      NaN          NaN
# 4     1060  Single Family         Single Family                Queen Anne      1888.4       37283       19354      NaN          NaN

# %%
## only keey record that have spatial information. 40 don't ave. 
positive = positive_example.loc[positive_example['COMPKEY_x'].notnull(),:].reset_index(drop = True).copy()

# %%
positive_all = positive.merge(str_update,left_on = 'COMPKEY_x', right_on = 'COMPKEY', how = 'left')

# %%
positive.isnull().sum()
# Out:
# Unnamed: 0                   0
# OBJECTID_x_x                 0
# INCKEY                       0
# COLDETKEY                    0
# REPORTNO                     0
# STATUS_x                     0
# ADDRTYPE                     0
# INTKEY                    2419
# LOCATION                     0
# EXCEPTRSNC                5581
# EXCEPTRSND                5581
# SEVERITYCO                   1
# SEVERITYDE                   0
# COLLISIONT                  17
# PERSONCOUN                   0
# PEDCOUNT                     0
# PEDCYLCOUN                   0
# VEHCOUNT                     0
# INJURIES                     0
# SERIOUSINJ                   0
# FATALITIES                   0
# INCDATE                      0
# INCDTTM                      0
# JUNCTIONTY                  35
# SDOT_COLCO                   0
# SDOT_COLDE                   0
# INATTENTIO                4782
# UNDERINFL                    0
# WEATHER                      6
# ROADCOND                     5
# LIGHTCOND                    7
# PEDROWNOTG                3843
# SDOTCOLNUM                2645
# SPEEDING                  5537
# ST_COLCODE                  17
# ST_COLDESC                  17
# SEGLANEKEY                   0
# CROSSWALKK                   0
# HITPARKEDC                   0
# geometry_x                   0
# near_str_index               0
# min_length                   0
# weather_group              136
# date                         0
# time                         0
# hour                       628
# dayofweek                    0
# weekday                      0
# rushhour                   628
# weather_group2             136
# min_length_cl_to_bike        0
# min_index_cl_to_bike         0
# cl_bike_match                0
# OBJECTID_y_x              3458
# STREET_NAM                3458
# LENGTH_MIL                3458
# STATUS_y                  3902
# COMPKEY                   3458
# CATALYTIC_                3837
# NETWORK_x                 3837
# DATE_COMPL                3530
# EXISTING_F                3458
# PLANNED_FA                4857
# PROJECT_NU                3839
# DATE_PLANN                5667
# DATE_EXPIR                5663
# SHAPE_Leng_x              3458
# geometry_y                3458
# index                     3458
# bike_facility                0
# bikelane_yr_complete      3530
# accident_year                0
# OBJECTID_x_y                 0
# ARTCLASS                     0
# COMPKEY_x                    0
# UNITIDSORT                   0
# UNITDESC_x                   0
# STNAME_ORD                   0
# XSTRLO                       0
# XSTRHI                       0
# ARTDESCRIP                   0
# OWNER                     5522
# STATUS_street               11
# BLOCKNBR                     0
# SPEEDLIMIT                  11
# SEGDIR                       0
# ONEWAY                       0
# ONEWAYDIR                 4923
# FLOW                      4927
# SEGLENGTH                    0
# SURFACEWID                 355
# SURFACETYP                 197
# SURFACET_1                5267
# INTRLO                       0
# DIRLO                        0
# INTKEYLO                     0
# INTRHI                       0
# DIRHI                        0
# NATIONHWYS                   0
# STREETTYPE                 123
# PVMTCONDIN                 482
# PVMTCOND_1                5268
# TRANCLASS                    0
# TRANDESCRI                  28
# SLOPE_PCT                    0
# PVMTCATEGO                   9
# PARKBOULEV                   0
# SHAPE_Leng_y                 0
# geometry                     0
# index_x                     97
# UNITDESC_y                  97
# STR                         97
# Side                        97
# CONDITION                   97
# CURBTYPE                    97
# CURRENT_STATUS              97
# FILLERTYPE                  97
# FILLERWID                   97
# LENUOM                     368
# SW_WIDTH                    97
# MATL                        97
# SURFTYPE                    97
# SWINCOMPLETEYN              97
# MULTIPLESURFACEYN           97
# CURBRAMPHIGH                97
# CURBRAMPMID                 97
# CURBRAMPLOW                 97
# SRTS_SIDEWALK_RANK          97
# PRIMARYCROSSSLOPE           97
# MINIMUMVARIABLEWIDTH        97
# closest_bike_index        2365
# OBJECTID_y_y              2365
# STREET_NAME               2366
# LENGTH_MILES              2365
# STATUS_bike               3004
# COMPKEY_y                 2387
# CATALYTIC_PROJECTS        2899
# NETWORK_y                 2894
# DATE_COMPLETED            2514
# EXISTING_FACILITY_TYPE       0
# PLANNED_FACILITY_TYPE     4394
# PROJECT_NUMBER            2915
# DATE_PLANNED              5667
# DATE_EXPIRED              5655
# SHAPE_Length              2365
# index_y                   2365
# SEGLENGTH_log                0
# SURFACEWID_log             355
# street_index                 0
# _merge                       0
# dtype: int64

# %%
len(positive_all)
# Out:
# 5667

# %%
positive_all.to_csv('./data/bikecl_street_bike_info_oct6_withzone_neighbour.csv', sep = ',',)

# %%
street = strt2.merge(str_update, left_on = 'COMPKEY_x', right_on = 'COMPKEY', how = 'left')

# %%
changedstreet_index = positive.loc[positive['accident_year'] < positive['bikelane_yr_complete'],'near_str_index'].reset_index(drop = True)

# %%
changedstreet_index = changedstreet_index.astype('int')
changedstreet_index = np.unique(changedstreet_index)

# %%
tempstr = street.iloc[changedstreet_index, :].reset_index(drop = True).copy() 
len(tempstr)
# Out:
# 382

# %%
tempstr.groupby(['EXISTING_FACILITY_TYPE']).size()
# Out:
# EXISTING_FACILITY_TYPE
# In Street, Major Separation     82
# In Street, Minor Separation     98
# Multi-use Trail                  6
# Neighborhood Greenway           21
# NoFacility                      47
# Sharrow                        128
# dtype: int64

# %%
tempstr2 = tempstr.loc[tempstr['EXISTING_FACILITY_TYPE'] != 'NoFacility', :].reset_index(drop = True).copy()
len(tempstr2)
# Out:
# 335

# %%
tempstr2.iloc[:,-19]
# Out:
# 0      In Street, Major Separation
# 1      In Street, Minor Separation
# 2      In Street, Minor Separation
# 3      In Street, Minor Separation
# 4                          Sharrow
# 5            Neighborhood Greenway
# 6                          Sharrow
# 7      In Street, Minor Separation
# 8                          Sharrow
# 9                          Sharrow
# 10     In Street, Major Separation
# 11     In Street, Major Separation
# 12           Neighborhood Greenway
# 13     In Street, Minor Separation
# 14                         Sharrow
# 15                         Sharrow
# 16                         Sharrow
# 17                         Sharrow
# 18     In Street, Minor Separation
# 19     In Street, Major Separation
# 20                         Sharrow
# 21     In Street, Minor Separation
# 22                         Sharrow
# 23                         Sharrow
# 24                         Sharrow
# 25                         Sharrow
# 26                         Sharrow
# 27     In Street, Major Separation
# 28                         Sharrow
# 29     In Street, Minor Separation
# 30           Neighborhood Greenway
# 31                         Sharrow
# 32     In Street, Major Separation
# 33                         Sharrow
# 34     In Street, Major Separation
# 35     In Street, Minor Separation
# 36     In Street, Minor Separation
# 37                         Sharrow
# 38                         Sharrow
# 39     In Street, Minor Separation
# 40     In Street, Major Separation
# 41                         Sharrow
# 42                         Sharrow
# 43     In Street, Minor Separation
# 44     In Street, Minor Separation
# 45     In Street, Minor Separation
# 46     In Street, Major Separation
# 47     In Street, Minor Separation
# 48                         Sharrow
# 49     In Street, Minor Separation
# 50                         Sharrow
# 51     In Street, Minor Separation
# 52     In Street, Major Separation
# 53                         Sharrow
# 54     In Street, Major Separation
# 55     In Street, Minor Separation
# 56     In Street, Minor Separation
# 57           Neighborhood Greenway
# 58                         Sharrow
# 59                         Sharrow
# 60                         Sharrow
# 61                 Multi-use Trail
# 62                         Sharrow
# 63                         Sharrow
# 64                         Sharrow
# 65     In Street, Minor Separation
# 66     In Street, Minor Separation
# 67     In Street, Minor Separation
# 68           Neighborhood Greenway
# 69     In Street, Minor Separation
# 70                         Sharrow
# 71     In Street, Major Separation
# 72     In Street, Minor Separation
# 73     In Street, Major Separation
# 74     In Street, Major Separation
# 75     In Street, Major Separation
# 76     In Street, Minor Separation
# 77     In Street, Minor Separation
# 78                         Sharrow
# 79                         Sharrow
# 80                         Sharrow
# 81     In Street, Minor Separation
# 82     In Street, Minor Separation
# 83                         Sharrow
# 84           Neighborhood Greenway
# 85                         Sharrow
# 86                         Sharrow
# 87                         Sharrow
# 88                         Sharrow
# 89                         Sharrow
# 90                         Sharrow
# 91     In Street, Major Separation
# 92                         Sharrow
# 93     In Street, Major Separation
# 94     In Street, Major Separation
# 95     In Street, Minor Separation
# 96     In Street, Minor Separation
# 97     In Street, Minor Separation
# 98     In Street, Minor Separation
# 99     In Street, Major Separation
# 100    In Street, Minor Separation
# 101    In Street, Minor Separation
# 102    In Street, Major Separation
# 103    In Street, Major Separation
# 104    In Street, Minor Separation
# 105    In Street, Minor Separation
# 106    In Street, Minor Separation
# 107    In Street, Major Separation
# 108                        Sharrow
# 109                        Sharrow
# 110    In Street, Minor Separation
# 111                        Sharrow
# 112    In Street, Minor Separation
# 113                        Sharrow
# 114          Neighborhood Greenway
# 115                        Sharrow
# 116          Neighborhood Greenway
# 117                        Sharrow
# 118                        Sharrow
# 119    In Street, Major Separation
# 120    In Street, Minor Separation
# 121                        Sharrow
# 122    In Street, Minor Separation
# 123    In Street, Minor Separation
# 124    In Street, Major Separation
# 125                        Sharrow
# 126                        Sharrow
# 127                        Sharrow
# 128    In Street, Minor Separation
# 129    In Street, Minor Separation
# 130          Neighborhood Greenway
# 131                        Sharrow
# 132    In Street, Major Separation
# 133    In Street, Minor Separation
# 134          Neighborhood Greenway
# 135          Neighborhood Greenway
# 136          Neighborhood Greenway
# 137    In Street, Minor Separation
# 138                        Sharrow
# 139                        Sharrow
# 140                        Sharrow
# 141    In Street, Minor Separation
# 142                Multi-use Trail
# 143                        Sharrow
# 144    In Street, Major Separation
# 145    In Street, Major Separation
# 146                        Sharrow
# 147    In Street, Minor Separation
# 148    In Street, Minor Separation
# 149    In Street, Major Separation
# 150    In Street, Minor Separation
# 151    In Street, Major Separation
# 152                        Sharrow
# 153                        Sharrow
# 154                        Sharrow
# 155                        Sharrow
# 156                        Sharrow
# 157                        Sharrow
# 158                        Sharrow
# 159                        Sharrow
# 160    In Street, Major Separation
# 161    In Street, Major Separation
# 162    In Street, Major Separation
# 163    In Street, Major Separation
# 164    In Street, Major Separation
# 165    In Street, Major Separation
# 166    In Street, Major Separation
# 167    In Street, Minor Separation
# 168                        Sharrow
# 169                        Sharrow
# 170                        Sharrow
# 171                        Sharrow
# 172                        Sharrow
# 173    In Street, Minor Separation
# 174                        Sharrow
# 175                        Sharrow
# 176                        Sharrow
# 177    In Street, Minor Separation
# 178    In Street, Minor Separation
# 179    In Street, Major Separation
# 180          Neighborhood Greenway
# 181    In Street, Major Separation
# 182    In Street, Major Separation
# 183                        Sharrow
# 184                Multi-use Trail
# 185                        Sharrow
# 186          Neighborhood Greenway
# 187    In Street, Major Separation
# 188                        Sharrow
# 189                Multi-use Trail
# 190    In Street, Minor Separation
# 191    In Street, Major Separation
# 192                        Sharrow
# 193    In Street, Minor Separation
# 194    In Street, Minor Separation
# 195                        Sharrow
# 196                        Sharrow
# 197                        Sharrow
# 198    In Street, Minor Separation
# 199                        Sharrow
# 200    In Street, Minor Separation
# 201    In Street, Major Separation
# 202    In Street, Major Separation
# 203                        Sharrow
# 204    In Street, Minor Separation
# 205                        Sharrow
# 206                Multi-use Trail
# 207    In Street, Minor Separation
# 208    In Street, Minor Separation
# 209                        Sharrow
# 210          Neighborhood Greenway
# 211    In Street, Major Separation
# 212                        Sharrow
# 213                        Sharrow
# 214          Neighborhood Greenway
# 215          Neighborhood Greenway
# 216    In Street, Minor Separation
# 217    In Street, Major Separation
# 218    In Street, Minor Separation
# 219    In Street, Minor Separation
# 220    In Street, Minor Separation
# 221          Neighborhood Greenway
# 222                        Sharrow
# 223    In Street, Major Separation
# 224    In Street, Minor Separation
# 225    In Street, Minor Separation
# 226    In Street, Major Separation
# 227    In Street, Minor Separation
# 228                        Sharrow
# 229    In Street, Major Separation
# 230    In Street, Major Separation
# 231                        Sharrow
# 232                        Sharrow
# 233    In Street, Minor Separation
# 234                        Sharrow
# 235                        Sharrow
# 236    In Street, Minor Separation
# 237    In Street, Minor Separation
# 238    In Street, Major Separation
# 239          Neighborhood Greenway
# 240    In Street, Major Separation
# 241    In Street, Major Separation
# 242                Multi-use Trail
# 243    In Street, Major Separation
# 244                        Sharrow
# 245    In Street, Major Separation
# 246    In Street, Major Separation
# 247    In Street, Major Separation
# 248                        Sharrow
# 249    In Street, Major Separation
# 250                        Sharrow
# 251    In Street, Major Separation
# 252                        Sharrow
# 253    In Street, Minor Separation
# 254                        Sharrow
# 255                        Sharrow
# 256    In Street, Major Separation
# 257    In Street, Major Separation
# 258    In Street, Major Separation
# 259                        Sharrow
# 260    In Street, Major Separation
# 261                        Sharrow
# 262                        Sharrow
# 263                        Sharrow
# 264    In Street, Major Separation
# 265    In Street, Major Separation
# 266    In Street, Minor Separation
# 267    In Street, Minor Separation
# 268                        Sharrow
# 269    In Street, Minor Separation
# 270    In Street, Major Separation
# 271                        Sharrow
# 272    In Street, Major Separation
# 273                        Sharrow
# 274    In Street, Major Separation
# 275                        Sharrow
# 276                        Sharrow
# 277                        Sharrow
# 278    In Street, Major Separation
# 279    In Street, Minor Separation
# 280    In Street, Major Separation
# 281                        Sharrow
# 282    In Street, Major Separation
# 283                        Sharrow
# 284          Neighborhood Greenway
# 285                        Sharrow
# 286    In Street, Major Separation
# 287                        Sharrow
# 288    In Street, Minor Separation
# 289                        Sharrow
# 290    In Street, Minor Separation
# 291                        Sharrow
# 292    In Street, Major Separation
# 293                        Sharrow
# 294    In Street, Minor Separation
# 295    In Street, Major Separation
# 296                        Sharrow
# 297                        Sharrow
# 298    In Street, Major Separation
# 299    In Street, Major Separation
# 300    In Street, Minor Separation
# 301                        Sharrow
# 302    In Street, Major Separation
# 303    In Street, Minor Separation
# 304                        Sharrow
# 305    In Street, Minor Separation
# 306    In Street, Minor Separation
# 307    In Street, Minor Separation
# 308          Neighborhood Greenway
# 309                        Sharrow
# 310                        Sharrow
# 311                        Sharrow
# 312    In Street, Minor Separation
# 313    In Street, Major Separation
# 314    In Street, Minor Separation
# 315    In Street, Major Separation
# 316                        Sharrow
# 317    In Street, Minor Separation
# 318    In Street, Major Separation
# 319    In Street, Major Separation
# 320    In Street, Minor Separation
# 321                        Sharrow
# 322                        Sharrow
# 323    In Street, Minor Separation
# 324    In Street, Minor Separation
# 325    In Street, Minor Separation
# 326    In Street, Minor Separation
# 327    In Street, Minor Separation
# 328                        Sharrow
# 329    In Street, Major Separation
# 330    In Street, Major Separation
# 331    In Street, Minor Separation
# 332    In Street, Minor Separation
# 333    In Street, Minor Separation
# 334    In Street, Minor Separation
# Name: EXISTING_FACILITY_TYPE, dtype: object

# %%
for i in np.arange(0,len(tempstr2)):
    tempstr2.iloc[i,-19] = 'NoFacility'

# %%
street_new = pd.concat([street, tempstr2],ignore_index = True)

# %%
street_new.isnull().sum()
# Out:
# OBJECTID_x                    0
# ARTCLASS                      0
# COMPKEY_x                     0
# UNITIDSORT                    0
# UNITDESC_x                    0
# STNAME_ORD                    0
# XSTRLO                        0
# XSTRHI                        0
# ARTDESCRIP                    0
# OWNER                     23379
# STATUS_street                44
# BLOCKNBR                      0
# SPEEDLIMIT                   28
# SEGDIR                        1
# ONEWAY                        4
# ONEWAYDIR                 22452
# FLOW                      22454
# SEGLENGTH                     0
# SURFACEWID                 3357
# SURFACETYP                  896
# SURFACET_1                23135
# INTRLO                        2
# DIRLO                         1
# INTKEYLO                      2
# INTRHI                        3
# DIRHI                         1
# NATIONHWYS                    0
# STREETTYPE                  476
# PVMTCONDIN                 4042
# PVMTCOND_1                23135
# TRANCLASS                     0
# TRANDESCRI                  170
# SLOPE_PCT                     7
# PVMTCATEGO                   60
# PARKBOULEV                    0
# SHAPE_Leng                    0
# geometry                      0
# index_x                     587
# UNITDESC_y                  587
# STR                         587
# Side                        587
# CONDITION                   587
# CURBTYPE                    587
# CURRENT_STATUS              587
# FILLERTYPE                  587
# FILLERWID                   587
# LENUOM                     1171
# SW_WIDTH                    587
# MATL                        587
# SURFTYPE                    587
# SWINCOMPLETEYN              587
# MULTIPLESURFACEYN           587
# CURBRAMPHIGH                587
# CURBRAMPMID                 587
# CURBRAMPLOW                 587
# SRTS_SIDEWALK_RANK          587
# PRIMARYCROSSSLOPE           587
# MINIMUMVARIABLEWIDTH        587
# closest_bike_index        18556
# OBJECTID_y                18556
# STREET_NAME               18557
# LENGTH_MILES              18556
# STATUS_bike               19540
# COMPKEY_y                 18605
# CATALYTIC_PROJECTS        19461
# NETWORK                   19452
# DATE_COMPLETED            18812
# EXISTING_FACILITY_TYPE        0
# PLANNED_FACILITY_TYPE     21812
# PROJECT_NUMBER            19534
# DATE_PLANNED              23830
# DATE_EXPIRED              23824
# SHAPE_Length              18556
# index_y                   18556
# SEGLENGTH_log                 0
# SURFACEWID_log             3357
# street_index                  0
# COMPKEY                       0
# CLASS_DESC                    0
# CATEGORY_D                    0
# GEN_ALIAS                     0
# AREA_ACRES                    0
# TOTAL_POPU                    0
# HOUSEHOLDS                    0
# AWDT_18                   17338
# AWDT_18_log               17338
# dtype: int64

# %%
street_new.to_csv('./data/street_allinfor_Oct6.csv', sep = ',')

# %%
positive.loc[:,['bike_facility' ,'EXISTING_FACILITY_TYPE']]
# Out:
#                     bike_facility       EXISTING_FACILITY_TYPE
# 0                      NoFacility                   NoFacility
# 1                      NoFacility  In Street, Major Separation
# 2                      NoFacility  In Street, Minor Separation
# 3                      NoFacility                   NoFacility
# 4                      NoFacility                   NoFacility
# ...                           ...                          ...
# 5662  In Street, Minor Separation  In Street, Minor Separation
# 5663                   NoFacility  In Street, Minor Separation
# 5664                      Sharrow                      Sharrow
# 5665                   NoFacility  In Street, Minor Separation
# 5666                   NoFacility                   NoFacility
#
# [5667 rows x 2 columns]

# %%
positive = positive_all.drop(columns = ['EXISTING_FACILITY_TYPE'])

# %%
'EXISTING_FACILITY_TYPE' in positive.columns
# Out:
# True

# %%
positive = positive.rename(columns = {'bike_facility' : 'EXISTING_FACILITY_TYPE',
                                   'rushhour': 'simulate_rushhour',
                                    'weather_group2': 'simulate_weather',
                                   'weekday': 'simulate_weekday'
                                  })
#positive_example.columns

# %%
#positive_example.isnull().sum()

# %%
## increase street size to 2x to include rushhour, weekday, weather x2, x2,x2 
n = len(strt2) * 8 
#hour_list = pd.Series(np.arange(0,))
#type(hour_list)
#test = pd.concat([hour_list]*len(strt2), ignore_index = True) 

import random
#random.seed(9001)

simulate_street = pd.concat([street_new]*8, ignore_index = True)  

simulate_weather = np.random.choice(a=['Clear or Partly Cloudy', 'Raining'],  size= len(street_new)*8,  p=[0.58, 0.42], replace = True ) 
simulate_weekday = np.random.choice(a=[1,0],  size= len(street_new)*8,  p=[0.7, 0.3], replace = True ) 
simulate_rushhour = np.random.choice(a=[1,0],  size= len(street_new)*8,  p=[0.5, 0.5], replace = True ) 
simulate_street['simulate_weekday'] = simulate_weekday 
simulate_street['simulate_rushhour'] = simulate_rushhour 
simulate_street['simulate_weather'] = simulate_weather

# %%
#positive.loc[:,['LENGTH_MILES','bike_facility']]
positive.loc[positive.loc[:, 'EXISTING_FACILITY_TYPE'] == 'NoFacility',['LENGTH_MILES']] = 0

# %%
#n = 24 * len(strt2)
#temp = (np.zeros(int(n*0.5))).tolist() + (np.ones(n- int(n*0.5))).tolist()
#simulate_street = pd.concat([strt2]*24, ignore_index = True)  
#simulate_street['simulate_rushhour'] = temp

# %%
positive.drop(columns = ['_merge'], inplace = True)

# %%
positive.head()
# Out:
#    Unnamed: 0  OBJECTID_x_x  INCKEY  COLDETKEY REPORTNO STATUS_x      ADDRTYPE   INTKEY                                           LOCATION EXCEPTRSNC EXCEPTRSND SEVERITYCO        SEVERITYDE COLLISIONT  PERSONCOUN  PEDCOUNT  PEDCYLCOUN  VEHCOUNT  INJURIES  SERIOUSINJ  FATALITIES                   INCDATE        INCDTTM                              JUNCTIONTY  SDOT_COLCO                                         SDOT_COLDE INATTENTIO UNDERINFL                 WEATHER ROADCOND                LIGHTCOND PEDROWNOTG  SDOTCOLNUM SPEEDING  ST_COLCODE              ST_COLDESC  SEGLANEKEY  CROSSWALKK HITPARKEDC                                   geometry_x  near_str_index  min_length           weather_group     date      time  hour  dayofweek  simulate_weekday  simulate_rushhour        simulate_weather  min_length_cl_to_bike  min_index_cl_to_bike  cl_bike_match  OBJECTID_y_x STREET_NAM  LENGTH_MIL STATUS_y  COMPKEY_x  CATALYTIC_ NETWORK_x DATE_COMPL EXISTING_F PLANNED_FA  PROJECT_NU  DATE_PLANN  \
# 0           0          1015   63600      63600  2188744  Matched  Intersection  35587.0                         1ST AVE NW AND NW 143RD ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2006-05-16T00:00:00.000Z   5/16/06 6:30  At Intersection (intersection related)          51  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   6136002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1265176.677676335 270845.8969054073)          2284.0    0.000000  Clear or Partly Cloudy  5/16/06   6:30:00   6.0          1                 1                0.0  Clear or Partly Cloudy            2576.622861                1800.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 1           1          1031   76900      76900  2620912  Matched  Intersection  29072.0                           BROADWAY AND E HOWELL ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-02-27T00:00:00.000Z  2/27/07 10:40  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight          Y   7058004.0      NaN        45.0  Vehicle - Pedalcyclist        6828           0          N  POINT (1273573.179700941 228816.6565423608)         11910.0    0.000000  Clear or Partly Cloudy  2/27/07  10:40:00  10.0          1                 1                0.0  Clear or Partly Cloudy               0.000102                2722.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 2           2          1105   66700      66700  2806857  Matched  Intersection  38204.0                       68TH AVE S AND RAINIER AVE S        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-06-02T00:00:00.000Z         6/2/07  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   7153002.0      NaN        45.0  Vehicle - Pedalcyclist        5012           0          N  POINT (1290743.220806524 189838.2621344477)          3727.0    0.000000  Clear or Partly Cloudy   6/2/07   0:00:00   NaN          5                 0                NaN  Clear or Partly Cloudy               0.000119                2588.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 3           3          1219   82300      82300  2894257  Matched         Block      NaN  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2008-08-05T00:00:00.000Z         8/5/08    Mid-Block (but intersection related)          21        MOTOR VEHICLE STRUCK PEDALCYCLIST, REAR END        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   8218038.0      NaN        45.0  Vehicle - Pedalcyclist       20579           0          N  POINT (1271403.979314715 201517.6661784053)         15724.0    0.000004  Clear or Partly Cloudy   8/5/08   0:00:00   NaN          1                 1                NaN  Clear or Partly Cloudy            1079.141473                1129.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 4           4          1320  124600     124600  3562409  Matched  Intersection  26818.0                WOODLAND PARK AVE N AND N 43RD N ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2011-12-07T00:00:00.000Z  12/7/11 21:57  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         N  Clear or Partly Cloudy      Dry  Dark - Street Lights On          Y  11341002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1268019.223855242 244249.3618381619)          3839.0    0.000000  Clear or Partly Cloudy  12/7/11  21:57:00  21.0          2                 1                0.0  Clear or Partly Cloudy             576.991064                2618.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
#
#   DATE_EXPIR  SHAPE_Leng_x geometry_y  index EXISTING_FACILITY_TYPE  bikelane_yr_complete  accident_year  OBJECTID_x_y  ARTCLASS  COMPKEY_x   UNITIDSORT                                         UNITDESC_x           STNAME_ORD         XSTRLO         XSTRHI          ARTDESCRIP OWNER STATUS_street  BLOCKNBR  SPEEDLIMIT SEGDIR ONEWAY ONEWAYDIR FLOW  SEGLENGTH  SURFACEWID SURFACETYP SURFACET_1                               INTRLO DIRLO  INTKEYLO                                 INTRHI DIRHI NATIONHWYS                         STREETTYPE  PVMTCONDIN  PVMTCOND_1  TRANCLASS           TRANDESCRI  SLOPE_PCT PVMTCATEGO PARKBOULEV  SHAPE_Leng_y                                           geometry  index_x                                         UNITDESC_y                                                STR                                               Side  CONDITION CURBTYPE CURRENT_STATUS FILLERTYPE  FILLERWID LENUOM  SW_WIDTH MATL SURFTYPE SWINCOMPLETEYN MULTIPLESURFACEYN CURBRAMPHIGH CURBRAMPMID  \
# 0        NaN           NaN        NaN    NaN             NoFacility                   NaN           2006        2322.0       0.0     1182.0     251400.0     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST           1ST AVE NW    NW 140TH ST    NW 143RD ST      Not Designated   NaN         INSVC   14000.0        20.0      N      N       NaN  NaN      662.0        22.0         ST        NaN           1ST AVE NW AND NW 140TH ST     N   35593.0             1ST AVE NW AND NW 143RD ST     S          N          Neighborhood Yield Street        71.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    661.927005  LINESTRING (1265163.643180326 270184.098248720...   3268.0  1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST...     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST   E SIDE                                       ...                NONE          INSVC       NONE        0.0   Feet       0.0        UIMPRV              N                 N            U           U
# 1        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007       12063.0       2.0     9449.0   57350170.0     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST             BROADWAY  XW E OLIVE ST    E HOWELL ST      Minor Arterial   NaN         INSVC    1700.0        25.0      N      N       NaN  NaN      426.0        52.0     AC/PCC        NaN           BROADWAY AND XW E OLIVE ST     N   29731.0               BROADWAY AND E HOWELL ST     S          N         Urban Village Neighborhood        45.0         NaN        2.0  MAJOR TRANSIT ROUTE        2.0        ART          N    426.060321  LINESTRING (1273569.558068931 228390.611613929...  16992.0  BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST...     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST   E SIDE                                       ...  EXCELLENT     410C          INSVC     TR/PCC       72.0   Feet      72.0           PCC              N                 N            Y           U
# 2        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007        3767.0       1.0    12437.0   93451000.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...        RAINIER AVE S     68TH AVE S  CORNELL AVE S  Principal Arterial   NaN         INSVC   10000.0        30.0     SE      N       NaN  NaN      394.0        59.0     AC/PCC        NaN         68TH AVE S AND RAINIER AVE S    SE   38204.0        CORNELL AVE S AND RAINIER AVE S    NW          Y             Urban Center Connector        64.0         NaN        2.0  MAJOR TRANSIT ROUTE        1.0        ART          N    503.128891  LINESTRING (1290743.220806524 189838.262134447...  34076.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...   NE SIDE                                      ...       GOOD     410C          INSVC       LSCP       24.0   Feet      72.0           PCC              N                 N            U           U
# 3        NaN           NaN        NaN    NaN             NoFacility                   NaN           2008       15925.0       1.0    14410.0  113000670.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S     S RIVER ST  S BRIGHTON ST  Principal Arterial   NaN         INSVC    6700.0        35.0     SE      N       NaN  NaN     1213.0        58.0     AC/PCC        NaN   EAST MARGINAL WAY S AND S RIVER ST    SE   34237.0  EAST MARGINAL WAY S AND S BRIGHTON ST    NW          Y                  Industrial Access        74.0         NaN        2.0  MAJOR TRANSIT ROUTE        0.0        ART          N   1212.724715  LINESTRING (1270954.337586254 201924.479874819...  20805.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...   NE SIDE                                      ...       FAIR     410A          INSVC         AC       16.0   Feet      44.0           PCC              N                 N            U           U
# 4        NaN           NaN        NaN    NaN             NoFacility                   NaN           2011        3879.0       0.0    13659.0  105900435.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N    N 43RD N ST      N 44TH ST      Not Designated   NaN         INSVC    4300.0        20.0      N      N       NaN  NaN      140.0        44.0         AC        NaN  WOODLAND PARK AVE N AND N 43RD N ST     N   26818.0      WOODLAND PARK AVE N AND N 44TH ST     S          N  Urban Village Neighborhood Access        36.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    139.999584  LINESTRING (1268019.223855242 244249.361838161...  46018.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...   E SIDE                                       ...       GOOD       AR          INSVC       LSCP       28.0   Feet      72.0           PCC              N                 N            Y           U
#
#   CURBRAMPLOW  SRTS_SIDEWALK_RANK  PRIMARYCROSSSLOPE  MINIMUMVARIABLEWIDTH  closest_bike_index  OBJECTID_y_y    STREET_NAME  LENGTH_MILES STATUS_bike  COMPKEY_y  CATALYTIC_PROJECTS NETWORK_y            DATE_COMPLETED PLANNED_FACILITY_TYPE  PROJECT_NUMBER  DATE_PLANNED DATE_EXPIRED  SHAPE_Length  index_y  SEGLENGTH_log  SURFACEWID_log  street_index  COMPKEY_y                CLASS_DESC               CATEGORY_D              GEN_ALIAS  AREA_ACRES  TOTAL_POPU  HOUSEHOLDS  AWDT_18  AWDT_18_log
# 0           U                 2.0                0.0                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       6.495266        3.091042        2284.0       1182             Single Family            Single Family  Broadview/Bitter Lake      1478.5       13725        6790      NaN          NaN
# 1           Y                 3.0                1.6                   0.0              2722.0       79314.0       BROADWAY           0.0       Meets     9449.0                 0.0  CITYWIDE  2008-12-31T00:00:00.000Z                   NaN             0.0           NaN          NaN    426.060473   2722.0       6.054439        3.951244       11910.0       9449        Major Institutions       Major Institutions           Capitol Hill       426.5       20952       14041  14600.0     9.588777
# 2           U                 3.0                1.0                   0.0              1736.0       78324.0  RAINIER AVE S           0.0       Meets    12437.0                 0.0  CITYWIDE  2015-12-31T00:00:00.000Z                   NaN           690.0           NaN          NaN    393.887547   1736.0       5.976351        4.077537        3727.0      12437      Commercial/Mixed Use  Neighborhood Commercial          Rainier Beach      1363.1       15336        5395  19000.0     9.852194
# 3           U                 3.0                2.1                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       7.100852        4.060443       15724.0      14410  Manufacturing/Industrial               Industrial             Georgetown      1183.9        1131         621  20300.0     9.918376
# 4           U                 1.0                2.7                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       4.941642        3.784190        3839.0      13659              Multi-Family     Lowrise Multi-Family            Wallingford       810.5       17016        7327      NaN          NaN

# %%
simulate_street.groupby('GEN_ALIAS').size()
# Out:
# GEN_ALIAS
# Alki/Admiral                              3360
# Arbor Heights                             2008
# Ballard                                   2024
# Beacon Hill                               3208
# Belltown                                  1072
# Broadview/Bitter Lake                     3232
# Capitol Hill                              2592
# Cascade/Eastlake                          3624
# Cedar Park/Meadowbrook                    2688
# Central Area/Squire Park                  4024
# Columbia City                             5296
# Downtown Commercial Core                  1576
# Duwamish/SODO                             4552
# Fauntleroy/Seaview                        4400
# First Hill                                2160
# Fremont                                   5336
# Georgetown                                2160
# Green Lake                                4584
# Greenwood/Phinney Ridge                   6208
# Haller Lake                               2576
# High Point                                1016
# Highland Park                             1496
# Interbay                                  2880
# Judkins Park                               752
# Laurelhurst/Sand Point                    3064
# Licton Springs                            1632
# Madison Park                              1448
# Madrona/Leschi                            4128
# Magnolia                                  5200
# Miller Park                               1504
# Montlake/Portage Bay                      2736
# Mt. Baker/North Rainier                   2896
# North Beach/Blue Ridge                    3792
# North Beacon Hill/Jefferson Park          5304
# North Capitol Hill                         896
# North Delridge                            2464
# Northgate/Maple Leaf                      2736
# Olympic Hills/Victory Heights             3744
# Pioneer Square/International District      928
# Queen Anne                               30016
# Rainier Beach                             4056
# Ravenna/Bryant                            5984
# Riverview                                  888
# Roxhill/Westwood                          2856
# Seward Park                               2784
# South Beacon Hill/NewHolly                4616
# South Park                                1928
# Sunset Hill/Loyal Heights                 3504
# University District                       2536
# Wallingford                               4344
# Wedgwood/View Ridge                       4424
# West Seattle Junction/Genesee Hill        4880
# Whittier Heights                          2528
# dtype: int64

# %%
simulate_street = simulate_street.rename(columns = {'LENGTH_MILES' : 'LENGTH_MIL'})

# %%
positive.head()
# Out:
#    Unnamed: 0  OBJECTID_x_x  INCKEY  COLDETKEY REPORTNO STATUS_x      ADDRTYPE   INTKEY                                           LOCATION EXCEPTRSNC EXCEPTRSND SEVERITYCO        SEVERITYDE COLLISIONT  PERSONCOUN  PEDCOUNT  PEDCYLCOUN  VEHCOUNT  INJURIES  SERIOUSINJ  FATALITIES                   INCDATE        INCDTTM                              JUNCTIONTY  SDOT_COLCO                                         SDOT_COLDE INATTENTIO UNDERINFL                 WEATHER ROADCOND                LIGHTCOND PEDROWNOTG  SDOTCOLNUM SPEEDING  ST_COLCODE              ST_COLDESC  SEGLANEKEY  CROSSWALKK HITPARKEDC                                   geometry_x  near_str_index  min_length           weather_group     date      time  hour  dayofweek  simulate_weekday  simulate_rushhour        simulate_weather  min_length_cl_to_bike  min_index_cl_to_bike  cl_bike_match  OBJECTID_y_x STREET_NAM  LENGTH_MIL STATUS_y  COMPKEY_x  CATALYTIC_ NETWORK_x DATE_COMPL EXISTING_F PLANNED_FA  PROJECT_NU  DATE_PLANN  \
# 0           0          1015   63600      63600  2188744  Matched  Intersection  35587.0                         1ST AVE NW AND NW 143RD ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2006-05-16T00:00:00.000Z   5/16/06 6:30  At Intersection (intersection related)          51  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   6136002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1265176.677676335 270845.8969054073)          2284.0    0.000000  Clear or Partly Cloudy  5/16/06   6:30:00   6.0          1                 1                0.0  Clear or Partly Cloudy            2576.622861                1800.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 1           1          1031   76900      76900  2620912  Matched  Intersection  29072.0                           BROADWAY AND E HOWELL ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-02-27T00:00:00.000Z  2/27/07 10:40  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight          Y   7058004.0      NaN        45.0  Vehicle - Pedalcyclist        6828           0          N  POINT (1273573.179700941 228816.6565423608)         11910.0    0.000000  Clear or Partly Cloudy  2/27/07  10:40:00  10.0          1                 1                0.0  Clear or Partly Cloudy               0.000102                2722.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 2           2          1105   66700      66700  2806857  Matched  Intersection  38204.0                       68TH AVE S AND RAINIER AVE S        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-06-02T00:00:00.000Z         6/2/07  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   7153002.0      NaN        45.0  Vehicle - Pedalcyclist        5012           0          N  POINT (1290743.220806524 189838.2621344477)          3727.0    0.000000  Clear or Partly Cloudy   6/2/07   0:00:00   NaN          5                 0                NaN  Clear or Partly Cloudy               0.000119                2588.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 3           3          1219   82300      82300  2894257  Matched         Block      NaN  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2008-08-05T00:00:00.000Z         8/5/08    Mid-Block (but intersection related)          21        MOTOR VEHICLE STRUCK PEDALCYCLIST, REAR END        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   8218038.0      NaN        45.0  Vehicle - Pedalcyclist       20579           0          N  POINT (1271403.979314715 201517.6661784053)         15724.0    0.000004  Clear or Partly Cloudy   8/5/08   0:00:00   NaN          1                 1                NaN  Clear or Partly Cloudy            1079.141473                1129.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 4           4          1320  124600     124600  3562409  Matched  Intersection  26818.0                WOODLAND PARK AVE N AND N 43RD N ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2011-12-07T00:00:00.000Z  12/7/11 21:57  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         N  Clear or Partly Cloudy      Dry  Dark - Street Lights On          Y  11341002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1268019.223855242 244249.3618381619)          3839.0    0.000000  Clear or Partly Cloudy  12/7/11  21:57:00  21.0          2                 1                0.0  Clear or Partly Cloudy             576.991064                2618.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
#
#   DATE_EXPIR  SHAPE_Leng_x geometry_y  index EXISTING_FACILITY_TYPE  bikelane_yr_complete  accident_year  OBJECTID_x_y  ARTCLASS  COMPKEY_x   UNITIDSORT                                         UNITDESC_x           STNAME_ORD         XSTRLO         XSTRHI          ARTDESCRIP OWNER STATUS_street  BLOCKNBR  SPEEDLIMIT SEGDIR ONEWAY ONEWAYDIR FLOW  SEGLENGTH  SURFACEWID SURFACETYP SURFACET_1                               INTRLO DIRLO  INTKEYLO                                 INTRHI DIRHI NATIONHWYS                         STREETTYPE  PVMTCONDIN  PVMTCOND_1  TRANCLASS           TRANDESCRI  SLOPE_PCT PVMTCATEGO PARKBOULEV  SHAPE_Leng_y                                           geometry  index_x                                         UNITDESC_y                                                STR                                               Side  CONDITION CURBTYPE CURRENT_STATUS FILLERTYPE  FILLERWID LENUOM  SW_WIDTH MATL SURFTYPE SWINCOMPLETEYN MULTIPLESURFACEYN CURBRAMPHIGH CURBRAMPMID  \
# 0        NaN           NaN        NaN    NaN             NoFacility                   NaN           2006        2322.0       0.0     1182.0     251400.0     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST           1ST AVE NW    NW 140TH ST    NW 143RD ST      Not Designated   NaN         INSVC   14000.0        20.0      N      N       NaN  NaN      662.0        22.0         ST        NaN           1ST AVE NW AND NW 140TH ST     N   35593.0             1ST AVE NW AND NW 143RD ST     S          N          Neighborhood Yield Street        71.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    661.927005  LINESTRING (1265163.643180326 270184.098248720...   3268.0  1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST...     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST   E SIDE                                       ...                NONE          INSVC       NONE        0.0   Feet       0.0        UIMPRV              N                 N            U           U
# 1        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007       12063.0       2.0     9449.0   57350170.0     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST             BROADWAY  XW E OLIVE ST    E HOWELL ST      Minor Arterial   NaN         INSVC    1700.0        25.0      N      N       NaN  NaN      426.0        52.0     AC/PCC        NaN           BROADWAY AND XW E OLIVE ST     N   29731.0               BROADWAY AND E HOWELL ST     S          N         Urban Village Neighborhood        45.0         NaN        2.0  MAJOR TRANSIT ROUTE        2.0        ART          N    426.060321  LINESTRING (1273569.558068931 228390.611613929...  16992.0  BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST...     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST   E SIDE                                       ...  EXCELLENT     410C          INSVC     TR/PCC       72.0   Feet      72.0           PCC              N                 N            Y           U
# 2        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007        3767.0       1.0    12437.0   93451000.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...        RAINIER AVE S     68TH AVE S  CORNELL AVE S  Principal Arterial   NaN         INSVC   10000.0        30.0     SE      N       NaN  NaN      394.0        59.0     AC/PCC        NaN         68TH AVE S AND RAINIER AVE S    SE   38204.0        CORNELL AVE S AND RAINIER AVE S    NW          Y             Urban Center Connector        64.0         NaN        2.0  MAJOR TRANSIT ROUTE        1.0        ART          N    503.128891  LINESTRING (1290743.220806524 189838.262134447...  34076.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...   NE SIDE                                      ...       GOOD     410C          INSVC       LSCP       24.0   Feet      72.0           PCC              N                 N            U           U
# 3        NaN           NaN        NaN    NaN             NoFacility                   NaN           2008       15925.0       1.0    14410.0  113000670.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S     S RIVER ST  S BRIGHTON ST  Principal Arterial   NaN         INSVC    6700.0        35.0     SE      N       NaN  NaN     1213.0        58.0     AC/PCC        NaN   EAST MARGINAL WAY S AND S RIVER ST    SE   34237.0  EAST MARGINAL WAY S AND S BRIGHTON ST    NW          Y                  Industrial Access        74.0         NaN        2.0  MAJOR TRANSIT ROUTE        0.0        ART          N   1212.724715  LINESTRING (1270954.337586254 201924.479874819...  20805.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...   NE SIDE                                      ...       FAIR     410A          INSVC         AC       16.0   Feet      44.0           PCC              N                 N            U           U
# 4        NaN           NaN        NaN    NaN             NoFacility                   NaN           2011        3879.0       0.0    13659.0  105900435.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N    N 43RD N ST      N 44TH ST      Not Designated   NaN         INSVC    4300.0        20.0      N      N       NaN  NaN      140.0        44.0         AC        NaN  WOODLAND PARK AVE N AND N 43RD N ST     N   26818.0      WOODLAND PARK AVE N AND N 44TH ST     S          N  Urban Village Neighborhood Access        36.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    139.999584  LINESTRING (1268019.223855242 244249.361838161...  46018.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...   E SIDE                                       ...       GOOD       AR          INSVC       LSCP       28.0   Feet      72.0           PCC              N                 N            Y           U
#
#   CURBRAMPLOW  SRTS_SIDEWALK_RANK  PRIMARYCROSSSLOPE  MINIMUMVARIABLEWIDTH  closest_bike_index  OBJECTID_y_y    STREET_NAME  LENGTH_MILES STATUS_bike  COMPKEY_y  CATALYTIC_PROJECTS NETWORK_y            DATE_COMPLETED PLANNED_FACILITY_TYPE  PROJECT_NUMBER  DATE_PLANNED DATE_EXPIRED  SHAPE_Length  index_y  SEGLENGTH_log  SURFACEWID_log  street_index  COMPKEY_y                CLASS_DESC               CATEGORY_D              GEN_ALIAS  AREA_ACRES  TOTAL_POPU  HOUSEHOLDS  AWDT_18  AWDT_18_log
# 0           U                 2.0                0.0                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       6.495266        3.091042        2284.0       1182             Single Family            Single Family  Broadview/Bitter Lake      1478.5       13725        6790      NaN          NaN
# 1           Y                 3.0                1.6                   0.0              2722.0       79314.0       BROADWAY           0.0       Meets     9449.0                 0.0  CITYWIDE  2008-12-31T00:00:00.000Z                   NaN             0.0           NaN          NaN    426.060473   2722.0       6.054439        3.951244       11910.0       9449        Major Institutions       Major Institutions           Capitol Hill       426.5       20952       14041  14600.0     9.588777
# 2           U                 3.0                1.0                   0.0              1736.0       78324.0  RAINIER AVE S           0.0       Meets    12437.0                 0.0  CITYWIDE  2015-12-31T00:00:00.000Z                   NaN           690.0           NaN          NaN    393.887547   1736.0       5.976351        4.077537        3727.0      12437      Commercial/Mixed Use  Neighborhood Commercial          Rainier Beach      1363.1       15336        5395  19000.0     9.852194
# 3           U                 3.0                2.1                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       7.100852        4.060443       15724.0      14410  Manufacturing/Industrial               Industrial             Georgetown      1183.9        1131         621  20300.0     9.918376
# 4           U                 1.0                2.7                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       4.941642        3.784190        3839.0      13659              Multi-Family     Lowrise Multi-Family            Wallingford       810.5       17016        7327      NaN          NaN

# %%
#full['acc'] = [ 1 if i == 'both' else 0 for i in full['_merge']]

# %%
numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1','SLOPE_PCT' ,
                    'SW_WIDTH' ,'FILLERWID','MINIMUMVARIABLEWIDTH', 'PRIMARYCROSSSLOPE', 'LENGTH_MIL']
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['SPEEDLIMIT','SEGDIR', 'STREETTYPE','ONEWAY', 'SURFACETYP','PVMTCATEGO',  
'CONDITION', 'SWINCOMPLETEYN', 'simulate_rushhour','simulate_weather','simulate_weekday', \
                        'EXISTING_FACILITY_TYPE','CLASS_DESC',  'GEN_ALIAS']

#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV'

# %%
positive_data = positive[numeric_features + categorical_features].copy()

# %%
positive_data['acc'] = 1

# %%
negative_data = simulate_street[numeric_features + categorical_features].copy()
negative_data['acc'] = 0

# %%
X = pd.concat([positive_data, negative_data])

# %%
## drop dupulicats so all scenarios from positive examples are moved 
X_temp = X.drop_duplicates(subset  = [numeric_features+ categorical_features][0], keep = False, inplace = False)

# %%
X_negative  = X_temp.loc[X_temp.loc[:,'acc'] == 0,:]

# %%
## add in positive examples again 
X_both = pd.concat([positive_data, X_negative ])

# %%
X_both.groupby('acc').size()
# Out:
# acc
# 0    65735
# 1     5667
# dtype: int64

# %%
65735/5667
# Out:
# 11.599611787541908

# %%
y = X_both['acc']

# %%
X_both.drop(columns = ['acc'], inplace = True)

# %%
y.to_csv('./data/label.csv', sep = ',', index= False)
X_both.to_csv('./data/training.csv', sep = ',', index= False)
# Out:
# //anaconda3/envs/bike/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_both, y, stratify = y,test_size=0.1, shuffle = True)

# %%
y_train = y_train.astype('int')

# %%
X_train.head()
# Out:
#         SEGLENGTH_log  SURFACEWID_log  PVMTCONDIN  PVMTCOND_1  SLOPE_PCT  SW_WIDTH  FILLERWID  MINIMUMVARIABLEWIDTH  PRIMARYCROSSSLOPE  LENGTH_MIL  SPEEDLIMIT SEGDIR                         STREETTYPE ONEWAY SURFACETYP PVMTCATEGO CONDITION SWINCOMPLETEYN  simulate_rushhour        simulate_weather  simulate_weekday EXISTING_FACILITY_TYPE     CLASS_DESC               GEN_ALIAS
# 52250        4.465908        3.583519        90.0         NaN        2.0      60.0       54.0                   0.0                3.0         NaN        30.0      E              Neighborhood Corridor      N        PCC        ART      GOOD              N                0.0  Clear or Partly Cloudy                 1             NoFacility  Single Family           Rainier Beach
# 116432       5.075174        3.218876        51.0         NaN        6.0      72.0       96.0                   0.0                2.1         NaN        20.0      E  Urban Village Neighborhood Access      N        PCC    NON-ART      GOOD              N                0.0  Clear or Partly Cloudy                 0             NoFacility   Multi-Family                 Fremont
# 184920       4.882802             NaN         NaN         NaN       21.0       0.0        0.0                   0.0                0.0         NaN        20.0      E          Neighborhood Yield Street      N         ST    NON-ART                        N                0.0  Clear or Partly Cloudy                 1             NoFacility  Single Family          Madrona/Leschi
# 66846        5.799093        3.367296        36.0         NaN        3.0      60.0       72.0                   0.0                0.8    0.094506        30.0      W              Neighborhood Corridor      N     AC/PCC        ART      GOOD              N                1.0                 Raining                 1                Sharrow  Single Family  North Beach/Blue Ridge
# 161199       5.560682        3.218876        38.0         NaN        6.0      60.0       60.0                   0.0                1.8         NaN        20.0      E          Neighborhood Yield Street      N        PCC    NON-ART      FAIR              N                0.0                 Raining                 1             NoFacility  Single Family  Laurelhurst/Sand Point

# %%
sum(y_train)/len(y_train)
# Out:
# 0.07936384432237283

# %%
# initial parameters
#RANDOM_STATE = 42
#RATIO = 0.1
#K_FOLD = 5
from sklearn.model_selection import StratifiedKFold
#K_FOLD = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
K_FOLD = StratifiedKFold(n_splits=5,shuffle=True)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline


## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# imbalanced learn 
#rus = RandomUnderSampler(random_state=RANDOM_STATE) 
rus = RandomUnderSampler()#ratio = RATIO

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(solver='liblinear')

# %%
#logistic regression without feature selection 

from sklearn.feature_selection import SelectFromModel

log2 = LogisticRegression(solver='liblinear', class_weight = 'balanced')
logReg2 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('feature_selection', SelectFromModel(LogisticRegression(penalty="l1", class_weight = 'balanced', solver='liblinear'))),
                          ('classifier', log2)])

## cross validate 
from sklearn.model_selection import cross_validate

scores = cross_validate(logReg2, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision'], cv = K_FOLD, return_train_score= True, return_estimator=True)
scores
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-270-a34e9f75cbcb> in <module>
#       5 log2 = LogisticRegression(solver='liblinear', class_weight = 'balanced')
#       6 logReg2 = Pipeline(steps=[('preprocessor', preprocessor),
# ----> 7                           ('feature_selection', SelectFromModel(log2(penalty="l1", class_weight = 'balanced', solver='liblinear'))),
#       8                           ('classifier', log2)])
#       9
#
# TypeError: 'LogisticRegression' object is not callable

# %%
# take coeff for now 
logReg2.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-271-1e6fc6afc35b> in <module>
#       1 # take coeff for now
# ----> 2 logReg2.fit(X_train, y_train)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     350             This estimator
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#     354                                  self._log_message(len(self.steps) - 1)):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# //anaconda3/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     466         self._validate_remainder(X)
#     467
# --> 468         result = self._fit_transform(X, y, _fit_transform_one)
#     469
#     470         if not result:
#
# //anaconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     410                     message=self._log_message(name, idx, len(transformers)))
#     411                 for idx, (name, trans, column, weight) in enumerate(
# --> 412                         self._iter(fitted=fitted, replace_strings=True), 1))
#     413         except ValueError as e:
#     414             if "Expected 2D array, got 1D array instead" in str(e):
#
# //anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# //anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# //anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# //anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# //anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# //anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# //anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     385         """
#     386         last_step = self._final_estimator
# --> 387         Xt, fit_params = self._fit(X, y, **fit_params)
#     388         with _print_elapsed_time('Pipeline',
#     389                                  self._log_message(len(self.steps) - 1)):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# //anaconda3/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
# --> 556             return self.fit(X, y, **fit_params).transform(X)
#     557
#     558
#
# //anaconda3/lib/python3.7/site-packages/sklearn/impute/_base.py in fit(self, X, y)
#     266                                                self.strategy,
#     267                                                self.missing_values,
# --> 268                                                fill_value)
#     269
#     270         if self.add_indicator:
#
# //anaconda3/lib/python3.7/site-packages/sklearn/impute/_base.py in _dense_fit(self, X, strategy, missing_values, fill_value)
#     356                 row_mask = np.logical_not(row_mask).astype(np.bool)
#     357                 row = row[row_mask]
# --> 358                 most_frequent[i] = _most_frequent(row, np.nan, 0)
#     359
#     360             return most_frequent
#
# //anaconda3/lib/python3.7/site-packages/sklearn/impute/_base.py in _most_frequent(array, extra_value, n_repeat)
#      59             # has already been NaN-masked.
#      60             warnings.simplefilter("ignore", RuntimeWarning)
# ---> 61             mode = stats.mode(array)
#      62
#      63         most_frequent_value = mode[0][0]
#
# //anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in mode(a, axis, nan_policy)
#     450         return ModeResult(np.array([]), np.array([]))
#     451
# --> 452     contains_nan, nan_policy = _contains_nan(a, nan_policy)
#     453
#     454     if contains_nan and nan_policy == 'omit':
#
# //anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in _contains_nan(a, nan_policy)
#     250         # e.g. np.isnan(a).any()
#     251         with np.errstate(invalid='ignore'):
# --> 252             contains_nan = np.isnan(np.sum(a))
#     253     except TypeError:
#     254         # This can happen when attempting to sum things which are not
#
# //anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    2074
#    2075     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2076                           initial=initial)
#    2077
#    2078
#
# //anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
#cat_name = logReg2.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names()

type(categorical_features)
categorical_features
# Out:
# ['SPEEDLIMIT',
#  'SEGDIR',
#  'STREETTYPE',
#  'ONEWAY',
#  'SURFACETYP',
#  'NATIONHWYS',
#  'PVMTCATEGO',
#  'PARKBOULEV',
#  'CONDITION',
#  'SWINCOMPLETEYN',
#  'simulate_rushhour',
#  'simulate_weather',
#  'simulate_weekday',
#  'EXISTING_FACILITY_TYPE']

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name)))
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'x0_20.0', 'x0_25.0', 'x0_30.0',
#        'x0_35.0', 'x0_40.0', 'x0_45.0', 'x0_50.0', 'x0_55.0', 'x1_E',
#        'x1_N', 'x1_NE', 'x1_NW', 'x1_S', 'x1_SE', 'x1_SW', 'x1_W',
#        'x2_Alley', 'x2_Downtown', 'x2_Downtown Neighborhood',
#        'x2_Downtown Neighborhood Access', 'x2_Industrial Access',
#        'x2_Minor Industrial Access', 'x2_Neighborhood Corridor',
#        'x2_Neighborhood Yield Street', 'x2_Urban Center Connector',
#        'x2_Urban Village Main', 'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_N', 'x9_Y', 'x10_0.0', 'x10_1.0', 'x11_Clear or Partly Cloudy',
#        'x11_Raining', 'x12_0.0', 'x12_1.0',
#        'x13_In Street, Major Separation',
#        'x13_In Street, Minor Separation', 'x13_Multi-use Trail',
#        'x13_Neighborhood Greenway', 'x13_NoFacility', 'x13_Sharrow'],
#       dtype=object)

# %%
for i in np.arange(0,len(featurename)):
    featurename[i] = featurename[i].replace('x10_', 'RushHour_').replace('x11_', 'Weather_').\
        replace('x12_', 'Weekday_').replace('x13_', 'Bike_Facility_').\
        replace('x0_', 'SpeedLimit_').replace('x1_', 'Dir_').replace('x2_', 'StreetType_').\
        replace('x3_', 'OneWay_').replace('x4_', 'Surface_').\
        replace('x5_', 'NationHwy_').replace('x6_', 'PVMTCATEGO').replace('x7_', 'ParkBoulev_').replace('x8_', 'SWCondition_').\
        replace('x9_', 'Incomplete_')
print(featurename)
# Out:
# ['SEGLENGTH_log' 'SURFACEWID_log' 'PVMTCONDIN' 'PVMTCOND_1' 'SLOPE_PCT'
#  'SW_WIDTH' 'FILLERWID' 'MINIMUMVARIABLEWIDTH' 'PRIMARYCROSSSLOPE'
#  'LENGTH_MIL' 'SpeedLimit_20.0' 'SpeedLimit_25.0' 'SpeedLimit_30.0'
#  'SpeedLimit_35.0' 'SpeedLimit_40.0' 'SpeedLimit_45.0' 'SpeedLimit_50.0'
#  'SpeedLimit_55.0' 'Dir_E' 'Dir_N' 'Dir_NE' 'Dir_NW' 'Dir_S' 'Dir_SE'
#  'Dir_SW' 'Dir_W' 'StreetType_Alley' 'StreetType_Downtown'
#  'StreetType_Downtown Neighborhood'
#  'StreetType_Downtown Neighborhood Access' 'StreetType_Industrial Access'
#  'StreetType_Minor Industrial Access' 'StreetType_Neighborhood Corridor'
#  'StreetType_Neighborhood Yield Street'
#  'StreetType_Urban Center Connector' 'StreetType_Urban Village Main'
#  'StreetType_Urban Village Neighborhood'
#  'StreetType_Urban Village Neighborhood Access' 'OneWay_N' 'OneWay_Y'
#  'Surface_AC' 'Surface_AC/AC' 'Surface_AC/PCC' 'Surface_GRAVEL'
#  'Surface_PCC' 'Surface_ST' 'NationHwy_N' 'NationHwy_Y' 'PVMTCATEGOART'
#  'PVMTCATEGOMLTUSETRL' 'PVMTCATEGONON-ART' 'PVMTCATEGONONE'
#  'PVMTCATEGOPATHWAY' 'PVMTCATEGOPVMTTOPARK' 'ParkBoulev_N' 'ParkBoulev_Y'
#  'SWCondition_ ' 'SWCondition_EXCELLENT' 'SWCondition_FAIR'
#  'SWCondition_GOOD' 'SWCondition_POOR' 'SWCondition_VERY-POOR'
#  'Incomplete_N' 'Incomplete_Y' 'RushHour_0.0' 'RushHour_1.0'
#  'Weather_Clear or Partly Cloudy' 'Weather_Raining' 'Weekday_0.0'
#  'Weekday_1.0' 'Bike_Facility_In Street, Major Separation'
#  'Bike_Facility_In Street, Minor Separation'
#  'Bike_Facility_Multi-use Trail' 'Bike_Facility_Neighborhood Greenway'
#  'Bike_Facility_NoFacility' 'Bike_Facility_Sharrow']

# %%
## 
f_imp = logReg2['classifier'].coef_
f_imp
# Out:
# array([[ 0.1542161 ,  0.32935418, -0.00491307,  0.00336492, -0.23293656,
#          0.23458248, -0.29147137, -0.05387331, -0.21361442,  0.26136182,
#          0.83525787,  0.71398695,  0.18894785, -0.35849714, -0.07872898,
#         -1.2363547 , -0.91551899,  0.96722596,  0.23233233,  0.22396035,
#         -0.63767542, -0.64302896, -0.29703706, -0.64252576,  0.48097865,
#          0.4373671 ,  0.18951943, -0.07857841, -1.32838589, -0.64982523,
#         -1.17644671, -0.06735188,  0.39473043,  0.37481727, -1.00882633,
#         -0.17819801, -0.63266485,  0.30953872, -1.34852533,  0.51511852,
#         -0.66170693, -0.09875294,  0.12063559,  0.89849402, -0.75092839,
#         -0.80959529, -0.66417803, -0.133175  , -0.55781068,  0.05673672,
#         -0.24735264,  0.67166788, -0.04632957, -0.21524418, -0.68659418,
#         -1.78075765, -0.66158853, -0.67332517,  0.35504801, -1.49606693,
#         -1.59496418,  0.58958901]])

# %%
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'SpeedLimit_20.0',
#        'SpeedLimit_25.0', 'SpeedLimit_30.0', 'SpeedLimit_35.0',
#        'SpeedLimit_40.0', 'SpeedLimit_45.0', 'SpeedLimit_50.0',
#        'SpeedLimit_55.0', 'Dir_E', 'Dir_N', 'Dir_NE', 'Dir_NW', 'Dir_S',
#        'Dir_SE', 'Dir_SW', 'Dir_W', 'StreetType_Alley',
#        'StreetType_Downtown', 'StreetType_Downtown Neighborhood',
#        'StreetType_Downtown Neighborhood Access',
#        'StreetType_Industrial Access',
#        'StreetType_Minor Industrial Access',
#        'StreetType_Neighborhood Corridor',
#        'StreetType_Neighborhood Yield Street',
#        'StreetType_Urban Center Connector',
#        'StreetType_Urban Village Main',
#        'StreetType_Urban Village Neighborhood',
#        'StreetType_Urban Village Neighborhood Access', 'OneWay_N',
#        'OneWay_Y', 'Surface_AC', 'Surface_AC/AC', 'Surface_AC/PCC',
#        'Surface_GRAVEL', 'Surface_PCC', 'Surface_ST', 'NationHwy_N',
#        'NationHwy_Y', 'PVMTCATEGOART', 'PVMTCATEGOMLTUSETRL',
#        'PVMTCATEGONON-ART', 'PVMTCATEGONONE', 'PVMTCATEGOPATHWAY',
#        'PVMTCATEGOPVMTTOPARK', 'ParkBoulev_N', 'ParkBoulev_Y',
#        'SWCondition_ ', 'SWCondition_EXCELLENT', 'SWCondition_FAIR',
#        'SWCondition_GOOD', 'SWCondition_POOR', 'SWCondition_VERY-POOR',
#        'Incomplete_N', 'Incomplete_Y', 'RushHour_0.0', 'RushHour_1.0',
#        'Weather_Clear or Partly Cloudy', 'Weather_Raining', 'Weekday_0.0',
#        'Weekday_1.0', 'Bike_Facility_In Street, Major Separation',
#        'Bike_Facility_In Street, Minor Separation',
#        'Bike_Facility_Multi-use Trail',
#        'Bike_Facility_Neighborhood Greenway', 'Bike_Facility_NoFacility',
#        'Bike_Facility_Sharrow'], dtype=object)

# %%
f_imp_top  =f_imp[np.abs(f_imp) > 0.5]
featurename_top  = featurename[ np.where((np.abs(f_imp) > 0.5)[0])]

# %%
featurename_top
# Out:
# array(['SpeedLimit_20.0', 'SpeedLimit_25.0', 'SpeedLimit_45.0',
#        'SpeedLimit_50.0', 'SpeedLimit_55.0', 'Dir_NE', 'Dir_NW', 'Dir_SE',
#        'StreetType_Downtown Neighborhood',
#        'StreetType_Downtown Neighborhood Access',
#        'StreetType_Industrial Access',
#        'StreetType_Urban Center Connector',
#        'StreetType_Urban Village Neighborhood', 'OneWay_N', 'OneWay_Y',
#        'Surface_AC', 'Surface_GRAVEL', 'Surface_PCC', 'Surface_ST',
#        'NationHwy_N', 'PVMTCATEGOART', 'PVMTCATEGONONE', 'ParkBoulev_N',
#        'ParkBoulev_Y', 'SWCondition_ ', 'SWCondition_EXCELLENT',
#        'SWCondition_GOOD', 'SWCondition_POOR', 'SWCondition_VERY-POOR'],
#       dtype=object)

# %%
f_imp_top
# Out:
# array([ 0.83525787,  0.71398695, -1.2363547 , -0.91551899,  0.96722596,
#        -0.63767542, -0.64302896, -0.64252576, -1.32838589, -0.64982523,
#        -1.17644671, -1.00882633, -0.63266485, -1.34852533,  0.51511852,
#        -0.66170693,  0.89849402, -0.75092839, -0.80959529, -0.66417803,
#        -0.55781068,  0.67166788, -0.68659418, -1.78075765, -0.66158853,
#        -0.67332517, -1.49606693, -1.59496418,  0.58958901])

# %%
# Plot! 

plt.figure(figsize=(5,20))
plt.barh(range(len(f_imp_top)),
         width=np.sort(f_imp_top))
plt.yticks(ticks=range(len(f_imp_top)), labels=featurename_top[np.argsort(f_imp_top)])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp_top)])
print(np.argsort(f_imp_top))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['Dir_SE' 'StreetType_Downtown' 'StreetType_Alley' 'SpeedLimit_35.0'
#  'PRIMARYCROSSSLOPE' 'PVMTCONDIN' 'SpeedLimit_20.0' 'SpeedLimit_25.0'
#  'PVMTCOND_1' 'Dir_E' 'SpeedLimit_55.0' 'Dir_S' 'Dir_W' 'Dir_N'
#  'SpeedLimit_45.0' 'Dir_SW' 'LENGTH_MIL' 'FILLERWID'
#  'MINIMUMVARIABLEWIDTH' 'SW_WIDTH' 'SpeedLimit_30.0' 'Dir_NE'
#  'SpeedLimit_40.0' 'StreetType_Downtown Neighborhood' 'Dir_NW'
#  'SURFACEWID_log' 'SEGLENGTH_log' 'SpeedLimit_50.0' 'SLOPE_PCT']
# [23 27 26 13  8  2 10 11  3 18 17 22 25 19 15 24  9  6  7  5 12 20 14 28
#  21  1  0 16  4]

# %%
# Plot! 

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp[0])])
print(np.argsort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['ParkBoulev_Y' 'SWCondition_POOR' 'SWCondition_GOOD' 'OneWay_N'
#  'StreetType_Downtown Neighborhood' 'SpeedLimit_45.0'
#  'StreetType_Industrial Access' 'StreetType_Urban Center Connector'
#  'SpeedLimit_50.0' 'Surface_ST' 'Surface_PCC' 'ParkBoulev_N'
#  'SWCondition_EXCELLENT' 'NationHwy_N' 'Surface_AC' 'SWCondition_ '
#  'StreetType_Downtown Neighborhood Access' 'Dir_NW' 'Dir_SE' 'Dir_NE'
#  'StreetType_Urban Village Neighborhood' 'PVMTCATEGOART' 'SpeedLimit_35.0'
#  'Dir_S' 'FILLERWID' 'PVMTCATEGONON-ART' 'SLOPE_PCT'
#  'PVMTCATEGOPVMTTOPARK' 'PRIMARYCROSSSLOPE'
#  'StreetType_Urban Village Main' 'NationHwy_Y' 'Surface_AC/AC'
#  'SpeedLimit_40.0' 'StreetType_Downtown'
#  'StreetType_Minor Industrial Access' 'MINIMUMVARIABLEWIDTH'
#  'PVMTCATEGOPATHWAY' 'PVMTCONDIN' 'PVMTCOND_1' 'PVMTCATEGOMLTUSETRL'
#  'Surface_AC/PCC' 'SEGLENGTH_log' 'SpeedLimit_30.0' 'StreetType_Alley'
#  'Dir_N' 'Dir_E' 'SW_WIDTH' 'LENGTH_MIL'
#  'StreetType_Urban Village Neighborhood Access' 'SURFACEWID_log'
#  'SWCondition_FAIR' 'StreetType_Neighborhood Yield Street'
#  'StreetType_Neighborhood Corridor' 'Dir_W' 'Dir_SW' 'OneWay_Y'
#  'SWCondition_VERY-POOR' 'PVMTCATEGONONE' 'SpeedLimit_25.0'
#  'SpeedLimit_20.0' 'Surface_GRAVEL' 'SpeedLimit_55.0']
# [55 60 59 38 28 15 30 34 16 45 44 54 57 46 40 56 29 21 23 20 36 48 13 22
#   6 50  4 53  8 35 47 41 14 27 31  7 52  2  3 49 42  0 12 26 19 18  5  9
#  37  1 58 33 32 25 24 39 61 51 11 10 43 17]

# %%
## Grid Search 

from sklearn.model_selection import GridSearchCV
params = {
    'penalty': ['l1','l2'],
    'C': [0.001, 0.01, 0.1, 1,10,100],
     'class_weight': ['balanced']
}
new_params = {'classifier__' + key: params[key] for key in params}
grid_lg_balance = GridSearchCV(logReg2, param_grid=new_params, cv=K_FOLD, scoring='roc_auc', return_train_score=True)
grid_lg_balance.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('preprocessor',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('num',
#                                                                          Pipeline(memory=None,
#                                                                                   steps=[('imputer',
#                                                                                           SimpleImputer(add_indicator=False,
#                                                                                                         co...
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='liblinear',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'classifier__class_weight': ['balanced'],
#                          'classifier__penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='roc_auc', verbose=0)

# %%
grid_lg_balance.best_params_
# Out:
# {'classifier__C': 1,
#  'classifier__class_weight': 'balanced',
#  'classifier__penalty': 'l2'}

# %%
f_imp = grid_lg_balance.best_estimator_['classifier'].coef_
f_imp
# Out:
# array([[ 1.37927187e-01,  2.90772366e-01,  1.82998642e-02,
#         -6.86278298e-03, -2.50259865e-01,  1.85188464e-01,
#         -4.91841901e-01, -4.25723253e-02, -1.99527555e-01,
#          2.71265846e-01,  6.49138325e-01,  4.82121936e-01,
#          1.31423234e-02, -3.08399236e-01,  9.09937509e-03,
#          1.22398491e-01, -1.16471386e+00, -5.04667043e-01,
#          9.28249967e-01,  2.28034950e-01, -1.30842833e-03,
#          2.65498356e-01, -5.94462951e-01, -6.14015698e-01,
#         -2.76171358e-01, -6.37704523e-01,  4.06791865e-01,
#          5.38414380e-01,  4.89547434e-01,  2.00580036e-01,
#          1.57166034e-01, -1.01295563e+00, -5.31540722e-01,
#         -1.12100866e+00,  1.17044374e-01,  5.10216028e-01,
#          4.62673531e-01, -9.18808351e-01, -4.15589306e-01,
#         -2.86290379e-01,  1.42769839e-01, -7.50461206e-01,
#          3.90789995e-01, -5.40436814e-01,  5.02739870e-01,
#         -4.47281369e-01, -3.96332628e-01, -3.05547056e-01,
#          2.38566281e-01,  1.14010137e+00,  1.75145403e-01,
#         -1.01612237e+00, -5.79657972e-01, -6.59912404e-01,
#         -5.67058510e-01, -1.34821175e-01,  3.86756395e-02,
#         -8.11000821e-02, -4.37155395e-01,  4.19799615e-01,
#         -3.37308109e-01, -3.04791353e-01,  5.49860447e-01,
#         -8.63992357e-01, -8.14066107e-01,  1.49250343e+00,
#          8.07861413e-01, -5.31748564e-01,  8.54519242e-01,
#         -8.29438231e-02, -7.03539275e-01, -9.45231034e-01,
#          6.78680121e-01, -1.28619078e+00,  1.42407601e-01,
#         -4.97909020e-01, -2.03970664e-01, -7.01879684e-01,
#         -1.37182143e-01,  7.37934866e-01,  9.09651090e-01,
#          6.30802258e-01,  7.89945379e-01,  8.06627670e-02,
#         -1.90565852e+00,  3.64700534e-01, -2.90263770e-01,
#          7.70116343e-01, -1.56493655e+00,  1.14943923e+00,
#         -4.85401842e-01, -1.73893435e+00,  8.81706091e-01,
#         -8.94461059e-01,  2.18788231e-01,  1.41044626e-01,
#          1.76995277e-01,  3.37943944e-01,  3.34058657e-01,
#         -5.50369587e-02, -6.67834709e-01,  5.30089327e-01,
#          9.64899475e-01,  2.59275403e-01, -5.65721589e-01,
#         -1.26243354e-01,  9.50227855e-03, -2.05146814e+00,
#          7.64046127e-01, -9.72218276e-01, -6.81586842e-01,
#         -2.02928428e-02,  5.56834549e-01, -1.25871423e+00,
#         -6.80308441e-01, -2.15712429e-02, -3.05903493e-01,
#          6.67322417e-01, -1.24204261e+00, -1.05198020e+00,
#          9.06674983e-01,  3.24049218e-01]])

# %%
cat_name = grid_lg_balance.best_estimator_.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names()

cat_name
# Out:
# array(['x0_20.0', 'x0_25.0', 'x0_30.0', 'x0_35.0', 'x0_40.0', 'x0_45.0',
#        'x0_50.0', 'x0_55.0', 'x1_E', 'x1_N', 'x1_NE', 'x1_NW', 'x1_S',
#        'x1_SE', 'x1_SW', 'x1_W', 'x2_Alley', 'x2_Downtown',
#        'x2_Downtown Neighborhood', 'x2_Downtown Neighborhood Access',
#        'x2_Industrial Access', 'x2_Minor Industrial Access',
#        'x2_Neighborhood Corridor', 'x2_Neighborhood Yield Street',
#        'x2_Urban Center Connector', 'x2_Urban Village Main',
#        'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_AC', 'x9_AC/AG', 'x9_AC/PCC', 'x9_BR', 'x9_GRAVEL', 'x9_OTH',
#        'x9_PCC', 'x9_PCC-TS', 'x9_PCC/AG', 'x9_PV/OTHER', 'x9_PVCC',
#        'x9_ST', 'x9_UIMPRV', 'x10_N', 'x10_Y', 'x11_ ', 'x12_ ', 'x12_AC',
#        'x12_BR', 'x12_GRAVEL', 'x12_LSCP', 'x12_NONE', 'x12_OTH',
#        'x12_PCC', 'x12_PV/OTHER', 'x12_PVCC', 'x12_SWALE', 'x12_TR/AC',
#        'x12_TR/BR', 'x12_TR/O', 'x12_TR/PCC', 'x12_UND', 'x13_ ',
#        'x13_410A', 'x13_410B', 'x13_410C', 'x13_AR', 'x13_DLPSTS',
#        'x13_EX', 'x13_G', 'x13_MONO', 'x13_NONE', 'x13_OTH', 'x13_ROLLCB',
#        'x13_TEAC', 'x13_TEPCC', 'x13_UND', 'x13_WHLSTP', 'x14_0.0',
#        'x14_1.0', 'x15_Clear or Partly Cloudy', 'x15_Raining', 'x16_0.0',
#        'x16_1.0', 'x17_In Street, Major Separation',
#        'x17_In Street, Minor Separation', 'x17_Multi-use Trail',
#        'x17_Neighborhood Greenway', 'x17_NoFacility', 'x17_Sharrow'],
#       dtype=object)

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name,)))
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'x0_20.0', 'x0_25.0', 'x0_30.0',
#        'x0_35.0', 'x0_40.0', 'x0_45.0', 'x0_50.0', 'x0_55.0', 'x1_E',
#        'x1_N', 'x1_NE', 'x1_NW', 'x1_S', 'x1_SE', 'x1_SW', 'x1_W',
#        'x2_Alley', 'x2_Downtown', 'x2_Downtown Neighborhood',
#        'x2_Downtown Neighborhood Access', 'x2_Industrial Access',
#        'x2_Minor Industrial Access', 'x2_Neighborhood Corridor',
#        'x2_Neighborhood Yield Street', 'x2_Urban Center Connector',
#        'x2_Urban Village Main', 'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_AC', 'x9_AC/AG', 'x9_AC/PCC', 'x9_BR', 'x9_GRAVEL', 'x9_OTH',
#        'x9_PCC', 'x9_PCC-TS', 'x9_PCC/AG', 'x9_PV/OTHER', 'x9_PVCC',
#        'x9_ST', 'x9_UIMPRV', 'x10_N', 'x10_Y', 'x11_ ', 'x12_ ', 'x12_AC',
#        'x12_BR', 'x12_GRAVEL', 'x12_LSCP', 'x12_NONE', 'x12_OTH',
#        'x12_PCC', 'x12_PV/OTHER', 'x12_PVCC', 'x12_SWALE', 'x12_TR/AC',
#        'x12_TR/BR', 'x12_TR/O', 'x12_TR/PCC', 'x12_UND', 'x13_ ',
#        'x13_410A', 'x13_410B', 'x13_410C', 'x13_AR', 'x13_DLPSTS',
#        'x13_EX', 'x13_G', 'x13_MONO', 'x13_NONE', 'x13_OTH', 'x13_ROLLCB',
#        'x13_TEAC', 'x13_TEPCC', 'x13_UND', 'x13_WHLSTP', 'x14_0.0',
#        'x14_1.0', 'x15_Clear or Partly Cloudy', 'x15_Raining', 'x16_0.0',
#        'x16_1.0', 'x17_In Street, Major Separation',
#        'x17_In Street, Minor Separation', 'x17_Multi-use Trail',
#        'x17_Neighborhood Greenway', 'x17_NoFacility', 'x17_Sharrow'],
#       dtype=object)

# %%
#logReg2.predict_proba(X)

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp[0])])
print(np.sort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['x13_TEPCC' 'x12_OTH' 'x12_TR/O' 'x12_SWALE' 'x9_ST' 'x15_Raining'
#  'x17_Multi-use Trail' 'x0_50.0' 'x2_Neighborhood Yield Street'
#  'x17_Neighborhood Greenway' 'x6_NONE' 'x2_Minor Industrial Access'
#  'x13_WHLSTP' 'x9_PV/OTHER' 'x2_Urban Village Neighborhood Access'
#  'x12_UND' 'x9_AC/AG' 'x9_AC/PCC' 'x4_AC/AC' 'x9_PCC/AG' 'x11_ ' 'x14_0.0'
#  'x16_0.0' 'x13_EX' 'x6_PVMTTOPARK' 'x1_W' 'x1_SE' 'x1_S' 'x6_PATHWAY'
#  'x7_N' 'x13_OTH' 'x4_GRAVEL' 'x9_OTH' 'x2_Neighborhood Corridor'
#  'x0_55.0' 'x10_N' 'FILLERWID' 'x12_TR/BR' 'x4_ST' 'x8_FAIR' 'x3_N' 'x5_N'
#  'x8_POOR' 'x0_35.0' 'x17_In Street, Major Separation' 'x5_Y'
#  'x8_VERY-POOR' 'x12_PV/OTHER' 'x3_Y' 'x1_SW' 'SLOPE_PCT' 'x10_Y'
#  'PRIMARYCROSSSLOPE' 'x12_ ' 'x7_Y' 'x13_ROLLCB' 'x9_PCC-TS'
#  'x8_EXCELLENT' 'x13_DLPSTS' 'MINIMUMVARIABLEWIDTH' 'x16_1.0' 'x14_1.0'
#  'PVMTCOND_1' 'x1_NE' 'x0_40.0' 'x13_TEAC' 'x0_30.0' 'PVMTCONDIN' 'x8_ '
#  'x12_NONE' 'x2_Urban Center Connector' 'x0_45.0' 'SEGLENGTH_log'
#  'x13_410A' 'x9_UIMPRV' 'x4_AC' 'x2_Industrial Access' 'x6_NON-ART'
#  'x13_410B' 'SW_WIDTH' 'x2_Downtown Neighborhood Access' 'x13_ ' 'x1_N'
#  'x6_ART' 'x13_NONE' 'x1_NW' 'LENGTH_MIL' 'SURFACEWID_log' 'x17_Sharrow'
#  'x13_AR' 'x13_410C' 'x12_PCC' 'x4_AC/PCC' 'x2_Alley' 'x8_GOOD'
#  'x2_Urban Village Neighborhood' 'x0_25.0' 'x2_Downtown Neighborhood'
#  'x4_PCC' 'x2_Urban Village Main' 'x13_G' 'x2_Downtown' 'x9_AC'
#  'x15_Clear or Partly Cloudy' 'x12_GRAVEL' 'x0_20.0'
#  'x17_In Street, Minor Separation' 'x9_PVCC' 'x12_AC' 'x13_UND' 'x12_PVCC'
#  'x12_LSCP' 'x9_GRAVEL' 'x9_PCC' 'x12_TR/PCC' 'x17_NoFacility' 'x12_BR'
#  'x1_E' 'x13_MONO' 'x6_MLTUSETRL' 'x12_TR/AC' 'x9_BR']
# [-2.05146814e+00 -1.90565852e+00 -1.73893435e+00 -1.56493655e+00
#  -1.28619078e+00 -1.25871423e+00 -1.24204261e+00 -1.16471386e+00
#  -1.12100866e+00 -1.05198020e+00 -1.01612237e+00 -1.01295563e+00
#  -9.72218276e-01 -9.45231034e-01 -9.18808351e-01 -8.94461059e-01
#  -8.63992357e-01 -8.14066107e-01 -7.50461206e-01 -7.03539275e-01
#  -7.01879684e-01 -6.81586842e-01 -6.80308441e-01 -6.67834709e-01
#  -6.59912404e-01 -6.37704523e-01 -6.14015698e-01 -5.94462951e-01
#  -5.79657972e-01 -5.67058510e-01 -5.65721589e-01 -5.40436814e-01
#  -5.31748564e-01 -5.31540722e-01 -5.04667043e-01 -4.97909020e-01
#  -4.91841901e-01 -4.85401842e-01 -4.47281369e-01 -4.37155395e-01
#  -4.15589306e-01 -3.96332628e-01 -3.37308109e-01 -3.08399236e-01
#  -3.05903493e-01 -3.05547056e-01 -3.04791353e-01 -2.90263770e-01
#  -2.86290379e-01 -2.76171358e-01 -2.50259865e-01 -2.03970664e-01
#  -1.99527555e-01 -1.37182143e-01 -1.34821175e-01 -1.26243354e-01
#  -8.29438231e-02 -8.11000821e-02 -5.50369587e-02 -4.25723253e-02
#  -2.15712429e-02 -2.02928428e-02 -6.86278298e-03 -1.30842833e-03
#   9.09937509e-03  9.50227855e-03  1.31423234e-02  1.82998642e-02
#   3.86756395e-02  8.06627670e-02  1.17044374e-01  1.22398491e-01
#   1.37927187e-01  1.41044626e-01  1.42407601e-01  1.42769839e-01
#   1.57166034e-01  1.75145403e-01  1.76995277e-01  1.85188464e-01
#   2.00580036e-01  2.18788231e-01  2.28034950e-01  2.38566281e-01
#   2.59275403e-01  2.65498356e-01  2.71265846e-01  2.90772366e-01
#   3.24049218e-01  3.34058657e-01  3.37943944e-01  3.64700534e-01
#   3.90789995e-01  4.06791865e-01  4.19799615e-01  4.62673531e-01
#   4.82121936e-01  4.89547434e-01  5.02739870e-01  5.10216028e-01
#   5.30089327e-01  5.38414380e-01  5.49860447e-01  5.56834549e-01
#   6.30802258e-01  6.49138325e-01  6.67322417e-01  6.78680121e-01
#   7.37934866e-01  7.64046127e-01  7.70116343e-01  7.89945379e-01
#   8.07861413e-01  8.54519242e-01  8.81706091e-01  9.06674983e-01
#   9.09651090e-01  9.28249967e-01  9.64899475e-01  1.14010137e+00
#   1.14943923e+00  1.49250343e+00]

# %%
# Try removing curbe features

# %%
numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1','SLOPE_PCT' ,
                    'SW_WIDTH' ,'FILLERWID','MINIMUMVARIABLEWIDTH', 'PRIMARYCROSSSLOPE', 'LENGTH_MIL']
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['SPEEDLIMIT','SEGDIR', 'STREETTYPE','ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,
'CONDITION', 'SWINCOMPLETEYN', 'simulate_rushhour','simulate_weather','simulate_weekday', 'EXISTING_FACILITY_TYPE']
X = full[numeric_features + categorical_features  ].copy()

# %%
negative_1 = full[numeric_features + categorical_features].copy()
negative = negative_1.loc[full['_merge'] == 'left_only',].reset_index(drop=True).copy()
#np.zeros(len(negative))
positive = positive_example[numeric_features + categorical_features].copy()
#np.ones(len(positive))
#X = pd.concat([negative,positive])
#X.columns

# %%
X = pd.concat([negative,positive])

# %%
y = pd.Series(np.concatenate((np.zeros(len(negative)), np.ones(len(positive))), axis=0))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y,test_size=0.1, shuffle = True)

# %%
y_train = y_train.astype('int')

# %%
sum(y_test)/len(y_test)
# Out:
# 0.05727115172522452

# %%
# initial parameters
#RANDOM_STATE = 42
#RATIO = 0.1
#K_FOLD = 5
from sklearn.model_selection import StratifiedKFold
#K_FOLD = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
K_FOLD = StratifiedKFold(n_splits=5,shuffle=True)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline


## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# imbalanced learn 
#rus = RandomUnderSampler(random_state=RANDOM_STATE) 
rus = RandomUnderSampler()#ratio = RATIO

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(solver='liblinear')

# %%
#logistic regression without oversampling 
log2 = LogisticRegression(solver='liblinear', class_weight = 'balanced')
logReg2 = Pipeline(steps=[('preprocessor', preprocessor),('classifier', log2)])

## cross validate 
from sklearn.model_selection import cross_validate

scores = cross_validate(logReg2, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision'], cv = K_FOLD, return_train_score= True, return_estimator=True)
scores
# Out:
# {'fit_time': array([64.85322094, 57.77560902, 66.80869722, 60.3643651 , 61.07885718]),
#  'score_time': array([0.8485539 , 0.89207101, 0.90392089, 0.88343883, 0.7898109 ]),
#  'estimator': (Pipeline(memory=None,
#            steps=[('preprocessor',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with_mean...
#                                                      'simulate_weather',
#                                                      'simulate_weekday',
#                                                      'EXISTING_FACILITY_TYPE'])],
#                                      verbose=False)),
#                   ('classifier',
#                    LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                       fit_intercept=True, intercept_scaling=1,
#                                       l1_ratio=None, max_iter=100,
#                                       multi_class='warn', n_jobs=None,
#                                       penalty='l2', random_state=None,
#                                       solver='liblinear', tol=0.0001, verbose=0,
#                                       warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('preprocessor',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with_mean...
#                                                      'simulate_weather',
#                                                      'simulate_weekday',
#                                                      'EXISTING_FACILITY_TYPE'])],
#                                      verbose=False)),
#                   ('classifier',
#                    LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                       fit_intercept=True, intercept_scaling=1,
#                                       l1_ratio=None, max_iter=100,
#                                       multi_class='warn', n_jobs=None,
#                                       penalty='l2', random_state=None,
#                                       solver='liblinear', tol=0.0001, verbose=0,
#                                       warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('preprocessor',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with_mean...
#                                                      'simulate_weather',
#                                                      'simulate_weekday',
#                                                      'EXISTING_FACILITY_TYPE'])],
#                                      verbose=False)),
#                   ('classifier',
#                    LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                       fit_intercept=True, intercept_scaling=1,
#                                       l1_ratio=None, max_iter=100,
#                                       multi_class='warn', n_jobs=None,
#                                       penalty='l2', random_state=None,
#                                       solver='liblinear', tol=0.0001, verbose=0,
#                                       warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('preprocessor',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with_mean...
#                                                      'simulate_weather',
#                                                      'simulate_weekday',
#                                                      'EXISTING_FACILITY_TYPE'])],
#                                      verbose=False)),
#                   ('classifier',
#                    LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                       fit_intercept=True, intercept_scaling=1,
#                                       l1_ratio=None, max_iter=100,
#                                       multi_class='warn', n_jobs=None,
#                                       penalty='l2', random_state=None,
#                                       solver='liblinear', tol=0.0001, verbose=0,
#                                       warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('preprocessor',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with_mean...
#                                                      'simulate_weather',
#                                                      'simulate_weekday',
#                                                      'EXISTING_FACILITY_TYPE'])],
#                                      verbose=False)),
#                   ('classifier',
#                    LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                       fit_intercept=True, intercept_scaling=1,
#                                       l1_ratio=None, max_iter=100,
#                                       multi_class='warn', n_jobs=None,
#                                       penalty='l2', random_state=None,
#                                       solver='liblinear', tol=0.0001, verbose=0,
#                                       warm_start=False))],
#            verbose=False)),
#  'test_roc_auc': array([0.8866438 , 0.89044061, 0.88439641, 0.88909431, 0.88510615]),
#  'train_roc_auc': array([0.8889388 , 0.88782125, 0.88939163, 0.88805906, 0.88932948]),
#  'test_recall': array([0.80901451, 0.83040489, 0.80657492, 0.81574924, 0.81957187]),
#  'train_recall': array([0.8213262 , 0.81540225, 0.82021399, 0.82116928, 0.81792128]),
#  'test_accuracy': array([0.80503282, 0.80245077, 0.80230217, 0.80593487, 0.80409664]),
#  'train_accuracy': array([0.80451671, 0.80372891, 0.80531971, 0.80403956, 0.80434592]),
#  'test_precision': array([0.20117781, 0.20208217, 0.19834555, 0.20285171, 0.20180723]),
#  'train_precision': array([0.2024589 , 0.200904  , 0.20302672, 0.20204964, 0.20183876])}

# %%
# take coeff for now 
logReg2.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('scaler',
#                                                                    StandardScaler(copy=True,
#                                                                                   with_mean...
#                                                    'simulate_weather',
#                                                    'simulate_weekday',
#                                                    'EXISTING_FACILITY_TYPE'])],
#                                    verbose=False)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='liblinear', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
cat_name = logReg2.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names()

cat_name
# Out:
# array(['x0_20.0', 'x0_25.0', 'x0_30.0', 'x0_35.0', 'x0_40.0', 'x0_45.0',
#        'x0_50.0', 'x0_55.0', 'x1_E', 'x1_N', 'x1_NE', 'x1_NW', 'x1_S',
#        'x1_SE', 'x1_SW', 'x1_W', 'x2_Alley', 'x2_Downtown',
#        'x2_Downtown Neighborhood', 'x2_Downtown Neighborhood Access',
#        'x2_Industrial Access', 'x2_Minor Industrial Access',
#        'x2_Neighborhood Corridor', 'x2_Neighborhood Yield Street',
#        'x2_Urban Center Connector', 'x2_Urban Village Main',
#        'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_N', 'x9_Y', 'x10_0.0', 'x10_1.0', 'x11_Clear or Partly Cloudy',
#        'x11_Raining', 'x12_0.0', 'x12_1.0',
#        'x13_In Street, Major Separation',
#        'x13_In Street, Minor Separation', 'x13_Multi-use Trail',
#        'x13_Neighborhood Greenway', 'x13_NoFacility', 'x13_Sharrow'],
#       dtype=object)

# %%
## 
f_imp = logReg2['classifier'].coef_
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name,)))
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'x0_20.0', 'x0_25.0', 'x0_30.0',
#        'x0_35.0', 'x0_40.0', 'x0_45.0', 'x0_50.0', 'x0_55.0', 'x1_E',
#        'x1_N', 'x1_NE', 'x1_NW', 'x1_S', 'x1_SE', 'x1_SW', 'x1_W',
#        'x2_Alley', 'x2_Downtown', 'x2_Downtown Neighborhood',
#        'x2_Downtown Neighborhood Access', 'x2_Industrial Access',
#        'x2_Minor Industrial Access', 'x2_Neighborhood Corridor',
#        'x2_Neighborhood Yield Street', 'x2_Urban Center Connector',
#        'x2_Urban Village Main', 'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_N', 'x9_Y', 'x10_0.0', 'x10_1.0', 'x11_Clear or Partly Cloudy',
#        'x11_Raining', 'x12_0.0', 'x12_1.0',
#        'x13_In Street, Major Separation',
#        'x13_In Street, Minor Separation', 'x13_Multi-use Trail',
#        'x13_Neighborhood Greenway', 'x13_NoFacility', 'x13_Sharrow'],
#       dtype=object)

# %%
# Plot! 

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp[0])])
print(np.argsort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['x13_Neighborhood Greenway' 'x0_50.0' 'x11_Raining'
#  'x2_Minor Industrial Access' 'x4_GRAVEL' 'x13_Multi-use Trail'
#  'x2_Neighborhood Yield Street' 'x0_55.0'
#  'x2_Urban Village Neighborhood Access' 'x6_PATHWAY' 'x6_NONE' 'x10_0.0'
#  'x12_0.0' 'x8_ ' 'x6_PVMTTOPARK' 'x1_SE' 'x1_W' 'x1_S'
#  'x2_Neighborhood Corridor' 'x4_ST' 'x4_AC/AC' 'x9_N' 'x3_N' 'x7_N' 'x5_N'
#  'x8_FAIR' 'x0_35.0' 'x13_In Street, Major Separation' 'FILLERWID' 'x1_SW'
#  'x5_Y' 'x7_Y' 'SLOPE_PCT' 'x3_Y' 'PRIMARYCROSSSLOPE' 'x9_Y'
#  'x8_VERY-POOR' 'x8_POOR' 'MINIMUMVARIABLEWIDTH' 'x0_45.0' 'x8_EXCELLENT'
#  'PVMTCONDIN' 'PVMTCOND_1' 'x12_1.0' 'x1_NE' 'x10_1.0' 'x0_40.0'
#  'x2_Industrial Access' 'x2_Urban Center Connector' 'x6_NON-ART'
#  'SEGLENGTH_log' 'x4_AC' 'x0_30.0' 'SW_WIDTH' 'x6_ART' 'x1_NW' 'x2_Alley'
#  'x1_N' 'LENGTH_MIL' 'SURFACEWID_log' 'x2_Downtown Neighborhood Access'
#  'x13_Sharrow' 'x4_AC/PCC' 'x2_Urban Village Neighborhood'
#  'x2_Urban Village Main' 'x2_Downtown Neighborhood'
#  'x11_Clear or Partly Cloudy' 'x8_GOOD' 'x2_Downtown' 'x4_PCC'
#  'x13_In Street, Minor Separation' 'x0_25.0' 'x0_20.0' 'x13_NoFacility'
#  'x1_E' 'x6_MLTUSETRL']
# [73 16 67 31 43 72 33 17 37 52 51 64 68 56 53 23 25 22 32 45 41 62 38 54
#  46 58 13 70  6 24 47 55  4 39  8 63 61 60  7 15 57  2  3 69 20 65 14 30
#  34 50  0 40 12  5 48 21 26 19  9  1 29 75 42 36 35 28 66 59 27 44 71 11
#  10 74 18 49]

# %%
# Plot! 

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(np.abs(f_imp[0])))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(np.abs(f_imp[0]))])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(np.abs(f_imp[0]))])
print(np.argsort(np.abs(f_imp[0])))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['PVMTCOND_1' 'PVMTCONDIN' 'x12_1.0' 'x1_NE' 'x10_1.0' 'x8_EXCELLENT'
#  'x0_40.0' 'x0_45.0' 'MINIMUMVARIABLEWIDTH' 'x2_Industrial Access'
#  'x2_Urban Center Connector' 'x8_POOR' 'x6_NON-ART' 'x8_VERY-POOR'
#  'SEGLENGTH_log' 'x4_AC' 'x9_Y' 'PRIMARYCROSSSLOPE' 'x0_30.0' 'x3_Y'
#  'SLOPE_PCT' 'SW_WIDTH' 'x6_ART' 'x1_NW' 'x2_Alley' 'x7_Y' 'x1_N'
#  'LENGTH_MIL' 'x5_Y' 'x1_SW' 'FILLERWID' 'x13_In Street, Major Separation'
#  'x0_35.0' 'SURFACEWID_log' 'x8_FAIR' 'x2_Downtown Neighborhood Access'
#  'x5_N' 'x13_Sharrow' 'x7_N' 'x3_N' 'x9_N' 'x4_AC/AC' 'x4_ST' 'x4_AC/PCC'
#  'x2_Urban Village Neighborhood' 'x2_Neighborhood Corridor'
#  'x2_Urban Village Main' 'x2_Downtown Neighborhood'
#  'x11_Clear or Partly Cloudy' 'x8_GOOD' 'x2_Downtown' 'x1_S' 'x1_W'
#  'x1_SE' 'x6_PVMTTOPARK' 'x8_ ' 'x12_0.0' 'x10_0.0' 'x6_NONE' 'x6_PATHWAY'
#  'x4_PCC' 'x13_In Street, Minor Separation' 'x0_25.0' 'x0_20.0'
#  'x2_Urban Village Neighborhood Access' 'x0_55.0' 'x13_NoFacility' 'x1_E'
#  'x2_Neighborhood Yield Street' 'x6_MLTUSETRL' 'x13_Multi-use Trail'
#  'x4_GRAVEL' 'x2_Minor Industrial Access' 'x11_Raining' 'x0_50.0'
#  'x13_Neighborhood Greenway']
# [ 3  2 69 20 65 57 14 15  7 30 34 60 50 61  0 40 63  8 12 39  4  5 48 21
#  26 55 19  9 47 24  6 70 13  1 58 29 46 75 54 38 62 41 45 42 36 32 35 28
#  66 59 27 22 25 23 53 56 68 64 51 52 44 71 11 10 37 17 74 18 33 49 72 43
#  31 67 16 73]

# %%
np.sort(np.abs(f_imp[0]))[-15:]
# Out:
# array([0.72113109, 0.74764401, 0.84827995, 0.85857071, 0.90347981,
#        0.9555665 , 0.98782638, 1.02588154, 1.02648169, 1.13670848,
#        1.16625273, 1.17799511, 1.2068492 , 1.21927037, 1.23223215])

# %%
f_imp[0]
# Out:
# array([ 0.15411936,  0.32958295, -0.00482301,  0.00337757, -0.23282757,
#         0.23478529, -0.29135371, -0.05390111, -0.21371157,  0.26141503,
#         0.84827995,  0.74764401,  0.22218696, -0.32512385,  0.04402983,
#        -0.04686093, -1.21927037, -0.90347981,  0.98782638,  0.25267753,
#         0.02162061,  0.24466131, -0.61746404, -0.62233314, -0.2775402 ,
#        -0.62204264,  0.24574313,  0.61659075,  0.57294736,  0.33827632,
#         0.05787177, -1.17799511, -0.51278996, -1.02588154,  0.06909033,
#         0.53059526,  0.5115282 , -0.85857071, -0.40516908, -0.22742512,
#         0.20198843, -0.43424795,  0.51038149, -1.16625273,  0.71592435,
#        -0.4603878 , -0.36608175, -0.26651244,  0.23730278,  1.02648169,
#         0.12380824, -0.68434856, -0.70242513, -0.63341321, -0.38418136,
#        -0.24841283, -0.64364218, -0.02815699, -0.33212315,  0.58681078,
#        -0.08447872, -0.13100394, -0.42431956, -0.20827463, -0.65968392,
#         0.02708973,  0.57425501, -1.2068492 , -0.64711619,  0.01452199,
#        -0.30853596,  0.72113109, -1.13670848, -1.23223215,  0.9555665 ,
#         0.36818481])

# %%
## Grid Search 

from sklearn.model_selection import GridSearchCV
params = {
    'penalty': ['l1','l2'],
    'C': [0.001, 0.01, 0.1, 1,10,100],
     'class_weight': ['balanced']
}
new_params = {'classifier__' + key: params[key] for key in params}
grid_lg_balance = GridSearchCV(logReg2, param_grid=new_params, cv=K_FOLD, scoring='roc_auc', return_train_score=True)
grid_lg_balance.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('preprocessor',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('num',
#                                                                          Pipeline(memory=None,
#                                                                                   steps=[('imputer',
#                                                                                           SimpleImputer(add_indicator=False,
#                                                                                                         co...
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='liblinear',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'classifier__class_weight': ['balanced'],
#                          'classifier__penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='roc_auc', verbose=0)

# %%
grid_lg_balance.best_params_
# Out:
# {'classifier__C': 1,
#  'classifier__class_weight': 'balanced',
#  'classifier__penalty': 'l2'}

# %%
f_imp = grid_lg_balance.best_estimator_['classifier'].coef_
f_imp
# Out:
# array([[ 1.37927187e-01,  2.90772366e-01,  1.82998642e-02,
#         -6.86278298e-03, -2.50259865e-01,  1.85188464e-01,
#         -4.91841901e-01, -4.25723253e-02, -1.99527555e-01,
#          2.71265846e-01,  6.49138325e-01,  4.82121936e-01,
#          1.31423234e-02, -3.08399236e-01,  9.09937509e-03,
#          1.22398491e-01, -1.16471386e+00, -5.04667043e-01,
#          9.28249967e-01,  2.28034950e-01, -1.30842833e-03,
#          2.65498356e-01, -5.94462951e-01, -6.14015698e-01,
#         -2.76171358e-01, -6.37704523e-01,  4.06791865e-01,
#          5.38414380e-01,  4.89547434e-01,  2.00580036e-01,
#          1.57166034e-01, -1.01295563e+00, -5.31540722e-01,
#         -1.12100866e+00,  1.17044374e-01,  5.10216028e-01,
#          4.62673531e-01, -9.18808351e-01, -4.15589306e-01,
#         -2.86290379e-01,  1.42769839e-01, -7.50461206e-01,
#          3.90789995e-01, -5.40436814e-01,  5.02739870e-01,
#         -4.47281369e-01, -3.96332628e-01, -3.05547056e-01,
#          2.38566281e-01,  1.14010137e+00,  1.75145403e-01,
#         -1.01612237e+00, -5.79657972e-01, -6.59912404e-01,
#         -5.67058510e-01, -1.34821175e-01,  3.86756395e-02,
#         -8.11000821e-02, -4.37155395e-01,  4.19799615e-01,
#         -3.37308109e-01, -3.04791353e-01,  5.49860447e-01,
#         -8.63992357e-01, -8.14066107e-01,  1.49250343e+00,
#          8.07861413e-01, -5.31748564e-01,  8.54519242e-01,
#         -8.29438231e-02, -7.03539275e-01, -9.45231034e-01,
#          6.78680121e-01, -1.28619078e+00,  1.42407601e-01,
#         -4.97909020e-01, -2.03970664e-01, -7.01879684e-01,
#         -1.37182143e-01,  7.37934866e-01,  9.09651090e-01,
#          6.30802258e-01,  7.89945379e-01,  8.06627670e-02,
#         -1.90565852e+00,  3.64700534e-01, -2.90263770e-01,
#          7.70116343e-01, -1.56493655e+00,  1.14943923e+00,
#         -4.85401842e-01, -1.73893435e+00,  8.81706091e-01,
#         -8.94461059e-01,  2.18788231e-01,  1.41044626e-01,
#          1.76995277e-01,  3.37943944e-01,  3.34058657e-01,
#         -5.50369587e-02, -6.67834709e-01,  5.30089327e-01,
#          9.64899475e-01,  2.59275403e-01, -5.65721589e-01,
#         -1.26243354e-01,  9.50227855e-03, -2.05146814e+00,
#          7.64046127e-01, -9.72218276e-01, -6.81586842e-01,
#         -2.02928428e-02,  5.56834549e-01, -1.25871423e+00,
#         -6.80308441e-01, -2.15712429e-02, -3.05903493e-01,
#          6.67322417e-01, -1.24204261e+00, -1.05198020e+00,
#          9.06674983e-01,  3.24049218e-01]])

# %%
cat_name = grid_lg_balance.best_estimator_.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names()

cat_name
# Out:
# array(['x0_20.0', 'x0_25.0', 'x0_30.0', 'x0_35.0', 'x0_40.0', 'x0_45.0',
#        'x0_50.0', 'x0_55.0', 'x1_E', 'x1_N', 'x1_NE', 'x1_NW', 'x1_S',
#        'x1_SE', 'x1_SW', 'x1_W', 'x2_Alley', 'x2_Downtown',
#        'x2_Downtown Neighborhood', 'x2_Downtown Neighborhood Access',
#        'x2_Industrial Access', 'x2_Minor Industrial Access',
#        'x2_Neighborhood Corridor', 'x2_Neighborhood Yield Street',
#        'x2_Urban Center Connector', 'x2_Urban Village Main',
#        'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_AC', 'x9_AC/AG', 'x9_AC/PCC', 'x9_BR', 'x9_GRAVEL', 'x9_OTH',
#        'x9_PCC', 'x9_PCC-TS', 'x9_PCC/AG', 'x9_PV/OTHER', 'x9_PVCC',
#        'x9_ST', 'x9_UIMPRV', 'x10_N', 'x10_Y', 'x11_ ', 'x12_ ', 'x12_AC',
#        'x12_BR', 'x12_GRAVEL', 'x12_LSCP', 'x12_NONE', 'x12_OTH',
#        'x12_PCC', 'x12_PV/OTHER', 'x12_PVCC', 'x12_SWALE', 'x12_TR/AC',
#        'x12_TR/BR', 'x12_TR/O', 'x12_TR/PCC', 'x12_UND', 'x13_ ',
#        'x13_410A', 'x13_410B', 'x13_410C', 'x13_AR', 'x13_DLPSTS',
#        'x13_EX', 'x13_G', 'x13_MONO', 'x13_NONE', 'x13_OTH', 'x13_ROLLCB',
#        'x13_TEAC', 'x13_TEPCC', 'x13_UND', 'x13_WHLSTP', 'x14_0.0',
#        'x14_1.0', 'x15_Clear or Partly Cloudy', 'x15_Raining', 'x16_0.0',
#        'x16_1.0', 'x17_In Street, Major Separation',
#        'x17_In Street, Minor Separation', 'x17_Multi-use Trail',
#        'x17_Neighborhood Greenway', 'x17_NoFacility', 'x17_Sharrow'],
#       dtype=object)

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name,)))
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'x0_20.0', 'x0_25.0', 'x0_30.0',
#        'x0_35.0', 'x0_40.0', 'x0_45.0', 'x0_50.0', 'x0_55.0', 'x1_E',
#        'x1_N', 'x1_NE', 'x1_NW', 'x1_S', 'x1_SE', 'x1_SW', 'x1_W',
#        'x2_Alley', 'x2_Downtown', 'x2_Downtown Neighborhood',
#        'x2_Downtown Neighborhood Access', 'x2_Industrial Access',
#        'x2_Minor Industrial Access', 'x2_Neighborhood Corridor',
#        'x2_Neighborhood Yield Street', 'x2_Urban Center Connector',
#        'x2_Urban Village Main', 'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_AC', 'x9_AC/AG', 'x9_AC/PCC', 'x9_BR', 'x9_GRAVEL', 'x9_OTH',
#        'x9_PCC', 'x9_PCC-TS', 'x9_PCC/AG', 'x9_PV/OTHER', 'x9_PVCC',
#        'x9_ST', 'x9_UIMPRV', 'x10_N', 'x10_Y', 'x11_ ', 'x12_ ', 'x12_AC',
#        'x12_BR', 'x12_GRAVEL', 'x12_LSCP', 'x12_NONE', 'x12_OTH',
#        'x12_PCC', 'x12_PV/OTHER', 'x12_PVCC', 'x12_SWALE', 'x12_TR/AC',
#        'x12_TR/BR', 'x12_TR/O', 'x12_TR/PCC', 'x12_UND', 'x13_ ',
#        'x13_410A', 'x13_410B', 'x13_410C', 'x13_AR', 'x13_DLPSTS',
#        'x13_EX', 'x13_G', 'x13_MONO', 'x13_NONE', 'x13_OTH', 'x13_ROLLCB',
#        'x13_TEAC', 'x13_TEPCC', 'x13_UND', 'x13_WHLSTP', 'x14_0.0',
#        'x14_1.0', 'x15_Clear or Partly Cloudy', 'x15_Raining', 'x16_0.0',
#        'x16_1.0', 'x17_In Street, Major Separation',
#        'x17_In Street, Minor Separation', 'x17_Multi-use Trail',
#        'x17_Neighborhood Greenway', 'x17_NoFacility', 'x17_Sharrow'],
#       dtype=object)

# %%
categorical_features
# Out:
# ['SPEEDLIMIT',
#  'SEGDIR',
#  'STREETTYPE',
#  'ONEWAY',
#  'SURFACETYP',
#  'NATIONHWYS',
#  'PVMTCATEGO',
#  'PARKBOULEV',
#  'CONDITION',
#  'SWINCOMPLETEYN',
#  'simulate_rushhour',
#  'simulate_weather',
#  'simulate_weekday',
#  'EXISTING_FACILITY_TYPE']

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name,)))
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'x0_20.0', 'x0_25.0', 'x0_30.0',
#        'x0_35.0', 'x0_40.0', 'x0_45.0', 'x0_50.0', 'x0_55.0', 'x1_E',
#        'x1_N', 'x1_NE', 'x1_NW', 'x1_S', 'x1_SE', 'x1_SW', 'x1_W',
#        'x2_Alley', 'x2_Downtown', 'x2_Downtown Neighborhood',
#        'x2_Downtown Neighborhood Access', 'x2_Industrial Access',
#        'x2_Minor Industrial Access', 'x2_Neighborhood Corridor',
#        'x2_Neighborhood Yield Street', 'x2_Urban Center Connector',
#        'x2_Urban Village Main', 'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_N',
#        'x5_Y', 'x6_ART', 'x6_MLTUSETRL', 'x6_NON-ART', 'x6_NONE',
#        'x6_PATHWAY', 'x6_PVMTTOPARK', 'x7_N', 'x7_Y', 'x8_ ',
#        'x8_EXCELLENT', 'x8_FAIR', 'x8_GOOD', 'x8_POOR', 'x8_VERY-POOR',
#        'x9_AC', 'x9_AC/AG', 'x9_AC/PCC', 'x9_BR', 'x9_GRAVEL', 'x9_OTH',
#        'x9_PCC', 'x9_PCC-TS', 'x9_PCC/AG', 'x9_PV/OTHER', 'x9_PVCC',
#        'x9_ST', 'x9_UIMPRV', 'x10_N', 'x10_Y', 'x11_ ', 'x12_ ', 'x12_AC',
#        'x12_BR', 'x12_GRAVEL', 'x12_LSCP', 'x12_NONE', 'x12_OTH',
#        'x12_PCC', 'x12_PV/OTHER', 'x12_PVCC', 'x12_SWALE', 'x12_TR/AC',
#        'x12_TR/BR', 'x12_TR/O', 'x12_TR/PCC', 'x12_UND', 'x13_ ',
#        'x13_410A', 'x13_410B', 'x13_410C', 'x13_AR', 'x13_DLPSTS',
#        'x13_EX', 'x13_G', 'x13_MONO', 'x13_NONE', 'x13_OTH', 'x13_ROLLCB',
#        'x13_TEAC', 'x13_TEPCC', 'x13_UND', 'x13_WHLSTP', 'x14_0.0',
#        'x14_1.0', 'x15_Clear or Partly Cloudy', 'x15_Raining', 'x16_0.0',
#        'x16_1.0', 'x17_In Street, Major Separation',
#        'x17_In Street, Minor Separation', 'x17_Multi-use Trail',
#        'x17_Neighborhood Greenway', 'x17_NoFacility', 'x17_Sharrow'],
#       dtype=object)

# %%
#logReg2.predict_proba(X)

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp[0])])
print(np.sort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['x13_TEPCC' 'x12_OTH' 'x12_TR/O' 'x12_SWALE' 'x9_ST' 'x15_Raining'
#  'x17_Multi-use Trail' 'x0_50.0' 'x2_Neighborhood Yield Street'
#  'x17_Neighborhood Greenway' 'x6_NONE' 'x2_Minor Industrial Access'
#  'x13_WHLSTP' 'x9_PV/OTHER' 'x2_Urban Village Neighborhood Access'
#  'x12_UND' 'x9_AC/AG' 'x9_AC/PCC' 'x4_AC/AC' 'x9_PCC/AG' 'x11_ ' 'x14_0.0'
#  'x16_0.0' 'x13_EX' 'x6_PVMTTOPARK' 'x1_W' 'x1_SE' 'x1_S' 'x6_PATHWAY'
#  'x7_N' 'x13_OTH' 'x4_GRAVEL' 'x9_OTH' 'x2_Neighborhood Corridor'
#  'x0_55.0' 'x10_N' 'FILLERWID' 'x12_TR/BR' 'x4_ST' 'x8_FAIR' 'x3_N' 'x5_N'
#  'x8_POOR' 'x0_35.0' 'x17_In Street, Major Separation' 'x5_Y'
#  'x8_VERY-POOR' 'x12_PV/OTHER' 'x3_Y' 'x1_SW' 'SLOPE_PCT' 'x10_Y'
#  'PRIMARYCROSSSLOPE' 'x12_ ' 'x7_Y' 'x13_ROLLCB' 'x9_PCC-TS'
#  'x8_EXCELLENT' 'x13_DLPSTS' 'MINIMUMVARIABLEWIDTH' 'x16_1.0' 'x14_1.0'
#  'PVMTCOND_1' 'x1_NE' 'x0_40.0' 'x13_TEAC' 'x0_30.0' 'PVMTCONDIN' 'x8_ '
#  'x12_NONE' 'x2_Urban Center Connector' 'x0_45.0' 'SEGLENGTH_log'
#  'x13_410A' 'x9_UIMPRV' 'x4_AC' 'x2_Industrial Access' 'x6_NON-ART'
#  'x13_410B' 'SW_WIDTH' 'x2_Downtown Neighborhood Access' 'x13_ ' 'x1_N'
#  'x6_ART' 'x13_NONE' 'x1_NW' 'LENGTH_MIL' 'SURFACEWID_log' 'x17_Sharrow'
#  'x13_AR' 'x13_410C' 'x12_PCC' 'x4_AC/PCC' 'x2_Alley' 'x8_GOOD'
#  'x2_Urban Village Neighborhood' 'x0_25.0' 'x2_Downtown Neighborhood'
#  'x4_PCC' 'x2_Urban Village Main' 'x13_G' 'x2_Downtown' 'x9_AC'
#  'x15_Clear or Partly Cloudy' 'x12_GRAVEL' 'x0_20.0'
#  'x17_In Street, Minor Separation' 'x9_PVCC' 'x12_AC' 'x13_UND' 'x12_PVCC'
#  'x12_LSCP' 'x9_GRAVEL' 'x9_PCC' 'x12_TR/PCC' 'x17_NoFacility' 'x12_BR'
#  'x1_E' 'x13_MONO' 'x6_MLTUSETRL' 'x12_TR/AC' 'x9_BR']
# [-2.05146814e+00 -1.90565852e+00 -1.73893435e+00 -1.56493655e+00
#  -1.28619078e+00 -1.25871423e+00 -1.24204261e+00 -1.16471386e+00
#  -1.12100866e+00 -1.05198020e+00 -1.01612237e+00 -1.01295563e+00
#  -9.72218276e-01 -9.45231034e-01 -9.18808351e-01 -8.94461059e-01
#  -8.63992357e-01 -8.14066107e-01 -7.50461206e-01 -7.03539275e-01
#  -7.01879684e-01 -6.81586842e-01 -6.80308441e-01 -6.67834709e-01
#  -6.59912404e-01 -6.37704523e-01 -6.14015698e-01 -5.94462951e-01
#  -5.79657972e-01 -5.67058510e-01 -5.65721589e-01 -5.40436814e-01
#  -5.31748564e-01 -5.31540722e-01 -5.04667043e-01 -4.97909020e-01
#  -4.91841901e-01 -4.85401842e-01 -4.47281369e-01 -4.37155395e-01
#  -4.15589306e-01 -3.96332628e-01 -3.37308109e-01 -3.08399236e-01
#  -3.05903493e-01 -3.05547056e-01 -3.04791353e-01 -2.90263770e-01
#  -2.86290379e-01 -2.76171358e-01 -2.50259865e-01 -2.03970664e-01
#  -1.99527555e-01 -1.37182143e-01 -1.34821175e-01 -1.26243354e-01
#  -8.29438231e-02 -8.11000821e-02 -5.50369587e-02 -4.25723253e-02
#  -2.15712429e-02 -2.02928428e-02 -6.86278298e-03 -1.30842833e-03
#   9.09937509e-03  9.50227855e-03  1.31423234e-02  1.82998642e-02
#   3.86756395e-02  8.06627670e-02  1.17044374e-01  1.22398491e-01
#   1.37927187e-01  1.41044626e-01  1.42407601e-01  1.42769839e-01
#   1.57166034e-01  1.75145403e-01  1.76995277e-01  1.85188464e-01
#   2.00580036e-01  2.18788231e-01  2.28034950e-01  2.38566281e-01
#   2.59275403e-01  2.65498356e-01  2.71265846e-01  2.90772366e-01
#   3.24049218e-01  3.34058657e-01  3.37943944e-01  3.64700534e-01
#   3.90789995e-01  4.06791865e-01  4.19799615e-01  4.62673531e-01
#   4.82121936e-01  4.89547434e-01  5.02739870e-01  5.10216028e-01
#   5.30089327e-01  5.38414380e-01  5.49860447e-01  5.56834549e-01
#   6.30802258e-01  6.49138325e-01  6.67322417e-01  6.78680121e-01
#   7.37934866e-01  7.64046127e-01  7.70116343e-01  7.89945379e-01
#   8.07861413e-01  8.54519242e-01  8.81706091e-01  9.06674983e-01
#   9.09651090e-01  9.28249967e-01  9.64899475e-01  1.14010137e+00
#   1.14943923e+00  1.49250343e+00]

# %%
# Plot! 

plt.figure(figsize=(5,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp[0])])
print(np.argsort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['x13_TEPCC' 'x12_OTH' 'x12_TR/O' 'x12_SWALE' 'x9_ST' 'x15_Raining'
#  'x17_Multi-use Trail' 'x0_50.0' 'x2_Neighborhood Yield Street'
#  'x17_Neighborhood Greenway' 'x6_NONE' 'x2_Minor Industrial Access'
#  'x13_WHLSTP' 'x9_PV/OTHER' 'x2_Urban Village Neighborhood Access'
#  'x12_UND' 'x9_AC/AG' 'x9_AC/PCC' 'x4_AC/AC' 'x9_PCC/AG' 'x11_ ' 'x14_0.0'
#  'x16_0.0' 'x13_EX' 'x6_PVMTTOPARK' 'x1_W' 'x1_SE' 'x1_S' 'x6_PATHWAY'
#  'x7_N' 'x13_OTH' 'x4_GRAVEL' 'x9_OTH' 'x2_Neighborhood Corridor'
#  'x0_55.0' 'x10_N' 'FILLERWID' 'x12_TR/BR' 'x4_ST' 'x8_FAIR' 'x3_N' 'x5_N'
#  'x8_POOR' 'x0_35.0' 'x17_In Street, Major Separation' 'x5_Y'
#  'x8_VERY-POOR' 'x12_PV/OTHER' 'x3_Y' 'x1_SW' 'SLOPE_PCT' 'x10_Y'
#  'PRIMARYCROSSSLOPE' 'x12_ ' 'x7_Y' 'x13_ROLLCB' 'x9_PCC-TS'
#  'x8_EXCELLENT' 'x13_DLPSTS' 'MINIMUMVARIABLEWIDTH' 'x16_1.0' 'x14_1.0'
#  'PVMTCOND_1' 'x1_NE' 'x0_40.0' 'x13_TEAC' 'x0_30.0' 'PVMTCONDIN' 'x8_ '
#  'x12_NONE' 'x2_Urban Center Connector' 'x0_45.0' 'SEGLENGTH_log'
#  'x13_410A' 'x9_UIMPRV' 'x4_AC' 'x2_Industrial Access' 'x6_NON-ART'
#  'x13_410B' 'SW_WIDTH' 'x2_Downtown Neighborhood Access' 'x13_ ' 'x1_N'
#  'x6_ART' 'x13_NONE' 'x1_NW' 'LENGTH_MIL' 'SURFACEWID_log' 'x17_Sharrow'
#  'x13_AR' 'x13_410C' 'x12_PCC' 'x4_AC/PCC' 'x2_Alley' 'x8_GOOD'
#  'x2_Urban Village Neighborhood' 'x0_25.0' 'x2_Downtown Neighborhood'
#  'x4_PCC' 'x2_Urban Village Main' 'x13_G' 'x2_Downtown' 'x9_AC'
#  'x15_Clear or Partly Cloudy' 'x12_GRAVEL' 'x0_20.0'
#  'x17_In Street, Minor Separation' 'x9_PVCC' 'x12_AC' 'x13_UND' 'x12_PVCC'
#  'x12_LSCP' 'x9_GRAVEL' 'x9_PCC' 'x12_TR/PCC' 'x17_NoFacility' 'x12_BR'
#  'x1_E' 'x13_MONO' 'x6_MLTUSETRL' 'x12_TR/AC' 'x9_BR']
# [107  84  91  88  73 113 118  16  33 119  51  31 109  71  37  93  63  64
#   41  70  77 110 114 100  53  25  23  22  52  54 104  43  67  32  17  75
#    6  90  45  58  38  46  60  13 116  47  61  86  39  24   4  76   8  78
#   55 105  69  57  99   7 115 111   3  20  14 106  12   2  56  83  34  15
#    0  95  74  40  30  50  96   5  29  94  19  48 103  21   9   1 121  98
#   97  85  42  26  59  36  11  28  44  35 101  27  62 112  81  10 117  72
#   79 108  87  82  66  68  92 120  80  18 102  49  89  65]

# %%
## Logsitic Regression with Undersampling 
from imblearn.pipeline import make_pipeline

logReg = make_pipeline(preprocessor,rus, log)
#logReg = Pipeline(steps=[('preprocessor', preprocessor),('undersampler', rus),('classifier', log)])

## cross validate 
from sklearn.model_selection import cross_validate

#scores = cross_validate(logReg, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision'], cv = K_FOLD, return_train_score= True, return_estimator=True)
#scores

# %%
## SMOTE 

from imblearn.over_sampling import SMOTE, ADASYN

sm = SMOTE()
#sm = KMeansSMOTE(sampling_strategy= 'minority', random_state=42)
## Logsitic Regression
from imblearn.pipeline import make_pipeline

from sklearn.linear_model import LogisticRegression
log = LogisticRegression(solver='liblinear')

logReg_sm = make_pipeline(preprocessor,sm, log)

## cross validate 
from sklearn.model_selection import cross_validate

#scores = cross_validate(logReg_sm, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision' , 'f1'], cv = K_FOLD, return_train_score= True, return_estimator=True)

# %%
#grid search 
from sklearn.model_selection import GridSearchCV
params = {
    'penalty': ['l1','l2'],
    'C': [0.001, 0.01, 0.1, 1,10],
     'class_weight': [None,'balanced']
}
new_params = {'logisticregression__' + key: params[key] for key in params}
grid_logReg_sm = GridSearchCV(logReg_sm, param_grid=new_params, cv=K_FOLD, scoring='roc_auc', return_train_score=True)
grid_logReg_sm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('columntransformer',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('num',
#                                                                          Pipeline(memory=None,
#                                                                                   steps=[('imputer',
#                                                                                           SimpleImputer(add_indicator=Fal...
#                                                            random_state=None,
#                                                            solver='liblinear',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'logisticregression__C': [0.001, 0.01, 0.1, 1, 10],
#                          'logisticregression__class_weight': [None, 'balanced'],
#                          'logisticregression__penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='roc_auc', verbose=0)

# %%
prediction = logReg_sm.predict(X_test)
len(prediction)

from sklearn import metrics 
print(metrics.recall_score(y_test, prediction))
print(metrics.precision_score(y_test, prediction))
print(metrics.roc_auc_score(y_test, prediction))
print(metrics.f1_score(y_test, prediction))
print(metrics.confusion_matrix(y_test, prediction))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-187-f0b82c79096f> in <module>
# ----> 1 prediction = logReg_sm.predict(X_test)
#       2 len(prediction)
#       3
#       4 from sklearn import metrics
#       5 print(metrics.recall_score(y_test, prediction))
#
# //anaconda3/lib/python3.7/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# //anaconda3/lib/python3.7/site-packages/imblearn/pipeline.py in predict(self, X, **predict_params)
#     345                 pass
#     346             else:
# --> 347                 Xt = transform.transform(Xt)
#     348         return self.steps[-1][-1].predict(Xt, **predict_params)
#     349
#
# //anaconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     507
#     508         """
# --> 509         check_is_fitted(self, 'transformers_')
#     510
#     511         X = _check_X(X)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# NotFittedError: This ColumnTransformer instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
cat_name = logReg.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name,)))

# %%
categorical_features

# %%
plt.figure(figsize=(20,20))
plt.barh(range(len(log.coef_[0])), width=np.sort(log.coef_[0]))
plt.yticks(ticks=range(len(log.coef_[0])), labels=featurename[np.argsort(log.coef_[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(log.coef_[0])])
print(np.sort(log.coef_[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')

# %%
## Random Forest with SMOTE 
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
#from preprocessing import OrdinalEncoder
## Random Oversampler 
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import NearMiss
sm= SMOTE() #ratio = RATIO
#nm = NearMiss(sampling_strategy = 'majority')

## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encode', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])


clf = RandomForestClassifier()
rf = make_pipeline(preprocessor,sm ,clf)

## cross validate 
from sklearn.model_selection import cross_validate

scores = cross_validate(rf, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision', 'f1'], cv = K_FOLD, return_train_score = True, return_estimator=True)
# Out:
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
scores
# Out:
# {'fit_time': array([30.83521819, 33.25223184, 20.20347595, 19.02819705, 18.74582314]),
#  'score_time': array([1.21761584, 0.57929397, 0.54773593, 0.54094911, 0.52541995]),
#  'estimator': (Pipeline(memory=None,
#            steps=[('columntransformer',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with...
#                    RandomForestClassifier(bootstrap=True, class_weight=None,
#                                           criterion='gini', max_depth=None,
#                                           max_features='auto',
#                                           max_leaf_nodes=None,
#                                           min_impurity_decrease=0.0,
#                                           min_impurity_split=None,
#                                           min_samples_leaf=1, min_samples_split=2,
#                                           min_weight_fraction_leaf=0.0,
#                                           n_estimators=10, n_jobs=None,
#                                           oob_score=False, random_state=None,
#                                           verbose=0, warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('columntransformer',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with...
#                    RandomForestClassifier(bootstrap=True, class_weight=None,
#                                           criterion='gini', max_depth=None,
#                                           max_features='auto',
#                                           max_leaf_nodes=None,
#                                           min_impurity_decrease=0.0,
#                                           min_impurity_split=None,
#                                           min_samples_leaf=1, min_samples_split=2,
#                                           min_weight_fraction_leaf=0.0,
#                                           n_estimators=10, n_jobs=None,
#                                           oob_score=False, random_state=None,
#                                           verbose=0, warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('columntransformer',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with...
#                    RandomForestClassifier(bootstrap=True, class_weight=None,
#                                           criterion='gini', max_depth=None,
#                                           max_features='auto',
#                                           max_leaf_nodes=None,
#                                           min_impurity_decrease=0.0,
#                                           min_impurity_split=None,
#                                           min_samples_leaf=1, min_samples_split=2,
#                                           min_weight_fraction_leaf=0.0,
#                                           n_estimators=10, n_jobs=None,
#                                           oob_score=False, random_state=None,
#                                           verbose=0, warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('columntransformer',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with...
#                    RandomForestClassifier(bootstrap=True, class_weight=None,
#                                           criterion='gini', max_depth=None,
#                                           max_features='auto',
#                                           max_leaf_nodes=None,
#                                           min_impurity_decrease=0.0,
#                                           min_impurity_split=None,
#                                           min_samples_leaf=1, min_samples_split=2,
#                                           min_weight_fraction_leaf=0.0,
#                                           n_estimators=10, n_jobs=None,
#                                           oob_score=False, random_state=None,
#                                           verbose=0, warm_start=False))],
#            verbose=False), Pipeline(memory=None,
#            steps=[('columntransformer',
#                    ColumnTransformer(n_jobs=None, remainder='drop',
#                                      sparse_threshold=0.3,
#                                      transformer_weights=None,
#                                      transformers=[('num',
#                                                     Pipeline(memory=None,
#                                                              steps=[('imputer',
#                                                                      SimpleImputer(add_indicator=False,
#                                                                                    copy=True,
#                                                                                    fill_value=None,
#                                                                                    missing_values=nan,
#                                                                                    strategy='median',
#                                                                                    verbose=0)),
#                                                                     ('scaler',
#                                                                      StandardScaler(copy=True,
#                                                                                     with...
#                    RandomForestClassifier(bootstrap=True, class_weight=None,
#                                           criterion='gini', max_depth=None,
#                                           max_features='auto',
#                                           max_leaf_nodes=None,
#                                           min_impurity_decrease=0.0,
#                                           min_impurity_split=None,
#                                           min_samples_leaf=1, min_samples_split=2,
#                                           min_weight_fraction_leaf=0.0,
#                                           n_estimators=10, n_jobs=None,
#                                           oob_score=False, random_state=None,
#                                           verbose=0, warm_start=False))],
#            verbose=False)),
#  'test_roc_auc': array([0.87653836, 0.87902982, 0.88306723, 0.88550508, 0.88621866]),
#  'train_roc_auc': array([0.99973445, 0.99970993, 0.99973506, 0.99968034, 0.99970545]),
#  'test_recall': array([0.48529412, 0.51470588, 0.50686275, 0.53039216, 0.53431373]),
#  'train_recall': array([0.95539216, 0.95      , 0.95196078, 0.94779412, 0.9502451 ]),
#  'test_accuracy': array([0.93799113, 0.94070962, 0.94063181, 0.93923125, 0.94063181]),
#  'train_accuracy': array([0.9951953 , 0.99496197, 0.9952343 , 0.99461184, 0.99498142]),
#  'test_precision': array([0.64537158, 0.66287879, 0.66537967, 0.64175563, 0.6542617 ]),
#  'train_precision': array([0.98359828, 0.98600865, 0.98754132, 0.98371916, 0.98601221]),
#  'test_f1': array([0.55400112, 0.5794702 , 0.57540345, 0.58078368, 0.58823529]),
#  'train_f1': array([0.96929007, 0.96766945, 0.96942468, 0.96542254, 0.9677983 ])}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 6, 10, 12],
}
new_params = {'randomforestclassifier__' + key: params[key] for key in params}
grid_imba = RandomizedSearchCV(rf, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                      n_jobs=None,
#                                                                      oob_score=False,
#                                                                      random_state=None,
#                                                                      verbose=0,
#                                                                      warm_start=False))],
#                                       verbose=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'randomforestclassifier__max_depth': [4,
#                                                                               6,
#                                                                               10,
#                                                                               12],
#                                         'randomforestclassifier__n_estimators': [50,
#                                                                                  100,
#                                                                                  200]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
#grid_imba.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['encode'].categories_

featurename = np.array(np.concatenate(( np.array(numeric_features), categorical_features)))
#featurename
#numeric_features + categorical_features
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'SPEEDLIMIT', 'SEGDIR',
#        'STREETTYPE', 'ONEWAY', 'SURFACETYP', 'PVMTCATEGO', 'CONDITION',
#        'SWINCOMPLETEYN', 'simulate_rushhour', 'simulate_weather',
#        'simulate_weekday', 'EXISTING_FACILITY_TYPE', 'CLASS_DESC',
#        'GEN_ALIAS'], dtype='<U22')

# %%
#f_imp = rf['randomforestclassifier'].feature_importances_

# %%
f_imp = grid_imba.best_estimator_['randomforestclassifier'].feature_importances_
f_imp
# Out:
# array([7.94683672e-04, 9.88009923e-02, 4.13669933e-04, 7.63122081e-05,
#        1.15380980e-03, 1.61224006e-02, 6.93938238e-03, 1.40019399e-05,
#        8.48803352e-03, 4.07337278e-03, 8.75704292e-02, 3.23535045e-03,
#        2.81149631e-02, 3.56996203e-04, 2.36514374e-02, 1.44847550e-01,
#        3.38049182e-03, 1.38133667e-05, 6.94171880e-02, 2.30843521e-01,
#        1.53970554e-01, 4.26006020e-03, 1.10223599e-01, 3.23738703e-03])

# %%
#cat_name = grid_imba.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()

# %%
grid_imba.best_params_
# Out:
# {'randomforestclassifier__n_estimators': 100,
#  'randomforestclassifier__max_depth': 4}

# %%
grid_imba.best_params_
grid_imba.best_score_
# Out:
# 0.7488235324630467

# %%
_y_prediction = grid_imba.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba.predict(X_train)

print(accuracy_score(y_train,_y_prediction))
print(recall_score(y_train,_y_prediction))
print(precision_score(y_train,_y_prediction))
print(roc_auc_score(y_train,_y_prediction))
# Out:
# 0.8731734644652277
# 0.7305882352941176
# 0.35478956389259186
# 0.8080266610455815

# %%
grid_imba.cv_results_
# Out:
# {'mean_fit_time': array([18.38070369, 16.91612601, 23.64188814, 15.82060043, 16.28603371,
#         20.82545543, 25.15644304, 14.46983997, 30.6679643 , 33.95130126]),
#  'std_fit_time': array([0.05007667, 0.13193982, 0.55371525, 0.02252725, 0.08560659,
#         0.22530716, 0.15959004, 0.16902369, 0.29055771, 1.16877765]),
#  'mean_score_time': array([0.33530601, 0.29316187, 0.48633893, 0.27030055, 0.29284867,
#         0.40011263, 0.50651328, 0.23263073, 0.66309619, 0.76210395]),
#  'std_score_time': array([0.00681634, 0.00150945, 0.03375236, 0.00451412, 0.0043936 ,
#         0.00342686, 0.00099386, 0.00151839, 0.00365544, 0.00914512]),
#  'param_randomforestclassifier__n_estimators': masked_array(data=[100, 100, 100, 50, 50, 100, 200, 50, 200, 200],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_randomforestclassifier__max_depth': masked_array(data=[6, 4, 12, 10, 12, 10, 6, 6, 10, 12],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'randomforestclassifier__n_estimators': 100,
#    'randomforestclassifier__max_depth': 6},
#   {'randomforestclassifier__n_estimators': 100,
#    'randomforestclassifier__max_depth': 4},
#   {'randomforestclassifier__n_estimators': 100,
#    'randomforestclassifier__max_depth': 12},
#   {'randomforestclassifier__n_estimators': 50,
#    'randomforestclassifier__max_depth': 10},
#   {'randomforestclassifier__n_estimators': 50,
#    'randomforestclassifier__max_depth': 12},
#   {'randomforestclassifier__n_estimators': 100,
#    'randomforestclassifier__max_depth': 10},
#   {'randomforestclassifier__n_estimators': 200,
#    'randomforestclassifier__max_depth': 6},
#   {'randomforestclassifier__n_estimators': 50,
#    'randomforestclassifier__max_depth': 6},
#   {'randomforestclassifier__n_estimators': 200,
#    'randomforestclassifier__max_depth': 10},
#   {'randomforestclassifier__n_estimators': 200,
#    'randomforestclassifier__max_depth': 12}],
#  'split0_test_score': array([0.73411765, 0.74470588, 0.64705882, 0.67058824, 0.64529412,
#         0.66294118, 0.71470588, 0.68764706, 0.67352941, 0.65588235]),
#  'split1_test_score': array([0.69882353, 0.71882353, 0.62352941, 0.65235294, 0.61588235,
#         0.65117647, 0.69647059, 0.69235294, 0.65705882, 0.61764706]),
#  'split2_test_score': array([0.68647059, 0.73294118, 0.62294118, 0.65882353, 0.61705882,
#         0.64588235, 0.67823529, 0.67352941, 0.64823529, 0.62294118]),
#  'mean_test_score': array([0.70647102, 0.73215706, 0.63117672, 0.66058839, 0.62607873,
#         0.65333348, 0.69647087, 0.68450985, 0.65960806, 0.63215723]),
#  'std_test_score': array([0.02018955, 0.010581  , 0.01123317, 0.00754843, 0.01359613,
#         0.00712932, 0.01488911, 0.00799841, 0.01048247, 0.01691523]),
#  'rank_test_score': array([ 2,  1,  9,  5, 10,  7,  3,  4,  6,  8], dtype=int32),
#  'split0_train_score': array([0.73235294, 0.73529412, 0.74058824, 0.70823529, 0.74823529,
#         0.70411765, 0.71617647, 0.69617647, 0.71323529, 0.75264706]),
#  'split1_train_score': array([0.72735294, 0.745     , 0.75235294, 0.72647059, 0.75176471,
#         0.71352941, 0.71117647, 0.71441176, 0.71823529, 0.74970588]),
#  'split2_train_score': array([0.71088235, 0.74147059, 0.75647059, 0.72764706, 0.75382353,
#         0.71441176, 0.70647059, 0.70441176, 0.72147059, 0.75029412]),
#  'mean_train_score': array([0.72352941, 0.74058824, 0.74980392, 0.72078431, 0.75127451,
#         0.71068627, 0.71127451, 0.705     , 0.71764706, 0.75088235]),
#  'std_train_score': array([0.00917282, 0.00401123, 0.0067298 , 0.00888649, 0.00230757,
#         0.00465867, 0.00396302, 0.00745614, 0.00338768, 0.00127073])}

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename [np.argsort(f_imp)],
    'Importance': np.sort(f_imp)
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,20))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Feature importance')
plt.title('Random forest feature importance')
#plt.savefig("fig/rf_feat_importance.png", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Random forest feature importance')

# %%
## Random Forest with undersampling Nearmiss
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
#from preprocessing import OrdinalEncoder
## Random Oversampler 
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import NearMiss
#sm= SMOTE() #ratio = RATIO
nm = NearMiss(sampling_strategy = 'majority')

## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encode', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])


clf = RandomForestClassifier()
rf = make_pipeline(preprocessor,nm ,clf)


from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 6, 10, 12],
}
new_params = {'randomforestclassifier__' + key: params[key] for key in params}
grid_imba2 = RandomizedSearchCV(rf, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba2.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                      n_jobs=None,
#                                                                      oob_score=False,
#                                                                      random_state=None,
#                                                                      verbose=0,
#                                                                      warm_start=False))],
#                                       verbose=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'randomforestclassifier__max_depth': [4,
#                                                                               6,
#                                                                               10,
#                                                                               12],
#                                         'randomforestclassifier__n_estimators': [50,
#                                                                                  100,
#                                                                                  200]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba2.predict(X_train)

print(accuracy_score(y_train,_y_prediction))
print(recall_score(y_train,_y_prediction))
print(precision_score(y_train,_y_prediction))
print(roc_auc_score(y_train,_y_prediction))
# Out:
# 0.7156906988686762
# 0.8774509803921569
# 0.20230560578661844
# 0.7895985315577863

# %%
## try XGboost 
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
xgboost = make_pipeline(preprocessor,xgb_model)

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

new_params = {'xgbclassifier__' + key: params[key] for key in params}


grid_imba3 = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba3.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
grid_imba3
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba3.predict(X_train)

print(accuracy_score(y_train,_y_prediction))
print(recall_score(y_train,_y_prediction))
print(precision_score(y_train,_y_prediction))
print(roc_auc_score(y_train,_y_prediction))
# Out:
# 0.6266942624609017
# 0.902156862745098
# 0.16378911395108753
# 0.7525523753559165

# %%
grid_imba3.best_score_
# Out:
# 0.9560785351161364

# %%
grid_imba3.best_params_
# Out:
# {'xgbclassifier__scale_pos_weight': 15,
#  'xgbclassifier__reg_alpha': 10000,
#  'xgbclassifier__min_child_weight': 5,
#  'xgbclassifier__max_depth': 5,
#  'xgbclassifier__learning_rate': 0.01,
#  'xgbclassifier__gamma': 0.0,
#  'xgbclassifier__colsample_bytree': 0.4}

# %%
from xgboost import plot_importance 
plot_importance(grid_imba3.best_estimator_['xgbclassifier'])

# %%
f_imp = grid_imba3.best_estimator_['xgbclassifier'].feature_importances_

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), categorical_features)))
len(featurename)
len(f_imp)
# Out:
# 24

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename [np.argsort(f_imp)],
    'Importance': np.sort(f_imp)
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,20))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Feature importance')
plt.title('Random forest feature importance')
#plt.savefig("fig/rf_feat_importance.png", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Random forest feature importance')

# %%
##XGBOOST with FEATURE SELECTION 

## try XGboost 
import xgboost as xgb
from sklearn.feature_selection import SelectFromModel

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
#xgboost = make_pipeline(preprocessor,xgb_model)
grid_imba4 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('feature_selection', SelectFromModel(xgb.XGBClassifier(threshold = 0.01))),
                          ('classifier', xgb_model)])


#params0 = {"threshold" : [0.001, 0.01, 0.03, 0.05, 0.08, 0.1 ]  }

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

#new_params4 = dict({'selectfrommodel__' + key: params0[key] for key in params0})
#new_params4.update( {'classifier__' + key: params[key] for key in params}.items())

new_params4 = {'xgbclassifier__' + key: params[key] for key in params}

grid_imba4 = RandomizedSearchCV(xgboost, param_distributions =new_params4, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba4.fit(X_train, y_train)

# %%
grid_imba4.best_estimator_.get_params()

# %%
grid_imba4.best_estimator_

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), categorical_features)))
f_imp = grid_imba4.best_estimator_['xgbclassifier'].feature_importances_

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename [np.argsort(f_imp)],
    'Importance': np.sort(f_imp)
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,20))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Feature importance')
plt.title('Random forest feature importance')
#plt.savefig("fig/rf_feat_importance.png", bbox_inches='tight')
