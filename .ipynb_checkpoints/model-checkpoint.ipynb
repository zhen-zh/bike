# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd 

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder ,OrdinalEncoder
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
## function to show model metrics 
def scores(model, X_, y_):
    from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score
    _y_prediction = model.predict(X_)
    print(len(_y_prediction))
    print("accuracy_score: ", accuracy_score(y_,_y_prediction))
    print("recall_score: ", recall_score(y_,_y_prediction))
    print("precision_score: ", precision_score(y_,_y_prediction))
    print(" roc_auc_score: ", roc_auc_score(y_,_y_prediction))

# %%
# function to plot ROC scores 

def roc_plot(model, X_test, y_test):
    from sklearn.metrics import roc_curve
    from sklearn.metrics import roc_auc_score
    
    # No skill model
    ns_probs = [0 for _ in range(len(y_test))]


    # predict based on X_test
    probs =xg_ord.predict_proba(X_test)[:,1]

    # calculate scores based on y_test
    ns_auc = roc_auc_score(y_test, ns_probs)
    lr_auc = roc_auc_score(y_test, probs)
    # summarize scores
    print('No Skill: ROC AUC=%.3f' % (ns_auc))
    print('Model: ROC AUC=%.3f' % (lr_auc))
    # calculate roc curves
    ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
    lr_fpr, lr_tpr, _ = roc_curve(y_test, probs)
    # plot the roc curve for the model
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
    plt.plot(lr_fpr, lr_tpr, marker='.', label= 'Model')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    # show the legend
    plt.legend()
    # show the plot
    plt.show()

# %%
bikecl  = pd.read_csv("./data/bikecl_with_bikelane_updated_Oct3.csv", sep= ",")
#strt2 = pd.read_csv('./data/street_withlane_Oct5.csv', sep= ",")

# %%
strt2 = pd.read_csv('./data/street_bike_sidewalk_oct6.csv', sep= ",")
len(strt2)
# Out:
# 23495

# %%
#Read file using gpd.read_file()
fp2 = "./data/Seattle_Streets/Seattle_Streets.shp"
street = gpd.read_file(fp2)

# filter out highway, 0 is non-artisial 
strt = street.loc[street['ARTCLASS'] < 4,].reset_index(drop = True).copy()

## remove road underconstruction or planned
Street_shp = strt.loc[(strt['STATUS'] != 'UNDERCONS') & (strt['STATUS'] != 'PLANNED'),:].reset_index(drop = True).copy()

# %%
strt2['street_index'] = strt2.index

# %%
## accident with positive examples 

positive_example = bikecl.merge(strt2, left_on = ['near_str_index'], right_on = ['street_index'] , how = 'left',
                               indicator = True)

#positive_example.loc[:,['near_str_index','bike_facility','index','EXISTING_FACILITY_TYPE']]

# %%
positive_example.groupby('bike_facility').size()
# Out:
# bike_facility
# In Street, Major Separation     157
# In Street, Minor Separation     820
# Multi-use Trail                  49
# Neighborhood Greenway            24
# NoFacility                     4114
# Sharrow                         543
# dtype: int64

# %%
positive_example.loc[positive_example['accident_year'] < positive_example['bikelane_yr_complete'],'bike_facility'] 
## was already changed to nofacility
# Out:
# 8       NoFacility
# 26      NoFacility
# 32      NoFacility
# 41      NoFacility
# 57      NoFacility
#            ...
# 4669    NoFacility
# 4721    NoFacility
# 4762    NoFacility
# 4846    NoFacility
# 4948    NoFacility
# Name: bike_facility, Length: 616, dtype: object

# %%
## zoning and neighbourhood information 
str_update = pd.read_csv('./data/str_neigh_zone_speed_oct6.csv')

# %%
str_update.head()
# Out:
#    COMPKEY     CLASS_DESC            CATEGORY_D                 GEN_ALIAS  AREA_ACRES  TOTAL_POPU  HOUSEHOLDS  AWDT_18  AWDT_18_log
# 0     1006       Downtown              Downtown  Downtown Commercial Core       206.5        4260        2530  21000.0     9.952278
# 1     1009       Downtown              Downtown  Downtown Commercial Core       206.5        4260        2530  17800.0     9.786954
# 2     1032   Multi-Family  Lowrise Multi-Family                Queen Anne      1888.4       37283       19354      NaN          NaN
# 3     1051  Single Family         Single Family                Queen Anne      1888.4       37283       19354      NaN          NaN
# 4     1060  Single Family         Single Family                Queen Anne      1888.4       37283       19354      NaN          NaN

# %%
## only keey record that have spatial information. 40 don't have. 
positive = positive_example.loc[positive_example['COMPKEY_x'].notnull(),:].reset_index(drop = True).copy()

# %%
positive_all = positive.merge(str_update,left_on = 'COMPKEY_x', right_on = 'COMPKEY', how = 'left')

# %%
positive.isnull().sum()
# Out:
# Unnamed: 0                   0
# OBJECTID_x_x                 0
# INCKEY                       0
# COLDETKEY                    0
# REPORTNO                     0
# STATUS_x                     0
# ADDRTYPE                     0
# INTKEY                    2419
# LOCATION                     0
# EXCEPTRSNC                5581
# EXCEPTRSND                5581
# SEVERITYCO                   1
# SEVERITYDE                   0
# COLLISIONT                  17
# PERSONCOUN                   0
# PEDCOUNT                     0
# PEDCYLCOUN                   0
# VEHCOUNT                     0
# INJURIES                     0
# SERIOUSINJ                   0
# FATALITIES                   0
# INCDATE                      0
# INCDTTM                      0
# JUNCTIONTY                  35
# SDOT_COLCO                   0
# SDOT_COLDE                   0
# INATTENTIO                4782
# UNDERINFL                    0
# WEATHER                      6
# ROADCOND                     5
# LIGHTCOND                    7
# PEDROWNOTG                3843
# SDOTCOLNUM                2645
# SPEEDING                  5537
# ST_COLCODE                  17
# ST_COLDESC                  17
# SEGLANEKEY                   0
# CROSSWALKK                   0
# HITPARKEDC                   0
# geometry_x                   0
# near_str_index               0
# min_length                   0
# weather_group              136
# date                         0
# time                         0
# hour                       628
# dayofweek                    0
# weekday                      0
# rushhour                   628
# weather_group2             136
# min_length_cl_to_bike        0
# min_index_cl_to_bike         0
# cl_bike_match                0
# OBJECTID_y_x              3458
# STREET_NAM                3458
# LENGTH_MIL                3458
# STATUS_y                  3902
# COMPKEY                   3458
# CATALYTIC_                3837
# NETWORK_x                 3837
# DATE_COMPL                3530
# EXISTING_F                3458
# PLANNED_FA                4857
# PROJECT_NU                3839
# DATE_PLANN                5667
# DATE_EXPIR                5663
# SHAPE_Leng_x              3458
# geometry_y                3458
# index                     3458
# bike_facility                0
# bikelane_yr_complete      3530
# accident_year                0
# OBJECTID_x_y                 0
# ARTCLASS                     0
# COMPKEY_x                    0
# UNITIDSORT                   0
# UNITDESC_x                   0
# STNAME_ORD                   0
# XSTRLO                       0
# XSTRHI                       0
# ARTDESCRIP                   0
# OWNER                     5522
# STATUS_street               11
# BLOCKNBR                     0
# SPEEDLIMIT                  11
# SEGDIR                       0
# ONEWAY                       0
# ONEWAYDIR                 4923
# FLOW                      4927
# SEGLENGTH                    0
# SURFACEWID                 355
# SURFACETYP                 197
# SURFACET_1                5267
# INTRLO                       0
# DIRLO                        0
# INTKEYLO                     0
# INTRHI                       0
# DIRHI                        0
# NATIONHWYS                   0
# STREETTYPE                 123
# PVMTCONDIN                 482
# PVMTCOND_1                5268
# TRANCLASS                    0
# TRANDESCRI                  28
# SLOPE_PCT                    0
# PVMTCATEGO                   9
# PARKBOULEV                   0
# SHAPE_Leng_y                 0
# geometry                     0
# index_x                     97
# UNITDESC_y                  97
# STR                         97
# Side                        97
# CONDITION                   97
# CURBTYPE                    97
# CURRENT_STATUS              97
# FILLERTYPE                  97
# FILLERWID                   97
# LENUOM                     368
# SW_WIDTH                    97
# MATL                        97
# SURFTYPE                    97
# SWINCOMPLETEYN              97
# MULTIPLESURFACEYN           97
# CURBRAMPHIGH                97
# CURBRAMPMID                 97
# CURBRAMPLOW                 97
# SRTS_SIDEWALK_RANK          97
# PRIMARYCROSSSLOPE           97
# MINIMUMVARIABLEWIDTH        97
# closest_bike_index        2365
# OBJECTID_y_y              2365
# STREET_NAME               2366
# LENGTH_MILES              2365
# STATUS_bike               3004
# COMPKEY_y                 2387
# CATALYTIC_PROJECTS        2899
# NETWORK_y                 2894
# DATE_COMPLETED            2514
# EXISTING_FACILITY_TYPE       0
# PLANNED_FACILITY_TYPE     4394
# PROJECT_NUMBER            2915
# DATE_PLANNED              5667
# DATE_EXPIRED              5655
# SHAPE_Length              2365
# index_y                   2365
# SEGLENGTH_log                0
# SURFACEWID_log             355
# street_index                 0
# _merge                       0
# dtype: int64

# %%
len(positive_all)
# Out:
# 5667

# %%
positive_all.to_csv('./data/bikecl_street_bike_info_oct6_withzone_neighbour.csv', sep = ',',)

# %%
street = strt2.merge(str_update, left_on = 'COMPKEY_x', right_on = 'COMPKEY', how = 'left')

# %%
len(street)
# Out:
# 23495

# %%
changedstreet_index = positive.loc[positive['accident_year'] < positive['bikelane_yr_complete'],'near_str_index'].reset_index(drop = True)

# %%
changedstreet_index = changedstreet_index.astype('int')
changedstreet_index = np.unique(changedstreet_index)

# %%
tempstr = street.iloc[changedstreet_index, :].reset_index(drop = True).copy() 
len(tempstr)
# Out:
# 382

# %%
tempstr.groupby(['EXISTING_FACILITY_TYPE']).size()
# Out:
# EXISTING_FACILITY_TYPE
# In Street, Major Separation     82
# In Street, Minor Separation     98
# Multi-use Trail                  6
# Neighborhood Greenway           21
# NoFacility                      47
# Sharrow                        128
# dtype: int64

# %%
tempstr2 = tempstr.loc[tempstr['EXISTING_FACILITY_TYPE'] != 'NoFacility', :].reset_index(drop = True).copy()
len(tempstr2)
# Out:
# 335

# %%
tempstr2.iloc[:,-19]
# Out:
# 0      In Street, Major Separation
# 1      In Street, Minor Separation
# 2      In Street, Minor Separation
# 3      In Street, Minor Separation
# 4                          Sharrow
# 5            Neighborhood Greenway
# 6                          Sharrow
# 7      In Street, Minor Separation
# 8                          Sharrow
# 9                          Sharrow
# 10     In Street, Major Separation
# 11     In Street, Major Separation
# 12           Neighborhood Greenway
# 13     In Street, Minor Separation
# 14                         Sharrow
# 15                         Sharrow
# 16                         Sharrow
# 17                         Sharrow
# 18     In Street, Minor Separation
# 19     In Street, Major Separation
# 20                         Sharrow
# 21     In Street, Minor Separation
# 22                         Sharrow
# 23                         Sharrow
# 24                         Sharrow
# 25                         Sharrow
# 26                         Sharrow
# 27     In Street, Major Separation
# 28                         Sharrow
# 29     In Street, Minor Separation
# 30           Neighborhood Greenway
# 31                         Sharrow
# 32     In Street, Major Separation
# 33                         Sharrow
# 34     In Street, Major Separation
# 35     In Street, Minor Separation
# 36     In Street, Minor Separation
# 37                         Sharrow
# 38                         Sharrow
# 39     In Street, Minor Separation
# 40     In Street, Major Separation
# 41                         Sharrow
# 42                         Sharrow
# 43     In Street, Minor Separation
# 44     In Street, Minor Separation
# 45     In Street, Minor Separation
# 46     In Street, Major Separation
# 47     In Street, Minor Separation
# 48                         Sharrow
# 49     In Street, Minor Separation
# 50                         Sharrow
# 51     In Street, Minor Separation
# 52     In Street, Major Separation
# 53                         Sharrow
# 54     In Street, Major Separation
# 55     In Street, Minor Separation
# 56     In Street, Minor Separation
# 57           Neighborhood Greenway
# 58                         Sharrow
# 59                         Sharrow
# 60                         Sharrow
# 61                 Multi-use Trail
# 62                         Sharrow
# 63                         Sharrow
# 64                         Sharrow
# 65     In Street, Minor Separation
# 66     In Street, Minor Separation
# 67     In Street, Minor Separation
# 68           Neighborhood Greenway
# 69     In Street, Minor Separation
# 70                         Sharrow
# 71     In Street, Major Separation
# 72     In Street, Minor Separation
# 73     In Street, Major Separation
# 74     In Street, Major Separation
# 75     In Street, Major Separation
# 76     In Street, Minor Separation
# 77     In Street, Minor Separation
# 78                         Sharrow
# 79                         Sharrow
# 80                         Sharrow
# 81     In Street, Minor Separation
# 82     In Street, Minor Separation
# 83                         Sharrow
# 84           Neighborhood Greenway
# 85                         Sharrow
# 86                         Sharrow
# 87                         Sharrow
# 88                         Sharrow
# 89                         Sharrow
# 90                         Sharrow
# 91     In Street, Major Separation
# 92                         Sharrow
# 93     In Street, Major Separation
# 94     In Street, Major Separation
# 95     In Street, Minor Separation
# 96     In Street, Minor Separation
# 97     In Street, Minor Separation
# 98     In Street, Minor Separation
# 99     In Street, Major Separation
# 100    In Street, Minor Separation
# 101    In Street, Minor Separation
# 102    In Street, Major Separation
# 103    In Street, Major Separation
# 104    In Street, Minor Separation
# 105    In Street, Minor Separation
# 106    In Street, Minor Separation
# 107    In Street, Major Separation
# 108                        Sharrow
# 109                        Sharrow
# 110    In Street, Minor Separation
# 111                        Sharrow
# 112    In Street, Minor Separation
# 113                        Sharrow
# 114          Neighborhood Greenway
# 115                        Sharrow
# 116          Neighborhood Greenway
# 117                        Sharrow
# 118                        Sharrow
# 119    In Street, Major Separation
# 120    In Street, Minor Separation
# 121                        Sharrow
# 122    In Street, Minor Separation
# 123    In Street, Minor Separation
# 124    In Street, Major Separation
# 125                        Sharrow
# 126                        Sharrow
# 127                        Sharrow
# 128    In Street, Minor Separation
# 129    In Street, Minor Separation
# 130          Neighborhood Greenway
# 131                        Sharrow
# 132    In Street, Major Separation
# 133    In Street, Minor Separation
# 134          Neighborhood Greenway
# 135          Neighborhood Greenway
# 136          Neighborhood Greenway
# 137    In Street, Minor Separation
# 138                        Sharrow
# 139                        Sharrow
# 140                        Sharrow
# 141    In Street, Minor Separation
# 142                Multi-use Trail
# 143                        Sharrow
# 144    In Street, Major Separation
# 145    In Street, Major Separation
# 146                        Sharrow
# 147    In Street, Minor Separation
# 148    In Street, Minor Separation
# 149    In Street, Major Separation
# 150    In Street, Minor Separation
# 151    In Street, Major Separation
# 152                        Sharrow
# 153                        Sharrow
# 154                        Sharrow
# 155                        Sharrow
# 156                        Sharrow
# 157                        Sharrow
# 158                        Sharrow
# 159                        Sharrow
# 160    In Street, Major Separation
# 161    In Street, Major Separation
# 162    In Street, Major Separation
# 163    In Street, Major Separation
# 164    In Street, Major Separation
# 165    In Street, Major Separation
# 166    In Street, Major Separation
# 167    In Street, Minor Separation
# 168                        Sharrow
# 169                        Sharrow
# 170                        Sharrow
# 171                        Sharrow
# 172                        Sharrow
# 173    In Street, Minor Separation
# 174                        Sharrow
# 175                        Sharrow
# 176                        Sharrow
# 177    In Street, Minor Separation
# 178    In Street, Minor Separation
# 179    In Street, Major Separation
# 180          Neighborhood Greenway
# 181    In Street, Major Separation
# 182    In Street, Major Separation
# 183                        Sharrow
# 184                Multi-use Trail
# 185                        Sharrow
# 186          Neighborhood Greenway
# 187    In Street, Major Separation
# 188                        Sharrow
# 189                Multi-use Trail
# 190    In Street, Minor Separation
# 191    In Street, Major Separation
# 192                        Sharrow
# 193    In Street, Minor Separation
# 194    In Street, Minor Separation
# 195                        Sharrow
# 196                        Sharrow
# 197                        Sharrow
# 198    In Street, Minor Separation
# 199                        Sharrow
# 200    In Street, Minor Separation
# 201    In Street, Major Separation
# 202    In Street, Major Separation
# 203                        Sharrow
# 204    In Street, Minor Separation
# 205                        Sharrow
# 206                Multi-use Trail
# 207    In Street, Minor Separation
# 208    In Street, Minor Separation
# 209                        Sharrow
# 210          Neighborhood Greenway
# 211    In Street, Major Separation
# 212                        Sharrow
# 213                        Sharrow
# 214          Neighborhood Greenway
# 215          Neighborhood Greenway
# 216    In Street, Minor Separation
# 217    In Street, Major Separation
# 218    In Street, Minor Separation
# 219    In Street, Minor Separation
# 220    In Street, Minor Separation
# 221          Neighborhood Greenway
# 222                        Sharrow
# 223    In Street, Major Separation
# 224    In Street, Minor Separation
# 225    In Street, Minor Separation
# 226    In Street, Major Separation
# 227    In Street, Minor Separation
# 228                        Sharrow
# 229    In Street, Major Separation
# 230    In Street, Major Separation
# 231                        Sharrow
# 232                        Sharrow
# 233    In Street, Minor Separation
# 234                        Sharrow
# 235                        Sharrow
# 236    In Street, Minor Separation
# 237    In Street, Minor Separation
# 238    In Street, Major Separation
# 239          Neighborhood Greenway
# 240    In Street, Major Separation
# 241    In Street, Major Separation
# 242                Multi-use Trail
# 243    In Street, Major Separation
# 244                        Sharrow
# 245    In Street, Major Separation
# 246    In Street, Major Separation
# 247    In Street, Major Separation
# 248                        Sharrow
# 249    In Street, Major Separation
# 250                        Sharrow
# 251    In Street, Major Separation
# 252                        Sharrow
# 253    In Street, Minor Separation
# 254                        Sharrow
# 255                        Sharrow
# 256    In Street, Major Separation
# 257    In Street, Major Separation
# 258    In Street, Major Separation
# 259                        Sharrow
# 260    In Street, Major Separation
# 261                        Sharrow
# 262                        Sharrow
# 263                        Sharrow
# 264    In Street, Major Separation
# 265    In Street, Major Separation
# 266    In Street, Minor Separation
# 267    In Street, Minor Separation
# 268                        Sharrow
# 269    In Street, Minor Separation
# 270    In Street, Major Separation
# 271                        Sharrow
# 272    In Street, Major Separation
# 273                        Sharrow
# 274    In Street, Major Separation
# 275                        Sharrow
# 276                        Sharrow
# 277                        Sharrow
# 278    In Street, Major Separation
# 279    In Street, Minor Separation
# 280    In Street, Major Separation
# 281                        Sharrow
# 282    In Street, Major Separation
# 283                        Sharrow
# 284          Neighborhood Greenway
# 285                        Sharrow
# 286    In Street, Major Separation
# 287                        Sharrow
# 288    In Street, Minor Separation
# 289                        Sharrow
# 290    In Street, Minor Separation
# 291                        Sharrow
# 292    In Street, Major Separation
# 293                        Sharrow
# 294    In Street, Minor Separation
# 295    In Street, Major Separation
# 296                        Sharrow
# 297                        Sharrow
# 298    In Street, Major Separation
# 299    In Street, Major Separation
# 300    In Street, Minor Separation
# 301                        Sharrow
# 302    In Street, Major Separation
# 303    In Street, Minor Separation
# 304                        Sharrow
# 305    In Street, Minor Separation
# 306    In Street, Minor Separation
# 307    In Street, Minor Separation
# 308          Neighborhood Greenway
# 309                        Sharrow
# 310                        Sharrow
# 311                        Sharrow
# 312    In Street, Minor Separation
# 313    In Street, Major Separation
# 314    In Street, Minor Separation
# 315    In Street, Major Separation
# 316                        Sharrow
# 317    In Street, Minor Separation
# 318    In Street, Major Separation
# 319    In Street, Major Separation
# 320    In Street, Minor Separation
# 321                        Sharrow
# 322                        Sharrow
# 323    In Street, Minor Separation
# 324    In Street, Minor Separation
# 325    In Street, Minor Separation
# 326    In Street, Minor Separation
# 327    In Street, Minor Separation
# 328                        Sharrow
# 329    In Street, Major Separation
# 330    In Street, Major Separation
# 331    In Street, Minor Separation
# 332    In Street, Minor Separation
# 333    In Street, Minor Separation
# 334    In Street, Minor Separation
# Name: EXISTING_FACILITY_TYPE, dtype: object

# %%
for i in np.arange(0,len(tempstr2)):
    tempstr2.iloc[i,-19] = 'NoFacility'

# %%
street_new = pd.concat([street, tempstr2],ignore_index = True)

# %%
street_new.isnull().sum()
# Out:
# OBJECTID_x                    0
# ARTCLASS                      0
# COMPKEY_x                     0
# UNITIDSORT                    0
# UNITDESC_x                    0
# STNAME_ORD                    0
# XSTRLO                        0
# XSTRHI                        0
# ARTDESCRIP                    0
# OWNER                     23379
# STATUS_street                44
# BLOCKNBR                      0
# SPEEDLIMIT                   28
# SEGDIR                        1
# ONEWAY                        4
# ONEWAYDIR                 22452
# FLOW                      22454
# SEGLENGTH                     0
# SURFACEWID                 3357
# SURFACETYP                  896
# SURFACET_1                23135
# INTRLO                        2
# DIRLO                         1
# INTKEYLO                      2
# INTRHI                        3
# DIRHI                         1
# NATIONHWYS                    0
# STREETTYPE                  476
# PVMTCONDIN                 4042
# PVMTCOND_1                23135
# TRANCLASS                     0
# TRANDESCRI                  170
# SLOPE_PCT                     7
# PVMTCATEGO                   60
# PARKBOULEV                    0
# SHAPE_Leng                    0
# geometry                      0
# index_x                     587
# UNITDESC_y                  587
# STR                         587
# Side                        587
# CONDITION                   587
# CURBTYPE                    587
# CURRENT_STATUS              587
# FILLERTYPE                  587
# FILLERWID                   587
# LENUOM                     1171
# SW_WIDTH                    587
# MATL                        587
# SURFTYPE                    587
# SWINCOMPLETEYN              587
# MULTIPLESURFACEYN           587
# CURBRAMPHIGH                587
# CURBRAMPMID                 587
# CURBRAMPLOW                 587
# SRTS_SIDEWALK_RANK          587
# PRIMARYCROSSSLOPE           587
# MINIMUMVARIABLEWIDTH        587
# closest_bike_index        18556
# OBJECTID_y                18556
# STREET_NAME               18557
# LENGTH_MILES              18556
# STATUS_bike               19540
# COMPKEY_y                 18605
# CATALYTIC_PROJECTS        19461
# NETWORK                   19452
# DATE_COMPLETED            18812
# EXISTING_FACILITY_TYPE        0
# PLANNED_FACILITY_TYPE     21812
# PROJECT_NUMBER            19534
# DATE_PLANNED              23830
# DATE_EXPIRED              23824
# SHAPE_Length              18556
# index_y                   18556
# SEGLENGTH_log                 0
# SURFACEWID_log             3357
# street_index                  0
# COMPKEY                       0
# CLASS_DESC                    0
# CATEGORY_D                    0
# GEN_ALIAS                     0
# AREA_ACRES                    0
# TOTAL_POPU                    0
# HOUSEHOLDS                    0
# AWDT_18                   17338
# AWDT_18_log               17338
# dtype: int64

# %%
street_new['SRTS_SIDEWALK_RANK'].unique()
# Out:
# array([ 3.,  1.,  4.,  2.,  0., nan])

# %%
street_new.loc[street_new['CONDITION'] == ' ' ,['CONDITION']] = np.nan

# %%
street_new['CONDITION'].astype('str')
street_new['CONDITION'].unique()
# Out:
# array(['FAIR', 'GOOD', 'POOR', 'VERY-POOR', nan, 'EXCELLENT'],
#       dtype=object)

# %%
street_new.to_csv('./data/street_allinfor_Oct6.csv', sep = ',')
#street_new = pd.read_csv('./data/street_allinfor_Oct6.csv')

# %%
positive.loc[:,['bike_facility' ,'EXISTING_FACILITY_TYPE']]
# Out:
#                     bike_facility       EXISTING_FACILITY_TYPE
# 0                      NoFacility                   NoFacility
# 1                      NoFacility  In Street, Major Separation
# 2                      NoFacility  In Street, Minor Separation
# 3                      NoFacility                   NoFacility
# 4                      NoFacility                   NoFacility
# ...                           ...                          ...
# 5662  In Street, Minor Separation  In Street, Minor Separation
# 5663                   NoFacility  In Street, Minor Separation
# 5664                      Sharrow                      Sharrow
# 5665                   NoFacility  In Street, Minor Separation
# 5666                   NoFacility                   NoFacility
#
# [5667 rows x 2 columns]

# %%
positive = positive_all.drop(columns = ['EXISTING_FACILITY_TYPE'])

# %%
'EXISTING_FACILITY_TYPE' in positive.columns
# Out:
# True

# %%
positive = positive.rename(columns = {'bike_facility' : 'EXISTING_FACILITY_TYPE',
                                   'rushhour': 'simulate_rushhour',
                                    'weather_group2': 'simulate_weather',
                                   'weekday': 'simulate_weekday'
                                  })
#positive_example.columns

# %%
#positive_example.isnull().sum()

# %%
## increase street size to 2x to include rushhour, weekday, weather x2, x2,x2 
n = len(strt2) * 8 
#hour_list = pd.Series(np.arange(0,))
#type(hour_list)
#test = pd.concat([hour_list]*len(strt2), ignore_index = True) 

import random
#random.seed(9001)

simulate_street = pd.concat([street_new]*8, ignore_index = True)  

simulate_weather = np.random.choice(a=['Clear or Partly Cloudy', 'Raining'],  size= len(street_new)*8,  p=[0.58, 0.42], replace = True ) 
simulate_weekday = np.random.choice(a=[1,0],  size= len(street_new)*8,  p=[0.7, 0.3], replace = True ) 
simulate_rushhour = np.random.choice(a=[1,0],  size= len(street_new)*8,  p=[0.5, 0.5], replace = True ) 
simulate_street['simulate_weekday'] = simulate_weekday 
simulate_street['simulate_rushhour'] = simulate_rushhour 
simulate_street['simulate_weather'] = simulate_weather

# %%
#positive.loc[:,['LENGTH_MILES','bike_facility']]
positive.loc[positive.loc[:, 'EXISTING_FACILITY_TYPE'] == 'NoFacility',['LENGTH_MILES']] = 0

# %%
#n = 24 * len(strt2)
#temp = (np.zeros(int(n*0.5))).tolist() + (np.ones(n- int(n*0.5))).tolist()
#simulate_street = pd.concat([strt2]*24, ignore_index = True)  
#simulate_street['simulate_rushhour'] = temp

# %%
positive.drop(columns = ['_merge'], inplace = True)

# %%
positive.head()
# Out:
#    Unnamed: 0  OBJECTID_x_x  INCKEY  COLDETKEY REPORTNO STATUS_x      ADDRTYPE   INTKEY                                           LOCATION EXCEPTRSNC EXCEPTRSND SEVERITYCO        SEVERITYDE COLLISIONT  PERSONCOUN  PEDCOUNT  PEDCYLCOUN  VEHCOUNT  INJURIES  SERIOUSINJ  FATALITIES                   INCDATE        INCDTTM                              JUNCTIONTY  SDOT_COLCO                                         SDOT_COLDE INATTENTIO UNDERINFL                 WEATHER ROADCOND                LIGHTCOND PEDROWNOTG  SDOTCOLNUM SPEEDING  ST_COLCODE              ST_COLDESC  SEGLANEKEY  CROSSWALKK HITPARKEDC                                   geometry_x  near_str_index  min_length           weather_group     date      time  hour  dayofweek  simulate_weekday  simulate_rushhour        simulate_weather  min_length_cl_to_bike  min_index_cl_to_bike  cl_bike_match  OBJECTID_y_x STREET_NAM  LENGTH_MIL STATUS_y  COMPKEY_x  CATALYTIC_ NETWORK_x DATE_COMPL EXISTING_F PLANNED_FA  PROJECT_NU  DATE_PLANN  \
# 0           0          1015   63600      63600  2188744  Matched  Intersection  35587.0                         1ST AVE NW AND NW 143RD ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2006-05-16T00:00:00.000Z   5/16/06 6:30  At Intersection (intersection related)          51  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   6136002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1265176.677676335 270845.8969054073)          2284.0    0.000000  Clear or Partly Cloudy  5/16/06   6:30:00   6.0          1                 1                0.0  Clear or Partly Cloudy            2576.622861                1800.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 1           1          1031   76900      76900  2620912  Matched  Intersection  29072.0                           BROADWAY AND E HOWELL ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-02-27T00:00:00.000Z  2/27/07 10:40  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight          Y   7058004.0      NaN        45.0  Vehicle - Pedalcyclist        6828           0          N  POINT (1273573.179700941 228816.6565423608)         11910.0    0.000000  Clear or Partly Cloudy  2/27/07  10:40:00  10.0          1                 1                0.0  Clear or Partly Cloudy               0.000102                2722.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 2           2          1105   66700      66700  2806857  Matched  Intersection  38204.0                       68TH AVE S AND RAINIER AVE S        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-06-02T00:00:00.000Z         6/2/07  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   7153002.0      NaN        45.0  Vehicle - Pedalcyclist        5012           0          N  POINT (1290743.220806524 189838.2621344477)          3727.0    0.000000  Clear or Partly Cloudy   6/2/07   0:00:00   NaN          5                 0                NaN  Clear or Partly Cloudy               0.000119                2588.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 3           3          1219   82300      82300  2894257  Matched         Block      NaN  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2008-08-05T00:00:00.000Z         8/5/08    Mid-Block (but intersection related)          21        MOTOR VEHICLE STRUCK PEDALCYCLIST, REAR END        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   8218038.0      NaN        45.0  Vehicle - Pedalcyclist       20579           0          N  POINT (1271403.979314715 201517.6661784053)         15724.0    0.000004  Clear or Partly Cloudy   8/5/08   0:00:00   NaN          1                 1                NaN  Clear or Partly Cloudy            1079.141473                1129.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 4           4          1320  124600     124600  3562409  Matched  Intersection  26818.0                WOODLAND PARK AVE N AND N 43RD N ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2011-12-07T00:00:00.000Z  12/7/11 21:57  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         N  Clear or Partly Cloudy      Dry  Dark - Street Lights On          Y  11341002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1268019.223855242 244249.3618381619)          3839.0    0.000000  Clear or Partly Cloudy  12/7/11  21:57:00  21.0          2                 1                0.0  Clear or Partly Cloudy             576.991064                2618.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
#
#   DATE_EXPIR  SHAPE_Leng_x geometry_y  index EXISTING_FACILITY_TYPE  bikelane_yr_complete  accident_year  OBJECTID_x_y  ARTCLASS  COMPKEY_x   UNITIDSORT                                         UNITDESC_x           STNAME_ORD         XSTRLO         XSTRHI          ARTDESCRIP OWNER STATUS_street  BLOCKNBR  SPEEDLIMIT SEGDIR ONEWAY ONEWAYDIR FLOW  SEGLENGTH  SURFACEWID SURFACETYP SURFACET_1                               INTRLO DIRLO  INTKEYLO                                 INTRHI DIRHI NATIONHWYS                         STREETTYPE  PVMTCONDIN  PVMTCOND_1  TRANCLASS           TRANDESCRI  SLOPE_PCT PVMTCATEGO PARKBOULEV  SHAPE_Leng_y                                           geometry  index_x                                         UNITDESC_y                                                STR                                               Side  CONDITION CURBTYPE CURRENT_STATUS FILLERTYPE  FILLERWID LENUOM  SW_WIDTH MATL SURFTYPE SWINCOMPLETEYN MULTIPLESURFACEYN CURBRAMPHIGH CURBRAMPMID  \
# 0        NaN           NaN        NaN    NaN             NoFacility                   NaN           2006        2322.0       0.0     1182.0     251400.0     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST           1ST AVE NW    NW 140TH ST    NW 143RD ST      Not Designated   NaN         INSVC   14000.0        20.0      N      N       NaN  NaN      662.0        22.0         ST        NaN           1ST AVE NW AND NW 140TH ST     N   35593.0             1ST AVE NW AND NW 143RD ST     S          N          Neighborhood Yield Street        71.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    661.927005  LINESTRING (1265163.643180326 270184.098248720...   3268.0  1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST...     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST   E SIDE                                       ...                NONE          INSVC       NONE        0.0   Feet       0.0        UIMPRV              N                 N            U           U
# 1        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007       12063.0       2.0     9449.0   57350170.0     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST             BROADWAY  XW E OLIVE ST    E HOWELL ST      Minor Arterial   NaN         INSVC    1700.0        25.0      N      N       NaN  NaN      426.0        52.0     AC/PCC        NaN           BROADWAY AND XW E OLIVE ST     N   29731.0               BROADWAY AND E HOWELL ST     S          N         Urban Village Neighborhood        45.0         NaN        2.0  MAJOR TRANSIT ROUTE        2.0        ART          N    426.060321  LINESTRING (1273569.558068931 228390.611613929...  16992.0  BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST...     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST   E SIDE                                       ...  EXCELLENT     410C          INSVC     TR/PCC       72.0   Feet      72.0           PCC              N                 N            Y           U
# 2        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007        3767.0       1.0    12437.0   93451000.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...        RAINIER AVE S     68TH AVE S  CORNELL AVE S  Principal Arterial   NaN         INSVC   10000.0        30.0     SE      N       NaN  NaN      394.0        59.0     AC/PCC        NaN         68TH AVE S AND RAINIER AVE S    SE   38204.0        CORNELL AVE S AND RAINIER AVE S    NW          Y             Urban Center Connector        64.0         NaN        2.0  MAJOR TRANSIT ROUTE        1.0        ART          N    503.128891  LINESTRING (1290743.220806524 189838.262134447...  34076.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...   NE SIDE                                      ...       GOOD     410C          INSVC       LSCP       24.0   Feet      72.0           PCC              N                 N            U           U
# 3        NaN           NaN        NaN    NaN             NoFacility                   NaN           2008       15925.0       1.0    14410.0  113000670.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S     S RIVER ST  S BRIGHTON ST  Principal Arterial   NaN         INSVC    6700.0        35.0     SE      N       NaN  NaN     1213.0        58.0     AC/PCC        NaN   EAST MARGINAL WAY S AND S RIVER ST    SE   34237.0  EAST MARGINAL WAY S AND S BRIGHTON ST    NW          Y                  Industrial Access        74.0         NaN        2.0  MAJOR TRANSIT ROUTE        0.0        ART          N   1212.724715  LINESTRING (1270954.337586254 201924.479874819...  20805.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...   NE SIDE                                      ...       FAIR     410A          INSVC         AC       16.0   Feet      44.0           PCC              N                 N            U           U
# 4        NaN           NaN        NaN    NaN             NoFacility                   NaN           2011        3879.0       0.0    13659.0  105900435.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N    N 43RD N ST      N 44TH ST      Not Designated   NaN         INSVC    4300.0        20.0      N      N       NaN  NaN      140.0        44.0         AC        NaN  WOODLAND PARK AVE N AND N 43RD N ST     N   26818.0      WOODLAND PARK AVE N AND N 44TH ST     S          N  Urban Village Neighborhood Access        36.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    139.999584  LINESTRING (1268019.223855242 244249.361838161...  46018.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...   E SIDE                                       ...       GOOD       AR          INSVC       LSCP       28.0   Feet      72.0           PCC              N                 N            Y           U
#
#   CURBRAMPLOW  SRTS_SIDEWALK_RANK  PRIMARYCROSSSLOPE  MINIMUMVARIABLEWIDTH  closest_bike_index  OBJECTID_y_y    STREET_NAME  LENGTH_MILES STATUS_bike  COMPKEY_y  CATALYTIC_PROJECTS NETWORK_y            DATE_COMPLETED PLANNED_FACILITY_TYPE  PROJECT_NUMBER  DATE_PLANNED DATE_EXPIRED  SHAPE_Length  index_y  SEGLENGTH_log  SURFACEWID_log  street_index  COMPKEY_y                CLASS_DESC               CATEGORY_D              GEN_ALIAS  AREA_ACRES  TOTAL_POPU  HOUSEHOLDS  AWDT_18  AWDT_18_log
# 0           U                 2.0                0.0                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       6.495266        3.091042        2284.0       1182             Single Family            Single Family  Broadview/Bitter Lake      1478.5       13725        6790      NaN          NaN
# 1           Y                 3.0                1.6                   0.0              2722.0       79314.0       BROADWAY           0.0       Meets     9449.0                 0.0  CITYWIDE  2008-12-31T00:00:00.000Z                   NaN             0.0           NaN          NaN    426.060473   2722.0       6.054439        3.951244       11910.0       9449        Major Institutions       Major Institutions           Capitol Hill       426.5       20952       14041  14600.0     9.588777
# 2           U                 3.0                1.0                   0.0              1736.0       78324.0  RAINIER AVE S           0.0       Meets    12437.0                 0.0  CITYWIDE  2015-12-31T00:00:00.000Z                   NaN           690.0           NaN          NaN    393.887547   1736.0       5.976351        4.077537        3727.0      12437      Commercial/Mixed Use  Neighborhood Commercial          Rainier Beach      1363.1       15336        5395  19000.0     9.852194
# 3           U                 3.0                2.1                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       7.100852        4.060443       15724.0      14410  Manufacturing/Industrial               Industrial             Georgetown      1183.9        1131         621  20300.0     9.918376
# 4           U                 1.0                2.7                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       4.941642        3.784190        3839.0      13659              Multi-Family     Lowrise Multi-Family            Wallingford       810.5       17016        7327      NaN          NaN

# %%
simulate_street.groupby('GEN_ALIAS').size()
# Out:
# GEN_ALIAS
# Alki/Admiral                              3360
# Arbor Heights                             2008
# Ballard                                   2024
# Beacon Hill                               3208
# Belltown                                  1072
# Broadview/Bitter Lake                     3232
# Capitol Hill                              2592
# Cascade/Eastlake                          3624
# Cedar Park/Meadowbrook                    2688
# Central Area/Squire Park                  4024
# Columbia City                             5296
# Downtown Commercial Core                  1576
# Duwamish/SODO                             4552
# Fauntleroy/Seaview                        4400
# First Hill                                2160
# Fremont                                   5336
# Georgetown                                2160
# Green Lake                                4584
# Greenwood/Phinney Ridge                   6208
# Haller Lake                               2576
# High Point                                1016
# Highland Park                             1496
# Interbay                                  2880
# Judkins Park                               752
# Laurelhurst/Sand Point                    3064
# Licton Springs                            1632
# Madison Park                              1448
# Madrona/Leschi                            4128
# Magnolia                                  5200
# Miller Park                               1504
# Montlake/Portage Bay                      2736
# Mt. Baker/North Rainier                   2896
# North Beach/Blue Ridge                    3792
# North Beacon Hill/Jefferson Park          5304
# North Capitol Hill                         896
# North Delridge                            2464
# Northgate/Maple Leaf                      2736
# Olympic Hills/Victory Heights             3744
# Pioneer Square/International District      928
# Queen Anne                               30016
# Rainier Beach                             4056
# Ravenna/Bryant                            5984
# Riverview                                  888
# Roxhill/Westwood                          2856
# Seward Park                               2784
# South Beacon Hill/NewHolly                4616
# South Park                                1928
# Sunset Hill/Loyal Heights                 3504
# University District                       2536
# Wallingford                               4344
# Wedgwood/View Ridge                       4424
# West Seattle Junction/Genesee Hill        4880
# Whittier Heights                          2528
# dtype: int64

# %%
simulate_street = simulate_street.rename(columns = {'LENGTH_MILES' : 'LENGTH_MIL'})

# %%
positive.head()
# Out:
#    Unnamed: 0  OBJECTID_x_x  INCKEY  COLDETKEY REPORTNO STATUS_x      ADDRTYPE   INTKEY                                           LOCATION EXCEPTRSNC EXCEPTRSND SEVERITYCO        SEVERITYDE COLLISIONT  PERSONCOUN  PEDCOUNT  PEDCYLCOUN  VEHCOUNT  INJURIES  SERIOUSINJ  FATALITIES                   INCDATE        INCDTTM                              JUNCTIONTY  SDOT_COLCO                                         SDOT_COLDE INATTENTIO UNDERINFL                 WEATHER ROADCOND                LIGHTCOND PEDROWNOTG  SDOTCOLNUM SPEEDING  ST_COLCODE              ST_COLDESC  SEGLANEKEY  CROSSWALKK HITPARKEDC                                   geometry_x  near_str_index  min_length           weather_group     date      time  hour  dayofweek  simulate_weekday  simulate_rushhour        simulate_weather  min_length_cl_to_bike  min_index_cl_to_bike  cl_bike_match  OBJECTID_y_x STREET_NAM  LENGTH_MIL STATUS_y  COMPKEY_x  CATALYTIC_ NETWORK_x DATE_COMPL EXISTING_F PLANNED_FA  PROJECT_NU  DATE_PLANN  \
# 0           0          1015   63600      63600  2188744  Matched  Intersection  35587.0                         1ST AVE NW AND NW 143RD ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2006-05-16T00:00:00.000Z   5/16/06 6:30  At Intersection (intersection related)          51  PEDALCYCLIST STRUCK MOTOR VEHICLE FRONT END AT...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   6136002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1265176.677676335 270845.8969054073)          2284.0    0.000000  Clear or Partly Cloudy  5/16/06   6:30:00   6.0          1                 1                0.0  Clear or Partly Cloudy            2576.622861                1800.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 1           1          1031   76900      76900  2620912  Matched  Intersection  29072.0                           BROADWAY AND E HOWELL ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-02-27T00:00:00.000Z  2/27/07 10:40  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight          Y   7058004.0      NaN        45.0  Vehicle - Pedalcyclist        6828           0          N  POINT (1273573.179700941 228816.6565423608)         11910.0    0.000000  Clear or Partly Cloudy  2/27/07  10:40:00  10.0          1                 1                0.0  Clear or Partly Cloudy               0.000102                2722.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 2           2          1105   66700      66700  2806857  Matched  Intersection  38204.0                       68TH AVE S AND RAINIER AVE S        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2007-06-02T00:00:00.000Z         6/2/07  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   7153002.0      NaN        45.0  Vehicle - Pedalcyclist        5012           0          N  POINT (1290743.220806524 189838.2621344477)          3727.0    0.000000  Clear or Partly Cloudy   6/2/07   0:00:00   NaN          5                 0                NaN  Clear or Partly Cloudy               0.000119                2588.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 3           3          1219   82300      82300  2894257  Matched         Block      NaN  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2008-08-05T00:00:00.000Z         8/5/08    Mid-Block (but intersection related)          21        MOTOR VEHICLE STRUCK PEDALCYCLIST, REAR END        NaN         0  Clear or Partly Cloudy      Dry                 Daylight        NaN   8218038.0      NaN        45.0  Vehicle - Pedalcyclist       20579           0          N  POINT (1271403.979314715 201517.6661784053)         15724.0    0.000004  Clear or Partly Cloudy   8/5/08   0:00:00   NaN          1                 1                NaN  Clear or Partly Cloudy            1079.141473                1129.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
# 4           4          1320  124600     124600  3562409  Matched  Intersection  26818.0                WOODLAND PARK AVE N AND N 43RD N ST        NaN        NaN          2  Injury Collision     Cycles           2         0           1         1         1           0           0  2011-12-07T00:00:00.000Z  12/7/11 21:57  At Intersection (intersection related)          18  MOTOR VEHICLE STRUCK PEDALCYCLIST, FRONT END A...        NaN         N  Clear or Partly Cloudy      Dry  Dark - Street Lights On          Y  11341002.0      NaN        45.0  Vehicle - Pedalcyclist           0           0          N  POINT (1268019.223855242 244249.3618381619)          3839.0    0.000000  Clear or Partly Cloudy  12/7/11  21:57:00  21.0          2                 1                0.0  Clear or Partly Cloudy             576.991064                2618.0        9999999           NaN        NaN         NaN      NaN        NaN         NaN       NaN        NaN        NaN        NaN         NaN         NaN
#
#   DATE_EXPIR  SHAPE_Leng_x geometry_y  index EXISTING_FACILITY_TYPE  bikelane_yr_complete  accident_year  OBJECTID_x_y  ARTCLASS  COMPKEY_x   UNITIDSORT                                         UNITDESC_x           STNAME_ORD         XSTRLO         XSTRHI          ARTDESCRIP OWNER STATUS_street  BLOCKNBR  SPEEDLIMIT SEGDIR ONEWAY ONEWAYDIR FLOW  SEGLENGTH  SURFACEWID SURFACETYP SURFACET_1                               INTRLO DIRLO  INTKEYLO                                 INTRHI DIRHI NATIONHWYS                         STREETTYPE  PVMTCONDIN  PVMTCOND_1  TRANCLASS           TRANDESCRI  SLOPE_PCT PVMTCATEGO PARKBOULEV  SHAPE_Leng_y                                           geometry  index_x                                         UNITDESC_y                                                STR                                               Side  CONDITION CURBTYPE CURRENT_STATUS FILLERTYPE  FILLERWID LENUOM  SW_WIDTH MATL SURFTYPE SWINCOMPLETEYN MULTIPLESURFACEYN CURBRAMPHIGH CURBRAMPMID  \
# 0        NaN           NaN        NaN    NaN             NoFacility                   NaN           2006        2322.0       0.0     1182.0     251400.0     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST           1ST AVE NW    NW 140TH ST    NW 143RD ST      Not Designated   NaN         INSVC   14000.0        20.0      N      N       NaN  NaN      662.0        22.0         ST        NaN           1ST AVE NW AND NW 140TH ST     N   35593.0             1ST AVE NW AND NW 143RD ST     S          N          Neighborhood Yield Street        71.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    661.927005  LINESTRING (1265163.643180326 270184.098248720...   3268.0  1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST...     1ST AVE NW BETWEEN NW 140TH ST AND NW 143RD ST   E SIDE                                       ...                NONE          INSVC       NONE        0.0   Feet       0.0        UIMPRV              N                 N            U           U
# 1        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007       12063.0       2.0     9449.0   57350170.0     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST             BROADWAY  XW E OLIVE ST    E HOWELL ST      Minor Arterial   NaN         INSVC    1700.0        25.0      N      N       NaN  NaN      426.0        52.0     AC/PCC        NaN           BROADWAY AND XW E OLIVE ST     N   29731.0               BROADWAY AND E HOWELL ST     S          N         Urban Village Neighborhood        45.0         NaN        2.0  MAJOR TRANSIT ROUTE        2.0        ART          N    426.060321  LINESTRING (1273569.558068931 228390.611613929...  16992.0  BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST...     BROADWAY BETWEEN XW E OLIVE ST AND E HOWELL ST   E SIDE                                       ...  EXCELLENT     410C          INSVC     TR/PCC       72.0   Feet      72.0           PCC              N                 N            Y           U
# 2        NaN           NaN        NaN    NaN             NoFacility                   NaN           2007        3767.0       1.0    12437.0   93451000.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...        RAINIER AVE S     68TH AVE S  CORNELL AVE S  Principal Arterial   NaN         INSVC   10000.0        30.0     SE      N       NaN  NaN      394.0        59.0     AC/PCC        NaN         68TH AVE S AND RAINIER AVE S    SE   38204.0        CORNELL AVE S AND RAINIER AVE S    NW          Y             Urban Center Connector        64.0         NaN        2.0  MAJOR TRANSIT ROUTE        1.0        ART          N    503.128891  LINESTRING (1290743.220806524 189838.262134447...  34076.0  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...  RAINIER AVE S BETWEEN 68TH AVE S AND CORNELL A...   NE SIDE                                      ...       GOOD     410C          INSVC       LSCP       24.0   Feet      72.0           PCC              N                 N            U           U
# 3        NaN           NaN        NaN    NaN             NoFacility                   NaN           2008       15925.0       1.0    14410.0  113000670.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S     S RIVER ST  S BRIGHTON ST  Principal Arterial   NaN         INSVC    6700.0        35.0     SE      N       NaN  NaN     1213.0        58.0     AC/PCC        NaN   EAST MARGINAL WAY S AND S RIVER ST    SE   34237.0  EAST MARGINAL WAY S AND S BRIGHTON ST    NW          Y                  Industrial Access        74.0         NaN        2.0  MAJOR TRANSIT ROUTE        0.0        ART          N   1212.724715  LINESTRING (1270954.337586254 201924.479874819...  20805.0  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...  EAST MARGINAL WAY S BETWEEN S RIVER ST AND S B...   NE SIDE                                      ...       FAIR     410A          INSVC         AC       16.0   Feet      44.0           PCC              N                 N            U           U
# 4        NaN           NaN        NaN    NaN             NoFacility                   NaN           2011        3879.0       0.0    13659.0  105900435.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N    N 43RD N ST      N 44TH ST      Not Designated   NaN         INSVC    4300.0        20.0      N      N       NaN  NaN      140.0        44.0         AC        NaN  WOODLAND PARK AVE N AND N 43RD N ST     N   26818.0      WOODLAND PARK AVE N AND N 44TH ST     S          N  Urban Village Neighborhood Access        36.0         NaN        0.0       NOT DESIGNATED        4.0    NON-ART          N    139.999584  LINESTRING (1268019.223855242 244249.361838161...  46018.0  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...  WOODLAND PARK AVE N BETWEEN N 43RD N ST AND N ...   E SIDE                                       ...       GOOD       AR          INSVC       LSCP       28.0   Feet      72.0           PCC              N                 N            Y           U
#
#   CURBRAMPLOW  SRTS_SIDEWALK_RANK  PRIMARYCROSSSLOPE  MINIMUMVARIABLEWIDTH  closest_bike_index  OBJECTID_y_y    STREET_NAME  LENGTH_MILES STATUS_bike  COMPKEY_y  CATALYTIC_PROJECTS NETWORK_y            DATE_COMPLETED PLANNED_FACILITY_TYPE  PROJECT_NUMBER  DATE_PLANNED DATE_EXPIRED  SHAPE_Length  index_y  SEGLENGTH_log  SURFACEWID_log  street_index  COMPKEY_y                CLASS_DESC               CATEGORY_D              GEN_ALIAS  AREA_ACRES  TOTAL_POPU  HOUSEHOLDS  AWDT_18  AWDT_18_log
# 0           U                 2.0                0.0                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       6.495266        3.091042        2284.0       1182             Single Family            Single Family  Broadview/Bitter Lake      1478.5       13725        6790      NaN          NaN
# 1           Y                 3.0                1.6                   0.0              2722.0       79314.0       BROADWAY           0.0       Meets     9449.0                 0.0  CITYWIDE  2008-12-31T00:00:00.000Z                   NaN             0.0           NaN          NaN    426.060473   2722.0       6.054439        3.951244       11910.0       9449        Major Institutions       Major Institutions           Capitol Hill       426.5       20952       14041  14600.0     9.588777
# 2           U                 3.0                1.0                   0.0              1736.0       78324.0  RAINIER AVE S           0.0       Meets    12437.0                 0.0  CITYWIDE  2015-12-31T00:00:00.000Z                   NaN           690.0           NaN          NaN    393.887547   1736.0       5.976351        4.077537        3727.0      12437      Commercial/Mixed Use  Neighborhood Commercial          Rainier Beach      1363.1       15336        5395  19000.0     9.852194
# 3           U                 3.0                2.1                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       7.100852        4.060443       15724.0      14410  Manufacturing/Industrial               Industrial             Georgetown      1183.9        1131         621  20300.0     9.918376
# 4           U                 1.0                2.7                   0.0                 NaN           NaN            NaN           0.0         NaN        NaN                 NaN       NaN                       NaN                   NaN             NaN           NaN          NaN           NaN      NaN       4.941642        3.784190        3839.0      13659              Multi-Family     Lowrise Multi-Family            Wallingford       810.5       17016        7327      NaN          NaN

# %%
#full['acc'] = [ 1 if i == 'both' else 0 for i in full['_merge']]

# %%
numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1','SLOPE_PCT' ,
                    'SW_WIDTH' ,'FILLERWID','MINIMUMVARIABLEWIDTH', 'PRIMARYCROSSSLOPE', 'LENGTH_MIL']
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['SPEEDLIMIT','SEGDIR', 'STREETTYPE','ONEWAY', 'SURFACETYP','PVMTCATEGO',  
'CONDITION', 'SWINCOMPLETEYN', 'simulate_rushhour','simulate_weather','simulate_weekday', \
                        'EXISTING_FACILITY_TYPE','CLASS_DESC',  'GEN_ALIAS']
new = ['SRTS_SIDEWALK_RANK','ARTCLASS']
#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV'

# %%
len(categorical_features) + len(numeric_features ) + 5
# Out:
# 29

# %%
positive_data = positive[numeric_features + categorical_features + new].copy()

# %%
positive_data['acc'] = 1

# %%
negative_data = simulate_street[numeric_features + categorical_features+ new].copy()
negative_data['acc'] = 0

# %%
X = pd.concat([positive_data, negative_data])

# %%
## drop dupulicats so all scenarios from positive examples are moved 
X_temp = X.drop_duplicates(subset  = [numeric_features+ categorical_features][0], keep = False, inplace = False)

# %%
X_negative  = X_temp.loc[X_temp.loc[:,'acc'] == 0,:]

# %%
## add in positive examples again 
X_both = pd.concat([positive_data, X_negative ])

# %%
X_both.groupby('acc').size()
# Out:
# acc
# 0    65735
# 1     5667
# dtype: int64

# %%
65735/5667
# Out:
# 11.599611787541908

# %%
y = X_both['acc']

# %%
X_both.drop(columns = ['acc'], inplace = True)

# %%
y.to_csv('./data/label_oct12.csv', sep = ',', index= False, header = True)
X_both.to_csv('./data/training_oct12.csv', sep = ',', index= False, header = True)

# %%
X_both.loc[X_both['CONDITION'] == ' ', ['CONDITION']] = np.nan

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_both, y, stratify = y,test_size=0.1, shuffle = True, random_state = 42)

# %%
y_train = y_train.astype('int')

# %%
X_train.head()
# Out:
#         SEGLENGTH_log  SURFACEWID_log  PVMTCONDIN  PVMTCOND_1  SLOPE_PCT  SW_WIDTH  FILLERWID  MINIMUMVARIABLEWIDTH  PRIMARYCROSSSLOPE  LENGTH_MIL  SPEEDLIMIT SEGDIR                         STREETTYPE ONEWAY SURFACETYP PVMTCATEGO CONDITION SWINCOMPLETEYN  simulate_rushhour        simulate_weather  simulate_weekday EXISTING_FACILITY_TYPE                CLASS_DESC                GEN_ALIAS  SRTS_SIDEWALK_RANK  ARTCLASS
# 102738       6.928538             NaN         NaN         NaN        0.0      58.0        0.0                   0.0                2.6         NaN        20.0     SE          Neighborhood Yield Street      N        PCC    NON-ART      GOOD              N                0.0                 Raining                 0             NoFacility              Multi-Family   Laurelhurst/Sand Point                 1.0       0.0
# 55250        5.860786        3.784190        84.0         NaN        5.0      72.0      115.0                   0.0                2.0         NaN        20.0      E            Minor Industrial Access      N        PCC    NON-ART      FAIR              N                1.0  Clear or Partly Cloudy                 0             NoFacility  Manufacturing/Industrial            Duwamish/SODO                 1.0       0.0
# 121760       5.056246        3.465736        81.0         NaN        3.0      72.0       92.0                   0.0                2.7    0.015828        20.0      S          Neighborhood Yield Street      N        PCC    NON-ART      FAIR              N                0.0                 Raining                 1  Neighborhood Greenway              Multi-Family  Mt. Baker/North Rainier                 1.0       0.0
# 42020        5.549076        3.044522       100.0         NaN        5.0       0.0        0.0                   0.0                0.0         NaN        20.0      E          Neighborhood Yield Street      N         ST    NON-ART       NaN              N                0.0  Clear or Partly Cloudy                 1             NoFacility             Single Family              Haller Lake                 2.0       0.0
# 159230       5.620401        3.737670        52.0         NaN        3.0      72.0       40.0                   0.0                1.8         NaN        20.0      E  Urban Village Neighborhood Access      N        PCC    NON-ART      FAIR              N                1.0  Clear or Partly Cloudy                 1             NoFacility      Commercial/Mixed Use         Cascade/Eastlake                 1.0       0.0

# %%
sum(y_train)/len(y_train)
# Out:
# 0.07936384432237283

# %%
# initial parameters
#RANDOM_STATE = 42
#RATIO = 0.1
#K_FOLD = 5
from sklearn.model_selection import StratifiedKFold
#K_FOLD = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
K_FOLD = StratifiedKFold(n_splits=5,shuffle=True)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline


## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# imbalanced learn 
#rus = RandomUnderSampler(random_state=RANDOM_STATE) 
#rus = RandomUnderSampler()#ratio = RATIO

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(solver='liblinear')

# %%
#logistic regression with feature selection 

from sklearn.feature_selection import SelectFromModel

log2 = LogisticRegression(solver='liblinear', class_weight = 'balanced')
logReg2 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('feature_selection', SelectFromModel(LogisticRegression(penalty="l1", class_weight = 'balanced', solver='liblinear'))),
                          ('classifier', log2)])

## cross validate 
from sklearn.model_selection import cross_validate

#scores = cross_validate(logReg2, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision'], cv = K_FOLD, return_train_score= True, return_estimator=True)
#scores

# %%
# take coeff for now 
logReg2.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('scaler',
#                                                                    StandardScaler(copy=True,
#                                                                                   with_mean...
#                                                               warm_start=False),
#                                  max_features=None, norm_order=1, prefit=False,
#                                  threshold=None)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='liblinear', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
cat_name = logReg2.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names()

# %%
categorical_features
# Out:
# ['SPEEDLIMIT',
#  'SEGDIR',
#  'STREETTYPE',
#  'ONEWAY',
#  'SURFACETYP',
#  'PVMTCATEGO',
#  'CONDITION',
#  'SWINCOMPLETEYN',
#  'simulate_rushhour',
#  'simulate_weather',
#  'simulate_weekday',
#  'EXISTING_FACILITY_TYPE',
#  'CLASS_DESC',
#  'GEN_ALIAS']

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name)))
#featurename

# %%
for i in np.arange(0,len(featurename)):
    featurename[i] = featurename[i].replace('x8_', 'RushHour_').replace('x9_', 'Weather_').\
        replace('x10_', 'Weekday_').replace('x11_', 'Bike_Facility_').\
        replace('x12_', 'Neighborhood').replace('x13_', 'Zoning').\
        replace('x0_', 'SpeedLimit_').replace('x1_', 'Dir_').replace('x2_', 'StreetType_').\
        replace('x3_', 'OneWay_').replace('x4_', 'Surface_').\
        replace('x5_', 'PVMTCATEGO').replace('x6_', 'Condition_').replace('x7_', 'SWIncomplete_')\
        
        
print(featurename)
# Out:
# ['SEGLENGTH_log' 'SURFACEWID_log' 'PVMTCONDIN' 'PVMTCOND_1' 'SLOPE_PCT'
#  'SW_WIDTH' 'FILLERWID' 'MINIMUMVARIABLEWIDTH' 'PRIMARYCROSSSLOPE'
#  'LENGTH_MIL' 'SpeedLimit_20.0' 'SpeedLimit_25.0' 'SpeedLimit_30.0'
#  'SpeedLimit_35.0' 'SpeedLimit_40.0' 'SpeedLimit_45.0' 'SpeedLimit_50.0'
#  'SpeedLimit_55.0' 'Dir_E' 'Dir_N' 'Dir_NE' 'Dir_NW' 'Dir_S' 'Dir_SE'
#  'Dir_SW' 'Dir_W' 'StreetType_Alley' 'StreetType_Downtown'
#  'StreetType_Downtown Neighborhood'
#  'StreetType_Downtown Neighborhood Access' 'StreetType_Industrial Access'
#  'StreetType_Minor Industrial Access' 'StreetType_Neighborhood Corridor'
#  'StreetType_Neighborhood Yield Street'
#  'StreetType_Urban Center Connector' 'StreetType_Urban Village Main'
#  'StreetType_Urban Village Neighborhood'
#  'StreetType_Urban Village Neighborhood Access' 'OneWay_N' 'OneWay_Y'
#  'Surface_AC' 'Surface_AC/AC' 'Surface_AC/PCC' 'Surface_GRAVEL'
#  'Surface_PCC' 'Surface_ST' 'PVMTCATEGOART' 'PVMTCATEGOMLTUSETRL'
#  'PVMTCATEGONON-ART' 'Condition_ ' 'Condition_EXCELLENT' 'Condition_FAIR'
#  'Condition_GOOD' 'Condition_POOR' 'Condition_VERY-POOR' 'SWIncomplete_N'
#  'SWIncomplete_Y' 'RushHour_0.0' 'RushHour_1.0'
#  'Weather_Clear or Partly Cloudy' 'Weather_Raining' 'Weekday_0'
#  'Weekday_1' 'Bike_Facility_In Street, Major Separation'
#  'Bike_Facility_In Street, Minor Separation'
#  'Bike_Facility_Multi-use Trail' 'Bike_Facility_Neighborhood Greenway'
#  'Bike_Facility_NoFacility' 'Bike_Facility_Sharrow'
#  'NeighborhoodCommercial/Mixed Use' 'NeighborhoodDowntown'
#  'NeighborhoodMajor Institutions' 'NeighborhoodManufacturing/Industrial'
#  'NeighborhoodMaster Planned Community' 'NeighborhoodMulti-Family'
#  'NeighborhoodSingle Family' 'ZoningAlki/Admiral' 'ZoningArbor Heights'
#  'ZoningBallard' 'ZoningBeacon Hill' 'ZoningBelltown'
#  'ZoningBroadview/Bitter Lake' 'ZoningCapitol Hill'
#  'ZoningCascade/Eastlake' 'ZoningCedar Park/Meadowbrook'
#  'ZoningCentral Area/Squire Park' 'ZoningColumbia City'
#  'ZoningDowntown Commercial Core' 'ZoningDuwamish/SODO'
#  'ZoningFauntleroy/Seaview' 'ZoningFirst Hill' 'ZoningFremont'
#  'ZoningGeorgetown' 'ZoningGreen Lake' 'ZoningGreenwood/Phinney Ridge'
#  'ZoningHaller Lake' 'ZoningHigh Point' 'ZoningHighland Park'
#  'ZoningInterbay' 'ZoningJudkins Park' 'ZoningLaurelhurst/Sand Point'
#  'ZoningLicton Springs' 'ZoningMadison Park' 'ZoningMadrona/Leschi'
#  'ZoningMagnolia' 'ZoningMiller Park' 'ZoningMontlake/Portage Bay'
#  'ZoningMt. Baker/North Rainier' 'ZoningNorth Beach/Blue Ridge'
#  'ZoningNorth Beacon Hill/Jefferson Park' 'ZoningNorth Capitol Hill'
#  'ZoningNorth Delridge' 'ZoningNorthgate/Maple Leaf'
#  'ZoningOlympic Hills/Victory Heights'
#  'ZoningPioneer Square/International District' 'ZoningQueen Anne'
#  'ZoningRainier Beach' 'ZoningRavenna/Bryant' 'ZoningRiverview'
#  'ZoningRoxhill/Westwood' 'ZoningSeward Park'
#  'ZoningSouth Beacon Hill/NewHolly' 'ZoningSouth Park'
#  'ZoningSunset Hill/Loyal Heights' 'ZoningUniversity District'
#  'ZoningWallingford' 'ZoningWedgwood/View Ridge'
#  'ZoningWest Seattle Junction/Genesee Hill' 'ZoningWhittier Heights']

# %%
## 
f_imp = logReg2['classifier'].coef_
f_imp
# Out:
# array([[ 2.83027492e-01,  2.32845630e-01,  9.11800825e-02,
#         -4.27506140e-02, -1.05315396e-01,  1.49020696e-01,
#         -3.71740332e-02,  6.59584577e-04,  2.06686338e-02,
#         -6.14846489e-03,  7.25602644e-01,  1.00028544e+00,
#          6.97715367e-01,  3.09780003e-01,  1.57333475e-01,
#         -7.98584049e-01, -1.27119318e+00, -1.36652734e+00,
#          5.38345179e-02,  1.35515177e-01, -2.12466771e-01,
#         -1.10851137e-01,  1.15707329e-01, -6.42657926e-02,
#         -3.33975466e-01,  4.86079470e-01,  5.53727401e-01,
#          1.21997612e+00, -4.52322847e-01, -2.50638874e-01,
#         -8.33026563e-01,  6.48047587e-03,  3.21278093e-02,
#         -2.45141127e-01, -9.12212157e-02, -4.54366422e-01,
#          1.06697327e-01,  5.21749922e-02,  8.72497987e-02,
#         -6.50533507e-01, -1.13979534e-01, -2.71967139e-02,
#          1.23183131e+00, -7.93064770e-01,  8.26331469e-02,
#         -3.28620397e-02, -2.21618401e-01,  7.09781671e-03,
#         -1.08033435e-01, -2.72804725e-01, -8.25810223e-02,
#         -4.63006615e-01, -6.20806841e-01,  7.52192039e-02,
#          8.70563679e-01, -1.41615132e+00, -1.02650750e+00,
#          4.80919858e-01, -5.09836099e-01,  2.74522731e-01,
#         -2.42873714e-01, -8.01274611e-01,  6.35071390e-01,
#          9.88026659e-02,  2.73682731e-01,  6.60992495e-02,
#          1.27865315e-01, -6.31693710e-01, -4.33556095e-01,
#         -8.23434365e-01, -1.09158386e-01, -1.44986515e+00,
#          8.72129117e-01, -3.62067916e-01, -1.75188589e-01,
#          1.42386882e+00,  4.35572328e-01,  2.14224677e-01,
#          7.51155742e-01, -2.31809289e-01,  6.34872739e-01,
#         -1.94693055e-01, -2.32128667e-01,  7.33126473e-01,
#          6.37978738e-01, -8.59338566e-01,  5.97557652e-01,
#          3.53396766e-01, -3.37666466e-01,  1.52734759e-01,
#         -2.10522888e+00, -1.09649130e-01,  1.69166903e-01,
#         -1.96375190e-01,  4.54614111e-01, -6.35269305e-01,
#          4.62215369e-01, -1.36795844e+00,  2.83515693e-01,
#          1.28344741e+00, -9.39870391e-02, -9.11657115e-01,
#         -4.27750888e-01,  5.50947306e-01,  2.44192161e-01,
#          3.57151422e-02,  1.03091195e-01, -2.60385047e-02,
#          1.82067635e-01, -7.57063090e-01,  1.22482774e-01,
#          5.43479593e-01, -3.86227789e-01, -1.90023929e-01,
#         -1.29917531e-01, -7.39190148e-01, -6.54465074e-01,
#          9.81489106e-01,  6.71841844e-01, -6.26217994e-01,
#         -5.67865069e-01,  3.22105443e-01]])

# %%
# Plot! 

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
print(featurename[np.argsort(f_imp[0])])
print(np.argsort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# ['ZoningFirst Hill' 'NeighborhoodMajor Institutions' 'SWIncomplete_N'
#  'ZoningHighland Park' 'SpeedLimit_55.0' 'SpeedLimit_50.0'
#  'SWIncomplete_Y' 'ZoningLicton Springs' 'ZoningCentral Area/Squire Park'
#  'StreetType_Industrial Access' 'NeighborhoodCommercial/Mixed Use'
#  'Weekday_0' 'SpeedLimit_45.0' 'Surface_GRAVEL'
#  'ZoningNorth Beacon Hill/Jefferson Park' 'ZoningQueen Anne'
#  'ZoningRainier Beach' 'OneWay_Y' 'ZoningHaller Lake'
#  'Bike_Facility_NoFacility' 'ZoningRoxhill/Westwood' 'Condition_GOOD'
#  'ZoningSeward Park' 'RushHour_1.0' 'Condition_FAIR'
#  'StreetType_Urban Village Main' 'StreetType_Downtown Neighborhood'
#  'Bike_Facility_Sharrow' 'ZoningMadison Park' 'ZoningNorthgate/Maple Leaf'
#  'NeighborhoodMaster Planned Community' 'ZoningDuwamish/SODO' 'Dir_SW'
#  'Condition_ ' 'StreetType_Downtown Neighborhood Access'
#  'StreetType_Neighborhood Yield Street' 'Weather_Raining'
#  'ZoningCapitol Hill' 'ZoningBeacon Hill' 'PVMTCATEGOART' 'Dir_NE'
#  'ZoningGreen Lake' 'ZoningBroadview/Bitter Lake'
#  'ZoningOlympic Hills/Victory Heights' 'NeighborhoodMulti-Family'
#  'ZoningPioneer Square/International District' 'Surface_AC' 'Dir_NW'
#  'ZoningFremont' 'NeighborhoodDowntown' 'PVMTCATEGONON-ART' 'SLOPE_PCT'
#  'ZoningLaurelhurst/Sand Point' 'StreetType_Urban Center Connector'
#  'Condition_EXCELLENT' 'Dir_SE' 'PVMTCOND_1' 'FILLERWID' 'Surface_ST'
#  'Surface_AC/AC' 'ZoningMt. Baker/North Rainier' 'LENGTH_MIL'
#  'MINIMUMVARIABLEWIDTH' 'StreetType_Minor Industrial Access'
#  'PVMTCATEGOMLTUSETRL' 'PRIMARYCROSSSLOPE'
#  'StreetType_Neighborhood Corridor' 'ZoningMiller Park'
#  'StreetType_Urban Village Neighborhood Access' 'Dir_E'
#  'Bike_Facility_Multi-use Trail' 'Condition_POOR' 'Surface_PCC' 'OneWay_N'
#  'PVMTCONDIN' 'Bike_Facility_In Street, Major Separation'
#  'ZoningMontlake/Portage Bay' 'StreetType_Urban Village Neighborhood'
#  'Dir_S' 'ZoningNorth Capitol Hill' 'Bike_Facility_Neighborhood Greenway'
#  'Dir_N' 'SW_WIDTH' 'ZoningFauntleroy/Seaview' 'SpeedLimit_40.0'
#  'ZoningGeorgetown' 'ZoningNorth Beach/Blue Ridge' 'ZoningArbor Heights'
#  'SURFACEWID_log' 'ZoningMagnolia'
#  'Bike_Facility_In Street, Minor Separation'
#  'Weather_Clear or Partly Cloudy' 'SEGLENGTH_log' 'ZoningInterbay'
#  'SpeedLimit_35.0' 'ZoningSouth Beacon Hill/NewHolly'
#  'ZoningDowntown Commercial Core' 'ZoningAlki/Admiral'
#  'ZoningGreenwood/Phinney Ridge' 'ZoningHigh Point' 'RushHour_0.0' 'Dir_W'
#  'ZoningNorth Delridge' 'ZoningMadrona/Leschi' 'StreetType_Alley'
#  'ZoningColumbia City' 'ZoningBelltown' 'Weekday_1'
#  'ZoningCedar Park/Meadowbrook' 'ZoningRiverview' 'SpeedLimit_30.0'
#  'SpeedLimit_20.0' 'ZoningCascade/Eastlake' 'ZoningBallard'
#  'Condition_VERY-POOR' 'NeighborhoodManufacturing/Industrial'
#  'ZoningRavenna/Bryant' 'SpeedLimit_25.0' 'StreetType_Downtown'
#  'Surface_AC/PCC' 'ZoningJudkins Park' 'NeighborhoodSingle Family']
# [ 90  71  55  97  17  16  56 101  85  30  69  61  15  43 109 115 116  39
#   95  67 119  52 120  58  51  35  28  68 102 112  73  88  24  49  29  33
#   60  82  79  46  20  93  81 113  74 114  40  21  91  70  48   4 100  34
#   50  23   3   6  45  41 107   9   7  31  47   8  32 105  37  18  65  53
#   44  38   2  63 106  36  22 110  66  19   5  89  14  92 108  77   1 104
#   64  59   0  98  13 121  87  76  94  96  57  25 111 103  26  86  80  62
#   84 118  12  10  83  78  54  72 117  11  27  42  99  75]

# %%
scores(logReg2,X_train, y_train)
# Out:
# 64261
# accuracy_score:  0.8359035807099173
# recall_score:  0.84
# precision_score:  0.30571612074502247
#  roc_auc_score:  0.8377752235425364

# %%
scores(logReg2,X_test, y_test)
# Out:
# 7141
# accuracy_score:  0.8382579470662372
# recall_score:  0.8641975308641975
# precision_score:  0.3125
#  roc_auc_score:  0.85010910921062

# %%
## Grid Search 

from sklearn.model_selection import GridSearchCV
params = {
    'penalty': ['l1','l2'],
    'C': [0.001, 0.01, 0.1, 1,10,100],
     'class_weight': ['balanced']
}
new_params = {'classifier__' + key: params[key] for key in params}
grid_lg_balance = GridSearchCV(logReg2, param_grid=new_params, cv=K_FOLD, scoring='recall', return_train_score=True)
grid_lg_balance.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('preprocessor',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('num',
#                                                                          Pipeline(memory=None,
#                                                                                   steps=[('imputer',
#                                                                                           SimpleImputer(add_indicator=False,
#                                                                                                         co...
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='liblinear',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'classifier__class_weight': ['balanced'],
#                          'classifier__penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='recall', verbose=0)

# %%
grid_lg_balance.best_params_
# Out:
# {'classifier__C': 0.1,
#  'classifier__class_weight': 'balanced',
#  'classifier__penalty': 'l1'}

# %%
grid_lg_balance.best_score_
# Out:
# 0.8376472968235239

# %%
f_imp = grid_lg_balance.best_estimator_['classifier'].coef_
f_imp
# Out:
# array([[ 0.27686873,  0.23895069,  0.08168891, -0.04184938, -0.09979206,
#          0.1517882 , -0.03441862,  0.        ,  0.00848106, -0.00960456,
#          0.        ,  0.68470366,  0.32075475,  0.        ,  0.        ,
#         -0.24476291,  0.        ,  0.        ,  0.10449783,  0.21179627,
#         -0.09214592,  0.        ,  0.05297164, -0.04419823,  0.        ,
#          0.11955659,  0.10663175,  1.0267607 , -0.13222512, -0.24470379,
#         -0.59932542,  0.        ,  0.        ,  0.        ,  0.        ,
#         -0.34624853,  0.10662722,  0.        ,  0.10166671,  0.        ,
#         -0.10367911,  0.        ,  1.12124462, -0.63300234,  0.0649339 ,
#          0.0109675 , -0.16488639,  0.05270081, -0.01815294, -0.13108162,
#          0.15332472, -0.19543873, -0.62146602,  0.06175791,  0.3736981 ,
#         -1.88400588, -1.07060026,  0.41983878, -0.53023691,  0.19856554,
#         -0.04179131, -0.77588515,  0.54258155,  0.        ,  0.31831841,
#          0.4355557 ,  0.14786754,  0.        , -0.35774862, -0.78260261,
#          0.        , -0.92206971,  0.76497386, -0.16296879, -0.12504036,
#          1.27252149,  0.34145521,  0.0551633 ,  0.61094529, -0.15497776,
#          0.48875426, -0.13073958, -0.09244202,  0.56695384,  0.5508261 ,
#         -0.72116226,  0.4905642 ,  0.25974049, -0.19165517,  0.        ,
#         -1.43570638, -0.05898958,  0.        , -0.10646314,  0.28536975,
#         -0.43160848,  0.37003603, -1.22187073,  0.03418992,  1.15491956,
#          0.        , -0.76698385, -0.36102825,  0.27192688,  0.14178165,
#          0.        ,  0.        ,  0.        ,  0.12134589, -0.63449276,
#          0.02335194,  0.27696322, -0.22874282,  0.        , -0.03028584,
#         -0.53072241, -0.56458973,  0.88296311,  0.55046786, -0.52810597,
#         -0.44172735,  0.18951799]])

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name,)))
featurename
# Out:
# array(['SEGLENGTH_log', 'SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1',
#        'SLOPE_PCT', 'SW_WIDTH', 'FILLERWID', 'MINIMUMVARIABLEWIDTH',
#        'PRIMARYCROSSSLOPE', 'LENGTH_MIL', 'x0_20.0', 'x0_25.0', 'x0_30.0',
#        'x0_35.0', 'x0_40.0', 'x0_45.0', 'x0_50.0', 'x0_55.0', 'x1_E',
#        'x1_N', 'x1_NE', 'x1_NW', 'x1_S', 'x1_SE', 'x1_SW', 'x1_W',
#        'x2_Alley', 'x2_Downtown', 'x2_Downtown Neighborhood',
#        'x2_Downtown Neighborhood Access', 'x2_Industrial Access',
#        'x2_Minor Industrial Access', 'x2_Neighborhood Corridor',
#        'x2_Neighborhood Yield Street', 'x2_Urban Center Connector',
#        'x2_Urban Village Main', 'x2_Urban Village Neighborhood',
#        'x2_Urban Village Neighborhood Access', 'x3_N', 'x3_Y', 'x4_AC',
#        'x4_AC/AC', 'x4_AC/PCC', 'x4_GRAVEL', 'x4_PCC', 'x4_ST', 'x5_ART',
#        'x5_MLTUSETRL', 'x5_NON-ART', 'x6_ ', 'x6_EXCELLENT', 'x6_FAIR',
#        'x6_GOOD', 'x6_POOR', 'x6_VERY-POOR', 'x7_N', 'x7_Y', 'x8_0.0',
#        'x8_1.0', 'x9_Clear or Partly Cloudy', 'x9_Raining', 'x10_0',
#        'x10_1', 'x11_In Street, Major Separation',
#        'x11_In Street, Minor Separation', 'x11_Multi-use Trail',
#        'x11_Neighborhood Greenway', 'x11_NoFacility', 'x11_Sharrow',
#        'x12_Commercial/Mixed Use', 'x12_Downtown',
#        'x12_Major Institutions', 'x12_Manufacturing/Industrial',
#        'x12_Master Planned Community', 'x12_Multi-Family',
#        'x12_Single Family', 'x13_Alki/Admiral', 'x13_Arbor Heights',
#        'x13_Ballard', 'x13_Beacon Hill', 'x13_Belltown',
#        'x13_Broadview/Bitter Lake', 'x13_Capitol Hill',
#        'x13_Cascade/Eastlake', 'x13_Cedar Park/Meadowbrook',
#        'x13_Central Area/Squire Park', 'x13_Columbia City',
#        'x13_Downtown Commercial Core', 'x13_Duwamish/SODO',
#        'x13_Fauntleroy/Seaview', 'x13_First Hill', 'x13_Fremont',
#        'x13_Georgetown', 'x13_Green Lake', 'x13_Greenwood/Phinney Ridge',
#        'x13_Haller Lake', 'x13_High Point', 'x13_Highland Park',
#        'x13_Interbay', 'x13_Judkins Park', 'x13_Laurelhurst/Sand Point',
#        'x13_Licton Springs', 'x13_Madison Park', 'x13_Madrona/Leschi',
#        'x13_Magnolia', 'x13_Miller Park', 'x13_Montlake/Portage Bay',
#        'x13_Mt. Baker/North Rainier', 'x13_North Beach/Blue Ridge',
#        'x13_North Beacon Hill/Jefferson Park', 'x13_North Capitol Hill',
#        'x13_North Delridge', 'x13_Northgate/Maple Leaf',
#        'x13_Olympic Hills/Victory Heights',
#        'x13_Pioneer Square/International District', 'x13_Queen Anne',
#        'x13_Rainier Beach', 'x13_Ravenna/Bryant', 'x13_Riverview',
#        'x13_Roxhill/Westwood', 'x13_Seward Park',
#        'x13_South Beacon Hill/NewHolly', 'x13_South Park',
#        'x13_Sunset Hill/Loyal Heights', 'x13_University District',
#        'x13_Wallingford', 'x13_Wedgwood/View Ridge',
#        'x13_West Seattle Junction/Genesee Hill', 'x13_Whittier Heights'],
#       dtype=object)

# %%
#logReg2.predict_proba(X)

plt.figure(figsize=(20,20))
plt.barh(range(len(f_imp[0])),
         width=np.sort(f_imp[0]))
plt.yticks(ticks=range(len(f_imp[0])), labels=featurename[np.argsort(f_imp[0])])
plt.title('Logistic regression coefficients')
#print(featurename[np.argsort(f_imp[0])])
#print(np.sort(f_imp[0]))
#plt.savefig("fig/lr_coeff.png", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Logistic regression coefficients')

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score
_y_prediction = grid_lg_balance.predict(X_train)
print(len(_y_prediction))


print(accuracy_score(y_train,_y_prediction))
print(recall_score(y_train,_y_prediction))
print(precision_score(y_train,_y_prediction))
print(roc_auc_score(y_train,_y_prediction))
# Out:
# 64261
# 0.8350321345761815
# 0.8437254901960785
# 0.30502587367973344
# 0.8390041051156185

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_lg_balance.predict(X_test)
print(len(_y_prediction))
print(accuracy_score(y_test,_y_prediction))
print(recall_score(y_test,_y_prediction))
print(precision_score(y_test,_y_prediction))
print(roc_auc_score(y_test,_y_prediction))
# Out:
# 7141
# 0.8304159081361154
# 0.8430335097001763
# 0.29875
# 0.8361805820481412

# %%
## try XGboost

# %%
numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN', 'PVMTCOND_1','SLOPE_PCT' ,
                    'SW_WIDTH' ,'FILLERWID','MINIMUMVARIABLEWIDTH', 'PRIMARYCROSSSLOPE', 'LENGTH_MIL']
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['SPEEDLIMIT','SEGDIR', 'STREETTYPE','ONEWAY', 'SURFACETYP','PVMTCATEGO',  
'CONDITION', 'SWINCOMPLETEYN', 'simulate_rushhour','simulate_weather','simulate_weekday', \
                        'EXISTING_FACILITY_TYPE','CLASS_DESC',  'GEN_ALIAS']

#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV'

# %%
import xgboost as xgb

## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
xgboost = make_pipeline(preprocessor,xgb_model)

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

new_params = {'xgbclassifier__' + key: params[key] for key in params}


grid_imba3 = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba3.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
scores( grid_imba3,X_train, y_train)
# Out:
# 64261
# 0.8054652121815721
# 0.8737254901960785
# 0.2731563783485564
# 0.83665314755912

# %%
scores( grid_imba3,X_test y_test)

# %%
grid_imba3.best_params_
# Out:
# {'xgbclassifier__scale_pos_weight': 15,
#  'xgbclassifier__reg_alpha': 100,
#  'xgbclassifier__min_child_weight': 5,
#  'xgbclassifier__max_depth': 4,
#  'xgbclassifier__learning_rate': 0.05,
#  'xgbclassifier__gamma': 0.3,
#  'xgbclassifier__colsample_bytree': 0.7}

# %%
grid_imba3.best_score_
# Out:
# 0.8627452506033148

# %%
# save the model to disk
import pickle

filename = 'model.sav'
pickle.dump(grid_imba3, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
#grid_imba3 = pickle.load(open(filename, 'rb'))

# %%
from sklearn.calibration import CalibratedClassifierCV, calibration_curve

# predict probabilities
probs = grid_imba3.predict_proba(X_test)[:,1]
# reliability diagram
fop, mpv = calibration_curve(y_test, probs, n_bins=10)
# plot perfectly calibrated
plt.plot([0, 1], [0, 1], linestyle='--')
# plot model reliability
plt.plot(mpv, fop, marker='.')
plt.show()

# %%
street = street.rename(columns = {'LENGTH_MILES' : 'LENGTH_MIL'})

# %%
#street[numeric_features + categorical_features]


street_all = pd.concat([street]*8, ignore_index = True)

# %%
street_all['simulate_rushhour'] = pd.Series(np.concatenate((np.zeros(len(street) * 4), np.ones(len(street) * 4)), axis=0))
street_all['simulate_weekday'] = pd.Series(np.concatenate((np.zeros(len(street) * 2), np.ones(len(street) * 2) , np.zeros(len(street) * 2), np.ones(len(street) * 2)), axis=0))
street_all['simulate_weather'] = pd.Series( ['Clear or Partly Cloudy' , 'Raining'] * len(street) * 4)

# %%
grid_imba3.best_score_
# Out:
# 0.8674507698537002

# %%
grid_imba3.predict(street_all[numeric_features + categorical_features])
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
risk_raw = grid_imba3.predict_proba(street_all[numeric_features + categorical_features])
risk_raw
# Out:
# array([[0.36251694, 0.63748306],
#        [0.5492816 , 0.4507184 ],
#        [0.67346597, 0.32653403],
#        ...,
#        [0.75110686, 0.24889314],
#        [0.22876972, 0.7712303 ],
#        [0.46965754, 0.53034246]], dtype=float32)

# %%
risk_raw
# Out:
# array([[0.36251694, 0.63748306],
#        [0.5492816 , 0.4507184 ],
#        [0.67346597, 0.32653403],
#        ...,
#        [0.75110686, 0.24889314],
#        [0.22876972, 0.7712303 ],
#        [0.46965754, 0.53034246]], dtype=float32)

# %%
risk =[risk_raw[i][1] for i in np.arange(0,len(risk_raw))]
pd.Series(risk).hist()

# %%
street_all['prob'] = pd.Series(risk)

# %%
Street_shp_pro = Street_shp.to_crs({'init': 'epsg:4326'})
Street_shp_pro.crs
# Out:
# {'init': 'epsg:4326'}

# %%
coord_list = Street_shp_pro['geometry'].astype('str').apply(lambda x : x.replace("LINESTRING (", "").replace(")", "").replace(",", "").split(' '))

coord_list
# Out:
# 0        [-122.3375442710094, 47.606121759368, -122.338...
# 1        [-122.340013428811, 47.60882096093927, -122.34...
# 2        [-122.3553845415613, 47.62637387155812, -122.3...
# 3        [-122.3555789814384, 47.6391160293215, -122.35...
# 4        [-122.3555328223153, 47.6456189886751, -122.35...
#                                ...
# 23490    [-122.3929431268078, 47.58407976209051, -122.3...
# 23491    [-122.3859930187936, 47.6539771324146, -122.38...
# 23492    [-122.2719664010849, 47.66127779814945, -122.2...
# 23493    [-122.3008869177021, 47.66326617773033, -122.3...
# 23494    [-122.3224517065414, 47.59750875698671, -122.3...
# Name: geometry, Length: 23495, dtype: object

# %%
Street_shp_pro['coordinates'] = pd.Series(coord_list).replace('[', '').replace(']','')
Street_shp_pro['coordinates']
# Out:
# 0        [-122.3375442710094, 47.606121759368, -122.338...
# 1        [-122.340013428811, 47.60882096093927, -122.34...
# 2        [-122.3553845415613, 47.62637387155812, -122.3...
# 3        [-122.3555789814384, 47.6391160293215, -122.35...
# 4        [-122.3555328223153, 47.6456189886751, -122.35...
#                                ...
# 23490    [-122.3929431268078, 47.58407976209051, -122.3...
# 23491    [-122.3859930187936, 47.6539771324146, -122.38...
# 23492    [-122.2719664010849, 47.66127779814945, -122.2...
# 23493    [-122.3008869177021, 47.66326617773033, -122.3...
# 23494    [-122.3224517065414, 47.59750875698671, -122.3...
# Name: coordinates, Length: 23495, dtype: object

# %%
## more than two coordinates 
np.where([len(Street_shp_pro['coordinates'][i]) > 4 for i in np.arange(0,len(Street_shp_pro))] )
# Out:
# (array([    4,     6,     7, ..., 23487, 23492, 23493]),)

# %%
Street_shp_pro['start_long'] = [Street_shp_pro['coordinates'][i][0] for i in np.arange(0,len(Street_shp_pro))]
Street_shp_pro['start_lat'] = [Street_shp_pro['coordinates'][i][1] for i in np.arange(0,len(Street_shp_pro))]

Street_shp_pro['end_long'] = [Street_shp_pro['coordinates'][i][-2] for i in np.arange(0,len(Street_shp_pro))]
Street_shp_pro['end_lat'] = [Street_shp_pro['coordinates'][i][-1] for i in np.arange(0,len(Street_shp_pro))]

# %%
Street_shp_pro.columns
# Out:
# Index(['OBJECTID', 'ARTCLASS', 'COMPKEY', 'UNITIDSORT', 'UNITDESC', 'STNAME_ORD', 'XSTRLO', 'XSTRHI', 'ARTDESCRIP', 'OWNER', 'STATUS', 'BLOCKNBR', 'SPEEDLIMIT', 'SEGDIR', 'ONEWAY', 'ONEWAYDIR', 'FLOW', 'SEGLENGTH', 'SURFACEWID', 'SURFACETYP', 'SURFACET_1', 'INTRLO', 'DIRLO', 'INTKEYLO', 'INTRHI', 'DIRHI', 'NATIONHWYS', 'STREETTYPE', 'PVMTCONDIN', 'PVMTCOND_1', 'TRANCLASS', 'TRANDESCRI', 'SLOPE_PCT', 'PVMTCATEGO', 'PARKBOULEV', 'SHAPE_Leng', 'geometry', 'coordinates', 'start_long', 'start_lat', 'end_long', 'end_lat'], dtype='object')

# %%
dot_coordinate = pd.DataFrame(Street_shp_pro['coordinates'].values.tolist(), index = Street_shp_pro['coordinates'].index)

# %%
dot_coordinate.head()

dot_coordinate.to_csv('./data/coordinates_for_streets.csv', sep = ",")

# %%
geo = Street_shp_pro.merge(coord_list, left_on = Street_shp_pro.index, right_on = coord_list.index, how = 'left')

# %%
allinfo = street_all.merge(geo.loc[:,['COMPKEY', 'coordinates', 'start_long' ,'start_lat', 'end_long', 'end_lat', 'geometry_x']],\
                left_on = 'COMPKEY_x', right_on = 'COMPKEY', how = 'left')

# %%
allinfo.to_csv('data/allinfo_Oct9.csv' , sep = ',', index =False)

# %%
rush_weekday_clear = allinfo.loc[(allinfo['simulate_rushhour'] == 1) & (allinfo['simulate_weekday'] == 1) & (allinfo['simulate_weather'] == 'Clear or Partly Cloudy'),:]

# %%
rush_weekday_rain = allinfo.loc[(allinfo['simulate_rushhour'] == 1) & (allinfo['simulate_weekday'] == 1) & (allinfo['simulate_weather'] == 'Raining'),:]

# %%
rush_weekend_clear = allinfo.loc[(allinfo['simulate_rushhour'] == 1) & (allinfo['simulate_weekday'] == 0) & (allinfo['simulate_weather'] == 'Clear or Partly Cloudy'),:]

# %%
rush_weekend_rain = allinfo.loc[(allinfo['simulate_rushhour'] == 1) & (allinfo['simulate_weekday'] == 0) & (allinfo['simulate_weather'] == 'Raining'),:]

# %%
rush_weekend_rain[]
# Out:
# 95321                   1ST AVE BETWEEN PIKE ST AND PINE ST
# 95323             1ST AVE N BETWEEN LYNN ST AND MCGRAW S ST
# 95325          1ST AVE NE BETWEEN NE 60TH ST AND NE 61ST ST
# 95327         1ST AVE NW BETWEEN N 42ND E ST AND NW 43RD ST
# 95329          1ST AVE NW BETWEEN NW 65TH ST AND NW 67TH ST
#                                 ...
# 142971       S GENESEE ST BETWEEN 37TH AVE S AND 38TH AVE S
# 142973    CALIFORNIA AVE SW BETWEEN SW ADMIRAL WAY AND S...
# 142975       GILMAN AVE W BETWEEN 26TH AVE W AND 27TH AVE W
# 142977    UNIVERSITY WAY NE BETWEEN NE 52ND ST AND NE 55...
# 142979       NE 75TH ST BETWEEN 27TH AVE NE AND 28TH AVE NE
# Name: UNITDESC_x, Length: 23830, dtype: object

# %%
nonrush_weekday_clear = allinfo.loc[(allinfo['simulate_rushhour'] == 0) & (allinfo['simulate_weekday'] == 1) & (allinfo['simulate_weather'] == 'Clear or Partly Cloudy'),:]

# %%
nonrush_weekday_rain = allinfo.loc[(allinfo['simulate_rushhour'] == 0) & (allinfo['simulate_weekday'] == 1) & (allinfo['simulate_weather'] == 'Raining'),:]

# %%
nonrush_weekend_clear = allinfo.loc[(allinfo['simulate_rushhour'] == 0) & (allinfo['simulate_weekday'] == 0) & (allinfo['simulate_weather'] == 'Clear or Partly Cloudy'),:]

# %%
nonrush_weekend_rain = allinfo.loc[(allinfo['simulate_rushhour'] == 0) & (allinfo['simulate_weekday'] == 0) & (allinfo['simulate_weather'] == 'Raining'),:]

# %%
selectCol = ['COMPKEY_x','UNITDESC_x','simulate_rushhour', 'simulate_weekday', 'simulate_weather', 'prob', 'prob_cali',
            'start_long', 'start_lat', 'end_long', 'end_lat', 'geometry_x', 'SEGLENGTH']

# %%
rush_weekday_clear[selectCol].to_csv('data/rush_weekday_clear_oct9.csv' , sep = ',', index =False)

rush_weekend_clear[selectCol].to_csv('data/rush_weekend_clear_oct9.csv' , sep = ',', index =False)

rush_weekday_rain[selectCol].to_csv('data/rush_weekday_rain_oct9.csv' , sep = ',', index =False)

rush_weekend_rain[selectCol].to_csv('data/rush_weekend_rain_oct9.csv' , sep = ',', index =False)

nonrush_weekday_clear[selectCol].to_csv('data/nonrush_weekday_clear_oct9.csv' , sep = ',', index =False)

nonrush_weekend_clear[selectCol].to_csv('data/nonrush_weekend_clear_oct9.csv' , sep = ',', index =False)

nonrush_weekday_rain[selectCol].to_csv('data/nonrush_weekday_rain_oct9.csv' , sep = ',', index =False)

nonrush_weekend_rain[selectCol].to_csv('data/nonrush_weekend_rain_oct9.csv' , sep = ',', index =False)

# %%
nonrush_weekend_clear['prob'].describe()
# Out:
# count    23830.000000
# mean         0.390590
# std          0.134184
# min          0.263582
# 25%          0.268324
# 50%          0.346696
# 75%          0.479464
# max          0.709543
# Name: prob, dtype: float64

# %%
type(Street_shp_pro['coordinates'][0])
# Out:
# list

# %%
grid_imba3.best_params_
# Out:
# {'xgbclassifier__scale_pos_weight': 15,
#  'xgbclassifier__reg_alpha': 10000,
#  'xgbclassifier__min_child_weight': 5,
#  'xgbclassifier__max_depth': 5,
#  'xgbclassifier__learning_rate': 0.01,
#  'xgbclassifier__gamma': 0.0,
#  'xgbclassifier__colsample_bytree': 0.4}

# %%
cat_name  = grid_imba3.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name)))

# %%
#grid_imba3.best_estimator_['xgbclassifier'].get_booster().get_score(importance_type= 'gain')

# %%
from xgboost import plot_importance 
plot_importance(grid_imba3.best_estimator_['xgbclassifier'],max_num_features = 15) #,

# %%
f_imp = grid_imba3.best_estimator_['xgbclassifier'].feature_importances_

# %%
f_imp

for i in np.arange(0,len(featurename)):
    featurename[i] = featurename[i].replace('x8_', 'RushHour_').replace('x9_', 'Weather_').\
        replace('x10_', 'Weekday_').replace('x11_', 'Bike_Facility_').\
        replace('x12_', 'Neighborhood_').replace('x13_', 'Zoning_').\
        replace('x0_', 'SpeedLimit_').replace('x1_', 'Direction_').replace('x2_', 'StreetType_').\
        replace('x3_', 'OneWay_').replace('x4_', 'Surface_').\
        replace('x5_', 'StreetClassification_').replace('x6_', 'Condition_').replace('x7_', 'SWIncomplete_')\
        
        
print(featurename)
# Out:
# ['SEGLENGTH_log' 'SURFACEWID_log' 'PVMTCONDIN' 'PVMTCOND_1' 'SLOPE_PCT'
#  'SW_WIDTH' 'FILLERWID' 'MINIMUMVARIABLEWIDTH' 'PRIMARYCROSSSLOPE'
#  'LENGTH_MIL' 'SpeedLimit_20.0' 'SpeedLimit_25.0' 'SpeedLimit_30.0'
#  'SpeedLimit_35.0' 'SpeedLimit_40.0' 'SpeedLimit_45.0' 'SpeedLimit_50.0'
#  'SpeedLimit_55.0' 'Direction_E' 'Direction_N' 'Direction_NE'
#  'Direction_NW' 'Direction_S' 'Direction_SE' 'Direction_SW' 'Direction_W'
#  'StreetType_Alley' 'StreetType_Downtown'
#  'StreetType_Downtown Neighborhood'
#  'StreetType_Downtown Neighborhood Access' 'StreetType_Industrial Access'
#  'StreetType_Minor Industrial Access' 'StreetType_Neighborhood Corridor'
#  'StreetType_Neighborhood Yield Street'
#  'StreetType_Urban Center Connector' 'StreetType_Urban Village Main'
#  'StreetType_Urban Village Neighborhood'
#  'StreetType_Urban Village Neighborhood Access' 'OneWay_N' 'OneWay_Y'
#  'Surface_AC' 'Surface_AC/AC' 'Surface_AC/PCC' 'Surface_GRAVEL'
#  'Surface_PCC' 'Surface_ST' 'StreetClassification_ART'
#  'StreetClassification_MLTUSETRL' 'StreetClassification_NON-ART'
#  'Condition_ ' 'Condition_EXCELLENT' 'Condition_FAIR' 'Condition_GOOD'
#  'Condition_POOR' 'Condition_VERY-POOR' 'SWIncomplete_N' 'SWIncomplete_Y'
#  'RushHour_0.0' 'RushHour_1.0' 'Weather_Clear or Partly Cloudy'
#  'Weather_Raining' 'Weekday_0' 'Weekday_1'
#  'Bike_Facility_In Street, Major Separation'
#  'Bike_Facility_In Street, Minor Separation'
#  'Bike_Facility_Multi-use Trail' 'Bike_Facility_Neighborhood Greenway'
#  'Bike_Facility_NoFacility' 'Bike_Facility_Sharrow'
#  'Neighborhood_Commercial/Mixed Use' 'Neighborhood_Downtown'
#  'Neighborhood_Major Institutions' 'Neighborhood_Manufacturing/Industrial'
#  'Neighborhood_Master Planned Community' 'Neighborhood_Multi-Family'
#  'Neighborhood_Single Family' 'Zoning_Alki/Admiral' 'Zoning_Arbor Heights'
#  'Zoning_Ballard' 'Zoning_Beacon Hill' 'Zoning_Belltown'
#  'Zoning_Broadview/Bitter Lake' 'Zoning_Capitol Hill'
#  'Zoning_Cascade/Eastlake' 'Zoning_Cedar Park/Meadowbrook'
#  'Zoning_Central Area/Squire Park' 'Zoning_Columbia City'
#  'Zoning_Downtown Commercial Core' 'Zoning_Duwamish/SODO'
#  'Zoning_Fauntleroy/Seaview' 'Zoning_First Hill' 'Zoning_Fremont'
#  'Zoning_Georgetown' 'Zoning_Green Lake' 'Zoning_Greenwood/Phinney Ridge'
#  'Zoning_Haller Lake' 'Zoning_High Point' 'Zoning_Highland Park'
#  'Zoning_Interbay' 'Zoning_Judkins Park' 'Zoning_Laurelhurst/Sand Point'
#  'Zoning_Licton Springs' 'Zoning_Madison Park' 'Zoning_Madrona/Leschi'
#  'Zoning_Magnolia' 'Zoning_Miller Park' 'Zoning_Montlake/Portage Bay'
#  'Zoning_Mt. Baker/North Rainier' 'Zoning_North Beach/Blue Ridge'
#  'Zoning_North Beacon Hill/Jefferson Park' 'Zoning_North Capitol Hill'
#  'Zoning_North Delridge' 'Zoning_Northgate/Maple Leaf'
#  'Zoning_Olympic Hills/Victory Heights'
#  'Zoning_Pioneer Square/International District' 'Zoning_Queen Anne'
#  'Zoning_Rainier Beach' 'Zoning_Ravenna/Bryant' 'Zoning_Riverview'
#  'Zoning_Roxhill/Westwood' 'Zoning_Seward Park'
#  'Zoning_South Beacon Hill/NewHolly' 'Zoning_South Park'
#  'Zoning_Sunset Hill/Loyal Heights' 'Zoning_University District'
#  'Zoning_Wallingford' 'Zoning_Wedgwood/View Ridge'
#  'Zoning_West Seattle Junction/Genesee Hill' 'Zoning_Whittier Heights']

# %%
#featurename = np.array(['StreetLength', 'StreetWidth', 'PavementCondition', 'PavementCondition_Secondary',
#       'Slope', 'Sidewalk_Width', 'Filler_Width', 'MinimumVriableWidth',
#       'PrimaryCrossSlope', 'BikeLane_Length', 'SpeedLimit', 'Direction',
#       'StreetType', 'OneWay', 'SurfaceType', 'Category', 'Sidewalk_Condition',
#       'SidewalkIncomplete', 'RushHour', 'Weather',
#       'Weekday', 'BikeFacilityType', 'Neighborhood',
#       'Zoning'])

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename[np.argsort(f_imp)][-25:],
    'Importance': np.sort(f_imp)[-25:]
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,10))
plt.barh(y = feat_imp['Feature'][-25:], width=feat_imp['Importance'][-25:])
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance',  fontsize=12)
plt.title('XGBoost Feature Importance', fontsize=15)
plt.savefig('Feature Importance_xgboost.png')

# %%
np.sort(f_imp)
# Out:
# array([0.        , 0.00053282, 0.0005411 , 0.00056172, 0.00063231,
#        0.00079981, 0.00186232, 0.00311781, 0.00360474, 0.00422621,
#        0.0051357 , 0.00519052, 0.00712066, 0.00719865, 0.00910948,
#        0.01261491, 0.02188811, 0.02539854, 0.05827867, 0.09695001,
#        0.11279297, 0.18047483, 0.21261045, 0.22935764], dtype=float32)

# %%
roc_plot(grid_imba3, X_test, y_test)
plt.savefig('ROC_xgboost.png')
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.912

# %%
##  XGboost ordinal variable 

# re_group variables 

numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN','SLOPE_PCT' ,
                    'SW_WIDTH' ,'LENGTH_MIL']
#'PVMTCOND_1', 'PRIMARYCROSSSLOPE','MINIMUMVARIABLEWIDTH','FILLERWID'
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['STREETTYPE', 'PVMTCATEGO',\
                        'EXISTING_FACILITY_TYPE','CLASS_DESC']
ordinal_features = ['SPEEDLIMIT', 'ARTCLASS', 'CONDITION','ONEWAY',\
                   'simulate_rushhour','simulate_weather','simulate_weekday']
#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV' , 'MINIMUMVARIABLEWIDTH' ,

# %%
import xgboost as xgb
from sklearn.preprocessing import OrdinalEncoder
## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('ord', ordinal_transformer, ordinal_features)])

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
xgboost = make_pipeline(preprocessor,xgb_model)

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

new_params = {'xgbclassifier__' + key: params[key] for key in params}


grid_imba_ord = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba_ord.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1679-87e8a2e8d06a> in <module>
#      35
#      36 grid_imba_ord = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
# ---> 37 grid_imba_ord.fit(X_train, y_train)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1467         evaluate_candidates(ParameterSampler(
#    1468             self.param_distributions, self.n_iter,
# -> 1469             random_state=self.random_state))
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/imblearn/pipeline.py in fit(self, X, y, **fit_params)
#     236
#     237         """
# --> 238         Xt, yt, fit_params = self._fit(X, y, **fit_params)
#     239         if self._final_estimator != 'passthrough':
#     240             self._final_estimator.fit(Xt, yt, **fit_params)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/imblearn/pipeline.py in _fit(self, X, y, **fit_params)
#     196                 X, fitted_transformer = fit_transform_one_cached(
#     197                     cloned_transformer, None, X, y,
# --> 198                     **fit_params_steps[name])
#     199             elif hasattr(cloned_transformer, "fit_resample"):
#     200                 X, y, fitted_transformer = fit_resample_one_cached(
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/imblearn/pipeline.py in _fit_transform_one(transformer, weight, X, y, **fit_params)
#     570 def _fit_transform_one(transformer, weight, X, y, **fit_params):
#     571     if hasattr(transformer, 'fit_transform'):
# --> 572         res = transformer.fit_transform(X, y, **fit_params)
#     573     else:
#     574         res = transformer.fit(X, y, **fit_params).transform(X)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     474         self._validate_remainder(X)
#     475
# --> 476         result = self._fit_transform(X, y, _fit_transform_one)
#     477
#     478         if not result:
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     418                     message=self._log_message(name, idx, len(transformers)))
#     419                 for idx, (name, trans, column, weight) in enumerate(
# --> 420                         self._iter(fitted=fitted, replace_strings=True), 1))
#     421         except ValueError as e:
#     422             if "Expected 2D array, got 1D array instead" in str(e):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     385         """
#     386         last_step = self._final_estimator
# --> 387         Xt, fit_params = self._fit(X, y, **fit_params)
#     388         with _print_elapsed_time('Pipeline',
#     389                                  self._log_message(len(self.steps) - 1)):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
# --> 556             return self.fit(X, y, **fit_params).transform(X)
#     557
#     558
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/impute/_base.py in fit(self, X, y)
#     266                                                self.strategy,
#     267                                                self.missing_values,
# --> 268                                                fill_value)
#     269
#     270         if self.add_indicator:
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/impute/_base.py in _dense_fit(self, X, strategy, missing_values, fill_value)
#     356                 row_mask = np.logical_not(row_mask).astype(np.bool)
#     357                 row = row[row_mask]
# --> 358                 most_frequent[i] = _most_frequent(row, np.nan, 0)
#     359
#     360             return most_frequent
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/sklearn/impute/_base.py in _most_frequent(array, extra_value, n_repeat)
#      59             # has already been NaN-masked.
#      60             warnings.simplefilter("ignore", RuntimeWarning)
# ---> 61             mode = stats.mode(array)
#      62
#      63         most_frequent_value = mode[0][0]
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/scipy/stats/stats.py in mode(a, axis, nan_policy)
#     450         return ModeResult(np.array([]), np.array([]))
#     451
# --> 452     contains_nan, nan_policy = _contains_nan(a, nan_policy)
#     453
#     454     if contains_nan and nan_policy == 'omit':
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/scipy/stats/stats.py in _contains_nan(a, nan_policy)
#     250         # e.g. np.isnan(a).any()
#     251         with np.errstate(invalid='ignore'):
# --> 252             contains_nan = np.isnan(np.sum(a))
#     253     except TypeError:
#     254         # This can happen when attempting to sum things which are not
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2180
#    2181     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2182                           initial=initial, where=where)
#    2183
#    2184
#
# //anaconda3/envs/bike/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:

# %%
scores(grid_imba_ord, X_train,y_train )
# Out:
# 64261
# accuracy_score:  0.6656292307931716
# recall_score:  0.9052941176470588
# precision_score:  0.18020373912025292
#  roc_auc_score:  0.7751314657808155

# %%
scores(grid_imba_ord, X_test,y_test )
# Out:
# 7141
# accuracy_score:  0.6629323624142277
# recall_score:  0.9153439153439153
# precision_score:  0.18033356497567754
#  roc_auc_score:  0.778253034641839

# %%
cat_name  = grid_imba_ord.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name, ordinal_features)))
len(featurename)
# Out:
# 41

# %%
from xgboost import plot_importance 
plot_importance(grid_imba_ord.best_estimator_['xgbclassifier'],max_num_features = 15) #,

# %%
# fweature importance 
f_imp = grid_imba_ord.best_estimator_['xgbclassifier'].feature_importances_

# %%
len(f_imp)
# Out:
# 41

# %%
categorical_features
# Out:
# ['STREETTYPE', 'PVMTCATEGO', 'EXISTING_FACILITY_TYPE', 'CLASS_DESC']

# %%
for i in np.arange(0,len(featurename)):
    featurename[i] = featurename[i].\
     replace('x0_', 'StreetType_').replace('x1_', 'StreetClass_').replace('x2_', 'BikeFacilities_').\
     replace('x4_', 'Zoning_').replace('SEGLENGTH_log', 'StreetLength').replace('SURFACEWID_log', 'StreetWidth').\
     replace('SURFACEWID_log', 'StreetWidth')
        
print(featurename)
# Out:
# ['StreetLength' 'StreetWidth' 'PVMTCONDIN' 'SLOPE_PCT' 'SW_WIDTH'
#  'LENGTH_MIL' 'StreetType_Alley' 'StreetType_Downtown'
#  'StreetType_Downtown Neighborhood'
#  'StreetType_Downtown Neighborhood Access' 'StreetType_Industrial Access'
#  'StreetType_Minor Industrial Access' 'StreetType_Neighborhood Corridor'
#  'StreetType_Neighborhood Yield Street'
#  'StreetType_Urban Center Connector' 'StreetType_Urban Village Main'
#  'StreetType_Urban Village Neighborhood'
#  'StreetType_Urban Village Neighborhood Access' 'StreetClassART'
#  'StreetClassMLTUSETRL' 'StreetClassNON-ART'
#  'BikeFacilities_In Street, Major Separation'
#  'BikeFacilities_In Street, Minor Separation'
#  'BikeFacilities_Multi-use Trail' 'BikeFacilities_Neighborhood Greenway'
#  'BikeFacilities_NoFacility' 'BikeFacilities_Sharrow'
#  'x3_Commercial/Mixed Use' 'x3_Downtown' 'x3_Major Institutions'
#  'x3_Manufacturing/Industrial' 'x3_Master Planned Community'
#  'x3_Multi-Family' 'x3_Single Family' 'SPEEDLIMIT' 'ARTCLASS' 'CONDITION'
#  'ONEWAY' 'simulate_rushhour' 'simulate_weather' 'simulate_weekday']

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename[np.argsort(f_imp)[:]],
    'Importance': np.sort(f_imp)[:]
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,10))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'][:])
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance',  fontsize=12)
plt.title('XGBoost Feature Importance', fontsize=15)
plt.savefig('Feature Importance_xgboost.png')

# %%
# save the model to disk
import pickle

filename = 'grid_imba_ord.sav'
pickle.dump(grid_imba_ord, open(filename, 'wb'))

filename = 'grid_imba4.sav'
pickle.dump(grid_imba4, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
#grid_imba_ord = pickle.load(open(filename, 'rb'))

# %%
roc_plot(grid_imba_ord, X_test, y_test)
plt.savefig('ROC_xgboost_ord.png')
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.889

# %%
# re_group variables , remove #ARTCLASS

numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN','SLOPE_PCT' ,
                    'SW_WIDTH' ,'LENGTH_MIL']
#'ARTCLASS'
#'PVMTCOND_1', 'PRIMARYCROSSSLOPE','MINIMUMVARIABLEWIDTH','FILLERWID'
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['STREETTYPE', 'PVMTCATEGO',\
                        'EXISTING_FACILITY_TYPE','CLASS_DESC']
ordinal_features = ['SPEEDLIMIT', 'CONDITION','ONEWAY',\
                   'simulate_rushhour','simulate_weather','simulate_weekday']
#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV' , 'MINIMUMVARIABLEWIDTH' ,

# %%
##  XGboost ordinal variable ,remove #ARTCLASS
import xgboost as xgb
from sklearn.preprocessing import OrdinalEncoder
## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('ord', ordinal_transformer, ordinal_features)])

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
xgboost = make_pipeline(preprocessor,xgb_model)

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

new_params = {'xgbclassifier__' + key: params[key] for key in params}


xg_ord = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
xg_ord.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
scores(xg_ord, X_train, y_train)
# Out:
# 64261
# accuracy_score:  0.676382253621948
# recall_score:  0.8935294117647059
# precision_score:  0.18367593712212818
#  roc_auc_score:  0.7755961996028784

# %%
scores(xg_ord, X_test, y_test)
# Out:
# 7141
# accuracy_score:  0.6791765859123372
# recall_score:  0.9047619047619048
# precision_score:  0.18654545454545454
#  roc_auc_score:  0.7822410071421327

# %%
filename = 'xg_ord.sav'
pickle.dump(xg_ord, open(filename, 'wb'))

# %%
roc_plot(xg_ord, X_test, y_test)
plt.savefig('ROC_xgboost_ord.png')
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.888

# %%
cat_name  = xg_ord.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()

# %%
cat_name  = xg_ord.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name, ordinal_features)))

# %%
from xgboost import plot_importance 
plot_importance(grid_imba_ord.best_estimator_['xgbclassifier'],max_num_features = 15) #,

# %%
f_imp = xg_ord.best_estimator_['xgbclassifier'].feature_importances_

# %%
f_imp = np.round(f_imp,2)

# %%
categorical_features
# Out:
# ['STREETTYPE', 'PVMTCATEGO', 'EXISTING_FACILITY_TYPE', 'CLASS_DESC']

# %%
#f_imp

for i in np.arange(0,len(featurename)):
    featurename[i] = featurename[i].\
      replace('x0_', 'StreetType_').replace('x1_', 'StreetClass_').replace('x2_', 'BikeFacilities_').\
      replace('x3_', 'Zoning_').\
      replace('SPEEDLIMIT', 'Speedlimlit').replace('simulate_weekday', 'Weekday').\
      replace('SURFACEWID_log', 'StreetWidth').replace('simulate_weather', 'Weather').\
      replace('NON-ART', 'Non-Arterial').replace('ART', 'Arterial').replace('SW_WIDTH', 'SidewalkWidth').\
    replace('MLTUSETRL', 'Multiuse')
    
        
        
#print(featurename)

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename[np.argsort(f_imp)[-15:]],
    'Importance': np.sort(f_imp)[-15:]
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(5,5))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'][-15:])
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance',  fontsize=12)
plt.xticks(np.arange(0, 0.25, 0.05))
plt.title('XGBoost Feature Importance', fontsize=12)
plt.savefig('Feature Importance_xgboost.png')

# %%
# re_group variables , remove #ARTCLASS

numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN','SLOPE_PCT' ,
                    'SW_WIDTH' ,'LENGTH_MIL']
#'ARTCLASS'
#'PVMTCOND_1', 'PRIMARYCROSSSLOPE','MINIMUMVARIABLEWIDTH','FILLERWID'
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['SPEEDLIMIT', 'CONDITION','ONEWAY',\
                   'simulate_rushhour','simulate_weather','simulate_weekday',\
                   'STREETTYPE', 'PVMTCATEGO',\
                    'EXISTING_FACILITY_TYPE','CLASS_DESC']
#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV' , 'MINIMUMVARIABLEWIDTH' ,

# %%
##  XGboost ordinal variable for all categorical variables
import xgboost as xgb
from sklearn.preprocessing import OrdinalEncoder
## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
xgboost = make_pipeline(preprocessor,xgb_model)

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

new_params = {'xgbclassifier__' + key: params[key] for key in params}


xg_ord_all = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
xg_ord_all.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
scores(xg_ord_all, X_train, y_train)
# Out:
# 64261
# accuracy_score:  0.7920356047991783
# recall_score:  0.8664705882352941
# precision_score:  0.25839083148169806
#  roc_auc_score:  0.8260447462905313

# %%
scores(xg_ord_all, X_test, y_test)
# Out:
# 7141
# accuracy_score:  0.788124912477244
# recall_score:  0.8800705467372134
# precision_score:  0.2566872427983539
#  roc_auc_score:  0.8301326265782204

# %%
filename = 'xg_ord_all.sav'
pickle.dump(xg_ord_all, open(filename, 'wb'))

# %%
roc_plot(xg_ord_all, X_test, y_test)
plt.savefig('ROC_xgboost_ord.png')
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.912

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), categorical_features)))

# %%
from xgboost import plot_importance 
plot_importance(grid_imba_ord.best_estimator_['xgbclassifier'],max_num_features = 15) #,

# %%
f_imp = xg_ord_all.best_estimator_['xgbclassifier'].feature_importances_

# %%
#f_imp

#for i in np.arange(0,len(featurename)):
#    featurename[i] = featurename[i].replace('x8_', 'RushHour_').replace('x9_', 'Weather_').\
#        replace('x10_', 'Weekday_').replace('x11_', 'Bike_Facility_').\
###        replace('x12_', 'Neighborhood_').replace('x13_', 'Zoning_').\
 #       replace('x0_', 'SpeedLimit_').replace('x1_', 'Direction_').replace('x2_', 'StreetType_').\
 #       replace('x3_', 'OneWay_').replace('x4_', 'Surface_').\
 #       replace('x5_', 'StreetClassification_').replace('x6_', 'Condition_').replace('x7_', 'SWIncomplete_')\
        
        
#print(featurename)

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename[np.argsort(f_imp)[:]],
    'Importance': np.sort(f_imp)[:]
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,10))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'][:])
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance',  fontsize=12)
plt.title('XGBoost Feature Importance', fontsize=15)
plt.savefig('Feature Importance_xgboost.png')

# %%
##XGBOOST with FEATURE SELECTION 

## try XGboost 
import xgboost as xgb
from sklearn.feature_selection import SelectFromModel

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
#xgboost = make_pipeline(preprocessor,xgb_model)
grid_imba4 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('feature_selection', SelectFromModel(xgb.XGBClassifier(threshold = 0.01))),
                          ('classifier', xgb_model)])


#params0 = {"threshold" : [0.001, 0.01, 0.03, 0.05, 0.08, 0.1 ]  }

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

#new_params4 = dict({'selectfrommodel__' + key: params0[key] for key in params0})
#new_params4.update( {'classifier__' + key: params[key] for key in params}.items())

new_params4 = {'xgbclassifier__' + key: params[key] for key in params}

grid_imba4 = RandomizedSearchCV(xgboost, param_distributions =new_params4, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba4.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
grid_imba4.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                      transformer_weights=None,
#                      transformers=[('num',
#                                     Pipeline(memory=None,
#                                              steps=[('imputer',
#                                                      SimpleImputer(add_indicator=False,
#                                                                    copy=True,
#                                                                    fill_value=None,
#                                                                    missing_values=nan,
#                                                                    strategy='median',
#                                                                    verbose=0)),
#                                                     ('scaler',
#                                                      StandardScaler(copy=True,
#                                                                     with_mean=True,
#                                                                     with_std=True))],
#                                              verbose=False),
#                                     ['SEGL...
#                                                                    strategy='most_frequent',
#                                                                    verbose=0)),
#                                                     ('encode',
#                                                      OrdinalEncoder(categories='auto',
#                                                                     dtype=<class 'numpy.float64'>))],
#                                              verbose=False),
#                                     ['SPEEDLIMIT', 'SEGDIR', 'STREETTYPE',
#                                      'ONEWAY', 'SURFACETYP', 'PVMTCATEGO',
#                                      'CONDITION', 'SWINCOMPLETEYN',
#                                      'simulate_rushhour', 'simulate_weather',
#                                      'simulate_weekday', 'EXISTING_FACILITY_TYPE',
#                                      'CLASS_DESC', 'GEN_ALIAS'])],
#                      verbose=False)),
#   ('xgbclassifier',
#    XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                  colsample_bynode=1, colsample_bytree=0.7, gamma=0.0,
#                  learning_rate=0.01, max_delta_step=0, max_depth=5,
#                  min_child_weight=7, missing=None, n_estimators=100, n_jobs=1,
#                  nthread=None, objective='binary:logistic', random_state=0,
#                  reg_alpha=100, reg_lambda=1, scale_pos_weight=15, seed=None,
#                  silent=None, subsample=1, verbosity=1))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#                    transformer_weights=None,
#                    transformers=[('num',
#                                   Pipeline(memory=None,
#                                            steps=[('imputer',
#                                                    SimpleImputer(add_indicator=False,
#                                                                  copy=True,
#                                                                  fill_value=None,
#                                                                  missing_values=nan,
#                                                                  strategy='median',
#                                                                  verbose=0)),
#                                                   ('scaler',
#                                                    StandardScaler(copy=True,
#                                                                   with_mean=True,
#                                                                   with_std=True))],
#                                            verbose=False),
#                                   ['SEGL...
#                                                                  strategy='most_frequent',
#                                                                  verbose=0)),
#                                                   ('encode',
#                                                    OrdinalEncoder(categories='auto',
#                                                                   dtype=<class 'numpy.float64'>))],
#                                            verbose=False),
#                                   ['SPEEDLIMIT', 'SEGDIR', 'STREETTYPE',
#                                    'ONEWAY', 'SURFACETYP', 'PVMTCATEGO',
#                                    'CONDITION', 'SWINCOMPLETEYN',
#                                    'simulate_rushhour', 'simulate_weather',
#                                    'simulate_weekday', 'EXISTING_FACILITY_TYPE',
#                                    'CLASS_DESC', 'GEN_ALIAS'])],
#                    verbose=False),
#  'xgbclassifier': XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=0.7, gamma=0.0,
#                learning_rate=0.01, max_delta_step=0, max_depth=5,
#                min_child_weight=7, missing=None, n_estimators=100, n_jobs=1,
#                nthread=None, objective='binary:logistic', random_state=0,
#                reg_alpha=100, reg_lambda=1, scale_pos_weight=15, seed=None,
#                silent=None, subsample=1, verbosity=1),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('num', Pipeline(memory=None,
#             steps=[('imputer',
#                     SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                   missing_values=nan, strategy='median',
#                                   verbose=0)),
#                    ('scaler',
#                     StandardScaler(copy=True, with_mean=True, with_std=True))],
#             verbose=False), ['SEGLENGTH_log',
#     'SURFACEWID_log',
#     'PVMTCONDIN',
#     'PVMTCOND_1',
#     'SLOPE_PCT',
#     'SW_WIDTH',
#     'FILLERWID',
#     'MINIMUMVARIABLEWIDTH',
#     'PRIMARYCROSSSLOPE',
#     'LENGTH_MIL']),
#   ('cat', Pipeline(memory=None,
#             steps=[('imputer',
#                     SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                   missing_values=nan, strategy='most_frequent',
#                                   verbose=0)),
#                    ('encode',
#                     OrdinalEncoder(categories='auto',
#                                    dtype=<class 'numpy.float64'>))],
#             verbose=False), ['SPEEDLIMIT',
#     'SEGDIR',
#     'STREETTYPE',
#     'ONEWAY',
#     'SURFACETYP',
#     'PVMTCATEGO',
#     'CONDITION',
#     'SWINCOMPLETEYN',
#     'simulate_rushhour',
#     'simulate_weather',
#     'simulate_weekday',
#     'EXISTING_FACILITY_TYPE',
#     'CLASS_DESC',
#     'GEN_ALIAS'])],
#  'columntransformer__verbose': False,
#  'columntransformer__num': Pipeline(memory=None,
#           steps=[('imputer',
#                   SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                 missing_values=nan, strategy='median',
#                                 verbose=0)),
#                  ('scaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True))],
#           verbose=False),
#  'columntransformer__cat': Pipeline(memory=None,
#           steps=[('imputer',
#                   SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                 missing_values=nan, strategy='most_frequent',
#                                 verbose=0)),
#                  ('encode',
#                   OrdinalEncoder(categories='auto',
#                                  dtype=<class 'numpy.float64'>))],
#           verbose=False),
#  'columntransformer__num__memory': None,
#  'columntransformer__num__steps': [('imputer',
#    SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                  missing_values=nan, strategy='median', verbose=0)),
#   ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True))],
#  'columntransformer__num__verbose': False,
#  'columntransformer__num__imputer': SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                missing_values=nan, strategy='median', verbose=0),
#  'columntransformer__num__scaler': StandardScaler(copy=True, with_mean=True, with_std=True),
#  'columntransformer__num__imputer__add_indicator': False,
#  'columntransformer__num__imputer__copy': True,
#  'columntransformer__num__imputer__fill_value': None,
#  'columntransformer__num__imputer__missing_values': nan,
#  'columntransformer__num__imputer__strategy': 'median',
#  'columntransformer__num__imputer__verbose': 0,
#  'columntransformer__num__scaler__copy': True,
#  'columntransformer__num__scaler__with_mean': True,
#  'columntransformer__num__scaler__with_std': True,
#  'columntransformer__cat__memory': None,
#  'columntransformer__cat__steps': [('imputer',
#    SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                  missing_values=nan, strategy='most_frequent', verbose=0)),
#   ('encode',
#    OrdinalEncoder(categories='auto', dtype=<class 'numpy.float64'>))],
#  'columntransformer__cat__verbose': False,
#  'columntransformer__cat__imputer': SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                missing_values=nan, strategy='most_frequent', verbose=0),
#  'columntransformer__cat__encode': OrdinalEncoder(categories='auto', dtype=<class 'numpy.float64'>),
#  'columntransformer__cat__imputer__add_indicator': False,
#  'columntransformer__cat__imputer__copy': True,
#  'columntransformer__cat__imputer__fill_value': None,
#  'columntransformer__cat__imputer__missing_values': nan,
#  'columntransformer__cat__imputer__strategy': 'most_frequent',
#  'columntransformer__cat__imputer__verbose': 0,
#  'columntransformer__cat__encode__categories': 'auto',
#  'columntransformer__cat__encode__dtype': numpy.float64,
#  'xgbclassifier__base_score': 0.5,
#  'xgbclassifier__booster': 'gbtree',
#  'xgbclassifier__colsample_bylevel': 1,
#  'xgbclassifier__colsample_bynode': 1,
#  'xgbclassifier__colsample_bytree': 0.7,
#  'xgbclassifier__gamma': 0.0,
#  'xgbclassifier__learning_rate': 0.01,
#  'xgbclassifier__max_delta_step': 0,
#  'xgbclassifier__max_depth': 5,
#  'xgbclassifier__min_child_weight': 7,
#  'xgbclassifier__missing': None,
#  'xgbclassifier__n_estimators': 100,
#  'xgbclassifier__n_jobs': 1,
#  'xgbclassifier__nthread': None,
#  'xgbclassifier__objective': 'binary:logistic',
#  'xgbclassifier__random_state': 0,
#  'xgbclassifier__reg_alpha': 100,
#  'xgbclassifier__reg_lambda': 1,
#  'xgbclassifier__scale_pos_weight': 15,
#  'xgbclassifier__seed': None,
#  'xgbclassifier__silent': None,
#  'xgbclassifier__subsample': 1,
#  'xgbclassifier__verbosity': 1}

# %%
grid_imba4.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0)),
#                                                                   ('scaler',
#                                                                    StandardScaler(copy=True,
#                                                                                   with...
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=0.7, gamma=0.0,
#                                learning_rate=0.01, max_delta_step=0,
#                                max_depth=5, min_child_weight=7, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='binary:logistic', random_state=0,
#                                reg_alpha=100, reg_lambda=1, scale_pos_weight=15,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)

# %%
featurename = np.array(np.concatenate(( np.array(numeric_features), categorical_features)))
f_imp = grid_imba4.best_estimator_['xgbclassifier'].feature_importances_

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename [np.argsort(f_imp)],
    'Importance': np.sort(f_imp)
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,20))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Feature importance')
plt.title('XGBoost feature importance')
#plt.savefig("fig/rf_feat_importance.png", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'XGBoost feature importance')

# %%
grid_imba4.best_score_
# Out:
# 0.860980175515842

# %%
street['SHAPE_Leng'].hist()

# %%
sum(street['SHAPE_Leng']> 850)/len(street)
# Out:
# 0.04486829391253203

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba4.predict(X_test)
print(len(_y_prediction))
print(accuracy_score(y_test,_y_prediction))
print(recall_score(y_test,_y_prediction))
print(precision_score(y_test,_y_prediction))
print(roc_auc_score(y_test,_y_prediction))
# Out:
# 7141
# 0.7927461139896373
# 0.8571428571428571
# 0.25782493368700266
# 0.822167412751532

# %%
## try XGboost 
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic")
xgboost = make_pipeline(preprocessor,xgb_model)

params = {"learning_rate"    : [0.01, 0.05, 0.10, 0.15, 0.20 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] ,
         "reg_alpha"    : [ 1, 10, 100, 1000, 10000],
         "scale_pos_weight" : [8,10,12,15] }

new_params = {'xgbclassifier__' + key: params[key] for key in params}


grid_imba5 = RandomizedSearchCV(xgboost, param_distributions =new_params, cv=K_FOLD, scoring='accuracy', return_train_score=True, n_iter = 10)
grid_imba5.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                  0.3, 0.4],
#                                         'xgbclassifier__learning_rate': [0.01,
#                                                                          0.05,
#                                                                          0.1,
#                                                                          0.15,
#                                                                          0.2],
#                                         'xgbclassifier__max_depth': [3, 4, 5, 6,
#                                                                      8, 10,
#                                                                      12],
#                                         'xgbclassifier__min_child_weight': [1,
#                                                                             3,
#                                                                             5,
#                                                                             7],
#                                         'xgbclassifier__reg_alpha': [1, 10, 100,
#                                                                      1000,
#                                                                      10000],
#                                         'xgbclassifier__scale_pos_weight': [8,
#                                                                             10,
#                                                                             12,
#                                                                             15]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='accuracy', verbose=0)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba5.predict(X_train)
print(len(_y_prediction))
print(accuracy_score(y_train,_y_prediction))
print(recall_score(y_train,_y_prediction))
print(precision_score(y_train,_y_prediction))
print(roc_auc_score(y_train,_y_prediction))
# Out:
# 64261
# 0.9318871477256812
# 0.953921568627451
# 0.5401354502053958
# 0.9419546147087493

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba5.predict(X_test)
print(len(y_test))
print(accuracy_score(y_test,_y_prediction))
print(recall_score(y_test,_y_prediction))
print(precision_score(y_test,_y_prediction))
print(roc_auc_score(y_test,_y_prediction))
# Out:
# 7141
# 0.9021145497829436
# 0.7848324514991182
# 0.4354207436399217
# 0.8485312242284153

# %% [markdown]
# # Old

# %%
# re_group variables , remove #ARTCLASS

numeric_features = ['SEGLENGTH_log','SURFACEWID_log', 'PVMTCONDIN','SLOPE_PCT' ,
                    'SW_WIDTH' ,'LENGTH_MIL']
#'ARTCLASS'
#'PVMTCOND_1', 'PRIMARYCROSSSLOPE','MINIMUMVARIABLEWIDTH','FILLERWID'
#categorical_features = ['ARTCLASS', 'SEGDIR', 'ONEWAY', 'SURFACETYP','NATIONHWYS' ,'PVMTCATEGO', 'PARKBOULEV' ,'TRANDESCRI', 'rushhour']
categorical_features = ['STREETTYPE', 'PVMTCATEGO',\
                        'EXISTING_FACILITY_TYPE','CLASS_DESC']
ordinal_features = ['SPEEDLIMIT', 'CONDITION','ONEWAY',\
                   'simulate_rushhour','simulate_weather','simulate_weekday']
#'MATL' , 'FILLERTYPE', 'CURBTYPE','NATIONHWYS' ,'PARKBOULEV' , 'MINIMUMVARIABLEWIDTH' ,

# %%
## Random Forest 
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
#from preprocessing import OrdinalEncoder
## Random Oversampler 
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import NearMiss
#sm= SMOTE() #ratio = RATIO
#nm = NearMiss(sampling_strategy = 'majority')

## pre-processing 


numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('ord', ordinal_transformer, ordinal_features)])



clf = RandomForestClassifier(class_weight = 'balanced')
rf = Pipeline(steps=[('preprocessor', preprocessor),
                          ('classifier', clf)])

## cross validate 
#from sklearn.model_selection import cross_validate

#scores = cross_validate(rf, X_train, y_train, scoring=['roc_auc','recall','accuracy','precision', 'f1'], cv = K_FOLD, return_train_score = True, return_estimator=True)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 6, 10, 12,15,20],
}
new_params = {'classifier__' + key: params[key] for key in params}
rf_grid = RandomizedSearchCV(rf, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
rf_grid.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('preprocessor',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicator=Fa...
#                                                                      n_estimators='warn',
#                                                                      n_jobs=None,
#                                                                      oob_score=False,
#                                                                      random_state=None,
#                                                                      verbose=0,
#                                                                      warm_start=False))],
#                                       verbose=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'classifier__max_depth': [4, 6, 10, 12,
#                                                                   15, 20],
#                                         'classifier__n_estimators': [50, 100,
#                                                                      200]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
scores(rf_grid, X_train, y_train)
# Out:
# 64261
# accuracy_score:  0.8089821197927203
# recall_score:  0.8498039215686275
# precision_score:  0.2735593006375055
#  roc_auc_score:  0.8276334900011965

# %%
scores(rf_grid, X_test, y_test)
# Out:
# 7141
# accuracy_score:  0.8050693180226859
# recall_score:  0.8571428571428571
# precision_score:  0.2704507512520868
#  roc_auc_score:  0.8288604459124691

# %%
cat_name  = rf_grid.best_estimator_.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names()
featurename = np.array(np.concatenate(( np.array(numeric_features), cat_name, ordinal_features)))

# %%
f_imp = rf_grid.best_estimator_['classifier'].feature_importances_
len(featurename)
# Out:
# 40

# %%
#cat_name = grid_imba.best_estimator_.named_steps['columntransformer'].transformers_[1][1].named_steps['onehot'].get_feature_names()

# %%
rf_grid.best_params_
# Out:
# {'classifier__n_estimators': 100, 'classifier__max_depth': 6}

# %%
rf_grid.best_score_
# Out:
# 0.8325489402745115

# %%
_y_prediction = rf_grid.predict(X_train)

# %%
feat_imp = pd.DataFrame({
    'Feature': featurename [np.argsort(f_imp)],
    'Importance': np.sort(f_imp)
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10,20))
plt.barh(y = feat_imp['Feature'], width=feat_imp['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Feature importance')
plt.title('Random forest feature importance')
#plt.savefig("fig/rf_feat_importance.png", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Random forest feature importance')

# %%
## Random Forest with undersampling Nearmiss
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
#from preprocessing import OrdinalEncoder
## Random Oversampler 
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import NearMiss
#sm= SMOTE() #ratio = RATIO
nm = NearMiss(sampling_strategy = 'majority')

## pre-processing 

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encode', OrdinalEncoder())])

from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])


clf = RandomForestClassifier()
rf = make_pipeline(preprocessor,nm ,clf)


from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
params = {
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 6, 10, 12],
}
new_params = {'randomforestclassifier__' + key: params[key] for key in params}
grid_imba2 = RandomizedSearchCV(rf, param_distributions =new_params, cv=K_FOLD, scoring='recall', return_train_score=True, n_iter = 10)
grid_imba2.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#                    error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('columntransformer',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='drop',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('num',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('imputer',
#                                                                                                 SimpleImputer(add_indicat...
#                                                                      n_jobs=None,
#                                                                      oob_score=False,
#                                                                      random_state=None,
#                                                                      verbose=0,
#                                                                      warm_start=False))],
#                                       verbose=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'randomforestclassifier__max_depth': [4,
#                                                                               6,
#                                                                               10,
#                                                                               12],
#                                         'randomforestclassifier__n_estimators': [50,
#                                                                                  100,
#                                                                                  200]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='recall', verbose=0)

# %%
grid_imba2.best_params_
# Out:
# {'randomforestclassifier__n_estimators': 200,
#  'randomforestclassifier__max_depth': 4}

# %%
grid_imba2.best_score_
# Out:
# 0.8843136034389169

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, classification_report, precision_score,roc_auc_score

_y_prediction = grid_imba2.predict(X_train)

print(accuracy_score(y_train,_y_prediction))
print(recall_score(y_train,_y_prediction))
print(precision_score(y_train,_y_prediction))
print(roc_auc_score(y_train,_y_prediction))
# Out:
# 0.7156906988686762
# 0.8774509803921569
# 0.20230560578661844
# 0.7895985315577863
