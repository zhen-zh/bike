# %% [markdown]
# # Introduction
#
# The goal of this notebook/workshop is to warm you all up to doing Exploratory Data Analysis (EDA) with python.
#
# ## Motivation
#
# For the majority of problems you address as a data scientist (preparation and career) that involve data - you'll have to do the following with the data you're given:
#
# 1. **Ingest**
# 2. **Clean**
# 3. **Analyize**
# 4. Implement a Model
# 5. Interpreting your findings
# 6. Disseminate your findings
#
# Here we're going to quickly go over some of the ways that you can do numbers **1-3** with python.
#
# ## Outline
#
# * Loading a dataset into memeory using Pandas
# * Understanding the data you are given
#     * Dealing with time
#     * Parsing text
# * Pivoting data
# * Visualizing data
#
#
# ## References
#
# ### [matplotlib](https://matplotlib.org/)
#
# Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits.
#
# ### [Pandas](https://pandas.pydata.org/)
#
# pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# ### [Seaborn](https://seaborn.pydata.org/)
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# # Dependencies
#
# ## Data
#
# [Crunchbase dataset on start-up investments](https://drive.google.com/file/d/1zsjN1tGWdXPb4wf4eTM62usMciSV-0sX/view)
#
# Other datasets are included in thrid party python libraries

# %%
# Third party imports

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# makes all generated figures render inline
# %matplotlib inline

# Always good idea to log the versions of your dependencies
print(pd.__version__, sns.__version__, np.__version__)
# Out:
# 0.24.2 0.9.0 1.16.3

# %% [markdown]
# # 1. Data ingestion
#
# Loading and processing your data so that you can do all the downstream things that need them

# %%
# Load data 

# You'll remember from your excercise that this is encoding in latin-1
crunchbase_df = pd.read_csv('Crunchbase_Startup_Investment_Data.csv', 
                           encoding='latin-1')

# %%
crunchbase_df = crunchbase_df[['company_name',
                             'company_category_list',
                             'company_market',
                             'company_state_code',
                             'company_region',
                             'investor_name',
                             'investor_category_list',
                             'investor_market',
                             'investor_state_code',
                             'investor_region',
                             'investor_city',
                             'funding_round_type',
                             'funding_round_code',
                             'funded_at',
                             'funded_month',
                             'funded_quarter',
                             'funded_year',
                             'raised_amount_total_usd']]

# %% [markdown]
# ## Converting columns

# %%
# Converting strings into dates
crunchbase_df.funded_at[0]
# Out:
# '1974-01-01'

# %%
# Sometimes this is very easy
pd.to_datetime(crunchbase_df.funded_at)[0]
# Out:
# Timestamp('1974-01-01 00:00:00')

# %%
# Othertimes you may need to specify format
pd.to_datetime(crunchbase_df.funded_at, 
               format='%Y-%m-%d')[0]
# Out:
# Timestamp('1974-01-01 00:00:00')

# %%
# Actually doing the conversion

crunchbase_df.funded_at = pd.to_datetime(crunchbase_df.funded_at, 
                                        format='%Y-%m-%d')

# %%
# looking at the amount of money raised
crunchbase_df.raised_amount_total_usd.head()
# Out:
# 0            NaN
# 1     1,000,000
# 2     1,000,000
# 3       724,000
# 4       165,000
# Name: raised_amount_total_usd, dtype: object

# %%
# We've got weird mix of strangly formatted strings and floats here 

# We can write a function to quickly convert these values

# %%
# Converting raised money to foats

import locale

locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')

def convert_string_to_float(x):
    """Functions are you friends, and you can write functions 
    which do complex operations on columns of dataframes"""
    if type(x) is str:
        try:
            return locale.atof(x)
        except ValueError:
            return np.nan
    elif type(x) is float:
        return x
    else:
        return np.nan

# apply is your friend
crunchbase_df.loc[ :, 'money_raised'] = crunchbase_df.raised_amount_total_usd.apply(convert_string_to_float)

# %%
# Let's say you want to parse company_category_list

# We think that the type of companies will be important 

crunchbase_df.company_category_list[0]
# Out:
# '|Internet|SEO|Services|Public Relations|Social Media|Consulting|'

# %%
# This is segmented in a way that makes logical sense '|' delimits things

# But how are you going to access these things?

# %%
crunchbase_df
# Out:
#                                    company_name  \
# 0                         AndrewBurnett.com Ltd
# 1                                      ABO Data
# 2                                      ABO Data
# 3                                          Ikro
# 4                                      Indelsul
# 5                             Laboratórios Noli
# 6                                       Polimax
# 7                                        Lenovo
# 8                                     Mixertech
# 9                                       Aeromot
# 10                                      Digitel
# 11                                  Curtume Erê
# 12                            Aehr Test Systems
# 13                            FSI International
# 14                       Employee Benefit Plans
# 15      Medaphis Physician Services Corporation
# 16                                      Telebit
# 17                       Chips and Technologies
# 18                                        Cisco
# 19                      Integrated Systems Inc.
# 20                                    NHK World
# 21                                    NHK World
# 22                                Clean Harbors
# 23                                    Microinox
# 24                     Digital Link Corporation
# 25                Platinum Software Corporation
# 26             Litchfield Financial Corporation
# 27                                Future Domain
# 28                                 Office Depot
# 29                Software Spectrum Corporation
# ...                                         ...
# 114475                                   InMobi
# 114476                              lancers Inc
# 114477                              lancers Inc
# 114478                              lancers Inc
# 114479                              lancers Inc
# 114480                              lancers Inc
# 114481                                   MEDIGO
# 114482                          Panoramic Power
# 114483                                  Qufenqi
# 114484                                 SendGrid
# 114485                                 SendGrid
# 114486                                 SendGrid
# 114487                            Shoes of Prey
# 114488                            Shoes of Prey
# 114489                                    Strap
# 114490                                    Strap
# 114491                                    Strap
# 114492                                    Strap
# 114493                                    Strap
# 114494                                    Strap
# 114495                                   Veniam
# 114496                                   Veniam
# 114497                                   Veniam
# 114498                                NowSecure
# 114499                                NowSecure
# 114500                                NowSecure
# 114501                                   Xeltis
# 114502                                   Xeltis
# 114503                                   Xeltis
# 114504                                  Vonjour
#
#                                     company_category_list  \
# 0       |Internet|SEO|Services|Public Relations|Social...
# 1                                   |Enterprise Software|
# 2                                   |Enterprise Software|
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                              |Hardware|
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                  |Hardware + Software|
# 13                                       |Semiconductors|
# 14                                                    NaN
# 15                                          |Health Care|
# 16                                                    NaN
# 17                                       |Semiconductors|
# 18             |Software|Hardware|Networking|Web Hosting|
# 19                                                    NaN
# 20                                                 |News|
# 21                                                 |News|
# 22                                     |Clean Technology|
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                           |E-Commerce|
# 29                                                    NaN
# ...                                                   ...
# 114475                               |Advertising|Mobile|
# 114476                        |Crowdsourcing|Curated Web|
# 114477                        |Crowdsourcing|Curated Web|
# 114478                        |Crowdsourcing|Curated Web|
# 114479                        |Crowdsourcing|Curated Web|
# 114480                        |Crowdsourcing|Curated Web|
# 114481                                      |Health Care|
# 114482                                 |Clean Technology|
# 114483                                         |Payments|
# 114484                      |Finance|Enterprise Software|
# 114485                      |Finance|Enterprise Software|
# 114486                      |Finance|Enterprise Software|
# 114487                                 |Shoes|E-Commerce|
# 114488                                 |Shoes|E-Commerce|
# 114489                                             |Apps|
# 114490                                             |Apps|
# 114491                                             |Apps|
# 114492                                             |Apps|
# 114493                                             |Apps|
# 114494                                             |Apps|
# 114495           |Communications Infrastructure|Wireless|
# 114496           |Communications Infrastructure|Wireless|
# 114497           |Communications Infrastructure|Wireless|
# 114498         |Software|Apps|Mobile Security|Technology|
# 114499         |Software|Apps|Mobile Security|Technology|
# 114500         |Software|Apps|Mobile Security|Technology|
# 114501                                                NaN
# 114502                                                NaN
# 114503                                                NaN
# 114504                              |Enterprise Software|
#
#              company_market company_state_code company_region  \
# 0                  Internet                NaN      Edinburgh
# 1       Enterprise Software                 TX     TX - Other
# 2       Enterprise Software                 TX     TX - Other
# 3                       NaN                NaN    BRA - Other
# 4                       NaN                NaN            NaN
# 5                       NaN                NaN   Porto Alegre
# 6                       NaN                NaN            NaN
# 7                  Hardware                 NC        Raleigh
# 8                       NaN                NaN            NaN
# 9                       NaN                NaN   Porto Alegre
# 10                      NaN                NaN    BRA - Other
# 11                      NaN                NaN    BRA - Other
# 12      Hardware + Software                 CA    SF Bay Area
# 13           Semiconductors                 MN    Minneapolis
# 14                      NaN                 MN    Minneapolis
# 15              Health Care                NaN            NaN
# 16                      NaN                 MA         Boston
# 17           Semiconductors                 CA    SF Bay Area
# 18                 Software                 CA    SF Bay Area
# 19                      NaN                 CA    SF Bay Area
# 20                     News                NaN            NaN
# 21                     News                NaN            NaN
# 22         Clean Technology                 MA         Boston
# 23                      NaN                NaN    BRA - Other
# 24                      NaN                 CA    SF Bay Area
# 25                      NaN                 CA        Anaheim
# 26                      NaN                 VT     VT - Other
# 27                      NaN                 CA        Anaheim
# 28               E-Commerce                 FL   Palm Beaches
# 29                      NaN                 TX         Dallas
# ...                     ...                ...            ...
# 114475               Mobile                 CA    SF Bay Area
# 114476        Crowdsourcing                NaN          Tokyo
# 114477        Crowdsourcing                NaN          Tokyo
# 114478        Crowdsourcing                NaN          Tokyo
# 114479        Crowdsourcing                NaN          Tokyo
# 114480        Crowdsourcing                NaN          Tokyo
# 114481          Health Care                NaN         Berlin
# 114482     Clean Technology                NaN       Tel Aviv
# 114483             Payments                NaN        Beijing
# 114484              Finance                 CO         Denver
# 114485              Finance                 CO         Denver
# 114486              Finance                 CO         Denver
# 114487           E-Commerce                NaN         Sydney
# 114488           E-Commerce                NaN         Sydney
# 114489                 Apps                 OH     Cincinnati
# 114490                 Apps                 OH     Cincinnati
# 114491                 Apps                 OH     Cincinnati
# 114492                 Apps                 OH     Cincinnati
# 114493                 Apps                 OH     Cincinnati
# 114494                 Apps                 OH     Cincinnati
# 114495             Wireless                NaN          Porto
# 114496             Wireless                NaN          Porto
# 114497             Wireless                NaN          Porto
# 114498                 Apps                 IL        Chicago
# 114499                 Apps                 IL        Chicago
# 114500                 Apps                 IL        Chicago
# 114501                  NaN                NaN         Zurich
# 114502                  NaN                NaN         Zurich
# 114503                  NaN                NaN         Zurich
# 114504  Enterprise Software                NaN            NaN
#
#                            investor_name  \
# 0                                   Ekaf
# 1                        ANTONIO MURRONI
# 2                        FILIPPO Murroni
# 3       CRP Companhia de Participac?o?es
# 4       CRP Companhia de Participac?o?es
# 5       CRP Companhia de Participac?o?es
# 6       CRP Companhia de Participac?o?es
# 7            Chinese Academy Of Sciences
# 8       CRP Companhia de Participac?o?es
# 9       CRP Companhia de Participac?o?es
# 10      CRP Companhia de Participac?o?es
# 11      CRP Companhia de Participac?o?es
# 12                       Summit Partners
# 13                       Summit Partners
# 14                       Summit Partners
# 15                       Summit Partners
# 16                       Summit Partners
# 17                       Summit Partners
# 18                       Sequoia Capital
# 19                       Summit Partners
# 20                    ITOCHU Corporation
# 21                             Microsoft
# 22                       Summit Partners
# 23      CRP Companhia de Participac?o?es
# 24                       Summit Partners
# 25                       Summit Partners
# 26                       Summit Partners
# 27                       Summit Partners
# 28                      Upfront Ventures
# 29                       Summit Partners
# ...                                  ...
# 114475                          SoftBank
# 114476                            COLOPL
# 114477           Globis Capital Partners
# 114478              GMO Venture Partners
# 114479                     GREE Ventures
# 114480                              KDDI
# 114481                    Accel Partners
# 114482                          Autodesk
# 114483                  BlueRun Ventures
# 114484             Bain Capital Ventures
# 114485         Bessemer Venture Partners
# 114486                     Foundry Group
# 114487                   Khosla Ventures
# 114488                   Sequoia Capital
# 114489                         CincyTech
# 114490        Hyde Park Venture Partners
# 114491                      Mercury Fund
# 114492                 Vine St. Ventures
# 114493                     Trevor Wright
# 114494                         Wendy Lea
# 114495              Cane Investments LLC
# 114496                     True Ventures
# 114497             Union Square Ventures
# 114498                     Baird Capital
# 114499                      Jump Capital
# 114500             Math Venture Partners
# 114501       Kurma Life Science Partners
# 114502            Life Sciences Partners
# 114503                       VI Partners
# 114504                     Kima Ventures
#
#                                    investor_category_list     investor_market  \
# 0                                                     NaN                 NaN
# 1                                                     NaN                 NaN
# 2                                                     NaN                 NaN
# 3                                                     NaN                 NaN
# 4                                                     NaN                 NaN
# 5                                                     NaN                 NaN
# 6                                                     NaN                 NaN
# 7                                             |Education|           Education
# 8                                                     NaN                 NaN
# 9                                                     NaN                 NaN
# 10                                                    NaN                 NaN
# 11                                                    NaN                 NaN
# 12                                                    NaN                 NaN
# 13                                                    NaN                 NaN
# 14                                                    NaN                 NaN
# 15                                                    NaN                 NaN
# 16                                                    NaN                 NaN
# 17                                                    NaN                 NaN
# 18                                      |Venture Capital|     Venture Capital
# 19                                                    NaN                 NaN
# 20                                                    NaN                 NaN
# 21                                 |Video Games|Software|         Video Games
# 22                                                    NaN                 NaN
# 23                                                    NaN                 NaN
# 24                                                    NaN                 NaN
# 25                                                    NaN                 NaN
# 26                                                    NaN                 NaN
# 27                                                    NaN                 NaN
# 28                                              |Finance|             Finance
# 29                                                    NaN                 NaN
# ...                                                   ...                 ...
# 114475  |Sales and Marketing|Media|Internet|Telecommun...               Media
# 114476                                            |Games|               Games
# 114477                                                NaN                 NaN
# 114478                                  |Venture Capital|     Venture Capital
# 114479                                                NaN                 NaN
# 114480                        |Telecommunications|Mobile|              Mobile
# 114481              |Technology|Internet|Venture Capital|     Venture Capital
# 114482                                         |Software|            Software
# 114483                                                NaN                 NaN
# 114484                                                NaN                 NaN
# 114485                                                NaN                 NaN
# 114486  |Startups|Finance|Consumer Electronics|Interne...            Software
# 114487                                                NaN                 NaN
# 114488                                  |Venture Capital|     Venture Capital
# 114489                                                NaN                 NaN
# 114490                                                NaN                 NaN
# 114491                                                NaN                 NaN
# 114492                                                NaN                 NaN
# 114493                                                NaN                 NaN
# 114494                                                NaN                 NaN
# 114495                                                NaN                 NaN
# 114496                                  |Venture Capital|     Venture Capital
# 114497                          |Finance|Venture Capital|     Venture Capital
# 114498                               |Financial Services|  Financial Services
# 114499                                                NaN                 NaN
# 114500                                                NaN                 NaN
# 114501                                                NaN                 NaN
# 114502                                                NaN                 NaN
# 114503                                                NaN                 NaN
# 114504                                                NaN                 NaN
#
#        investor_state_code investor_region investor_city funding_round_type  \
# 0                      NaN             NaN           NaN               seed
# 1                      NaN             NaN           NaN               seed
# 2                      NaN             NaN           NaN               seed
# 3                      NaN             NaN           NaN            venture
# 4                      NaN             NaN           NaN            venture
# 5                      NaN             NaN           NaN            venture
# 6                      NaN             NaN           NaN            venture
# 7                      NaN         Beijing       Beijing        undisclosed
# 8                      NaN             NaN           NaN            venture
# 9                      NaN             NaN           NaN            venture
# 10                     NaN             NaN           NaN            venture
# 11                     NaN             NaN           NaN            venture
# 12                      MA          Boston        Boston        undisclosed
# 13                      MA          Boston        Boston        undisclosed
# 14                      MA          Boston        Boston        undisclosed
# 15                      MA          Boston        Boston        undisclosed
# 16                      MA          Boston        Boston        undisclosed
# 17                      MA          Boston        Boston        undisclosed
# 18                      CA     SF Bay Area    Menlo Park            venture
# 19                      MA          Boston        Boston        undisclosed
# 20                     NaN           Tokyo         Tokyo            venture
# 21                      WA         Seattle       Redmond            venture
# 22                      MA          Boston        Boston        undisclosed
# 23                     NaN             NaN           NaN            venture
# 24                      MA          Boston        Boston        undisclosed
# 25                      MA          Boston        Boston        undisclosed
# 26                      MA          Boston        Boston        undisclosed
# 27                      MA          Boston        Boston        undisclosed
# 28                      CA     Los Angeles   Los Angeles        undisclosed
# 29                      MA          Boston        Boston        undisclosed
# ...                    ...             ...           ...                ...
# 114475                 NaN           Tokyo         Tokyo            venture
# 114476                 NaN             NaN           NaN            venture
# 114477                 NaN           Tokyo         Tokyo            venture
# 114478                 NaN           Tokyo         Tokyo            venture
# 114479                 NaN           Tokyo         Tokyo            venture
# 114480                 NaN           Tokyo         Tokyo            venture
# 114481                  CA     SF Bay Area     Palo Alto            venture
# 114482                  CA     SF Bay Area    San Rafael            venture
# 114483                  CA     SF Bay Area    Menlo Park            venture
# 114484                  MA          Boston        Boston            venture
# 114485                  CA     SF Bay Area    Menlo Park            venture
# 114486                  CO          Denver       Boulder            venture
# 114487                  CA     SF Bay Area    Menlo Park            venture
# 114488                  CA     SF Bay Area    Menlo Park            venture
# 114489                  OH      Cincinnati    Cincinnati               seed
# 114490                  IL         Chicago       Chicago               seed
# 114491                  TX         Houston       Houston               seed
# 114492                 NaN             NaN           NaN               seed
# 114493                 NaN             NaN           NaN               seed
# 114494                 NaN             NaN           NaN               seed
# 114495                  NY      NY - Other     Irvington            venture
# 114496                  CA     SF Bay Area     Palo Alto            venture
# 114497                  NY   New York City      New York            venture
# 114498                 NaN          London        London            venture
# 114499                  IL         Chicago       Chicago            venture
# 114500                  IL         Chicago       Chicago            venture
# 114501                 NaN             NaN           NaN            venture
# 114502                 NaN       Amsterdam     Amsterdam            venture
# 114503                 NaN          Zurich           Zug            venture
# 114504                 NaN           Paris         Paris               seed
#
#        funding_round_code  funded_at funded_month funded_quarter  funded_year  \
# 0                     NaN 1974-01-01      1974-01        1974-Q1         1974
# 1                     NaN 1979-01-01      1979-01        1979-Q1         1979
# 2                     NaN 1979-01-01      1979-01        1979-Q1         1979
# 3                       A 1982-06-01      1982-06        1982-Q2         1982
# 4                       A 1982-12-01      1982-12        1982-Q4         1982
# 5                       A 1982-12-01      1982-12        1982-Q4         1982
# 6                       A 1983-06-01      1983-06        1983-Q2         1983
# 7                     NaN 1984-01-01      1984-01        1984-Q1         1984
# 8                       A 1984-05-01      1984-05        1984-Q2         1984
# 9                       A 1985-05-01      1985-05        1985-Q2         1985
# 10                      A 1985-05-01      1985-05        1985-Q2         1985
# 11                      A 1985-06-01      1985-06        1985-Q2         1985
# 12                    NaN 1985-09-19      1985-09        1985-Q3         1985
# 13                    NaN 1985-10-20      1985-10        1985-Q4         1985
# 14                    NaN 1986-03-19      1986-03        1986-Q1         1986
# 15                    NaN 1986-05-30      1986-05        1986-Q2         1986
# 16                    NaN 1986-06-20      1986-06        1986-Q2         1986
# 17                    NaN 1986-07-03      1986-07        1986-Q3         1986
# 18                      A 1987-01-01      1987-01        1987-Q1         1987
# 19                    NaN 1987-04-03      1987-04        1987-Q2         1987
# 20                      D 1987-06-16      1987-06        1987-Q2         1987
# 21                      D 1987-06-16      1987-06        1987-Q2         1987
# 22                    NaN 1987-08-18      1987-08        1987-Q3         1987
# 23                      A 1987-11-01      1987-11        1987-Q4         1987
# 24                    NaN 1987-12-23      1987-12        1987-Q4         1987
# 25                    NaN 1988-09-29      1988-09        1988-Q3         1988
# 26                    NaN 1988-11-21      1988-11        1988-Q4         1988
# 27                    NaN 1989-03-07      1989-03        1989-Q1         1989
# 28                    NaN 1989-06-01      1989-06        1989-Q2         1989
# 29                    NaN 1989-12-01      1989-12        1989-Q4         1989
# ...                   ...        ...          ...            ...          ...
# 114475                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114476                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114477                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114478                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114479                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114480                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114481                  A 2014-12-02      2014-12        2014-Q4         2014
# 114482                  C 2014-12-02      2014-12        2014-Q4         2014
# 114483                  C 2014-12-02      2014-12        2014-Q4         2014
# 114484                  C 2014-12-02      2014-12        2014-Q4         2014
# 114485                  C 2014-12-02      2014-12        2014-Q4         2014
# 114486                  C 2014-12-02      2014-12        2014-Q4         2014
# 114487                  A 2014-12-02      2014-12        2014-Q4         2014
# 114488                  A 2014-12-02      2014-12        2014-Q4         2014
# 114489                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114490                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114491                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114492                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114493                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114494                NaN 2014-12-02      2014-12        2014-Q4         2014
# 114495                  A 2014-12-02      2014-12        2014-Q4         2014
# 114496                  A 2014-12-02      2014-12        2014-Q4         2014
# 114497                  A 2014-12-02      2014-12        2014-Q4         2014
# 114498                  A 2014-12-02      2014-12        2014-Q4         2014
# 114499                  A 2014-12-02      2014-12        2014-Q4         2014
# 114500                  A 2014-12-02      2014-12        2014-Q4         2014
# 114501                  B 2014-12-02      2014-12        2014-Q4         2014
# 114502                  B 2014-12-02      2014-12        2014-Q4         2014
# 114503                  B 2014-12-02      2014-12        2014-Q4         2014
# 114504                NaN 2014-12-20      2014-12        2014-Q4         2014
#
#        raised_amount_total_usd  money_raised
# 0                          NaN           NaN
# 1                   1,000,000      1000000.0
# 2                   1,000,000      1000000.0
# 3                     724,000       724000.0
# 4                     165,000       165000.0
# 5                     155,000       155000.0
# 6                      94,000        94000.0
# 7                          NaN           NaN
# 8                          NaN           NaN
# 9                     243,000       243000.0
# 10                    666,000       666000.0
# 11                    169,000       169000.0
# 12                         NaN           NaN
# 13                         NaN           NaN
# 14                         NaN           NaN
# 15                         NaN           NaN
# 16                         NaN           NaN
# 17                         NaN           NaN
# 18                  2,500,000      2500000.0
# 19                         NaN           NaN
# 20                         NaN           NaN
# 21                         NaN           NaN
# 22                         NaN           NaN
# 23                    476,000       476000.0
# 24                         NaN           NaN
# 25                         NaN           NaN
# 26                         NaN           NaN
# 27                         NaN           NaN
# 28                         NaN           NaN
# 29                         NaN           NaN
# ...                        ...           ...
# 114475              5,000,000      5000000.0
# 114476              8,450,000      8450000.0
# 114477              8,450,000      8450000.0
# 114478              8,450,000      8450000.0
# 114479              8,450,000      8450000.0
# 114480              8,450,000      8450000.0
# 114481              6,230,684      6230684.0
# 114482              7,000,000      7000000.0
# 114483            100,000,000    100000000.0
# 114484             20,000,000     20000000.0
# 114485             20,000,000     20000000.0
# 114486             20,000,000     20000000.0
# 114487              5,500,000      5500000.0
# 114488              5,500,000      5500000.0
# 114489              1,200,000      1200000.0
# 114490              1,200,000      1200000.0
# 114491              1,200,000      1200000.0
# 114492              1,200,000      1200000.0
# 114493              1,200,000      1200000.0
# 114494              1,200,000      1200000.0
# 114495              4,900,000      4900000.0
# 114496              4,900,000      4900000.0
# 114497              4,900,000      4900000.0
# 114498             12,500,000     12500000.0
# 114499             12,500,000     12500000.0
# 114500             12,500,000     12500000.0
# 114501             34,000,000     34000000.0
# 114502             34,000,000     34000000.0
# 114503             34,000,000     34000000.0
# 114504                    -              NaN
#
# [114505 rows x 19 columns]

# %%
# It kind of looks like this information is redundant

# Let's drop all of the duplicated elements (with the same 'company_name', 'company_category_list' )
# And then let's see if there are any duplicated companies
deduped_df = crunchbase_df[~crunchbase_df.duplicated(subset=['company_name', 'company_category_list'], keep='first')]

deduped_df
# Out:
#                                    company_name  \
# 0                         AndrewBurnett.com Ltd
# 1                                      ABO Data
# 3                                          Ikro
# 4                                      Indelsul
# 5                             Laboratórios Noli
# 6                                       Polimax
# 7                                        Lenovo
# 8                                     Mixertech
# 9                                       Aeromot
# 10                                      Digitel
# 11                                  Curtume Erê
# 12                            Aehr Test Systems
# 13                            FSI International
# 14                       Employee Benefit Plans
# 15      Medaphis Physician Services Corporation
# 16                                      Telebit
# 17                       Chips and Technologies
# 18                                        Cisco
# 19                      Integrated Systems Inc.
# 20                                    NHK World
# 22                                Clean Harbors
# 23                                    Microinox
# 24                     Digital Link Corporation
# 25                Platinum Software Corporation
# 26             Litchfield Financial Corporation
# 27                                Future Domain
# 28                                 Office Depot
# 29                Software Spectrum Corporation
# 30                          Knowledge Adventure
# 31                   Saber Software Corporation
# ...                                         ...
# 114349                           Baedal Minjeok
# 114355                                  CARsgen
# 114356                        Dashboard Systems
# 114358                                 Equilume
# 114359                              FindURClass
# 114362                                 Genomics
# 114370                    Pond-Deshpande Centre
# 114371                                      QLL
# 114388                                    Coyno
# 114392                                 Purse.IO
# 114400                                 AppInTop
# 114401                                 Camaloon
# 114402                              WorkCompass
# 114403                             Creamfinance
# 114405                                IzumoBase
# 114406                    LoudCell Technologies
# 114412                                    Orori
# 114418                      A Crowd of Monsters
# 114421                          Ascendis Pharma
# 114438                                  GLENTEL
# 114439                                   Grid4C
# 114440                         Interrad Medical
# 114449                                  OfferUp
# 114450                              RiverSilica
# 114453                  Apellis Pharmaceuticals
# 114464                  CANbridge Life Sciences
# 114469                                 Helpling
# 114495                                   Veniam
# 114501                                   Xeltis
# 114504                                  Vonjour
#
#                                     company_category_list  \
# 0       |Internet|SEO|Services|Public Relations|Social...
# 1                                   |Enterprise Software|
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                              |Hardware|
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                  |Hardware + Software|
# 13                                       |Semiconductors|
# 14                                                    NaN
# 15                                          |Health Care|
# 16                                                    NaN
# 17                                       |Semiconductors|
# 18             |Software|Hardware|Networking|Web Hosting|
# 19                                                    NaN
# 20                                                 |News|
# 22                                     |Clean Technology|
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                           |E-Commerce|
# 29                                                    NaN
# 30                                                |Games|
# 31                                                    NaN
# ...                                                   ...
# 114349                                                NaN
# 114355                                                NaN
# 114356                      |Project Management|Software|
# 114358      |Health Care|Pharmaceuticals|Medical Devices|
# 114359                                                NaN
# 114362                                                NaN
# 114370                                     |Entrepreneur|
# 114371                                                NaN
# 114388                                                NaN
# 114392                             |Marketplaces|Bitcoin|
# 114400                                                NaN
# 114401  |Artists Globally|Printing|Technology|E-Commerce|
# 114402  |Reviews and Recommendations|Human Resources|E...
# 114403                               |Financial Services|
# 114405                                         |Software|
# 114406                                         |Software|
# 114412                                                NaN
# 114418                                            |Games|
# 114421                                                NaN
# 114438             |Services|Wireless|Telecommunications|
# 114439                                                NaN
# 114440                                      |Health Care|
# 114449            |Craigslist Killers|Classifieds|Mobile|
# 114450                                                NaN
# 114453                                    |Biotechnology|
# 114464                                    |Biotechnology|
# 114469                                        |Consumers|
# 114495           |Communications Infrastructure|Wireless|
# 114501                                                NaN
# 114504                              |Enterprise Software|
#
#              company_market company_state_code company_region  \
# 0                  Internet                NaN      Edinburgh
# 1       Enterprise Software                 TX     TX - Other
# 3                       NaN                NaN    BRA - Other
# 4                       NaN                NaN            NaN
# 5                       NaN                NaN   Porto Alegre
# 6                       NaN                NaN            NaN
# 7                  Hardware                 NC        Raleigh
# 8                       NaN                NaN            NaN
# 9                       NaN                NaN   Porto Alegre
# 10                      NaN                NaN    BRA - Other
# 11                      NaN                NaN    BRA - Other
# 12      Hardware + Software                 CA    SF Bay Area
# 13           Semiconductors                 MN    Minneapolis
# 14                      NaN                 MN    Minneapolis
# 15              Health Care                NaN            NaN
# 16                      NaN                 MA         Boston
# 17           Semiconductors                 CA    SF Bay Area
# 18                 Software                 CA    SF Bay Area
# 19                      NaN                 CA    SF Bay Area
# 20                     News                NaN            NaN
# 22         Clean Technology                 MA         Boston
# 23                      NaN                NaN    BRA - Other
# 24                      NaN                 CA    SF Bay Area
# 25                      NaN                 CA        Anaheim
# 26                      NaN                 VT     VT - Other
# 27                      NaN                 CA        Anaheim
# 28               E-Commerce                 FL   Palm Beaches
# 29                      NaN                 TX         Dallas
# 30                    Games                 CA    Los Angeles
# 31                      NaN                 TX         Dallas
# ...                     ...                ...            ...
# 114349                  NaN                NaN          Seoul
# 114355                  NaN                NaN            NaN
# 114356             Software                NaN         Moscow
# 114358      Medical Devices                NaN    IRL - Other
# 114359                  NaN                NaN         Mumbai
# 114362                  NaN                NaN            NaN
# 114370         Entrepreneur                 NB    Fredericton
# 114371                  NaN                NaN         Taiwan
# 114388                  NaN                NaN         Berlin
# 114392              Bitcoin                 CA    SF Bay Area
# 114400                  NaN                NaN            NaN
# 114401     Artists Globally                NaN      Barcelona
# 114402                 SaaS                NaN           Cork
# 114403   Financial Services                NaN           Riga
# 114405             Software                NaN          Tokyo
# 114406             Software                 CA    SF Bay Area
# 114412                  NaN                NaN        Jakarta
# 114418                Games                NaN            NaN
# 114421                  NaN                 CA    SF Bay Area
# 114438   Telecommunications                 BC        Burnaby
# 114439                  NaN                NaN    ISR - Other
# 114440          Health Care                 MN    Minneapolis
# 114449   Craigslist Killers                 WA        Seattle
# 114450                  NaN                NaN      Bangalore
# 114453        Biotechnology                 KY     Louisville
# 114464        Biotechnology                NaN        Beijing
# 114469            Consumers                NaN         Berlin
# 114495             Wireless                NaN          Porto
# 114501                  NaN                NaN         Zurich
# 114504  Enterprise Software                NaN            NaN
#
#                                   investor_name  \
# 0                                          Ekaf
# 1                               ANTONIO MURRONI
# 3              CRP Companhia de Participac?o?es
# 4              CRP Companhia de Participac?o?es
# 5              CRP Companhia de Participac?o?es
# 6              CRP Companhia de Participac?o?es
# 7                   Chinese Academy Of Sciences
# 8              CRP Companhia de Participac?o?es
# 9              CRP Companhia de Participac?o?es
# 10             CRP Companhia de Participac?o?es
# 11             CRP Companhia de Participac?o?es
# 12                              Summit Partners
# 13                              Summit Partners
# 14                              Summit Partners
# 15                              Summit Partners
# 16                              Summit Partners
# 17                              Summit Partners
# 18                              Sequoia Capital
# 19                              Summit Partners
# 20                           ITOCHU Corporation
# 22                              Summit Partners
# 23             CRP Companhia de Participac?o?es
# 24                              Summit Partners
# 25                              Summit Partners
# 26                              Summit Partners
# 27                              Summit Partners
# 28                             Upfront Ventures
# 29                              Summit Partners
# 30                                William Lohse
# 31                              Summit Partners
# ...                                         ...
# 114349                            Goldman Sachs
# 114355                                     BVCF
# 114356                    Buran Venture Capital
# 114358                       Enterprise Ireland
# 114359                           VentureNursery
# 114362                        Invesco Perpetual
# 114370                     McConnell Foundation
# 114371                          B Dash Ventures
# 114388  Axel Springer Plug and Play Accelerator
# 114392                              FundersClub
# 114400              Run Capital Investment Fund
# 114401                       Caixa Capital Risc
# 114402                       Enterprise Ireland
# 114403                            Flint Capital
# 114405                 Global Brain Corporation
# 114406                            Pradeep Gupta
# 114412                               Ideosource
# 114418                       Caixa Capital Risc
# 114421                         OrbiMed Advisors
# 114438                            Exfinity Fund
# 114439                Israel Cleantech Ventures
# 114440                                Arthurian
# 114449                      Andreessen Horowitz
# 114450                            Exfinity Fund
# 114453                        Aju IB Investment
# 114464                  QiMing Venture Partners
# 114469                Mangrove Capital Partners
# 114495                     Cane Investments LLC
# 114501              Kurma Life Science Partners
# 114504                            Kima Ventures
#
#                        investor_category_list  investor_market  \
# 0                                         NaN              NaN
# 1                                         NaN              NaN
# 3                                         NaN              NaN
# 4                                         NaN              NaN
# 5                                         NaN              NaN
# 6                                         NaN              NaN
# 7                                 |Education|        Education
# 8                                         NaN              NaN
# 9                                         NaN              NaN
# 10                                        NaN              NaN
# 11                                        NaN              NaN
# 12                                        NaN              NaN
# 13                                        NaN              NaN
# 14                                        NaN              NaN
# 15                                        NaN              NaN
# 16                                        NaN              NaN
# 17                                        NaN              NaN
# 18                          |Venture Capital|  Venture Capital
# 19                                        NaN              NaN
# 20                                        NaN              NaN
# 22                                        NaN              NaN
# 23                                        NaN              NaN
# 24                                        NaN              NaN
# 25                                        NaN              NaN
# 26                                        NaN              NaN
# 27                                        NaN              NaN
# 28                                  |Finance|          Finance
# 29                                        NaN              NaN
# 30                                        NaN              NaN
# 31                                        NaN              NaN
# ...                                       ...              ...
# 114349                              |Finance|          Finance
# 114355                                    NaN              NaN
# 114356                                    NaN              NaN
# 114358                  |Finance|Enterprises|      Enterprises
# 114359                  |Incubators|Startups|         Startups
# 114362                                    NaN              NaN
# 114370                                    NaN              NaN
# 114371                                    NaN              NaN
# 114388                     |Startups|Finance|         Startups
# 114392                              |Finance|          Finance
# 114400                                    NaN              NaN
# 114401                              |Finance|          Finance
# 114402                  |Finance|Enterprises|      Enterprises
# 114403  |Media|Finance Technology|Technology|       Technology
# 114405                                    NaN              NaN
# 114406                                    NaN              NaN
# 114412                                    NaN              NaN
# 114418                              |Finance|          Finance
# 114421                                    NaN              NaN
# 114438                                    NaN              NaN
# 114439                                    NaN              NaN
# 114440                                    NaN              NaN
# 114449              |Finance|Venture Capital|  Venture Capital
# 114450                                    NaN              NaN
# 114453                                    NaN              NaN
# 114464                                    NaN              NaN
# 114469     |Internet|Finance|Venture Capital|         Internet
# 114495                                    NaN              NaN
# 114501                                    NaN              NaN
# 114504                                    NaN              NaN
#
#        investor_state_code   investor_region     investor_city  \
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
# 5                      NaN               NaN               NaN
# 6                      NaN               NaN               NaN
# 7                      NaN           Beijing           Beijing
# 8                      NaN               NaN               NaN
# 9                      NaN               NaN               NaN
# 10                     NaN               NaN               NaN
# 11                     NaN               NaN               NaN
# 12                      MA            Boston            Boston
# 13                      MA            Boston            Boston
# 14                      MA            Boston            Boston
# 15                      MA            Boston            Boston
# 16                      MA            Boston            Boston
# 17                      MA            Boston            Boston
# 18                      CA       SF Bay Area        Menlo Park
# 19                      MA            Boston            Boston
# 20                     NaN             Tokyo             Tokyo
# 22                      MA            Boston            Boston
# 23                     NaN               NaN               NaN
# 24                      MA            Boston            Boston
# 25                      MA            Boston            Boston
# 26                      MA            Boston            Boston
# 27                      MA            Boston            Boston
# 28                      CA       Los Angeles       Los Angeles
# 29                      MA            Boston            Boston
# 30                     NaN               NaN               NaN
# 31                      MA            Boston            Boston
# ...                    ...               ...               ...
# 114349                  NY     New York City          New York
# 114355                 NaN               NaN               NaN
# 114356                 NaN            Moscow            Moscow
# 114358                 NaN            Dublin            Dublin
# 114359                 NaN            Mumbai            Mumbai
# 114362                 NaN  Henley On Thames  Henley On Thames
# 114370                 NaN               NaN               NaN
# 114371                 NaN             Tokyo             Tokyo
# 114388                 NaN            Berlin            Berlin
# 114392                  CA       SF Bay Area     San Francisco
# 114400                 NaN               NaN               NaN
# 114401                 NaN         Barcelona         Barcelona
# 114402                 NaN            Dublin            Dublin
# 114403                 NaN         Barcelona         Barcelona
# 114405                 NaN             Tokyo             Tokyo
# 114406                 NaN               NaN               NaN
# 114412                 NaN           Jakarta           Jakarta
# 114418                 NaN         Barcelona         Barcelona
# 114421                  NY     New York City          New York
# 114438                 NaN               NaN               NaN
# 114439                 NaN          Tel Aviv    Ramat Hasharon
# 114440                 NaN               NaN               NaN
# 114449                  CA       SF Bay Area        Menlo Park
# 114450                 NaN               NaN               NaN
# 114453                 NaN             Seoul             Seoul
# 114464                 NaN          Shanghai          Shanghai
# 114469                 NaN         Luxemburg         Luxemburg
# 114495                  NY        NY - Other         Irvington
# 114501                 NaN               NaN               NaN
# 114504                 NaN             Paris             Paris
#
#        funding_round_type funding_round_code  funded_at funded_month  \
# 0                    seed                NaN 1974-01-01      1974-01
# 1                    seed                NaN 1979-01-01      1979-01
# 3                 venture                  A 1982-06-01      1982-06
# 4                 venture                  A 1982-12-01      1982-12
# 5                 venture                  A 1982-12-01      1982-12
# 6                 venture                  A 1983-06-01      1983-06
# 7             undisclosed                NaN 1984-01-01      1984-01
# 8                 venture                  A 1984-05-01      1984-05
# 9                 venture                  A 1985-05-01      1985-05
# 10                venture                  A 1985-05-01      1985-05
# 11                venture                  A 1985-06-01      1985-06
# 12            undisclosed                NaN 1985-09-19      1985-09
# 13            undisclosed                NaN 1985-10-20      1985-10
# 14            undisclosed                NaN 1986-03-19      1986-03
# 15            undisclosed                NaN 1986-05-30      1986-05
# 16            undisclosed                NaN 1986-06-20      1986-06
# 17            undisclosed                NaN 1986-07-03      1986-07
# 18                venture                  A 1987-01-01      1987-01
# 19            undisclosed                NaN 1987-04-03      1987-04
# 20                venture                  D 1987-06-16      1987-06
# 22            undisclosed                NaN 1987-08-18      1987-08
# 23                venture                  A 1987-11-01      1987-11
# 24            undisclosed                NaN 1987-12-23      1987-12
# 25            undisclosed                NaN 1988-09-29      1988-09
# 26            undisclosed                NaN 1988-11-21      1988-11
# 27            undisclosed                NaN 1989-03-07      1989-03
# 28            undisclosed                NaN 1989-06-01      1989-06
# 29            undisclosed                NaN 1989-12-01      1989-12
# 30                   seed                NaN 1990-01-01      1990-01
# 31            undisclosed                NaN 1990-02-23      1990-02
# ...                   ...                ...        ...          ...
# 114349            venture                  D 2014-11-26      2014-11
# 114355            venture                  A 2014-11-26      2014-11
# 114356            venture                NaN 2014-11-26      2014-11
# 114358               seed                NaN 2014-11-26      2014-11
# 114359              angel                NaN 2014-11-26      2014-11
# 114362            venture                NaN 2014-11-26      2014-11
# 114370               seed                NaN 2014-11-26      2014-11
# 114371            venture                NaN 2014-11-26      2014-11
# 114388               seed                NaN 2014-11-27      2014-11
# 114392               seed                NaN 2014-11-27      2014-11
# 114400            venture                  A 2014-11-28      2014-11
# 114401               seed                NaN 2014-11-28      2014-11
# 114402               seed                NaN 2014-11-28      2014-11
# 114403            venture                NaN 2014-11-28      2014-11
# 114405            venture                NaN 2014-11-28      2014-11
# 114406            venture                NaN 2014-11-28      2014-11
# 114412               seed                NaN 2014-11-28      2014-11
# 114418            venture                NaN 2014-12-01      2014-12
# 114421            venture                  D 2014-12-01      2014-12
# 114438            venture                NaN 2014-12-01      2014-12
# 114439            venture                NaN 2014-12-01      2014-12
# 114440            venture                  E 2014-12-01      2014-12
# 114449              angel                NaN 2014-12-01      2014-12
# 114450            venture                NaN 2014-12-01      2014-12
# 114453            venture                  C 2014-12-02      2014-12
# 114464            venture                  A 2014-12-02      2014-12
# 114469            venture                  A 2014-12-02      2014-12
# 114495            venture                  A 2014-12-02      2014-12
# 114501            venture                  B 2014-12-02      2014-12
# 114504               seed                NaN 2014-12-20      2014-12
#
#        funded_quarter  funded_year raised_amount_total_usd  money_raised
# 0             1974-Q1         1974                     NaN           NaN
# 1             1979-Q1         1979              1,000,000      1000000.0
# 3             1982-Q2         1982                724,000       724000.0
# 4             1982-Q4         1982                165,000       165000.0
# 5             1982-Q4         1982                155,000       155000.0
# 6             1983-Q2         1983                 94,000        94000.0
# 7             1984-Q1         1984                     NaN           NaN
# 8             1984-Q2         1984                     NaN           NaN
# 9             1985-Q2         1985                243,000       243000.0
# 10            1985-Q2         1985                666,000       666000.0
# 11            1985-Q2         1985                169,000       169000.0
# 12            1985-Q3         1985                     NaN           NaN
# 13            1985-Q4         1985                     NaN           NaN
# 14            1986-Q1         1986                     NaN           NaN
# 15            1986-Q2         1986                     NaN           NaN
# 16            1986-Q2         1986                     NaN           NaN
# 17            1986-Q3         1986                     NaN           NaN
# 18            1987-Q1         1987              2,500,000      2500000.0
# 19            1987-Q2         1987                     NaN           NaN
# 20            1987-Q2         1987                     NaN           NaN
# 22            1987-Q3         1987                     NaN           NaN
# 23            1987-Q4         1987                476,000       476000.0
# 24            1987-Q4         1987                     NaN           NaN
# 25            1988-Q3         1988                     NaN           NaN
# 26            1988-Q4         1988                     NaN           NaN
# 27            1989-Q1         1989                     NaN           NaN
# 28            1989-Q2         1989                     NaN           NaN
# 29            1989-Q4         1989                     NaN           NaN
# 30            1990-Q1         1990                 60,000        60000.0
# 31            1990-Q1         1990                     NaN           NaN
# ...               ...          ...                     ...           ...
# 114349        2014-Q4         2014             36,000,000     36000000.0
# 114355        2014-Q4         2014                     NaN           NaN
# 114356        2014-Q4         2014              2,190,000      2190000.0
# 114358        2014-Q4         2014                685,166       685166.0
# 114359        2014-Q4         2014                250,000       250000.0
# 114362        2014-Q4         2014             16,200,000     16200000.0
# 114370        2014-Q4         2014                500,000       500000.0
# 114371        2014-Q4         2014                450,000       450000.0
# 114388        2014-Q4         2014                  3,118         3118.0
# 114392        2014-Q4         2014                300,000       300000.0
# 114400        2014-Q4         2014              6,000,000      6000000.0
# 114401        2014-Q4         2014                873,166       873166.0
# 114402        2014-Q4         2014                811,531       811531.0
# 114403        2014-Q4         2014              6,200,000      6200000.0
# 114405        2014-Q4         2014              1,350,000      1350000.0
# 114406        2014-Q4         2014              1,000,000      1000000.0
# 114412        2014-Q4         2014                     NaN           NaN
# 114418        2014-Q4         2014                560,248       560248.0
# 114421        2014-Q4         2014             60,000,000     60000000.0
# 114438        2014-Q4         2014              1,610,000      1610000.0
# 114439        2014-Q4         2014              1,500,000      1500000.0
# 114440        2014-Q4         2014              7,500,000      7500000.0
# 114449        2014-Q4         2014             15,000,000     15000000.0
# 114450        2014-Q4         2014              1,500,000      1500000.0
# 114453        2014-Q4         2014             33,000,000     33000000.0
# 114464        2014-Q4         2014             10,000,000     10000000.0
# 114469        2014-Q4         2014             17,000,000     17000000.0
# 114495        2014-Q4         2014              4,900,000      4900000.0
# 114501        2014-Q4         2014             34,000,000     34000000.0
# 114504        2014-Q4         2014                    -              NaN
#
# [32332 rows x 19 columns]

# %%
deduped_df[deduped_df.duplicated(subset=['company_name'], keep=False)]
# Out:
#             company_name                              company_category_list  \
# 4517              Jasper  |SaaS|Internet of Things|M2M|Cloud Computing|M...
# 7092                Dash                       |Gps|Maps|Navigation|Mobile|
# 13113              Roost                                      |Real Estate|
# 13222              Telly                                      |Photography|
# 16067            Innovis                                 |Clean Technology|
# 20049               Peek  |Electronics|Messaging|Chat|Email|Apps|Cloud C...
# 24113              Spire                 |Social Network Media|Web Hosting|
# 25990             Helium                |Publishing|Journalism|Curated Web|
# 29334              Telly                                           |Mobile|
# 30243             Tiempo                                   |Semiconductors|
# 31732             Radius  |Sales and Marketing|Marketing Automation|Busi...
# 35855              Draft  |Finance|Soccer|Trading|All Markets|Fantasy Sp...
# 37304           inMarket  |Apps|Hardware|Shopping|Retail|Online Reservat...
# 39704           inMarket  |Mobile Shopping|Advertising|Retail|Shopping|M...
# 40380                Cue                                      |Curated Web|
# 43185              Polar            |World Domination|Apps|Mobile|Software|
# 44075              Karma                                           |Mobile|
# 44237             Splash                |Internet|Social Media|Curated Web|
# 44946             Jasper                                       |E-Commerce|
# 47049          Hopscotch                               |Apps|iPhone|Mobile|
# 48551          trippiece                                      |Curated Web|
# 48552          trippiece                                           |Travel|
# 48992              Draft                                         |Software|
# 49205               Zoom                |Collaboration|Enterprise Software|
# 51453           Sidewalk  |Online Rental|Universities|Textbooks|Colleges...
# 52318               Leap     |Social Games|Photography|Mobile|Social Media|
# 53961             Hubbub  |News|Messaging|Video Streaming|File Sharing|M...
# 54888              Robin  |Email|Twitter Applications|Social Media|Tech ...
# 56344            Innovis                               |Telecommunications|
# 57387               Peek  |Mobile|Internet|Marketplaces|Network Security...
# ...                  ...                                                ...
# 93173           Singular             |Mobile|Augmented Reality|Advertising|
# 94741               Leap                                           |Sports|
# 94845              Shift                                       |Technology|
# 94891           Traction                      |Brand Marketing|Advertising|
# 96834              Roost   |Self Storage|Parking|Peer-to-Peer|Marketplaces|
# 98526              Blink  |Video|Photography|Product Development Service...
# 100330            Breeze                           |Services|Cars|Startups|
# 100471           Statzup                                                NaN
# 100694           Statzup                                         |Startups|
# 101831            Stitch                  |SaaS|Sales and Marketing|Mobile|
# 104904             Weave            |Dental|Telecommunications|Web Hosting|
# 105392            Hubbub  |Shopping|Online Shopping|E-Commerce|Marketpla...
# 105688            Vessel                   |Content Creators|Content|Video|
# 106427             Robin  |Meeting Software|Business Analytics|Office Sp...
# 106641            Spring                                         |Shopping|
# 107109            Tiempo        |Small and Medium Businesses|SaaS|Software|
# 107110          Traction                                     |Marketplaces|
# 107131             Weave  |Professional Networking|Location Based Servic...
# 107199          Singular            |Marketing Automation|SaaS|Advertising|
# 108547            Seesaw                        |Entertainment|Kids|Events|
# 109108    Social Studios                                         |Software|
# 109467             Wakie  |Online Dating|Crowdsourcing|Social Media|Mobile|
# 110041          Flywheel        |Web Design|Blogging Platforms|Web Hosting|
# 111718             Roost                                  |Home Automation|
# 112019  The Learning Lab                      |Training|Tutoring|Education|
# 112827             Peach                     |Online Auctions|Fashion|Apps|
# 112902             Blink                                         |Software|
# 113667           Lockbox                                        |Consumers|
# 113984               Cue                                    |Biotechnology|
# 113986               Cue                                                NaN
#
#                      company_market company_state_code  company_region  \
# 4517             Internet of Things                 CA     SF Bay Area
# 7092                           Maps                 TX      TX - Other
# 13113                   Real Estate                 CA     SF Bay Area
# 13222                   Photography                 CA     SF Bay Area
# 16067              Clean Technology                NaN     GBR - Other
# 20049                        Mobile                 NY   New York City
# 24113                   Web Hosting                 MA          Boston
# 25990                    Publishing                 MA          Boston
# 29334                        Mobile                 CA     SF Bay Area
# 30243                Semiconductors                NaN   Franche-Comte
# 31732          Marketing Automation                 CA     SF Bay Area
# 35855                       Trading                 MA          Boston
# 37304           Online Reservations                 CA     Los Angeles
# 39704               Mobile Shopping                 CA     Los Angeles
# 40380                   Curated Web                 CA     SF Bay Area
# 43185                        Mobile                 ON         Toronto
# 44075                        Mobile                 CA     SF Bay Area
# 44237                  Social Media                NaN             NaN
# 44946                    E-Commerce                NaN       New Delhi
# 47049                          Apps                 CA     SF Bay Area
# 48551                   Curated Web                NaN           Tokyo
# 48552                        Travel                NaN           Tokyo
# 48992                      Software                NaN             NaN
# 49205                 Collaboration                 CA     SF Bay Area
# 51453                 Online Rental                 UT  Salt Lake City
# 52318                        Mobile                NaN             NaN
# 53961                          News                NaN          Vienna
# 54888            Tech Field Support                NaN     NLD - Other
# 56344            Telecommunications                NaN       New Delhi
# 57387                       Tourism                 CA     SF Bay Area
# ...                             ...                ...             ...
# 93173                   Advertising                NaN          Manaus
# 94741                        Sports                NaN           Sofia
# 94845                    Technology                 CA     SF Bay Area
# 94891               Brand Marketing                NaN             NaN
# 96834                  Self Storage                 CA     SF Bay Area
# 98526                          News                 NY   New York City
# 100330                     Startups                 CA     SF Bay Area
# 100471                          NaN                NaN        Budapest
# 100694                     Startups                NaN        Budapest
# 101831          Sales and Marketing                 CA     SF Bay Area
# 104904           Telecommunications                 UT  Salt Lake City
# 105392                        Local                NaN          London
# 105688                      Content                NaN             NaN
# 106427             Meeting Software                 MA          Boston
# 106641                     Shopping                 NY   New York City
# 107109  Small and Medium Businesses                 CA     SF Bay Area
# 107110                 Marketplaces                 CA     SF Bay Area
# 107131                       Mobile                 CA     SF Bay Area
# 107199         Marketing Automation                 CA     SF Bay Area
# 108547                Entertainment                NaN             NaN
# 109108                     Software                NaN        Tel Aviv
# 109467                Crowdsourcing                NaN             NaN
# 110041                  Web Hosting                 NE           Omaha
# 111718              Home Automation                 CA     SF Bay Area
# 112019                    Education                NaN       Singapore
# 112827                      Fashion                 CA     SF Bay Area
# 112902                     Software                NaN     JPN - Other
# 113667                    Consumers                NaN          Berlin
# 113984                Biotechnology                 CA       San Diego
# 113986                          NaN                 CA       San Diego
#
#                            investor_name  \
# 4517                           Benchmark
# 7092    Kleiner Perkins Caufield & Byers
# 13113          General Catalyst Partners
# 13222                        XG Ventures
# 16067                      Finance Wales
# 20049                       RRE Ventures
# 24113                    Hearst Ventures
# 25990           Northport Private Equity
# 29334               Plug & Play Ventures
# 30243                      Aster Capital
# 31732                   BlueRun Ventures
# 35855                          Techstars
# 37304                       Mark DiPaola
# 39704                       Mark DiPaola
# 40380                 Founder Collective
# 43185                    BlueSky Capital
# 44075                         CrunchFund
# 44237                 Quotidian Ventures
# 44946            IndoUS Venture Partners
# 47049                           AngelPad
# 48551                   Samurai Incubate
# 48552                   Samurai Incubate
# 48992                       Y Combinator
# 49205                    TEEC Angel Fund
# 51453                  Cherokee & Walker
# 52318                       The Brandery
# 53961                      Hares Youssef
# 54888                      Triniventures
# 56344              Nokia Growth Partners
# 57387                    Khosla Ventures
# ...                                  ...
# 93173                              Wayra
# 94741                             Eleven
# 94845         Great Oaks Venture Capital
# 94891                          Lightbank
# 96834                    105 Capital LLC
# 98526                          NXTP Labs
# 100330                        Mark Cuban
# 100471                        PortfoLion
# 100694   Day One Capital Fund Management
# 101831                    Eniac Ventures
# 104904                      Fuel Capital
# 105392                  Forward Partners
# 105688                         Benchmark
# 106427                     Atlas Venture
# 106641                          BoxGroup
# 107109                      Y Combinator
# 107110                      Y Combinator
# 107131                  Darling Ventures
# 107199         General Catalyst Partners
# 108547                UpTech Accelerator
# 109108                Moonscape Ventures
# 109467                      Leta Capital
# 110041        Hyde Park Venture Partners
# 111718                               DCM
# 112019              Advent International
# 112827              IDG Capital Partners
# 112902                  Innovation Works
# 113667           High-Tech Gruenderfonds
# 113984                       Immortalana
# 113986                    SherpaVentures
#
#                                    investor_category_list     investor_market  \
# 4517                            |Finance|Venture Capital|     Venture Capital
# 7092                                                  NaN                 NaN
# 13113                                                 NaN                 NaN
# 13222                                                 NaN                 NaN
# 16067                                                 NaN                 NaN
# 20049   |Wireless|Messaging|Application Platforms|E-Co...            Wireless
# 24113                                                 NaN                 NaN
# 25990                                                 NaN                 NaN
# 29334               |Technology|Startups|Venture Capital|     Venture Capital
# 30243                                                 NaN                 NaN
# 31732                                                 NaN                 NaN
# 35855                  |Startups|Venture Capital|Finance|     Venture Capital
# 37304                                                 NaN                 NaN
# 39704                                                 NaN                 NaN
# 40380                                                 NaN                 NaN
# 43185                                                 NaN                 NaN
# 44075                                           |Finance|             Finance
# 44237                                                 NaN                 NaN
# 44946                                                 NaN                 NaN
# 47049                                    |Product Design|      Product Design
# 48551   |Tablets|iPad|iPhone|Mobile|Social Media|Adver...              iPhone
# 48552   |Tablets|iPad|iPhone|Mobile|Social Media|Adver...              iPhone
# 48992       |Startups|Consulting|Venture Capital|Finance|          Consulting
# 49205                                                 NaN                 NaN
# 51453                                                 NaN                 NaN
# 52318                                          |Startups|            Startups
# 53961                                                 NaN                 NaN
# 54888                                                 NaN                 NaN
# 56344   |Mobile Games|Mobile|Big Data Analytics|Advert...              Mobile
# 57387                                                 NaN                 NaN
# ...                                                   ...                 ...
# 93173   |Financial Services|Startups|ICT|Incubators|Fi...  Financial Services
# 94741                                  |Finance|Startups|            Startups
# 94845                                                 NaN                 NaN
# 94891                           |Collaboration|Coworking|       Collaboration
# 96834                                                 NaN                 NaN
# 98526   |Startups|Teachers|Venture Capital|Automotive|...            Startups
# 100330                                                NaN                 NaN
# 100471                                                NaN                 NaN
# 100694                   |Investment Management|Pre Seed|            Pre Seed
# 101831                                                NaN                 NaN
# 104904                                                NaN                 NaN
# 105392            |Incubators|E-Commerce|Venture Capital|          Incubators
# 105688                          |Finance|Venture Capital|     Venture Capital
# 106427                         |Life Sciences|Technology|          Technology
# 106641                                  |Venture Capital|     Venture Capital
# 107109      |Startups|Consulting|Venture Capital|Finance|          Consulting
# 107110      |Startups|Consulting|Venture Capital|Finance|          Consulting
# 107131                                                NaN                 NaN
# 107199                                                NaN                 NaN
# 108547                                          |Finance|             Finance
# 109108                                                NaN                 NaN
# 109467                                                NaN                 NaN
# 110041                                                NaN                 NaN
# 111718                                          |Finance|             Finance
# 112019                                                NaN                 NaN
# 112827                          |Venture Capital|Finance|             Finance
# 112902                                          |Finance|             Finance
# 113667                                                NaN                 NaN
# 113984                                                NaN                 NaN
# 113986                                                NaN                 NaN
#
#        investor_state_code investor_region   investor_city funding_round_type  \
# 4517                    CA     SF Bay Area   San Francisco            venture
# 7092                    CA     SF Bay Area      Menlo Park            venture
# 13113                   MA          Boston       Cambridge            venture
# 13222                   CA     SF Bay Area      Menlo Park        undisclosed
# 16067                  NaN         Cardiff         Cardiff            venture
# 20049                   NY   New York City        New York            venture
# 24113                   NY   New York City        New York            venture
# 25990                   MN     Minneapolis      Northfield            venture
# 29334                   CA     SF Bay Area       Sunnyvale               seed
# 30243                  NaN           Paris           Paris            venture
# 31732                   CA     SF Bay Area      Menlo Park            venture
# 35855                   CO          Denver         Boulder               seed
# 37304                  NaN             NaN             NaN            venture
# 39704                  NaN             NaN             NaN            venture
# 40380                   NY   New York City        New York               seed
# 43185                   ON         Toronto         Toronto              angel
# 44075                   CA     SF Bay Area   San Francisco        undisclosed
# 44237                  NaN             NaN             NaN        undisclosed
# 44946                  NaN       Bangalore       Bangalore            venture
# 47049                   CA     SF Bay Area   San Francisco               seed
# 48551                  NaN           Tokyo           Tokyo               seed
# 48552                  NaN           Tokyo           Tokyo               seed
# 48992                   CA     SF Bay Area   Mountain View               seed
# 49205                  NaN             NaN             NaN               seed
# 51453                   UT  Salt Lake City  Salt Lake City            venture
# 52318                   OH      Cincinnati      Cincinnati               seed
# 53961                  NaN             NaN             NaN               seed
# 54888                  NaN             NaN             NaN               seed
# 56344                   CA     SF Bay Area       Sunnyvale        undisclosed
# 57387                   CA     SF Bay Area      Menlo Park               seed
# ...                    ...             ...             ...                ...
# 93173                  NaN          Madrid          Madrid               seed
# 94741                  NaN           Sofia           Sofia               seed
# 94845                   NY   New York City        New York               seed
# 94891                   IL         Chicago         Chicago               seed
# 96834                  NaN             NaN             NaN               seed
# 98526                  NaN    Buenos Aires    Buenos Aires               seed
# 100330                 NaN             NaN             NaN               seed
# 100471                 NaN        Budapest        Budapest               seed
# 100694                 NaN        Budapest        Budapest               seed
# 101831                  NY   New York City        New York               seed
# 104904                  CA     SF Bay Area   San Francisco            venture
# 105392                 NaN          London          London            venture
# 105688                  CA     SF Bay Area   San Francisco            venture
# 106427                  MA          Boston       Cambridge               seed
# 106641                  NY   New York City        New York            venture
# 107109                  CA     SF Bay Area   Mountain View               seed
# 107110                  CA     SF Bay Area   Mountain View               seed
# 107131                 NaN             NaN             NaN               seed
# 107199                  MA          Boston       Cambridge               seed
# 108547                  KY      KY - Other       Covington               seed
# 109108                 NaN          Zurich          Zürich            venture
# 109467                 NaN          Moscow          Moscow            venture
# 110041                  IL         Chicago         Chicago               seed
# 111718                  CA     SF Bay Area      Menlo Park               seed
# 112019                  MA          Boston          Boston        undisclosed
# 112827                 NaN         Beijing         Beijing               seed
# 112902                  PA      Pittsburgh      Pittsburgh            venture
# 113667                 NaN            Bonn            Bonn               seed
# 113984                 NaN             NaN             NaN            venture
# 113986                  CA     SF Bay Area   San Francisco            venture
#
#        funding_round_code  funded_at funded_month funded_quarter  funded_year  \
# 4517                    A 2005-06-01      2005-06        2005-Q2         2005
# 7092                    A 2006-01-01      2006-01        2006-Q1         2006
# 13113                   A 2007-01-01      2007-01        2007-Q1         2007
# 13222                 NaN 2007-01-01      2007-01        2007-Q1         2007
# 16067                 NaN 2007-06-12      2007-06        2007-Q2         2007
# 20049                   A 2008-01-01      2008-01        2008-Q1         2008
# 24113                   A 2008-07-08      2008-07        2008-Q3         2008
# 25990                   A 2008-10-27      2008-10        2008-Q4         2008
# 29334                 NaN 2009-05-01      2009-05        2009-Q2         2009
# 30243                   B 2009-06-26      2009-06        2009-Q2         2009
# 31732                   A 2009-09-19      2009-09        2009-Q3         2009
# 35855                 NaN 2010-03-01      2010-03        2010-Q1         2010
# 37304                   A 2010-05-01      2010-05        2010-Q2         2010
# 39704                   A 2010-08-01      2010-08        2010-Q3         2010
# 40380                 NaN 2010-08-31      2010-08        2010-Q3         2010
# 43185                 NaN 2010-12-01      2010-12        2010-Q4         2010
# 44075                 NaN 2011-01-01      2011-01        2011-Q1         2011
# 44237                 NaN 2011-01-01      2011-01        2011-Q1         2011
# 44946                   A 2011-01-25      2011-01        2011-Q1         2011
# 47049                 NaN 2011-04-01      2011-04        2011-Q2         2011
# 48551                 NaN 2011-05-16      2011-05        2011-Q2         2011
# 48552                 NaN 2011-05-16      2011-05        2011-Q2         2011
# 48992                 NaN 2011-06-01      2011-06        2011-Q2         2011
# 49205                 NaN 2011-06-01      2011-06        2011-Q2         2011
# 51453                   A 2011-08-02      2011-08        2011-Q3         2011
# 52318                 NaN 2011-08-31      2011-08        2011-Q3         2011
# 53961                 NaN 2011-10-07      2011-10        2011-Q4         2011
# 54888                 NaN 2011-11-01      2011-11        2011-Q4         2011
# 56344                 NaN 2011-12-12      2011-12        2011-Q4         2011
# 57387                 NaN 2012-01-01      2012-01        2012-Q1         2012
# ...                   ...        ...          ...            ...          ...
# 93173                 NaN 2013-12-03      2013-12        2013-Q4         2013
# 94741                 NaN 2014-01-01      2014-01        2014-Q1         2014
# 94845                 NaN 2014-01-01      2014-01        2014-Q1         2014
# 94891                 NaN 2014-01-01      2014-01        2014-Q1         2014
# 96834                 NaN 2014-02-01      2014-02        2014-Q1         2014
# 98526                 NaN 2014-03-01      2014-03        2014-Q1         2014
# 100330                NaN 2014-04-01      2014-04        2014-Q2         2014
# 100471                NaN 2014-04-01      2014-04        2014-Q2         2014
# 100694                NaN 2014-04-03      2014-04        2014-Q2         2014
# 101831                NaN 2014-04-24      2014-04        2014-Q2         2014
# 104904                  A 2014-06-11      2014-06        2014-Q2         2014
# 105392                  A 2014-06-19      2014-06        2014-Q2         2014
# 105688                NaN 2014-06-24      2014-06        2014-Q2         2014
# 106427                NaN 2014-07-07      2014-07        2014-Q3         2014
# 106641                  A 2014-07-09      2014-07        2014-Q3         2014
# 107109                NaN 2014-07-16      2014-07        2014-Q3         2014
# 107110                NaN 2014-07-16      2014-07        2014-Q3         2014
# 107131                NaN 2014-07-16      2014-07        2014-Q3         2014
# 107199                NaN 2014-07-17      2014-07        2014-Q3         2014
# 108547                NaN 2014-08-11      2014-08        2014-Q3         2014
# 109108                NaN 2014-08-20      2014-08        2014-Q3         2014
# 109467                NaN 2014-08-26      2014-08        2014-Q3         2014
# 110041                NaN 2014-09-05      2014-09        2014-Q3         2014
# 111718                NaN 2014-10-02      2014-10        2014-Q4         2014
# 112019                NaN 2014-10-08      2014-10        2014-Q4         2014
# 112827                NaN 2014-10-23      2014-10        2014-Q4         2014
# 112902                  A 2014-10-27      2014-10        2014-Q4         2014
# 113667                NaN 2014-11-11      2014-11        2014-Q4         2014
# 113984                  A 2014-11-18      2014-11        2014-Q4         2014
# 113986                  A 2014-11-18      2014-11        2014-Q4         2014
#
#        raised_amount_total_usd  money_raised
# 4517                7,500,000      7500000.0
# 7092               10,000,000     10000000.0
# 13113               5,500,000      5500000.0
# 13222                      NaN           NaN
# 16067                 987,056       987056.0
# 20049                      NaN           NaN
# 24113               9,000,000      9000000.0
# 25990              17,000,000     17000000.0
# 29334                      NaN           NaN
# 30243               7,030,000      7030000.0
# 31732               2,750,000      2750000.0
# 35855                      NaN           NaN
# 37304               1,000,000      1000000.0
# 39704               1,000,000      1000000.0
# 40380                 700,000       700000.0
# 43185               3,000,000      3000000.0
# 44075                      NaN           NaN
# 44237                      NaN           NaN
# 44946              12,000,000     12000000.0
# 47049                      NaN           NaN
# 48551                      NaN           NaN
# 48552                  47,864        47864.0
# 48992                      NaN           NaN
# 49205               3,000,000      3000000.0
# 51453              15,000,000     15000000.0
# 52318                  25,000        25000.0
# 53961                 300,000       300000.0
# 54888               1,500,000      1500000.0
# 56344                      NaN           NaN
# 57387               1,400,000      1400000.0
# ...                        ...           ...
# 93173                  50,000        50000.0
# 94741                  34,419        34419.0
# 94845                      NaN           NaN
# 94891                      NaN           NaN
# 96834                 100,000       100000.0
# 98526                  25,000        25000.0
# 100330                     NaN           NaN
# 100471                     NaN           NaN
# 100694                275,177       275177.0
# 101831              3,250,000      3250000.0
# 104904              5,000,000      5000000.0
# 105392              3,398,489      3398489.0
# 105688             75,000,000     75000000.0
# 106427              1,400,000      1400000.0
# 106641              7,500,000      7500000.0
# 107109                120,000       120000.0
# 107110                120,000       120000.0
# 107131                120,000       120000.0
# 107199              5,000,000      5000000.0
# 108547                 20,000        20000.0
# 109108              3,100,000      3100000.0
# 109467              1,000,000      1000000.0
# 110041              1,200,000      1200000.0
# 111718                975,000       975000.0
# 112019                     NaN           NaN
# 112827                500,000       500000.0
# 112902             20,000,000     20000000.0
# 113667                     NaN           NaN
# 113984              7,500,000      7500000.0
# 113986              7,500,000      7500000.0
#
# [91 rows x 19 columns]

# %%
# Looks like there are 91 companies that were entered multiple times
deduped_df[deduped_df.company_name == 'Lockbox']
# Out:
#        company_name company_category_list company_market company_state_code  \
# 86242       Lockbox         |Curated Web|    Curated Web                NaN
# 113667      Lockbox           |Consumers|      Consumers                NaN
#
#        company_region            investor_name investor_category_list  \
# 86242       Melbourne           Natasha Mandie                    NaN
# 113667         Berlin  High-Tech Gruenderfonds                    NaN
#
#        investor_market investor_state_code investor_region investor_city  \
# 86242              NaN                 NaN             NaN           NaN
# 113667             NaN                 NaN            Bonn          Bonn
#
#        funding_round_type funding_round_code  funded_at funded_month  \
# 86242                seed                NaN 2013-08-20      2013-08
# 113667               seed                NaN 2014-11-11      2014-11
#
#        funded_quarter  funded_year raised_amount_total_usd  money_raised
# 86242         2013-Q3         2013              2,500,000      2500000.0
# 113667        2014-Q4         2014                     NaN           NaN

# %%
# A Quick look implies that these are companies with the same names from different locations
# Or companies that pivoted causing them to fall into a new market

# I'm just going to drop these from our dataset for the sake of this example
deduped_df = deduped_df[~deduped_df.duplicated(subset=['company_name'], keep='first')]

# %%
deduped_df.company_category_list.head()
# Out:
# 0    |Internet|SEO|Services|Public Relations|Social...
# 1                                |Enterprise Software|
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# Name: company_category_list, dtype: object

# %%
deduped_df.company_category_list.str.split('|').head()
# Out:
# 0    [, Internet, SEO, Services, Public Relations, ...
# 1                            [, Enterprise Software, ]
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# Name: company_category_list, dtype: object

# %%
# let's convert these to an object that python can easily work with, A list

def convert_pipe_delimited_to_list(x):
    if type(x) is str:
        return [category.strip() for category in x.split('|') if category]
    else:
        return []

# %%
convert_pipe_delimited_to_list(deduped_df.company_category_list[0])
# Out:
# ['Internet',
#  'SEO',
#  'Services',
#  'Public Relations',
#  'Social Media',
#  'Consulting']

# %%
deduped_df['list_of_categories'] = deduped_df.company_category_list.apply(convert_pipe_delimited_to_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
deduped_df.list_of_categories.head()
# Out:
# 0    [Internet, SEO, Services, Public Relations, So...
# 1                                [Enterprise Software]
# 3                                                   []
# 4                                                   []
# 5                                                   []
# Name: list_of_categories, dtype: object

# %%
# Now we can find all of the posisble categories
# Using pythong sets!

import itertools

# First we are going to make one massive list
# Itertools chain, chains together a collection of iterators into one big iterator
master_list_of_categories = list(itertools.chain(*deduped_df.list_of_categories))

# %%
# now we can make a set of these elements to find the total number of company categories
unique_categoreies = set(master_list_of_categories)

len(unique_categoreies)
# Out:
# 794

# %%
master_list_of_categories
# Out:
# ['Internet',
#  'SEO',
#  'Services',
#  'Public Relations',
#  'Social Media',
#  'Consulting',
#  'Enterprise Software',
#  'Hardware',
#  'Hardware + Software',
#  'Semiconductors',
#  'Health Care',
#  'Semiconductors',
#  'Software',
#  'Hardware',
#  'Networking',
#  'Web Hosting',
#  'News',
#  'Clean Technology',
#  'E-Commerce',
#  'Games',
#  'Social Media',
#  'Advertising',
#  'Coffee',
#  'Hospitality',
#  'Pets',
#  'Retail',
#  'Web Tools',
#  'Business Productivity',
#  'Financial Services',
#  'Security',
#  'Software',
#  'Software',
#  'Consulting',
#  'Business Information Systems',
#  'Internet Marketing',
#  'Retail',
#  'Medical Devices',
#  'Sporting Goods',
#  'Retail',
#  'Health Care',
#  'Business Development',
#  'Advertising',
#  'Software',
#  'Games',
#  'Business Development',
#  'Investment Management',
#  'Business Services',
#  'Entertainment',
#  'Content',
#  'Social Media',
#  'Sales and Marketing',
#  'Technology',
#  'Advertising',
#  'Media',
#  'Consulting',
#  'Web Hosting',
#  'Television',
#  'Digital Signage',
#  'Software',
#  'Photography',
#  'Email',
#  'Portals',
#  'Search',
#  'Curated Web',
#  'Software',
#  'Restaurants',
#  'Food Processing',
#  'Hospitality',
#  'Consumer Goods',
#  'Groceries',
#  'Crowdsourcing',
#  'E-Commerce',
#  'Mobile',
#  'Public Relations',
#  'Hospitality',
#  'Search',
#  'Social Media',
#  'E-Commerce',
#  'Security',
#  'Industrial Automation',
#  'Intelligent Systems',
#  'VoIP',
#  'Finance',
#  'Biotechnology',
#  'Media',
#  'Weddings',
#  'Social Media',
#  'Software',
#  'Technology',
#  'Telecommunications',
#  'Biotechnology',
#  'Information Technology',
#  'Internet',
#  'Curated Web',
#  'Digital Media',
#  'Broadcasting',
#  'Mobile',
#  'Telecommunications',
#  'Public Relations',
#  'Internet',
#  'Business Services',
#  'All Markets',
#  'Search',
#  'Auctions',
#  'E-Commerce',
#  'Networking',
#  'Telecommunications',
#  'Health and Wellness',
#  'Consulting',
#  'Enterprise Software',
#  'Enterprise Software',
#  'Hardware + Software',
#  'Internet',
#  'Curated Web',
#  'E-Commerce',
#  'Reviews and Recommendations',
#  'Curated Web',
#  'Curated Web',
#  'Software',
#  'Biotechnology',
#  'Analytics',
#  'Auctions',
#  'Curated Web',
#  'Consulting',
#  'Content',
#  'Publishing',
#  'Tablets',
#  'Mobile',
#  'Social Media',
#  'Search',
#  'Portals',
#  'Software',
#  'Television',
#  'Hardware + Software',
#  'Photography',
#  'Curated Web',
#  'Software',
#  'Biotechnology',
#  'Internet',
#  'Curated Web',
#  'Hardware + Software',
#  'Enterprises',
#  'Enterprise Software',
#  'Local Businesses',
#  'Music',
#  'Advertising',
#  'Curated Web',
#  'Software',
#  'Video Streaming',
#  'Information Technology',
#  'Blogging Platforms',
#  'Email',
#  'Search',
#  'Logistics Company',
#  'Shipping Broker Industry',
#  'Shipping',
#  'Web Development',
#  'Software',
#  'Biotechnology',
#  'Software',
#  'Banking',
#  'Security',
#  'Advertising',
#  'Location Based Services',
#  'Search',
#  'B2B',
#  'E-Commerce',
#  'Information Technology',
#  'Curated Web',
#  'Analytics',
#  'Mobile',
#  'E-Commerce',
#  'Mobile',
#  'Software',
#  'Search',
#  'E-Commerce',
#  'Software',
#  'Social Media',
#  'Manufacturing',
#  'Web Design',
#  'Search Marketing',
#  'Internet Marketing',
#  'SEO',
#  'Advertising',
#  'Employer Benefits Programs',
#  'Human Resources',
#  'Loyalty Programs',
#  'Incentives',
#  'Discounts',
#  'Shopping',
#  'E-Commerce',
#  'Medical',
#  'Payments',
#  'P2P Money Transfer',
#  'E-Commerce',
#  'Databases',
#  'Finance',
#  'Software',
#  'Hardware + Software',
#  'Enterprises',
#  'Cloud Computing',
#  'Analytics',
#  'Curated Web',
#  'Curated Web',
#  'Consulting',
#  'Consulting',
#  'E-Commerce',
#  'Financial Services',
#  'Web Hosting',
#  'Health and Wellness',
#  'Biotechnology',
#  'Recipes',
#  'Cooking',
#  'E-Commerce',
#  'Market Research',
#  'MMO Games',
#  'Mobile',
#  'Video Games',
#  'Games',
#  'Enterprises',
#  'Software',
#  'Mobile',
#  'Biotechnology',
#  'Business Services',
#  'Hospitality',
#  'Internet',
#  'Hotels',
#  'Travel',
#  'E-Commerce',
#  'Music',
#  'Auctions',
#  'Technology',
#  'Real Estate',
#  'Mobile',
#  'Comparison Shopping',
#  'Curated Web',
#  'Computers',
#  'Education',
#  'Hospitality',
#  'Television',
#  'Entertainment',
#  'Services',
#  'Advertising',
#  'Enterprises',
#  'Manufacturing',
#  'Web Hosting',
#  'Software',
#  'Hotels',
#  'Hospitality',
#  'Internet Marketing',
#  'Marketing Automation',
#  'Email Marketing',
#  'Direct Marketing',
#  'Advertising',
#  'Consumer Electronics',
#  'Entertainment',
#  'Games',
#  'Investment Management',
#  'Software',
#  'Brand Marketing',
#  'Messaging',
#  'Retail',
#  'Curated Web',
#  'Coupons',
#  'Shopping',
#  'Local',
#  'Advertising',
#  'Search',
#  'Email',
#  'Advertising Platforms',
#  'Biotechnology',
#  'Education',
#  'Real Estate',
#  'Software',
#  'Internet',
#  'E-Commerce',
#  'Software',
#  'E-Commerce',
#  'Technology',
#  'Internet Marketing',
#  'Curated Web',
#  'Travel & Tourism',
#  'Advertising',
#  'E-Commerce',
#  'Business Services',
#  'Travel',
#  'Hardware + Software',
#  'Financial Services',
#  'Banking',
#  'Curated Web',
#  'Internet',
#  'Wireless',
#  'E-Commerce',
#  'Software',
#  'Photography',
#  'Marketing Automation',
#  'Lead Generation',
#  'Software',
#  'Music',
#  'Curated Web',
#  'Web Hosting',
#  'Cloud Data Services',
#  'Payments',
#  'Retail',
#  'E-Commerce',
#  'Mobile',
#  'Crowdsourcing',
#  'Gas',
#  'Travel',
#  'Oil',
#  'Curated Web',
#  'Technology',
#  'VoIP',
#  'Internet',
#  'Curated Web',
#  'Ticketing',
#  'Hotels',
#  'Travel',
#  'Mobile',
#  'Software',
#  'Cable',
#  'Apps',
#  'Mobile',
#  'E-Commerce',
#  'Customer Service',
#  'CRM',
#  'SaaS',
#  'Software',
#  'Consumer Goods',
#  'Enterprise Software',
#  'Television',
#  'Software',
#  'Services',
#  'Advertising',
#  'Software',
#  'Medical Devices',
#  'Entertainment',
#  'Reviews and Recommendations',
#  'Customer Service',
#  'Payments',
#  'Nonprofits',
#  'Advertising Networks',
#  'Advertising',
#  'App Marketing',
#  'Mobile',
#  'Business Services',
#  'Digital Rights Management',
#  'Security',
#  'Advertising',
#  'SEO',
#  'Web Design',
#  'Content',
#  'Design',
#  'E-Commerce',
#  'Mobile Commerce',
#  'Apps',
#  'Telecommunications',
#  'Mobile',
#  'Services',
#  'Security',
#  'Information Security',
#  'Content',
#  'Domains',
#  'Publishing',
#  'Games',
#  'Payments',
#  'E-Commerce',
#  'Software',
#  'Online Shopping',
#  'E-Commerce',
#  'Communications Hardware',
#  'Communications Infrastructure',
#  'Telecommunications',
#  'Wireless',
#  'Mobile',
#  'Security',
#  'Email',
#  'Semantic Search',
#  'SaaS',
#  'SEO',
#  'Sales and Marketing',
#  'Advertising',
#  'Software',
#  'Online Travel',
#  'Hotels',
#  'Restaurants',
#  'Travel',
#  'Travel',
#  'News',
#  'Software',
#  'E-Commerce',
#  'Analytics',
#  'CRM',
#  'Software',
#  'Fashion',
#  'Trading',
#  'Pets',
#  'Information Services',
#  'Enterprises',
#  'E-Commerce',
#  'Search',
#  'Advertising',
#  'E-Commerce',
#  'Freelancers',
#  'Human Resources',
#  'Outsourcing',
#  'Employment',
#  'Career Management',
#  'Curated Web',
#  'Consulting',
#  'E-Commerce',
#  'E-Commerce',
#  'Advertising',
#  'Search Marketing',
#  'Software',
#  'News',
#  'Mobile',
#  'Enterprises',
#  'Health Care',
#  'E-Commerce',
#  'Digital Media',
#  'Music',
#  'Curated Web',
#  'IaaS',
#  'Cloud Computing',
#  'Software',
#  'Advertising',
#  'Video Games',
#  'Games',
#  'Messaging',
#  'E-Commerce',
#  'Social Network Media',
#  'Mobile Games',
#  'Social Games',
#  'Mobile',
#  'Games',
#  'Software',
#  'Supply Chain Management',
#  'Cloud Computing',
#  'Transportation',
#  'Mobile',
#  'Software',
#  'Business Intelligence',
#  'Games',
#  'Payments',
#  'Enterprise Software',
#  'Information Technology',
#  'Forums',
#  'Mobile',
#  'Advertising',
#  'Finance',
#  'Semiconductors',
#  'Photography',
#  'Games',
#  'Internet Marketing',
#  'Mobile',
#  'Internet',
#  'Entertainment',
#  'Media',
#  'Curated Web',
#  'Financial Services',
#  'Software',
#  'E-Commerce',
#  'Big Data Analytics',
#  'Cloud-Based Music',
#  'Mobile Software Tools',
#  'Mobile Search',
#  'Email',
#  'Portals',
#  'Information Technology',
#  'Search',
#  'Health and Wellness',
#  'Wireless',
#  'Advertising',
#  'Mobile',
#  'Retail',
#  'E-Commerce',
#  'Education',
#  'Internet',
#  'Domains',
#  'Mobile',
#  'Curated Web',
#  'Mobile Analytics',
#  'Mobile Advertising',
#  'Advertising Exchanges',
#  'Advertising Platforms',
#  'Advertising Networks',
#  'Mobile Games',
#  'Biotechnology',
#  'Finance',
#  'Advertising',
#  'Internet',
#  'Software',
#  'Advertising',
#  'Technology',
#  'Flash Storage',
#  'Hardware + Software',
#  'Curated Web',
#  'E-Commerce',
#  'Enterprise Software',
#  'News',
#  'Software',
#  'Security',
#  'Logistics',
#  'Shipping',
#  'Search',
#  'Enterprise Software',
#  'Curated Web',
#  'Online Video Advertising',
#  'Mobile Advertising',
#  'Content Delivery',
#  'Advertising',
#  'Business Services',
#  'Design',
#  'Commodities',
#  'Energy',
#  'Web Tools',
#  'Security',
#  'Physicians',
#  'Software',
#  'Mobile',
#  'Health Care',
#  'Health and Wellness',
#  'Software',
#  'Public Relations',
#  'Public Relations',
#  'Semiconductors',
#  'All Markets',
#  'Wireless',
#  'Consumer Electronics',
#  'Hardware + Software',
#  'Event Management',
#  'Software',
#  'Video',
#  'Software',
#  'Enterprise Software',
#  'Manufacturing',
#  'Enterprise Software',
#  'Web Hosting',
#  'Software',
#  'Health and Wellness',
#  'Physicians',
#  'Health Care',
#  'Storage',
#  'Education',
#  'Development Platforms',
#  'Mobile',
#  'Application Platforms',
#  'Security',
#  'Software',
#  'Health Care',
#  'Education',
#  'Software',
#  'Software',
#  'Wireless',
#  'Mobile',
#  'Accounting',
#  'Sales and Marketing',
#  'Chat',
#  'Android',
#  'iPhone',
#  'Home & Garden',
#  'Tablets',
#  'Mobile',
#  'CRM',
#  'Enterprise Software',
#  'Security',
#  'Software',
#  'Security',
#  'Semiconductors',
#  'Email',
#  'Marketing Automation',
#  'Software',
#  'Mobile',
#  'Hardware + Software',
#  'Computers',
#  'Mobile',
#  'Mobile',
#  'Hardware + Software',
#  'Home Decor',
#  'Handmade',
#  'E-Commerce',
#  'Internet',
#  'Restaurants',
#  'Local',
#  'Mobile',
#  'Location Based Services',
#  'E-Commerce',
#  'Hospitality',
#  'Information Technology',
#  'Network Security',
#  'Security',
#  'Software',
#  'Contact Management',
#  'Web Design',
#  'Mobile',
#  'E-Commerce',
#  'Search',
#  'Enterprises',
#  'Enterprise Software',
#  'Enterprise Software',
#  'Finance',
#  'Hardware + Software',
#  'News',
#  'Crowdsourcing',
#  'Cloud Computing',
#  'Enterprise Software',
#  'Television',
#  'Software',
#  'Hardware',
#  'Hardware + Software',
#  'Mobile',
#  'Search',
#  'Content',
#  'Curated Web',
#  'Web Hosting',
#  'Search',
#  'Manufacturing',
#  'Enterprises',
#  'Enterprise Software',
#  'Software',
#  'Women',
#  'News',
#  'Services',
#  'Transportation',
#  'Software',
#  'Peer-to-Peer',
#  'Artificial Intelligence',
#  'Software',
#  'Semiconductors',
#  'Curated Web',
#  'Games',
#  'Advertising',
#  'Curated Web',
#  'Medical Professionals',
#  'Education',
#  'Mobile',
#  'Games',
#  'E-Commerce',
#  'Education',
#  'Software',
#  'Email',
#  'Security',
#  'Software',
#  'News',
#  'E-Commerce',
#  'Mobile',
#  'Software',
#  'Analytics',
#  'Text Analytics',
#  'Language Learning',
#  'Search',
#  'Software',
#  'Education',
#  'Enterprise Software',
#  'Software',
#  'Health Care',
#  'Sales and Marketing',
#  'Mobile',
#  'Software',
#  'Automotive',
#  'Curated Web',
#  'SaaS',
#  'Payments',
#  'Risk Management',
#  'Finance',
#  'Enterprise Software',
#  'Security',
#  'Advertising',
#  'E-Commerce Platforms',
#  'Market Research',
#  'Digital Media',
#  'Software',
#  'Software',
#  'Software',
#  'Domains',
#  'E-Commerce',
#  'Software',
#  'Games',
#  'Mobile',
#  'Web Hosting',
#  'Enterprise Software',
#  'Collaboration',
#  'Knowledge Management',
#  'Software',
#  'Business Services',
#  'Curated Web',
#  'Biotechnology',
#  'Messaging',
#  'Biotechnology',
#  'Hardware',
#  'Hardware + Software',
#  'Biotechnology',
#  'Mobile',
#  'Software',
#  'Hardware',
#  'Semiconductors',
#  'Nanotechnology',
#  'Consumer Electronics',
#  'Internet TV',
#  'Digital Rights Management',
#  'Games',
#  'Software',
#  'Pharmaceuticals',
#  'Enterprise Software',
#  'Lighting',
#  'Open Source',
#  'Databases',
#  'Enterprise Software',
#  'Software',
#  'Web Hosting',
#  'Security',
#  'Software',
#  'Enterprise Software',
#  'Software',
#  'Enterprise Software',
#  'IaaS',
#  'Cloud Computing',
#  'SaaS',
#  'Enterprise Software',
#  'Education',
#  'Web CMS',
#  'Content',
#  'Software',
#  'Biotechnology',
#  'Mobile',
#  'Services',
#  'Software',
#  'SaaS',
#  'Human Resources',
#  'Education',
#  'Artists Globally',
#  'Social Media',
#  'Biotechnology',
#  'Finance',
#  'Software',
#  'Software',
#  'Enterprise Search',
#  'Content',
#  'Web Development',
#  'Enterprise Software',
#  'Health Care',
#  'Biotechnology',
#  'Fashion',
#  'Messaging',
#  'VoIP',
#  'Mobile',
#  'Software',
#  'Content',
#  'Social Network Media',
#  'Peer-to-Peer',
#  'Games',
#  'Contact Management',
#  'Crowdsourcing',
#  'Task Management',
#  'Email',
#  'Networking',
#  'CRM',
#  'Software',
#  'Fantasy Sports',
#  'Sports',
#  'Internet',
#  'Information Technology',
#  'Consulting',
#  'Manufacturing',
#  'Education',
#  'Software',
#  'Enterprise Software',
#  'Software',
#  'Electronics',
#  'Manufacturing',
#  'Wireless',
#  'Education',
#  'Enterprise Software',
#  'Hospitality',
#  'Location Based Services',
#  'Security',
#  'Mobile',
#  'Wireless',
#  'Mobile',
#  'Information Services',
#  'Hardware + Software',
#  'Messaging',
#  'Semiconductors',
#  'Software',
#  'Mobile',
#  'Education',
#  'Messaging',
#  'Real Time',
#  'Databases',
#  'Software',
#  'Hardware + Software',
#  'Technology',
#  'Business Services',
#  'Finance',
#  'Security',
#  'Software',
#  'Manufacturing',
#  'Hardware + Software',
#  'Enterprise Software',
#  'Internet',
#  'Web Hosting',
#  'Health Care',
#  'Software',
#  'Renewable Energies',
#  'Green',
#  'Solar',
#  'Clean Technology',
#  'Internet',
#  'Network Security',
#  'Sales and Marketing',
#  'Analytics',
#  'PaaS',
#  'SaaS',
#  'Cloud Computing',
#  'File Sharing',
#  'Software',
#  'Supply Chain Management',
#  'SaaS',
#  'Software',
#  'Product Design',
#  'Network Security',
#  'Networking',
#  'Hardware + Software',
#  'Security',
#  'Distribution',
#  'Content Delivery',
#  'Digital Media',
#  'Software',
#  'Mobile',
#  'Telecommunications',
#  'Messaging',
#  'Mobile',
#  'Health Care',
#  'Search',
#  'Advertising',
#  'Video Games',
#  'Software',
#  'Music',
#  'Games',
#  'Mobile',
#  'Health Care',
#  'Advertising Platforms',
#  'Internet Radio Market',
#  'Advertising',
#  'Television',
#  'Enterprise Software',
#  'Software',
#  'Usability',
#  'Software',
#  'Video Streaming',
#  'Social Network Media',
#  'Video',
#  'Hardware + Software',
#  'Games',
#  'Digital Media',
#  'Public Relations',
#  'Sales and Marketing',
#  'Social Media',
#  'Advertising',
#  'Real Time',
#  'Video',
#  'Mobile',
#  'Health and Wellness',
#  'Trading',
#  'Synchronization',
#  'Databases',
#  'Contact Management',
#  'Curated Web',
#  'Mobile',
#  'Search',
#  'Enterprise Software',
#  'Enterprise Software',
#  'Semiconductors',
#  'Security',
#  'Private Social Networking',
#  'Networking',
#  'Social Media',
#  'Curated Web',
#  'Curated Web',
#  'Manufacturing',
#  'Software',
#  'News',
#  'Curated Web',
#  'Mobile',
#  'Advertising',
#  'Video Streaming',
#  'Audio',
#  'Music',
#  'Messaging',
#  'Web Hosting',
#  'Automotive',
#  'Health and Wellness',
#  'Solar',
#  'Clean Technology',
#  'Semiconductors',
#  'Medical Devices',
#  'Biotechnology',
#  'Health Care',
#  'iOS',
#  'Games',
#  'Information Security',
#  'Cloud Management',
#  'Advertising',
#  'Entertainment',
#  'Social Media',
#  'Games',
#  'Biotechnology',
#  'Security',
#  'Analytics',
#  'Consumer Electronics',
#  'Robotics',
#  'Software',
#  'Human Resources',
#  'Recruiting',
#  'Career Management',
#  'Software',
#  'Software',
#  'Design',
#  'Sustainability',
#  'Simulation',
#  'SaaS',
#  'Clean Technology',
#  'Security',
#  'News',
#  'Clean Technology',
#  'Mobile',
#  'Manufacturing',
#  'E-Commerce',
#  'Travel',
#  'Software',
#  'Semiconductors',
#  'Finance',
#  'Health and Wellness',
#  'Biotechnology',
#  'Fashion',
#  'Software',
#  'Business Services',
#  'Games',
#  'Cloud Computing',
#  'Manufacturing',
#  'Business Services',
#  'Health and Wellness',
#  'Data Security',
#  'Homeland Security',
#  'Storage',
#  'Software',
#  'Software',
#  'VoIP',
#  'Networking',
#  'Software',
#  'Medical',
#  'Health Care',
#  'Health and Wellness',
#  'Hardware + Software',
#  'Analytics',
#  'Games',
#  'Enterprise Software',
#  'Software',
#  'Digital Media',
#  'Mobile',
#  'Web CMS',
#  'Blogging Platforms',
#  'Curated Web',
#  'Manufacturing',
#  'Clean Technology',
#  'Network Security',
#  'Security',
#  'Credit Cards',
#  'Online Shopping',
#  'Business Services',
#  'E-Commerce',
#  'Games',
#  'Television',
#  'Hardware + Software',
#  'Biotechnology',
#  'Navigation',
#  'Gps',
#  'Public Transportation',
#  'Web Development',
#  'Software',
#  'Software',
#  'Curated Web',
#  'Mobile',
#  'Health Care',
#  'Clean Technology',
#  'Nanotechnology',
#  'Enterprise Software',
#  'Sensors',
#  'Curated Web',
#  'Creative',
#  'Predictive Analytics',
#  'Sales and Marketing',
#  'Design',
#  'Optimization',
#  'Advertising',
#  'Open Source',
#  'Browser Extensions',
#  'Curated Web',
#  'Mobile Security',
#  ...]

# %%
# Then we can use special python objects to quickly count the instances of these
# Categories

from collections import Counter 

Counter(master_list_of_categories)
# Out:
# Counter({'Internet': 629,
#          'SEO': 113,
#          'Services': 183,
#          'Public Relations': 129,
#          'Social Media': 1591,
#          'Consulting': 307,
#          'Enterprise Software': 1754,
#          'Hardware': 135,
#          'Hardware + Software': 885,
#          'Semiconductors': 459,
#          'Health Care': 1077,
#          'Software': 4641,
#          'Networking': 374,
#          'Web Hosting': 481,
#          'News': 407,
#          'Clean Technology': 983,
#          'E-Commerce': 2258,
#          'Games': 1363,
#          'Advertising': 1563,
#          'Coffee': 7,
#          'Hospitality': 373,
#          'Pets': 49,
#          'Retail': 277,
#          'Web Tools': 130,
#          'Business Productivity': 13,
#          'Financial Services': 167,
#          'Security': 633,
#          'Business Information Systems': 6,
#          'Internet Marketing': 184,
#          'Medical Devices': 118,
#          'Sporting Goods': 9,
#          'Business Development': 39,
#          'Investment Management': 51,
#          'Business Services': 159,
#          'Entertainment': 303,
#          'Content': 245,
#          'Sales and Marketing': 404,
#          'Technology': 439,
#          'Media': 289,
#          'Television': 153,
#          'Digital Signage': 18,
#          'Photography': 355,
#          'Email': 132,
#          'Portals': 22,
#          'Search': 506,
#          'Curated Web': 2022,
#          'Restaurants': 119,
#          'Food Processing': 25,
#          'Consumer Goods': 75,
#          'Groceries': 16,
#          'Crowdsourcing': 175,
#          'Mobile': 3132,
#          'Industrial Automation': 8,
#          'Intelligent Systems': 6,
#          'VoIP': 61,
#          'Finance': 1078,
#          'Biotechnology': 2155,
#          'Weddings': 54,
#          'Telecommunications': 124,
#          'Information Technology': 203,
#          'Digital Media': 227,
#          'Broadcasting': 37,
#          'All Markets': 21,
#          'Auctions': 63,
#          'Health and Wellness': 761,
#          'Reviews and Recommendations': 192,
#          'Analytics': 1089,
#          'Publishing': 212,
#          'Tablets': 57,
#          'Enterprises': 251,
#          'Local Businesses': 67,
#          'Music': 441,
#          'Video Streaming': 180,
#          'Blogging Platforms': 93,
#          'Logistics Company': 3,
#          'Shipping Broker Industry': 1,
#          'Shipping': 38,
#          'Web Development': 283,
#          'Banking': 65,
#          'Location Based Services': 224,
#          'B2B': 177,
#          'Manufacturing': 480,
#          'Web Design': 61,
#          'Search Marketing': 26,
#          'Employer Benefits Programs': 13,
#          'Human Resources': 152,
#          'Loyalty Programs': 85,
#          'Incentives': 60,
#          'Discounts': 73,
#          'Shopping': 173,
#          'Medical': 205,
#          'Payments': 209,
#          'P2P Money Transfer': 18,
#          'Databases': 130,
#          'Cloud Computing': 511,
#          'Recipes': 16,
#          'Cooking': 21,
#          'Market Research': 63,
#          'MMO Games': 28,
#          'Video Games': 57,
#          'Hotels': 93,
#          'Travel': 480,
#          'Real Estate': 263,
#          'Comparison Shopping': 18,
#          'Computers': 33,
#          'Education': 949,
#          'Marketing Automation': 93,
#          'Email Marketing': 59,
#          'Direct Marketing': 26,
#          'Consumer Electronics': 141,
#          'Brand Marketing': 172,
#          'Messaging': 420,
#          'Coupons': 83,
#          'Local': 168,
#          'Advertising Platforms': 47,
#          'Travel & Tourism': 33,
#          'Wireless': 160,
#          'Lead Generation': 76,
#          'Cloud Data Services': 99,
#          'Gas': 9,
#          'Oil': 15,
#          'Ticketing': 88,
#          'Cable': 6,
#          'Apps': 632,
#          'Customer Service': 126,
#          'CRM': 185,
#          'SaaS': 894,
#          'Nonprofits': 120,
#          'Advertising Networks': 19,
#          'App Marketing': 75,
#          'Digital Rights Management': 13,
#          'Design': 256,
#          'Mobile Commerce': 146,
#          'Information Security': 29,
#          'Domains': 16,
#          'Online Shopping': 134,
#          'Communications Hardware': 23,
#          'Communications Infrastructure': 18,
#          'Semantic Search': 59,
#          'Online Travel': 52,
#          'Fashion': 502,
#          'Trading': 64,
#          'Information Services': 49,
#          'Freelancers': 45,
#          'Outsourcing': 41,
#          'Employment': 87,
#          'Career Management': 82,
#          'IaaS': 33,
#          'Social Network Media': 401,
#          'Mobile Games': 109,
#          'Social Games': 130,
#          'Supply Chain Management': 43,
#          'Transportation': 136,
#          'Business Intelligence': 166,
#          'Forums': 21,
#          'Big Data Analytics': 152,
#          'Cloud-Based Music': 5,
#          'Mobile Software Tools': 49,
#          'Mobile Search': 2,
#          'Mobile Analytics': 13,
#          'Mobile Advertising': 53,
#          'Advertising Exchanges': 9,
#          'Flash Storage': 40,
#          'Logistics': 78,
#          'Online Video Advertising': 17,
#          'Content Delivery': 33,
#          'Commodities': 7,
#          'Energy': 65,
#          'Physicians': 20,
#          'Event Management': 41,
#          'Video': 546,
#          'Storage': 143,
#          'Development Platforms': 33,
#          'Application Platforms': 33,
#          'Accounting': 55,
#          'Chat': 77,
#          'Android': 347,
#          'iPhone': 355,
#          'Home & Garden': 58,
#          'Home Decor': 9,
#          'Handmade': 4,
#          'Network Security': 77,
#          'Contact Management': 32,
#          'Women': 36,
#          'Peer-to-Peer': 102,
#          'Artificial Intelligence': 62,
#          'Medical Professionals': 10,
#          'Text Analytics': 12,
#          'Language Learning': 48,
#          'Automotive': 245,
#          'Risk Management': 45,
#          'E-Commerce Platforms': 30,
#          'Collaboration': 225,
#          'Knowledge Management': 14,
#          'Nanotechnology': 82,
#          'Internet TV': 13,
#          'Pharmaceuticals': 98,
#          'Lighting': 21,
#          'Open Source': 117,
#          'Web CMS': 47,
#          'Artists Globally': 23,
#          'Enterprise Search': 20,
#          'Task Management': 42,
#          'Fantasy Sports': 15,
#          'Sports': 298,
#          'Electronics': 61,
#          'Real Time': 151,
#          'Renewable Energies': 35,
#          'Green': 34,
#          'Solar': 48,
#          'PaaS': 78,
#          'File Sharing': 129,
#          'Product Design': 19,
#          'Distribution': 49,
#          'Internet Radio Market': 12,
#          'Usability': 11,
#          'Synchronization': 19,
#          'Private Social Networking': 38,
#          'Audio': 94,
#          'iOS': 182,
#          'Cloud Management': 55,
#          'Robotics': 46,
#          'Recruiting': 163,
#          'Sustainability': 34,
#          'Simulation': 8,
#          'Data Security': 48,
#          'Homeland Security': 15,
#          'Credit Cards': 32,
#          'Navigation': 37,
#          'Gps': 52,
#          'Public Transportation': 119,
#          'Sensors': 45,
#          'Creative': 52,
#          'Predictive Analytics': 93,
#          'Optimization': 67,
#          'Browser Extensions': 43,
#          'Mobile Security': 43,
#          'Innovation Engineering': 10,
#          'Mobile Payments': 118,
#          'Algorithms': 20,
#          'Postal and Courier Services': 12,
#          'Insurance': 55,
#          'Specialty Retail': 5,
#          'Online Reservations': 47,
#          'Cosmetics': 20,
#          'Beauty': 56,
#          'Social Recruiting': 24,
#          'Video on Demand': 40,
#          'Facebook Applications': 235,
#          'Clean Energy': 63,
#          'Marketplaces': 416,
#          'Content Syndication': 25,
#          'Productivity Software': 108,
#          'Windows Phone 7': 16,
#          'Healthcare Services': 27,
#          'Hospitals': 36,
#          'Big Data': 439,
#          'Ediscovery': 64,
#          'Data Visualization': 58,
#          'Virtualization': 86,
#          'Trusted Networks': 13,
#          'Brokers': 11,
#          'Web Presence Management': 7,
#          'Displays': 20,
#          'Performance Marketing': 19,
#          'Local Search': 50,
#          'Art': 78,
#          'Photo Sharing': 101,
#          'Startups': 318,
#          'Social Business': 17,
#          'Personal Branding': 5,
#          'Small and Medium Businesses': 113,
#          'Data Integration': 45,
#          'Mobile Social': 21,
#          'SMS': 59,
#          'Communities': 74,
#          'Identity': 52,
#          'All Students': 60,
#          'Colleges': 83,
#          'Linux': 15,
#          'Maps': 62,
#          'Batteries': 14,
#          'Customer Support Tools': 30,
#          'FreetoPlay Gaming': 14,
#          'Graphics': 51,
#          'Agriculture': 40,
#          'Water': 16,
#          'Alumni': 3,
#          'Fitness': 121,
#          'Health Services Industry': 9,
#          'Doctors': 29,
#          'Online Scheduling': 48,
#          'Service Providers': 36,
#          'Tech Field Support': 27,
#          'Web Browsers': 16,
#          'Vacation Rentals': 25,
#          'Infrastructure': 42,
#          'Credit': 29,
#          '3D': 71,
#          'Finance Technology': 89,
#          'Hedge Funds': 6,
#          'Subscription Businesses': 37,
#          'World Domination': 21,
#          'Career Planning': 17,
#          'Internet Service Providers': 9,
#          'Mac': 10,
#          'Semantic Web': 35,
#          'Intellectual Asset Management': 12,
#          'Legal': 105,
#          'Events': 233,
#          'Image Recognition': 34,
#          'Local Based Services': 27,
#          'Virtual Worlds': 47,
#          'Mobile Enterprise': 12,
#          'Mobility': 45,
#          'Data Centers': 44,
#          'Life Sciences': 41,
#          'Classifieds': 33,
#          'Virtual Workforces': 10,
#          'Personal Finance': 62,
#          'Crowdfunding': 85,
#          'Promotional': 47,
#          'User Experience Design': 33,
#          'Unifed Communications': 15,
#          'Privacy': 42,
#          'Cloud Infrastructure': 31,
#          'Social Commerce': 182,
#          'Document Management': 45,
#          'Video Conferencing': 14,
#          'Industrial': 9,
#          'Mechanical Solutions': 4,
#          'Textbooks': 35,
#          'App Stores': 34,
#          'Social Search': 43,
#          'Wine And Spirits': 33,
#          'Internet of Things': 118,
#          'M2M': 25,
#          'Aerospace': 23,
#          'Mobile Devices': 34,
#          'RFID': 21,
#          'IT Management': 25,
#          'Project Management': 77,
#          'Therapeutics': 36,
#          'Visual Search': 10,
#          'Meeting Software': 27,
#          'Organic': 10,
#          'Identity Management': 30,
#          'Fraud Detection': 23,
#          'Recycling': 25,
#          'Online Dating': 59,
#          'Local Advertising': 15,
#          'Augmented Reality': 40,
#          'Monetization': 47,
#          'Photo Editing': 13,
#          'Professional Services': 28,
#          'Price Comparison': 56,
#          'Cloud Security': 33,
#          'Social Bookmarking': 24,
#          'Engineering Firms': 9,
#          'Architecture': 16,
#          'Construction': 27,
#          'Nightlife': 14,
#          'Kids': 89,
#          'Concerts': 38,
#          'Demographies': 7,
#          'Test and Measurement': 6,
#          'Genetic Testing': 3,
#          'Humanitarian': 14,
#          'Biometrics': 12,
#          'Online Rental': 47,
#          'Training': 60,
#          'Procurement': 9,
#          'Point of Sale': 41,
#          'Content Creators': 11,
#          'Tracking': 66,
#          'Guides': 20,
#          'Smart Grid': 21,
#          'Internet Infrastructure': 4,
#          'Data Center Infrastructure': 7,
#          'Governments': 14,
#          'Ad Targeting': 55,
#          'Cars': 72,
#          'Testing': 46,
#          'Social Media Marketing': 130,
#          'RIM': 5,
#          'ICT': 4,
#          'Telephony': 16,
#          'Energy Management': 20,
#          'Electronic Health Records': 23,
#          'Social Media Advertising': 23,
#          'Printing': 45,
#          'Polling': 22,
#          'Surveys': 35,
#          'Twitter Applications': 112,
#          'Entrepreneur': 55,
#          'Data Mining': 42,
#          'Stock Exchanges': 34,
#          'Diagnostics': 19,
#          'Systems': 23,
#          'Spam Filtering': 4,
#          'Virtual Currency': 28,
#          'Gadget': 12,
#          'Consumer Internet': 45,
#          'Social Buying': 45,
#          'Journalism': 34,
#          'Content Discovery': 22,
#          'Mens Specific': 7,
#          'Developer APIs': 112,
#          'Translation': 33,
#          'Personalization': 84,
#          'Cyber': 9,
#          'Energy Efficiency': 45,
#          'Interface Design': 18,
#          'Senior Citizens': 8,
#          'Mass Customization': 20,
#          'Environmental Innovation': 42,
#          'Staffing Firms': 15,
#          'Machine Learning': 85,
#          'Email Newsletters': 8,
#          'UV LEDs': 1,
#          'Online Gaming': 21,
#          'Toys': 26,
#          'iPad': 135,
#          'Celebrity': 24,
#          'Mobile Infrastructure': 5,
#          'Mobile Video': 24,
#          'E-Books': 15,
#          'Estimation and Quoting': 7,
#          'Advice': 16,
#          'Consumers': 101,
#          'Tourism': 37,
#          'Professional Networking': 14,
#          'Social CRM': 33,
#          'Social Media Monitoring': 30,
#          'Automated Kiosk': 4,
#          'Computer Vision': 27,
#          'Kinect': 10,
#          'Tutoring': 31,
#          'Match-Making': 12,
#          'Gift Card': 63,
#          'Corporate Training': 13,
#          'Lasers': 5,
#          'Group SMS': 3,
#          'Comics': 5,
#          'New Product Development': 9,
#          'Cyber Security': 23,
#          'Hip Hop': 1,
#          'Video Editing': 15,
#          'Social Opinion Platform': 2,
#          'Politics': 39,
#          'Lead Management': 14,
#          'Lifestyle': 101,
#          'Chemicals': 12,
#          'Retail Technology': 32,
#          'Film': 46,
#          'Semiconductor Manufacturing Equipment': 3,
#          'Archiving': 11,
#          'Collaborative Consumption': 71,
#          'Diabetes': 18,
#          'Electrical Distribution': 8,
#          'Opinions': 31,
#          'QR Codes': 29,
#          'Creative Industries': 7,
#          'NFC': 36,
#          'Gambling': 31,
#          'DIY': 19,
#          'Personal Health': 26,
#          'iPod Touch': 18,
#          'Religion': 6,
#          'Certification Test': 10,
#          'Craigslist Killers': 8,
#          'Office Space': 11,
#          'Teenagers': 8,
#          'Shoes': 22,
#          'Charter Schools': 11,
#          'Teachers': 37,
#          'Freemium': 19,
#          'Proximity Internet': 15,
#          'Speech Recognition': 14,
#          'Reputation': 32,
#          'Natural Language Processing': 31,
#          'Neuroscience': 12,
#          'Gamification': 69,
#          'Skill Assessment': 25,
#          'Visualization': 36,
#          'Contests': 16,
#          'Franchises': 7,
#          'Licensing': 17,
#          'WebOS': 3,
#          'Application Performance Monitoring': 12,
#          'Enterprise 2.0': 12,
#          'Geospatial': 18,
#          'Online Identity': 6,
#          'Billing': 35,
#          'Product Development Services': 23,
#          'Game': 48,
#          'IT and Cybersecurity': 18,
#          'Game Mechanics': 8,
#          'Psychology': 25,
#          'Venture Capital': 65,
#          'Enterprise Resource Planning': 6,
#          'Sponsorship': 11,
#          'Auto': 19,
#          'MicroBlogging': 19,
#          'Wind': 6,
#          'Tea': 2,
#          'General Public Worldwide': 2,
#          'Universities': 39,
#          'High Schools': 28,
#          'College Campuses': 10,
#          'Video Chat': 19,
#          'Parenting': 63,
#          'Advanced Materials': 4,
#          'Baby Boomers': 2,
#          'Elder Care': 4,
#          'Senior Health': 2,
#          'Plumbers': 4,
#          'Presentations': 28,
#          'Flowers': 5,
#          'Farming': 9,
#          'Health Care Information Technology': 91,
#          'Sales Automation': 22,
#          'Emerging Markets': 19,
#          'Corporate IT': 4,
#          'Charity': 28,
#          'Property Management': 28,
#          'Virtual Goods': 15,
#          'Non Profit': 17,
#          'Mobile Shopping': 17,
#          'Carbon': 5,
#          'Coworking': 3,
#          'SNS': 13,
#          'Writers': 10,
#          'Jewelry': 29,
#          'Business Analytics': 22,
#          'Intellectual Property': 12,
#          'Contact Centers': 8,
#          'Social Media Management': 23,
#          'Independent Music Labels': 5,
#          'Music Services': 14,
#          'Interest Graph': 22,
#          'Spas': 4,
#          'Innovation Management': 9,
#          'Rapidly Expanding': 6,
#          'Twin-Tip Skis': 2,
#          'Google Apps': 12,
#          'Social Media Platforms': 13,
#          'Mining Technologies': 3,
#          'Social Television': 34,
#          'Limousines': 5,
#          'Leisure': 19,
#          'Music Venues': 12,
#          'Vertical Search': 12,
#          'Exercise': 19,
#          'Nutrition': 22,
#          'Organic Food': 18,
#          'Commercial Real Estate': 19,
#          'UHB LEDs': 1,
#          'Underserved Children': 2,
#          'Consumer Behavior': 8,
#          'Commercial Solar': 5,
#          'Cosmetic Surgery': 4,
#          'Infrastructure Builders': 4,
#          'Residential Solar': 7,
#          'Specialty Chemicals': 2,
#          'Mobile Emergency&Health': 12,
#          'Group Buying': 26,
#          'Active Lifestyle': 5,
#          'Dental': 16,
#          'K-12 Education': 27,
#          'Babies': 20,
#          'App Discovery': 3,
#          'Nightclubs': 10,
#          'Theatre': 5,
#          'Developer Tools': 31,
#          'Soccer': 14,
#          'Wealth Management': 8,
#          'Indoor Positioning': 6,
#          'Wire': 1,
#          'Flash Sales': 32,
#          'Niche Specific': 1,
#          'Utilities': 24,
#          'Online Auctions': 4,
#          'Enterprise Softw': 1,
#          'Sunglasses': 3,
#          'Software Compliance': 6,
#          'Social + Mobile + Local': 14,
#          'Industrial Energy Efficiency': 4,
#          'Rural Energy': 1,
#          'Distributed Generation': 1,
#          'Law Enforcement': 15,
#          'Defense': 12,
#          'Young Adults': 4,
#          'Outdoors': 11,
#          'DOD/Military': 8,
#          'Data Center Automation': 3,
#          'Green Consumer Goods': 2,
#          'Direct Sales': 5,
#          'Transaction Processing': 10,
#          'Rental Housing': 14,
#          'Adventure Travel': 15,
#          'Mobile Health': 43,
#          'Taxis': 7,
#          'English-Speaking': 6,
#          'Data Privacy': 3,
#          'Custom Retail': 2,
#          'Local Coupons': 4,
#          'Energy IT': 5,
#          'CAD': 10,
#          'mHealth': 29,
#          'Mobile Coupons': 11,
#          'Health and Insurance': 21,
#          'Financial Exchanges': 6,
#          'Drones': 12,
#          'EBooks': 4,
#          'Embedded Hardware and Software': 13,
#          'Q&A': 7,
#          'Social Fundraising': 8,
#          'Governance': 1,
#          'Fleet Management': 8,
#          'Collectibles': 13,
#          'Homeless Shelter': 2,
#          'Gold': 2,
#          'Shared Services': 5,
#          'Film Production': 9,
#          'Angels': 8,
#          'Lingerie': 3,
#          'Tobacco': 1,
#          'Natural Resources': 9,
#          'In-Flight Entertainment': 4,
#          'Outdoor Advertising': 2,
#          'Enterprise Security': 6,
#          'BPO Services': 3,
#          'Incubators': 23,
#          'Space Travel': 1,
#          'Enterprise Application': 6,
#          'Home Automation': 63,
#          'Low Bid Auctions': 1,
#          'Enterprise Purchasing': 3,
#          'Home Renovation': 17,
#          'Skate Wear': 1,
#          'Bitcoin': 58,
#          'B2B Express Delivery': 1,
#          'Corporate Wellness': 5,
#          'Bioinformatics': 3,
#          'Bridging Online and Offline': 16,
#          'Field Support Services': 3,
#          'Mob': 1,
#          '3D Technology': 16,
#          'Entertainment Industry': 9,
#          'Government Innovation': 6,
#          'Families': 10,
#          'Real Estate Investors': 6,
#          'Direct Advertising': 1,
#          'Human Resource Automation': 3,
#          'Moneymaking': 1,
#          'Offline Businesses': 10,
#          'Social Travel': 22,
#          'Real': 1,
#          'Designers': 6,
#          'Call Center Automation': 5,
#          'Clinical Trials': 14,
#          'Early-Stage Technology': 1,
#          'Console Gaming': 2,
#          'Gift Registries': 3,
#          'Heavy Industry': 6,
#          'High Tech': 4,
#          'Digital Entertainment': 13,
#          'Home Owners': 3,
#          'Quantified Self': 5,
#          'New Technologies': 3,
#          'Social Innovation': 4,
#          'Registrars': 5,
#          'Consumer Lending': 5,
#          'Eyewear': 4,
#          'Ventures for Good': 3,
#          'Specialty Foods': 26,
#          'Craft Beer': 6,
#          'Material Science': 7,
#          'Water Purification': 7,
#          'Remediation': 2,
#          'Human Computer Interaction': 9,
#          '3D Printing': 16,
#          'College Recruiting': 4,
#          'Public Safety': 5,
#          'Wholesale': 17,
#          'Video Game Tournaments': 1,
#          'Weird Hardware': 1,
#          'Educational Games': 16,
#          'Social Media Agent': 1,
#          'Mobile Analyt': 1,
#          'Pervasive Computing': 2,
#          'Clean Technology IT': 1,
#          'Deep Information Technology': 4,
#          'Casual Games': 2,
#          'Oil & Gas': 11,
#          'Distributors': 5,
#          'Racing': 1,
#          'Music Education': 4,
#          'Insurance Companies': 5,
#          'Animal Feed': 4,
#          'University Students': 2,
#          'Recreation': 3,
#          'Oil and Gas': 4,
#          'Energy Storage': 2,
#          'Fuels': 4,
#          'Edutainment': 1,
#          'Lifestyle Products': 4,
#          'Sex': 3,
#          'Smart Building': 4,
#          'Product Search': 2,
#          'Interior Design': 7,
#          'Face Recognition': 2,
#          'PC Gaming': 3,
#          'Assisitive Technology': 3,
#          'Local Commerce': 4,
#          'Content Summarization': 1,
#          'Self Development': 4,
#          'Debt Collecting': 2,
#          'Textiles': 4,
#          'Bicycles': 4,
#          'Farmers Market': 3,
#          'Medication Adherence': 4,
#          'Operating Systems': 2,
#          'Landsacping': 1,
#          'Diving': 2,
#          'TV Production': 2,
#          'Social News': 4,
#          'Labor Optimization': 1,
#          'Realtors': 4,
#          'Unmanned Air Systems': 1,
#          'Social Investing': 1,
#          'Lotteries': 1,
#          'Virtual Desktop': 1,
#          'Bananas': 1,
#          'Motion Capture': 1,
#          'Internet Technology': 2,
#          'Service Industries': 2,
#          'Rehabilitation': 3,
#          'Video Processing': 3,
#          'Assisted Living': 2,
#          'Child Care': 4,
#          'Boating Industry': 2,
#          'Impact Investing': 2,
#          'Surfing Community': 1,
#          'Cause Marketing': 1,
#          'Enterprise Hardware': 2,
#          'Private School': 2,
#          'Google Glass': 2,
#          'Musicians': 2,
#          'Gift Exchange': 1,
#          'Electric Vehicles': 4,
#          'Retirement': 3,
#          'Building Products': 3,
#          'Fmcg': 1,
#          'Physical Security': 2,
#          'Timeshares': 1,
#          'Parking': 7,
#          'Technical Continuing Education': 1,
#          'Lifestyle Businesses': 1,
#          'Funeral Industry': 1,
#          'Resorts': 2,
#          'Multi-level Marketing': 1,
#          'Optical Communications': 1,
#          'Aquaculture': 1,
#          'Green Advertising': 1,
#          'Social Activists': 1,
#          'Radical Breakthrough Startups': 1,
#          'Temporary Staffing': 1,
#          'Minerals': 1,
#          'Bio-Pharm': 9,
#          'Nutraceutical': 2,
#          'Civil Engineers': 2,
#          'Hunting Industry': 1,
#          'English Speaking Caribbean': 1,
#          'Veterinary': 3,
#          'Building Owners': 1,
#          'Performing Arts': 1,
#          'Film Distribution': 2,
#          'Charities': 1,
#          'Golf Equipment': 1,
#          'Alternative Medicine': 3,
#          'Waste Management': 3,
#          'Biomass Power Generation': 1,
#          'Utility Land Vehicles': 1,
#          'Synthetic Biology': 1,
#          'China Internet': 1,
#          'Musical Instruments': 1,
#          'Vending and Concessions': 1,
#          'Business Travelers': 1,
#          'Personal Data': 1,
#          'Sports Stadiums': 1,
#          'Motors': 1,
#          'Green Building': 1})

# %%
deduped_df

# %%
# Now lets say we want to have a matrix which maps each company to the categories they posses
# This could be very useful for downstream machine learning applications

# This is tricky, but possible! with the power of pivot tables!

# First create a long table
data = []
for index, row in deduped_df.iterrows():
    for category in row['list_of_categories']:
        row_to_append = [row['company_name'], category, 1]
        data.append(row_to_append)

columns=['company', 'category', 'value']

company_category_dataframe = pd.DataFrame(data=data, columns=columns)

# %%
company_category_dataframe.head()
# Out:
#                  company          category  value
# 0  AndrewBurnett.com Ltd          Internet      1
# 1  AndrewBurnett.com Ltd               SEO      1
# 2  AndrewBurnett.com Ltd          Services      1
# 3  AndrewBurnett.com Ltd  Public Relations      1
# 4  AndrewBurnett.com Ltd      Social Media      1

# %%
# Now we can make a pivot table from this!

company_to_category_matrix = pd.pivot_table(data=company_category_dataframe, 
                                           columns='category', 
                                           index='company',
                                           values='value')

# %%
company_to_category_matrix.head()
# Out:
# category           3D  3D Printing  3D Technology  Accounting  \
# company
# #waywire          NaN          NaN            NaN         NaN
# 'Rock' Your Paper NaN          NaN            NaN         NaN
# .Fox Networks     NaN          NaN            NaN         NaN
# 0-6.com           NaN          NaN            NaN         NaN
# 004 Technologies  NaN          NaN            NaN         NaN
#
# category           Active Lifestyle  Ad Targeting  Advanced Materials  \
# company
# #waywire                        NaN           NaN                 NaN
# 'Rock' Your Paper               NaN           NaN                 NaN
# .Fox Networks                   NaN           NaN                 NaN
# 0-6.com                         NaN           NaN                 NaN
# 004 Technologies                NaN           NaN                 NaN
#
# category           Adventure Travel  Advertising  Advertising Exchanges  ...  \
# company                                                                  ...
# #waywire                        NaN          NaN                    NaN  ...
# 'Rock' Your Paper               NaN          NaN                    NaN  ...
# .Fox Networks                   NaN          1.0                    NaN  ...
# 0-6.com                         NaN          NaN                    NaN  ...
# 004 Technologies                NaN          NaN                    NaN  ...
#
# category           Wireless  Women  World Domination  Writers  Young Adults  \
# company
# #waywire                NaN    NaN               NaN      NaN           NaN
# 'Rock' Your Paper       NaN    NaN               NaN      NaN           NaN
# .Fox Networks           NaN    NaN               NaN      NaN           NaN
# 0-6.com                 NaN    NaN               NaN      NaN           NaN
# 004 Technologies        NaN    NaN               NaN      NaN           NaN
#
# category           iOS  iPad  iPhone  iPod Touch  mHealth
# company
# #waywire           NaN   NaN     NaN         NaN      NaN
# 'Rock' Your Paper  NaN   NaN     NaN         NaN      NaN
# .Fox Networks      NaN   NaN     NaN         NaN      NaN
# 0-6.com            NaN   NaN     NaN         NaN      NaN
# 004 Technologies   NaN   NaN     NaN         NaN      NaN
#
# [5 rows x 794 columns]

# %%
# Some asthetics

sns.set_context("talk")

# %% [markdown]
# # Exploratory plots (pandas)
#
# Now let's get into some plotting

# %%
data_frame = sns.load_dataset('iris')

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Describe is helpful in understanding your data

data_frame.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Piviot Tables!
#
# Pivot tables are a very useful tool for generating quick views of what's going on with your data.
#
# They work identically to groupby/aggregration in SQL databases. Here is a poorly formatted list of built in agg functions.
#
#     Function	Description
#     =====================================
#     count	Number of non-NA observations
#     sum	Sum of values
#     mean	Mean of values
#     mad	Mean absolute deviation
#     median	Arithmetic median of values
#     min	Minimum
#     max	Maximum
#     mode	Mode
#     abs	Absolute Value
#     prod	Product of values
#     std	Bessel-corrected sample standard deviation
#     var	Unbiased variance
#     sem	Standard error of the mean
#     skew	Sample skewness (3rd moment)
#     kurt	Sample kurtosis (4th moment)
#     quantile	Sample quantile (value at %)
#     cumsum	Cumulative sum
#     cumprod	Cumulative product
#     cummax	Cumulative maximum
#     cummin	Cumulative minimum

# %%
# We can check to see if we have a balanced data set

pd.pivot_table(data=data_frame, index='species', aggfunc='count')
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
# We can look at the mean values of data

pd.pivot_table(data=data_frame, values=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], 
               index='species', columns=None, 
               aggfunc='mean', fill_value=None, margins=False, 
               dropna=True, margins_name='All')
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa             1.462        0.246         5.006        3.428
# versicolor         4.260        1.326         5.936        2.770
# virginica          5.552        2.026         6.588        2.974

# %%
# We can generate the mean and standard deviation

mean_std_df = pd.pivot_table(data=data_frame, values=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], 
               index='species', columns=None, 
               aggfunc=['mean', 'std'], fill_value=None, margins=False, 
               dropna=True, margins_name='All')
mean_std_df
# Out:
#                    mean                                               std  \
#            petal_length petal_width sepal_length sepal_width petal_length
# species
# setosa            1.462       0.246        5.006       3.428     0.173664
# versicolor        4.260       1.326        5.936       2.770     0.469911
# virginica         5.552       2.026        6.588       2.974     0.551895
#
#
#            petal_width sepal_length sepal_width
# species
# setosa        0.105386     0.352490    0.379064
# versicolor    0.197753     0.516171    0.313798
# virginica     0.274650     0.635880    0.322497

# %%
# Indexing into hierarchical columns
# We can isolate the data we want

mean_std_df['mean']
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa             1.462        0.246         5.006        3.428
# versicolor         4.260        1.326         5.936        2.770
# virginica          5.552        2.026         6.588        2.974

# %% [markdown]
# ## Plotting with pandas
#
# Pandas is designed to plot **structured dataframes**. Meaning things that look like piviot tables.

# %%
mean_std_df['mean'].plot(kind='bar')

# %%
mean_std_df['mean'].plot(kind='bar', yerr=mean_std_df['std'])

# %%
mean_std_df['mean'].boxplot()

# %% [markdown]
# # Plotting with seaborn
#
# Seaborn is a statistical plotting package that is designed to plot **LONG dataframes**. Meaning that you only have one numerical value per row.
#
# Do your columns look very redundant? If so they are probably long.

# %% [markdown]
# Seaborn natively can make some very impressive summary images

# %%
sns.set_context('talk')

# %%
sns.pairplot(data=data_frame, hue="species")

# %% [markdown]
# Trying to replicate the bar plots from above

# %%
data_frame.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.barplot(x='species', y='petal_width', data=data_frame)

# %%
sns.barplot(x='petal_width', y='species', data=data_frame)

# %% [markdown]
# If we want to create the above data with the way the data_frame is currently structured we need to build it with a foor loop.

# %%
# Making functions using for loops

fig, ax = plt.subplots(ncols=4, nrows=1, sharey=True, sharex=True, figsize=(16, 4))

for fig_ind, category in enumerate(['sepal_length', 'sepal_width', 'petal_length', 'petal_width']):
    sns.barplot(x='species', y=category,
                data=data_frame, ax=ax[fig_ind])
    ax[fig_ind].set_title(category)
    ax[fig_ind].set_ylabel('')
    ax[fig_ind].set_xticklabels(ax[fig_ind].get_xticklabels(), rotation=30)

# %% [markdown]
# Let's say we want to do this without using a for loop....
#
# We need to mamke our data **even longer!**

# %%
melted_data_frame = data_frame.melt(id_vars='species')

# %%
melted_data_frame.head()
# Out:
#   species      variable  value
# 0  setosa  sepal_length    5.1
# 1  setosa  sepal_length    4.9
# 2  setosa  sepal_length    4.7
# 3  setosa  sepal_length    4.6
# 4  setosa  sepal_length    5.0

# %%
sns.barplot(x='species', y='value', hue='variable', data=melted_data_frame)

# %%
sns.boxplot(x='species', y='value', hue='variable', data=melted_data_frame)

# %%
sns.violinplot(x='species', y='value', hue='variable', data=melted_data_frame)

# %%
sns.swarmplot(x='species', y='value', hue='variable', data=melted_data_frame)

# %%
sns.boxenplot(x='species', y='value', hue='variable', data=melted_data_frame)

# %%
ax = sns.boxenplot(x='value', y='species', hue='variable', data=melted_data_frame)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Looking at dense scatters? Use kde plots.

# %%
# Alpha controls the opacity of a point

data_frame.plot(x='sepal_length', y='petal_width', kind='scatter', alpha=0.2)

# %%
sns.kdeplot(data=data_frame[['sepal_length', 'petal_width']], shade_lowest=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
ax = data_frame.plot(x='sepal_length', y='petal_width', kind='scatter', alpha=1, c='k')
sns.kdeplot(data=data_frame[['sepal_length', 'petal_width']], shade_lowest=True, ax=ax)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %% [markdown]
# # Summary plots using both pandas and seaborn

# %% [markdown]
# ## Coorlation plots

# %%
# You can generate a coorelation matrix using pandas

data_frame.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(data_frame.corr(), annot=True, cmap="YlGnBu", cbar=False)

# %%
sns.clustermap(data_frame.corr(), annot=True, cmap="YlGnBu")

# %% [markdown]
# # A quick look at timeseries data

# %%
# We can look at how these things change over time

deduped_df.plot(x='funded_at', y='money_raised')

# %%
deduped_df.plot(x='funded_at', y='money_raised', logy=True)

# %%
# We can do fancy averaging things with seaborn 
# IF we cluster the data together in time
# We are going to do this on a monthly basis

deduped_df['mock_funded_month'] = pd.to_datetime(deduped_df.funded_month)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
ax = sns.lineplot(data=deduped_df, x='mock_funded_month', y='money_raised')
ax.set_yscale('log')

# %%
ax = sns.lineplot(data=deduped_df, x='mock_funded_month', y='money_raised', hue='funding_round_code')
ax.set_yscale('log')

# %%
# let's try using year

ax = sns.lineplot(data=deduped_df, x='funded_year', y='money_raised', hue='funding_round_code')
ax.set_yscale('log')
